# %% [markdown]
# ### Imports

# %%
if "running_pipeline" not in globals():
    print("Running imports...")
    # %run "C:\Users\james\Documents\MLB\Code\U1. Imports.ipynb"
    # %run "C:\Users\james\Documents\MLB\Code\U2. Utilities.ipynb"
    # %run "C:\Users\james\Documents\MLB\Code\U3. Classes.ipynb"
    print("Imports in.")
else:
    print("Imports already in.")
# Out:
# Running imports...
# Imports in.

# %% [markdown]
# ### Games

# %%
if "running_pipeline" not in globals():
    all_game_df = read_and_save_games(team_map, generate=True)
    game_df = all_game_df[(all_game_df['date'] >= todaysdate) & (all_game_df['date'] <= todaysdate)].reset_index(drop=True)

# %% [markdown]
# ### Settings

# %%
running_pipeline = True

# %% [markdown]
# ### 004. Bullpens

# %%
print("Parameters:")
print("game_df")
# Out:
# Parameters:
# game_df

# %%
# %run "C:\Users\james\Documents\MLB\Code\004. Bullpens.ipynb"
# Out:
# Imports already in.
# game_df already generated.
# CPU times: total: 0 ns
# Wall time: 53.9 s

# %% [markdown]
# ### 005. Rosters

# %%
print("Parameters:")
print("game_df")
# Out:
# Parameters:
# game_df

# %%
# %run "005. Rosters.ipynb"
# Out:
# Imports already in.
# game_df already generated.

# %% [markdown]
# ### 006. Weather

# %%
print("Parameters:")
print(f"todaysdate: {todaysdate}")
# Out:
# Parameters:
# todaysdate: 20240817

# %%
# %run "C:\Users\james\Documents\MLB\Code\006. Weather.ipynb"

# %% [markdown]
# ### 007. Projections

# %%
scrape_slates = True

# %%
print("Parameters:")
print(f"todaysdate: {todaysdate}")
print(f"scrape_slates: {scrape_slates}")
# Out:
# Parameters:
# todaysdate: 20240920
# scrape_slates: True

# %%
# %run "C:\Users\james\Documents\MLB\Code\007. Projections.ipynb"
# Out:
# Imports already in.
# Scraping slates: True

# %% [markdown]
# ### 006B. Park and Weather Factors.ipynb

# %%
train = False

start_year = 2013
end_year = 2024
short = 50
long = 300
adjust = False    
park_window = 10000
park_window_min = 5000
league_window = 60000
league_window_min = 60000
base_year = 2014

historic = False
run_multiplier_dataset = False

# %%
print("Parameters:")
print("game_df")

print(f"train: {train}")
print(f"start_year: {start_year}")
print(f"end_year: {end_year}")
print(f"short: {short}")
print(f"long: {long}")
print(f"adjust: {adjust}")
print(f"park_window: {park_window}")
print(f"park_window_min: {park_window_min}")
print(f"league_window: {league_window}")
print(f"league_window_min: {league_window_min}")
print(f"base_year: {base_year}")

print(f"historic: {historic}")
print(f"run_multiplier_dataset: {run_multiplier_dataset}")
# Out:
# Parameters:
# game_df
# train: False
# start_year: 2013
# end_year: 2024
# short: 50
# long: 300
# adjust: False
# park_window: 10000
# park_window_min: 5000
# league_window: 60000
# league_window_min: 60000
# base_year: 2014
# historic: False
# run_multiplier_dataset: False

# %%
# %run "C:\Users\james\Documents\MLB\Code\006B. Park and Weather Factors.ipynb"
# Out:
# Imports already in.
# game_df already generated.
# 20240920
# CHW@SDP uses Swish Analytics weather.

# %% [markdown]
# ### 008. Odds Sportsbook Review

# %%
date = todaysdate
date_dash = todaysdate_dash

# %%
print("Parameters:")
print("game_df")
print(f"date: {date}")
print(f"date_dash: {date_dash}")
# Out:
# Parameters:
# game_df
# date: 20240920
# date_dash: 2024-09-20

# %%
# %run "C:\Users\james\Documents\MLB\Code\008. Odds Sportsbook Review.ipynb"
# Out:
# Imports already in.
# game_df already generated.

# %% [markdown]
# ### 009. Contest Guides

# %%
date = todaysdate

# %%
print("Parameters:")
print("game_df")
print(f"date: {date}")
# Out:
# Parameters:
# game_df
# date: 20240920

# %%
# %run "C:\Users\james\Documents\MLB\Code\009. Contest Guides.ipynb"
# Out:
# Imports already in.
# game_df already generated.
# 167380594
# 167380596
# 167380593
# 167380599
# 167380589
# 167380582
# 167380584
# 167380579
# 167376937
# 167377552
# 167380528
# 167380527
# 167380529
# 167380532
# 167380531
# 167380514
# 167380519
# 167380516
# 167380517
# 167376844
# 167380576
# 167380585

# %% [markdown]
# ### 011. Matchups

# %%
write_complete_dataset = False

# %%
print("Parameters:")
print("game_df")
print(f"write_complete_dataset: {write_complete_dataset}")
# Out:
# Parameters:
# game_df
# write_complete_dataset: False

# %%
# %run "C:\Users\james\Documents\MLB\Code\011. Matchups.ipynb"
# Out:
# Imports already in.
# game_df already generated.
# CPU times: total: 20.3 s
# Wall time: 20.6 s
# 15
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:   18.7s finished
# CPU times: total: 4.56 s
# Wall time: 19.2 s
