# %% [markdown]
# # M03. Predict PAs
# - This predicts the outcome of plate appearances
# - Type: Model
# - Run Frequency: Irregular
# - Sources:
#     - MLB API
#     - Steamer
# - Created: 4/19/2024
# - Updated: 6/4/2025

# %% [markdown]
# Consider:
# - imputed starter, imputed reliever, unimputed starter, unimputed reliever variables
# - b1_wfx x Coors, b2_wfx x Coors, hr_wfx x Coors

# %% [markdown]
# ### Imports

# %%
# %run "U1. Imports.ipynb"
# %run "U2. Functions.ipynb"
# %run "U3. Classes.ipynb"
# %run "U4. Datasets.ipynb"
# %run "U5. Models.ipynb"

# %%
# Set option to display numbers without scientific notation
pd.set_option('display.float_format', '{:.6f}'.format)

# %% [markdown]
# ### Data

# %% [markdown]
# ##### Park x Weather Factors

# %%
multiplier_df = pd.read_csv(os.path.join(baseball_path, "Park and Weather Factors.csv"))

# %% [markdown]
# Choose WFX
# - _unadj: predicted based on weather / predicted based on batted ball <br>
# - _adj: average of actual rates in similarly predicted games / predicted based on batted ball

# %%
wfx_type = 'adj'
for event in events_list:
    multiplier_df[f'{event}_wfx_l'] = multiplier_df[f'{event}_wfx_{wfx_type}_l'].copy()
    multiplier_df[f'{event}_wfx_r'] = multiplier_df[f'{event}_wfx_{wfx_type}_r'].copy()

# %% [markdown]
# ##### Plate Appearances

# %%
complete_dataset = pd.read_csv(os.path.join(baseball_path, "Final Dataset.csv"))

# %% [markdown]
# ##### Steamer

# %%
steamer_hitters_df = pd.read_csv(os.path.join(baseball_path, "A03. Steamer", "steamer_hitters_weekly_log.csv"), encoding='iso-8859-1')

# %%
steamer_pitchers_df = pd.read_csv(os.path.join(baseball_path, "A03. Steamer", "steamer_pitchers_weekly_log.csv"), encoding='iso-8859-1')

# %% [markdown]
# ### Clean

# %% [markdown]
# ##### MLB Stats API

# %%
complete_dataset = complete_dataset[~complete_dataset[batter_inputs].isin([np.inf, -np.inf]).any(axis=1)]
complete_dataset = complete_dataset[~complete_dataset[pitcher_inputs].isin([np.inf, -np.inf]).any(axis=1)]

# %%
# %%time
complete_dataset[batter_inputs] = scale_batter_stats.transform(complete_dataset[batter_inputs])
complete_dataset[pitcher_inputs] = scale_pitcher_stats.transform(complete_dataset[pitcher_inputs])
# Out:
# CPU times: total: 1.73 s
# Wall time: 1.75 s

# %% [markdown]
# ##### Steamer

# %% [markdown]
# Clean

# %%
steamer_hitters_df2 = clean_steamer_hitters(steamer_hitters_df)
steamer_hitters_df2.dropna(subset=batter_stats_fg, inplace=True)

# %% [markdown]
# Scale

# %%
steamer_hitters_df2[batter_stats_fg] = scale_batter_stats_steamer.transform(steamer_hitters_df2[batter_stats_fg])

# %% [markdown]
# Read in pitchers

# %% [markdown]
# Clean

# %%
steamer_pitchers_df2 = clean_steamer_pitchers(steamer_pitchers_df)
steamer_pitchers_df2.dropna(subset=pitcher_stats_fg2, inplace=True)

# %% [markdown]
# Scale

# %%
steamer_pitchers_df2[pitcher_stats_fg] = scale_pitcher_stats_steamer.transform(steamer_pitchers_df2[pitcher_stats_fg])

# %% [markdown]
# ##### Merge

# %% [markdown]
# Format dates

# %%
complete_dataset['date_time'] = pd.to_datetime(complete_dataset['date'], format='%Y%m%d')
complete_dataset['date_time_copy'] = complete_dataset['date_time'].copy()
steamer_hitters_df2['date_time'] = pd.to_datetime(steamer_hitters_df2['date'], format='%Y%m%d')
steamer_pitchers_df2['date_time'] = pd.to_datetime(steamer_pitchers_df2['date'], format='%Y%m%d')

steamer_hitters_df2.rename(columns={'mlbamid': 'batter'}, inplace=True)
steamer_pitchers_df2.rename(columns={'mlbamid': 'pitcher'}, inplace=True)

# %% [markdown]
# Sort to prep for merge

# %%
complete_dataset.sort_values('date_time', inplace=True)
steamer_hitters_df2.sort_values('date_time', inplace=True)
steamer_pitchers_df2.sort_values('date_time', inplace=True)

# %% [markdown]
# Drop unnecessary columns

# %%
steamer_hitters_df2.drop(columns=['date', 'firstname', 'lastname', 'steamerid'], inplace=True)
steamer_pitchers_df2.drop(columns=['date', 'firstname', 'lastname', 'steamerid'], inplace=True)

# %% [markdown]
# Remove missing pitchers (occurs occassionally in 2014)

# %%
steamer_pitchers_df2 = steamer_pitchers_df2[~steamer_pitchers_df2['pitcher'].isna()].reset_index(drop=True)

# %% [markdown]
# Set data types

# %%
complete_dataset['batter'] = complete_dataset['batter'].astype(int).astype(str)
complete_dataset['pitcher'] = complete_dataset['pitcher'].astype(int).astype(str)
steamer_hitters_df2['batter'] = steamer_hitters_df2['batter'].astype(int).astype(str)
steamer_pitchers_df2['pitcher'] = steamer_pitchers_df2['pitcher'].astype(int).astype(str)

# %% [markdown]
# Merge asof most recent date in Steamer

# %%
complete_merged_df = pd.merge_asof(
    complete_dataset,
    steamer_hitters_df2,
    on='date_time',
    by='batter',  # Group by 'batter'
    direction='backward'  # Use 'backward', 'forward', or 'nearest' as appropriate
)
# Correct datetime (might be unnecessary, but I'm not sure which date_time it takes after the merge)
complete_merged_df['date_time'] = complete_merged_df['date_time_copy'].copy()

complete_merged_df = pd.merge_asof(
    complete_merged_df,
    steamer_pitchers_df2,
    on='date_time',
    by='pitcher',  # Group by 'batter'
    direction='backward'  # Use 'backward', 'forward', or 'nearest' as appropriate
)

# %% [markdown]
# Merge WFX

# %%
complete_merged_df = pd.merge(complete_merged_df, multiplier_df, on=['gamePk', 'date', 'venue_id'], how='left')

# %%
multiplier_df.head()
# Out:
#    venue_id  gamePk      date  b1_wfx_unadj_l  b2_wfx_unadj_l  b3_wfx_unadj_l  \
# 0        12  529406  20180329        1.062281        1.020507        0.848780
# 1      4169  529407  20180329        1.056724        0.977328        0.947824
# 2         7  529408  20180329        1.149103        0.987938        1.178290
# 3       680  529409  20180329        1.001485        0.934016        0.776826
# 4        15  529410  20180329        1.027769        1.017541        1.021615
#
#    hr_wfx_unadj_l  bb_wfx_unadj_l  hbp_wfx_unadj_l  so_wfx_unadj_l  \
# 0        1.096988        0.967057         0.931696        1.009747
# 1        0.886396        0.960825         1.011342        0.996969
# 2        0.553328        1.024037         0.853930        0.970074
# 3        1.024584        0.973359         1.176910        0.993606
# 4        1.044376        0.935188         1.048478        1.017710
#
#    fo_wfx_unadj_l  go_wfx_unadj_l  lo_wfx_unadj_l  po_wfx_unadj_l  \
# 0        0.946605        0.961679        1.029211        1.068196
# 1        1.004928        0.964997        1.052094        1.108025
# 2        1.043993        0.897146        1.118214        1.219417
# 3        1.020191        0.977160        1.048922        1.092359
# 4        1.014303        0.973249        1.025070        0.950526
#
#    b1_wfx_adj_l  b2_wfx_adj_l  b3_wfx_adj_l  hr_wfx_adj_l  bb_wfx_adj_l  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1      0.000000      1.047874     11.299180      0.000000      1.598916
# 2      0.119888      1.292378      9.792623      1.597886      1.385727
# 3      0.356588      1.452694      6.528415      1.474971      1.224469
# 4      0.451884      1.237297      4.896311      1.106229      1.068677
#
#    hbp_wfx_adj_l  so_wfx_adj_l  fo_wfx_adj_l  go_wfx_adj_l  lo_wfx_adj_l  \
# 0            NaN           NaN           NaN           NaN           NaN
# 1       0.000000      0.400954      0.356211      1.802714      1.573803
# 2       3.021935      0.641526      0.569938      1.268576      1.075432
# 3       2.014623      0.540773      0.681369      1.297680      1.382794
# 4       2.092109      0.744849      0.711966      1.255736      1.259042
#
#    po_wfx_adj_l  b1_wfx_unadj_r  b2_wfx_unadj_r  b3_wfx_unadj_r  \
# 0           NaN        1.048496        0.940945        0.763121
# 1      2.905000        1.053015        0.983331        0.843660
# 2      2.517667        1.079502        0.955478        1.064442
# 3      2.224684        0.997784        0.897939        0.710931
# 4      2.078192        1.009905        0.993709        0.872539
#
#    hr_wfx_unadj_r  bb_wfx_unadj_r  hbp_wfx_unadj_r  so_wfx_unadj_r  \
# 0        1.064729        0.975018         0.844502        1.014702
# 1        0.874256        0.977942         1.259712        0.999625
# 2        0.612305        1.009985         1.213291        0.966247
# 3        0.927285        0.986081         1.266165        0.989930
# 4        1.057157        0.935405         1.235137        1.020880
#
#    fo_wfx_unadj_r  go_wfx_unadj_r  lo_wfx_unadj_r  po_wfx_unadj_r  \
# 0        0.958782        0.977224        1.042642        1.068694
# 1        1.025771        0.945378        1.068183        1.046580
# 2        1.011751        0.938412        1.153579        1.230186
# 3        1.027722        0.989095        1.062025        1.086539
# 4        0.992268        0.993545        1.022956        0.934532
#
#    b1_wfx_adj_r  b2_wfx_adj_r  b3_wfx_adj_r  hr_wfx_adj_r  bb_wfx_adj_r  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1      0.749297      1.921102      0.000000      0.665786      1.465673
# 2      0.815052      1.901499      0.000000      0.332893      1.690010
# 3      0.823105      1.779960      0.000000      1.287186      1.582660
# 4      0.917048      1.575108      0.000000      1.298282      1.309135
#
#    hbp_wfx_adj_r  so_wfx_adj_r  fo_wfx_adj_r  go_wfx_adj_r  lo_wfx_adj_r  \
# 0            NaN           NaN           NaN           NaN           NaN
# 1       0.000000      1.378278      0.489791      0.826244      1.081990
# 2       1.850164      1.139189      0.564759      0.772847      1.070949
# 3       2.240755      0.930979      0.768338      0.809007      1.194850
# 4       2.624921      0.882004      0.739517      0.973975      1.076469
#
#    po_wfx_adj_r  b1_pred_weather_l  b2_pred_weather_l  b3_pred_weather_l  \
# 0           NaN           0.147677           0.044267           0.003414
# 1      0.887639           0.146905           0.042394           0.003813
# 2      1.313343           0.159747           0.042855           0.004740
# 3      0.993914           0.139226           0.040516           0.003125
# 4      0.967345           0.142880           0.044139           0.004110
#
#    hr_pred_weather_l  bb_pred_weather_l  hbp_pred_weather_l  \
# 0           0.034326           0.082476            0.010277
# 1           0.027737           0.081944            0.011156
# 2           0.017314           0.087335            0.009419
# 3           0.032061           0.083013            0.012982
# 4           0.032680           0.079758            0.011565
#
#    so_pred_weather_l  fo_pred_weather_l  go_pred_weather_l  lo_pred_weather_l  \
# 0           0.228942           0.120792           0.218234           0.059451
# 1           0.226045           0.128234           0.218987           0.060773
# 2           0.219947           0.133219           0.203590           0.064592
# 3           0.225282           0.130182           0.221747           0.060590
# 4           0.230748           0.129431           0.220860           0.059212
#
#    po_pred_weather_l  b1_pred_batted_l  b2_pred_batted_l  b3_pred_batted_l  \
# 0           0.050142          0.139019          0.043378          0.004023
# 1           0.052012          0.139019          0.043378          0.004023
# 2           0.057241          0.139019          0.043378          0.004023
# 3           0.051276          0.139019          0.043378          0.004023
# 4           0.044619          0.139019          0.043378          0.004023
#
#    hr_pred_batted_l  bb_pred_batted_l  hbp_pred_batted_l  so_pred_batted_l  \
# 0          0.031291          0.085285           0.011030          0.226732
# 1          0.031291          0.085285           0.011030          0.226732
# 2          0.031291          0.085285           0.011030          0.226732
# 3          0.031291          0.085285           0.011030          0.226732
# 4          0.031291          0.085285           0.011030          0.226732
#
#    fo_pred_batted_l  go_pred_batted_l  lo_pred_batted_l  po_pred_batted_l  \
# 0          0.127606          0.226931          0.057764          0.046941
# 1          0.127606          0.226931          0.057764          0.046941
# 2          0.127606          0.226931          0.057764          0.046941
# 3          0.127606          0.226931          0.057764          0.046941
# 4          0.127606          0.226931          0.057764          0.046941
#
#    b1_pred_batted_mean_l  b2_pred_batted_mean_l  b3_pred_batted_mean_l  \
# 0                    NaN                    NaN                    NaN
# 1               0.139019               0.043378               0.004023
# 2               0.139019               0.043378               0.004023
# 3               0.139019               0.043378               0.004023
# 4               0.139019               0.043378               0.004023
#
#    hr_pred_batted_mean_l  bb_pred_batted_mean_l  hbp_pred_batted_mean_l  \
# 0                    NaN                    NaN                     NaN
# 1               0.031291               0.085285                0.011030
# 2               0.031291               0.085285                0.011030
# 3               0.031291               0.085285                0.011030
# 4               0.031291               0.085285                0.011030
#
#    so_pred_batted_mean_l  fo_pred_batted_mean_l  go_pred_batted_mean_l  \
# 0                    NaN                    NaN                    NaN
# 1               0.226732               0.127606               0.226931
# 2               0.226732               0.127606               0.226931
# 3               0.226732               0.127606               0.226931
# 4               0.226732               0.127606               0.226931
#
#    lo_pred_batted_mean_l  po_pred_batted_mean_l  b1_pred_weather_r  \
# 0                    NaN                    NaN           0.145761
# 1               0.057764               0.046941           0.146389
# 2               0.057764               0.046941           0.150071
# 3               0.057764               0.046941           0.138711
# 4               0.057764               0.046941           0.140396
#
#    b2_pred_weather_r  b3_pred_weather_r  hr_pred_weather_r  bb_pred_weather_r  \
# 0           0.040816           0.003070           0.033317           0.083155
# 1           0.042655           0.003394           0.027357           0.083404
# 2           0.041447           0.004282           0.019160           0.086137
# 3           0.038951           0.002860           0.029016           0.084098
# 4           0.043105           0.003510           0.033080           0.079776
#
#    hbp_pred_weather_r  so_pred_weather_r  fo_pred_weather_r  \
# 0            0.009315           0.230066           0.122346
# 1            0.013895           0.226647           0.130894
# 2            0.013383           0.219079           0.129105
# 3            0.013966           0.224449           0.131143
# 4            0.013624           0.231466           0.126619
#
#    go_pred_weather_r  lo_pred_weather_r  po_pred_weather_r  b1_pred_batted_r  \
# 0           0.221762           0.060227           0.050166          0.139019
# 1           0.214535           0.061702           0.049128          0.139019
# 2           0.212954           0.066635           0.057746          0.139019
# 3           0.224456           0.061347           0.051003          0.139019
# 4           0.225466           0.059090           0.043868          0.139019
#
#    b2_pred_batted_r  b3_pred_batted_r  hr_pred_batted_r  bb_pred_batted_r  \
# 0          0.043378          0.004023          0.031291          0.085285
# 1          0.043378          0.004023          0.031291          0.085285
# 2          0.043378          0.004023          0.031291          0.085285
# 3          0.043378          0.004023          0.031291          0.085285
# 4          0.043378          0.004023          0.031291          0.085285
#
#    hbp_pred_batted_r  so_pred_batted_r  fo_pred_batted_r  go_pred_batted_r  \
# 0           0.011030          0.226732          0.127606          0.226931
# 1           0.011030          0.226732          0.127606          0.226931
# 2           0.011030          0.226732          0.127606          0.226931
# 3           0.011030          0.226732          0.127606          0.226931
# 4           0.011030          0.226732          0.127606          0.226931
#
#    lo_pred_batted_r  po_pred_batted_r  b1_pred_batted_mean_r  \
# 0          0.057764          0.046941                    NaN
# 1          0.057764          0.046941               0.139019
# 2          0.057764          0.046941               0.139019
# 3          0.057764          0.046941               0.139019
# 4          0.057764          0.046941               0.139019
#
#    b2_pred_batted_mean_r  b3_pred_batted_mean_r  hr_pred_batted_mean_r  \
# 0                    NaN                    NaN                    NaN
# 1               0.043378               0.004023               0.031291
# 2               0.043378               0.004023               0.031291
# 3               0.043378               0.004023               0.031291
# 4               0.043378               0.004023               0.031291
#
#    bb_pred_batted_mean_r  hbp_pred_batted_mean_r  so_pred_batted_mean_r  \
# 0                    NaN                     NaN                    NaN
# 1               0.085285                0.011030               0.226732
# 2               0.085285                0.011030               0.226732
# 3               0.085285                0.011030               0.226732
# 4               0.085285                0.011030               0.226732
#
#    fo_pred_batted_mean_r  go_pred_batted_mean_r  lo_pred_batted_mean_r  \
# 0                    NaN                    NaN                    NaN
# 1               0.127606               0.226931               0.057764
# 2               0.127606               0.226931               0.057764
# 3               0.127606               0.226931               0.057764
# 4               0.127606               0.226931               0.057764
#
#    po_pred_batted_mean_r     b1_l     b2_l     b3_l     hr_l     bb_l  \
# 0                    NaN 0.000000 0.045455 0.045455 0.000000 0.136364
# 1               0.046941 0.033333 0.066667 0.033333 0.100000 0.100000
# 2               0.046941 0.115385 0.076923 0.000000 0.038462 0.076923
# 3               0.046941 0.102564 0.025641 0.000000 0.000000 0.051282
# 4               0.046941 0.216216 0.027027 0.027027 0.000000 0.081081
#
#      hbp_l     so_l     fo_l     go_l     lo_l     po_l     b1_r     b2_r  \
# 0 0.000000 0.090909 0.045455 0.409091 0.090909 0.136364 0.104167 0.083333
# 1 0.066667 0.200000 0.100000 0.166667 0.033333 0.100000 0.122449 0.081633
# 2 0.000000 0.076923 0.115385 0.307692 0.115385 0.076923 0.116667 0.066667
# 3 0.025641 0.307692 0.102564 0.256410 0.051282 0.076923 0.166667 0.041667
# 4 0.000000 0.270270 0.081081 0.297297 0.000000 0.000000 0.216216 0.027027
#
#       b3_r     hr_r     bb_r    hbp_r     so_r     fo_r     go_r     lo_r  \
# 0 0.000000 0.020833 0.125000 0.000000 0.312500 0.062500 0.187500 0.062500
# 1 0.000000 0.000000 0.163265 0.040816 0.204082 0.081633 0.163265 0.061224
# 2 0.000000 0.100000 0.116667 0.033333 0.116667 0.150000 0.200000 0.083333
# 3 0.000000 0.041667 0.041667 0.041667 0.166667 0.083333 0.333333 0.041667
# 4 0.000000 0.054054 0.135135 0.000000 0.297297 0.081081 0.135135 0.054054
#
#       po_r  b1_wfx_l  b1_wfx_r  b2_wfx_l  b2_wfx_r  b3_wfx_l  b3_wfx_r  \
# 0 0.041667       NaN       NaN       NaN       NaN       NaN       NaN
# 1 0.081633  0.000000  0.749297  1.047874  1.921102 11.299180  0.000000
# 2 0.016667  0.119888  0.815052  1.292378  1.901499  9.792623  0.000000
# 3 0.041667  0.356588  0.823105  1.452694  1.779960  6.528415  0.000000
# 4 0.000000  0.451884  0.917048  1.237297  1.575108  4.896311  0.000000
#
#    hr_wfx_l  hr_wfx_r  bb_wfx_l  bb_wfx_r  hbp_wfx_l  hbp_wfx_r  so_wfx_l  \
# 0       NaN       NaN       NaN       NaN        NaN        NaN       NaN
# 1  0.000000  0.665786  1.598916  1.465673   0.000000   0.000000  0.400954
# 2  1.597886  0.332893  1.385727  1.690010   3.021935   1.850164  0.641526
# 3  1.474971  1.287186  1.224469  1.582660   2.014623   2.240755  0.540773
# 4  1.106229  1.298282  1.068677  1.309135   2.092109   2.624921  0.744849
#
#    so_wfx_r  fo_wfx_l  fo_wfx_r  go_wfx_l  go_wfx_r  lo_wfx_l  lo_wfx_r  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1  1.378278  0.356211  0.489791  1.802714  0.826244  1.573803  1.081990
# 2  1.139189  0.569938  0.564759  1.268576  0.772847  1.075432  1.070949
# 3  0.930979  0.681369  0.768338  1.297680  0.809007  1.382794  1.194850
# 4  0.882004  0.711966  0.739517  1.255736  0.973975  1.259042  1.076469
#
#    po_wfx_l  po_wfx_r
# 0       NaN       NaN
# 1  2.905000  0.887639
# 2  2.517667  1.313343
# 3  2.224684  0.993914
# 4  2.078192  0.967345

# %% [markdown]
# ##### Impute

# %% [markdown]
# For players with insufficient sample sizes, stats are imputed

# %% [markdown]
# Option 1: Steamer

# %% [markdown]
# First, remove from dataset if ever missing FG/Steamer stats

# %%
complete_merged_df = complete_merged_df[~complete_merged_df['b1_rate'].isna()]
complete_merged_df = complete_merged_df[~complete_merged_df['H9'].isna()]

# %%
# Add hands to use in imputation
batter_stats_fg_imp = batter_stats_fg + ['b_L', 'p_L', 'imp_b']
pitcher_stats_fg_imp = pitcher_stats_fg + ['b_L', 'p_L', 'imp_p']

### Batters
# Use Steamer stats to predict API/Statcast stats for those with limited samples
batter_predictions = impute_batter_stats.predict(complete_merged_df.loc[complete_merged_df['pa_b'] < 40, batter_stats_fg_imp])

# Impute inputs with limited sample size with predicted values
complete_merged_df.loc[complete_merged_df['pa_b'] < 40, batter_inputs] = batter_predictions

### Pitchers
# Use Steamer stats to predict API/Statcast stats for those with limited samples
pitcher_predictions = impute_pitcher_stats.predict(complete_merged_df.loc[complete_merged_df['pa_p'] < 40, pitcher_stats_fg_imp])

# Impute inputs with limited sample size with predicted values
complete_merged_df.loc[complete_merged_df['pa_p'] < 40, pitcher_inputs] = pitcher_predictions

# %% [markdown]
# Option 2: 0s

# %%
# # Testing instead of imputing, just weighting with 0s
# complete_merged_df[batter_inputs].fillna(0, inplace=True)
# complete_merged_df[pitcher_inputs].fillna(0, inplace=True)

# # Calculate the weighted average for each column in pitcher_stats
# # Could be simplified, but I wanted to show the steps
# # Weighted average of provided value and 0. PAs and 50-PAs are weights. 
# for col in batter_inputs:
#     complete_merged_df[col] = (complete_merged_df[col] * complete_merged_df['pa_b'] + 0 * (50-complete_merged_df['pa_b']))/50

# # Calculate the weighted average for each column in pitcher_stats
# for col in pitcher_inputs:
#     complete_merged_df[col] = (complete_merged_df[col] * complete_merged_df['pa_p'] + 0 * (50-complete_merged_df['pa_p']))/50

# %% [markdown]
# ### Select Data

# %% [markdown]
# Drop early observations

# %%
complete_merged_df = complete_merged_df[complete_merged_df['game_date'] > '2015-07-01']

# %% [markdown]
# Drop atypical events

# %%
complete_merged_df = complete_merged_df.query('eventsModel != "Cut"')

# %% [markdown]
# Drop observations from inactive parks

# %%
active_parks = list(team_map['VENUE_ID'].astype(int))
complete_merged_df = complete_merged_df[complete_merged_df['venue_id'].astype(int).isin(active_parks)]

# %% [markdown]
# ### Select Variables

# %% [markdown]
# Batter Inputs

# %%
batter_input_list = batter_inputs

# %% [markdown]
# Pitcher Inputs

# %%
pitcher_input_list = pitcher_inputs

# %% [markdown]
# Hand Inputs

# %%
hand_input_list = ['p_L', 'b_L']

# %% [markdown]
# Imputation Inputs

# %%
imp_input_list = ['imp_b', 'imp_p']

# %% [markdown]
# Starter Input(s)

# %%
starter_input_list = ['starter']

# %% [markdown]
# Cumulative Inning Inputs

# %%
cumulative_inning_input_list = [col for col in complete_merged_df.columns if col.endswith("_inning")]

# %%
cumulative_inning_input_list.remove('rbi_inning')

# %% [markdown]
# Cumulative Game Inputs

# %%
cumulative_game_input_list = [col for col in complete_merged_df.columns if col.endswith("_game")]

# %%
cumulative_game_input_list.remove('rbi_game')

# %% [markdown]
# Game State Inputs

# %%
complete_merged_df['winning'] = (complete_merged_df['preBatterScore'] > complete_merged_df['prePitcherScore']).astype(int)
complete_merged_df['winning_big'] = (complete_merged_df['preBatterScore'] > complete_merged_df['prePitcherScore'] + 3).astype(int)

# %%
game_state_input_list = ['onFirst', 'onSecond', 'onThird', 'top', 'score_diff', 'prePitcherScore', 'preBatterScore', 'winning', 'winning_big', 'times_faced']

# %% [markdown]
# Inning Inputs

# %%
for inning in range(1, 12):
    complete_merged_df[f'inning_{inning}'] = (complete_merged_df['inning'] == inning).astype(int)
complete_merged_df['inning_11'] = (complete_merged_df['inning'] >= 11).astype(int)

# %%
inning_input_list = [col for col in complete_merged_df.columns if col.startswith("inning_")]

# %% [markdown]
# Out Inputs

# %%
for out in range(0, 3):
    complete_merged_df[f'outs_{out}'] = (complete_merged_df['outs_pre'] == out).astype(int)

# %%
out_input_list = ['outs_0', 'outs_1', 'outs_2']

# %% [markdown]
# Venue Inputs

# %%
complete_merged_df['venue_id2'] = complete_merged_df['venue_id'].copy()
complete_merged_df = pd.get_dummies(complete_merged_df, columns=['venue_id2'], prefix='venue')

# %%
venue_input_list = [col for col in complete_merged_df.columns if col.startswith("venue_") and col != "venue_id" and col != "venue_name"]

# %% [markdown]
# Multiplier Inputs

# %%
for event in events_list:
    # Assign multiplier for their 
    complete_merged_df[f'{event}_wfx'] = np.where(complete_merged_df['batSide'] == "L", complete_merged_df[f'{event}_wfx_l'], complete_merged_df[f'{event}_wfx_r'])

# %%
multiplier_input_list = [f'{event}_wfx' for event in events_list]

# %% [markdown]
# Imputation and starter interactions

# %%
# complete_merged_df['imputed_starter'] = complete_merged_df['imp_p'] * complete_merged_df['starter']
# complete_merged_df['imputed_reliever'] = complete_merged_df['imp_p'] * (complete_merged_df['starter'] == 0).astype(int)
# complete_merged_df['unimputed_starter'] = (complete_merged_df['imp_p'] == 0).astype(int) * complete_merged_df['starter']
# complete_merged_df['unimputed_reliever'] = (complete_merged_df['imp_p'] == 0).astype(int) * (complete_merged_df['starter'] == 0).astype(int)

# %%
# imp_starter_input_list = ['imputed_starter', 'imputed_reliever', 'unimputed_starter', 'unimputed_reliever']

# %% [markdown]
# Inputs

# %%
input_list = batter_input_list + pitcher_input_list + hand_input_list + imp_input_list + starter_input_list + cumulative_inning_input_list + cumulative_game_input_list + game_state_input_list + inning_input_list + out_input_list + venue_input_list + multiplier_input_list

# %% [markdown]
# Outputs

# %%
output_list = ['is_out', 'eventsModel']

# %% [markdown]
# Other variables

# %%
additional_list = ['pa_b', 'pa_p', 'year', 'date', 'gamePk', 'atBatIndex', 'venue_id', 'batterName', 'pitcherName']

# %% [markdown]
# Variables to keep

# %%
keep_list = input_list + output_list + additional_list

# %% [markdown]
# ### Shift

# %% [markdown]
# Many batter and pitcher stats are calculated at the end of the plate appearance. For prediction purposes, we need these stats coming into the plate appearance.

# %% [markdown]
# ##### Batter Inputs

# %% [markdown]
# Sort

# %%
complete_merged_df.sort_values(['date', 'gamePk', 'atBatIndex'], ascending=True, inplace=True)

# %% [markdown]
# Shift

# %%
complete_merged_df[batter_inputs + ['ab_b', 'pa_b', 'imp_b']] = complete_merged_df.groupby(['batter', 'pitchHand'])[batter_inputs + ['ab_b', 'pa_b', 'imp_b']].shift(1)

# %% [markdown]
# ##### Pitcher Inputs

# %% [markdown]
# Sort

# %%
complete_merged_df.sort_values(['date', 'gamePk', 'atBatIndex'], ascending=True, inplace=True)

# %% [markdown]
# Shift

# %%
complete_merged_df[pitcher_inputs + ['ab_p', 'pa_p', 'imp_p']] = complete_merged_df.groupby(['pitcher', 'batSide'])[pitcher_inputs + ['ab_p', 'pa_p', 'imp_p']].shift(1)

# %% [markdown]
# ##### Inning Sums

# %% [markdown]
# Sort

# %%
complete_merged_df.sort_values(['date', 'gamePk', 'atBatIndex'], ascending=True, inplace=True)

# %% [markdown]
# Shift

# %%
complete_merged_df[cumulative_inning_input_list] = complete_merged_df.groupby(['gamePk', 'inning', 'pitcher'])[cumulative_inning_input_list].shift(1)
complete_merged_df[cumulative_inning_input_list] = complete_merged_df[cumulative_inning_input_list].fillna(0)

# %% [markdown]
# ##### Game Sums

# %% [markdown]
# Sort

# %%
complete_merged_df.sort_values(['date', 'gamePk', 'atBatIndex'], ascending=True, inplace=True)

# %% [markdown]
# Shift

# %%
complete_merged_df[cumulative_game_input_list + ['times_faced']] = complete_merged_df.groupby(['gamePk', 'pitcher'])[cumulative_game_input_list + ['times_faced']].shift(1)
complete_merged_df[cumulative_game_input_list + ['times_faced']] = complete_merged_df[cumulative_game_input_list + ['times_faced']].fillna(0)

# %% [markdown]
# ### Model Dataset

# %% [markdown]
# Create Model Dataset

# %%
model_dataset = complete_merged_df[keep_list]

model_dataset.dropna(subset=input_list, inplace=True)
model_dataset.reset_index(drop=True, inplace=True)

# %% [markdown]
# Free up memory

# %%
del complete_merged_df, complete_dataset, steamer_hitters_df, steamer_hitters_df2, steamer_pitchers_df, steamer_pitchers_df2, multiplier_df, batter_predictions, pitcher_predictions

# %%
n1 = len(input_list) + 1

# %% [markdown]
# ### Train/Test Split

# %% [markdown]
# Split

# %%
np.random.seed(42)
model_dataset['split'] = np.random.choice([0, 0, 1], size=len(model_dataset))

# %% [markdown]
# Create masks to identify training and testing datasets

# %% [markdown]
# Note: to train on the entire dataset, you can simply set split = 0 for the entire dataset

# %%
training_mask = (model_dataset['split'] == 0)

# %% [markdown]
# ### All

# %%
all_stat_list = []

# %% [markdown]
# ##### Settings

# %%
layers = (512, 256, 128, 64)
activation = 'relu'
max_iter = 100
alpha = 0.00001
learning_rate_init = 0.0001 
batch_size='auto'
batch_size=8192
random_state = random.randint(10000,99900)
dropout = 0.1 # Need to switch to MLPDropout to use
early_stopping = True
tol=0.000001
n_iter_no_change=10
num_models = 40
num_classifiers = 1

quantiles = 10

len(input_list)
# Out:
# 164

# %% [markdown]
# Remove venue dummies

# %%
input_list = batter_input_list + pitcher_input_list + hand_input_list + imp_input_list + starter_input_list + cumulative_inning_input_list + cumulative_game_input_list + game_state_input_list + inning_input_list + out_input_list + multiplier_input_list
len(input_list)
# Out:
# 164

# %%
# # Apply Scaler
# scaler = StandardScaler()
# # scaler = MinMaxScaler(feature_range=(-1,1))
# model_dataset[multiplier_input_list] = scaler.fit_transform(model_dataset[multiplier_input_list])

# %%
# # Apply StandardScaler
# scaler = StandardScaler()
# model_dataset[cumulative_inning_input_list] = scaler.fit_transform(model_dataset[cumulative_inning_input_list])

# # Apply StandardScaler
# scaler = StandardScaler()
# model_dataset[cumulative_game_input_list] = scaler.fit_transform(model_dataset[cumulative_game_input_list])

# %%
# input_list = batter_input_list + pitcher_input_list + hand_input_list + imp_input_list + starter_input_list + cumulative_inning_input_list + cumulative_game_input_list + game_state_input_list + inning_input_list + out_input_list + ['b1_wfx', 'b2_wfx', 'hr_wfx'] + wfx_venue_list + venue_input_list
# len(input_list)

# %%
# model_dataset = pd.merge(model_dataset, venue_map_df[['id', 'location.elevation', 
#                                                       'fieldInfo.leftLine', 'fieldInfo.leftCenter', 'fieldInfo.center', 'fieldInfo.rightCenter', 'fieldInfo.rightLine']],
#                                                       how='left', left_on=['venue_id'], right_on=['id'])

# %%
# input_list = batter_input_list + pitcher_input_list + hand_input_list + imp_input_list + starter_input_list + cumulative_inning_input_list + cumulative_game_input_list + game_state_input_list + inning_input_list + out_input_list + multiplier_input_list #+ ['location.elevation'] #, 'fieldInfo.leftLine', 'fieldInfo.leftCenter', 'fieldInfo.center', 'fieldInfo.rightCenter', 'fieldInfo.rightLine']
# len(input_list)

# %%
# %%time
for i in range(num_models):
    # Set filename
    all_filename = f"predict_all_{''.join(str(x) for x in layers)}_{random_state+i}_{todaysdate}.sav"
    print(all_filename)

    # Determine if voting
    if num_classifiers > 1:
        print("Voting Classifier")
        # Build list of MLP classifiers with varied random_state
        estimators = []
        for j in range(num_classifiers):
            clf = MLPClassifier(
                hidden_layer_sizes=layers,
                activation=activation,
                verbose=True,
                alpha=alpha,
                learning_rate_init=learning_rate_init,
                early_stopping=early_stopping,
                random_state=random_state + i + j * 100,
                max_iter=max_iter,
                tol=tol,
                n_iter_no_change=n_iter_no_change,
                batch_size=batch_size
            )
            estimators.append((f"mlp_{j}", clf))
        
        # Combine into a soft voting classifier
        predict_all = VotingClassifier(estimators=estimators, voting='soft', n_jobs=-1)

    else:
        print("Single Classifier")
        # Create Model
        predict_all = MLPClassifier(hidden_layer_sizes=layers, activation=activation, verbose=True, alpha=alpha, 
                                    learning_rate_init=learning_rate_init, early_stopping=early_stopping, random_state=random_state+i, max_iter=max_iter,
                                    tol=tol, n_iter_no_change=n_iter_no_change,
                                    batch_size=batch_size, validation_fraction=0.05)

    # Fit
    predict_all.fit(model_dataset[training_mask][input_list], model_dataset[training_mask][['eventsModel']].values.ravel())

    # Save model
    pickle.dump(predict_all, open(os.path.join(model_path, "M03. Plate Appearances", all_filename), 'wb'))
    
    # Predict all types
    all_outputs = list(predict_all.classes_)
    all_outputs_pred = [x + "_pred" for x in all_outputs]
    
    model_dataset.loc[~training_mask, all_outputs_pred] = predict_all.predict_proba(model_dataset[~training_mask][input_list])


    ### Constructed Stats
    # FP - Outs
    model_dataset.loc[~training_mask, 'FP_P_act'] = ((model_dataset.loc[~training_mask, 'eventsModel'] == "fo").astype(int) * 0.2534 +
                                                     (model_dataset.loc[~training_mask, 'eventsModel'] == "go").astype(int) * 0.2534 +
                                                     (model_dataset.loc[~training_mask, 'eventsModel'] == "po").astype(int) * 0.2534 +
                                                     (model_dataset.loc[~training_mask, 'eventsModel'] == "lo").astype(int) * 0.2534 +
                                                     (model_dataset.loc[~training_mask, 'eventsModel'] == "so").astype(int) * 2.4866)

    model_dataset.loc[~training_mask, 'FP_P_pred'] = (model_dataset[~training_mask]['fo_pred'] * 0.2534 +
                                                      model_dataset[~training_mask]['go_pred'] * 0.2534 +
                                                      model_dataset[~training_mask]['po_pred'] * 0.2534 + 
                                                      model_dataset[~training_mask]['lo_pred'] * 0.2534 +
                                                      model_dataset[~training_mask]['so_pred'] * 2.4866)

    # FP - Safe
    model_dataset.loc[~training_mask, 'FP_B_act'] = ((model_dataset.loc[~training_mask, 'eventsModel'] == "b1").astype(int)  *  4.3665 +
                                                     (model_dataset.loc[~training_mask, 'eventsModel'] == "b2").astype(int)  *  6.8271 +
                                                     (model_dataset.loc[~training_mask, 'eventsModel'] == "b3").astype(int)  * 10.8503 +
                                                     (model_dataset.loc[~training_mask, 'eventsModel'] == "hr").astype(int)  * 15.2611 +
                                                     (model_dataset.loc[~training_mask, 'eventsModel'] == "bb").astype(int)  *  2.8725 +
                                                     (model_dataset.loc[~training_mask, 'eventsModel'] == "hbp").astype(int) *  2.9639)

    model_dataset.loc[~training_mask, 'FP_B_pred'] = (model_dataset[~training_mask]['b1_pred']  *  4.3665 +
                                                      model_dataset[~training_mask]['b2_pred']  *  6.8271 +
                                                      model_dataset[~training_mask]['b3_pred']  * 10.8503 + 
                                                      model_dataset[~training_mask]['hr_pred']  * 15.2611 +
                                                      model_dataset[~training_mask]['bb_pred']  *  2.8725 +
                                                      model_dataset[~training_mask]['hbp_pred'] *  2.9639)

    # wOBA (roughly)
    model_dataset.loc[~training_mask, 'wOBA_act'] = ((model_dataset.loc[~training_mask, 'eventsModel'] == "b1").astype(int)  * 0.882 +
                                                     (model_dataset.loc[~training_mask, 'eventsModel'] == "b2").astype(int)  * 1.254 +
                                                     (model_dataset.loc[~training_mask, 'eventsModel'] == "b3").astype(int)  * 1.590 +
                                                     (model_dataset.loc[~training_mask, 'eventsModel'] == "hr").astype(int)  * 2.050 +
                                                     (model_dataset.loc[~training_mask, 'eventsModel'] == "bb").astype(int)  * 0.689 +
                                                     (model_dataset.loc[~training_mask, 'eventsModel'] == "hbp").astype(int) * 0.720)

    model_dataset.loc[~training_mask, 'wOBA_pred'] = (model_dataset[~training_mask]['b1_pred']  * 0.882 +
                                                      model_dataset[~training_mask]['b2_pred']  * 1.254 +
                                                      model_dataset[~training_mask]['b3_pred']  * 1.590 + 
                                                      model_dataset[~training_mask]['hr_pred']  * 2.050 +
                                                      model_dataset[~training_mask]['bb_pred']  * 0.689 +
                                                      model_dataset[~training_mask]['hbp_pred'] * 0.720)
    
    # Out
    model_dataset['is_out_act'] = model_dataset['is_out'].copy()
    
    model_dataset.loc[~training_mask, 'is_out_pred'] = (model_dataset[~training_mask]['fo_pred'] +
                                                        model_dataset[~training_mask]['go_pred'] +
                                                        model_dataset[~training_mask]['po_pred'] + 
                                                        model_dataset[~training_mask]['lo_pred'] +
                                                        model_dataset[~training_mask]['so_pred'])


    # "TESTING"
    model_dataset['so_act'] = (model_dataset['eventsModel'] == "so").astype(int)
    print(model_dataset[~training_mask].groupby(['imp_p', 'starter'])[['FP_P_pred', 'FP_P_act', 'wOBA_pred', 'wOBA_act', 'so_pred', 'so_act']].mean())

    print(model_dataset[~training_mask].groupby('venue_id')[['FP_B_pred', 'FP_B_act', 'FP_P_pred', 'FP_P_act']].mean())

    model_dataset['hr_act'] = (model_dataset['eventsModel'] == "hr").astype(int)
    model_dataset['hr_wfx_decile'] = pd.qcut(model_dataset['hr_wfx'], q=10, labels=False) + 1
    print(model_dataset[~training_mask].groupby('hr_wfx_decile')[['hr_pred', 'hr_act']].mean())
    
    
    # Quantiles
    year = 2024
    venue = 19
    
    for var in all_outputs:
        # Create actual outcome column
        model_dataset.loc[~training_mask, f'{var}_act'] = (model_dataset.loc[~training_mask, 'eventsModel'] == var).astype(int)
        
        # Create deciles
        model_dataset.loc[~training_mask, f'{var}_decile'] = pd.qcut(model_dataset.loc[~training_mask, f'{var}_pred'], quantiles, labels=False, duplicates='drop')
        
        # Create aggregated dataframe
        globals()[f"{var}_df"] = model_dataset.loc[~training_mask].groupby(f'{var}_decile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()
        globals()[f"{var}_year_df"] = model_dataset.query(f'year >= {year}').loc[~training_mask].groupby(f'{var}_decile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()
        globals()[f"{var}_venue_df"] = model_dataset.query(f'venue_id == {venue}').loc[~training_mask].groupby(f'{var}_decile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()
    
    for var in ['is_out', 'wOBA', 'FP_B', 'FP_P']:
        # Create deciles
        model_dataset.loc[~training_mask, f'{var}_decile'] = pd.qcut(model_dataset.loc[~training_mask, f'{var}_pred'], quantiles, labels=False, duplicates='drop')
        
        # Create aggregated dataframe
        globals()[f"{var}_df"] = model_dataset.loc[~training_mask].groupby(f'{var}_decile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()
        globals()[f"{var}_year_df"] = model_dataset.query(f'year >= {year}').loc[~training_mask].groupby(f'{var}_decile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()
        globals()[f"{var}_venue_df"] = model_dataset.query(f'venue_id == {venue}').loc[~training_mask].groupby(f'{var}_decile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()

    # All
    all_df_list = []
    for var in all_outputs + ['is_out', 'wOBA', 'FP_B', 'FP_P']:
        actual = model_dataset.loc[~training_mask][f'{var}_act'].mean()
        predicted = model_dataset.loc[~training_mask][f'{var}_pred'].mean()
        mult = actual/predicted
        stdev = model_dataset.loc[~training_mask][f'{var}_pred'].std()
        globals()[f"{var}_df"]['se'] = (globals()[f"{var}_df"][f'{var}_act'] - globals()[f"{var}_df"][f'{var}_pred']) ** 2
        mse = globals()[f"{var}_df"]['se'].mean()
        all_df = pd.DataFrame(["All", var, actual, predicted, mult, stdev, mse])
        all_df_list.append(all_df)
    
    all_dfs = pd.concat(all_df_list, axis=1).T
    
    # Year
    recent_df_list = []
    for var in all_outputs + ['is_out', 'wOBA', 'FP_B', 'FP_P']:
        actual = model_dataset.query(f'year >= {year}').loc[~training_mask][f'{var}_act'].mean()
        predicted = model_dataset.query(f'year == {year}').loc[~training_mask][f'{var}_pred'].mean()
        mult = actual/predicted
        stdev = model_dataset.query(f'year == {year}').loc[~training_mask][f'{var}_pred'].std()
        globals()[f"{var}_year_df"]['se'] = (globals()[f"{var}_year_df"][f'{var}_act'] - globals()[f"{var}_year_df"][f'{var}_pred']) ** 2
        mse = globals()[f"{var}_year_df"]['se'].mean()
        recent_df = pd.DataFrame([str(int(year)), var, actual, predicted, mult, stdev, mse])
        recent_df_list.append(recent_df)
    
    recent_dfs = pd.concat(recent_df_list, axis=1).T
    
    # DataFrame
    all_stat_df = pd.concat([all_dfs, recent_dfs], axis=0).reset_index(drop=True)
    all_stat_df.columns = ['Year', 'Output', 'Actual', 'Predicted', "Multiplier", 'Std. Dev', 'MSE']
    all_stat_df['File'] = all_filename
    all_stat_df['Layers'] = str(layers)
    all_stat_df['Models'] = num_models
    all_stat_df['State'] = random_state+i
    all_stat_df[['Year', 'File', 'Layers', 'Models', 'State', 'Output', 'Actual', 'Predicted', "Multiplier", 'Std. Dev', 'MSE']]

    print(all_stat_df[['Year', 'Output', 'Actual', 'Predicted', 'Multiplier', 'Std. Dev', 'MSE']])
    
    all_stat_list.append(all_stat_df)
    
    graph_options = ["", "_year", "_venue"]
    graph_index = 1
    graph = graph_options[graph_index]
    print(f"Graphing {graph}")

    # Create figures
    rows, columns = 5, 3
    fig, axs = plt.subplots(rows, columns, figsize=(9, 15))
    
    # Ensure that the number of plots doesn't exceed available subplots
    total_plots = rows * columns
    output_vars = all_outputs + ['is_out', 'wOBA', 'FP_B', 'FP_P']
    
    # Limit the number of plots to the available subplots
    output_vars = output_vars[:total_plots]
    
    for i, var in enumerate(output_vars):
        row = i // columns  # Calculate the row index based on the iteration
        col = i % columns   # Calculate the column index based on the iteration
        axs[row, col].plot(globals()[f"{var}{graph}_df"][f'{var}_decile'], globals()[f"{var}{graph}_df"][f'{var}_pred'], color='red')
        axs[row, col].plot(globals()[f"{var}{graph}_df"][f'{var}_decile'], globals()[f"{var}{graph}_df"][f'{var}_act'], color='black')
        axs[row, col].set_title(var)
    
    # Add some space between subplots to prevent overlapping
    fig.tight_layout(pad=.0)
    
    # Show the figure
    plt.show()
# Out:
# predict_all_51225612864_92055_20250623.sav
# Single Classifier
# Iteration 1, loss = 2.18948748
# Validation score: 0.262162
# Iteration 2, loss = 2.03858692
# Validation score: 0.265481
# Iteration 3, loss = 2.02588385
# Validation score: 0.266987
# Iteration 4, loss = 2.02061952
# Validation score: 0.268212
# Iteration 5, loss = 2.01745965
# Validation score: 0.267957
# Iteration 6, loss = 2.01523206
# Validation score: 0.268824
# Iteration 7, loss = 2.01340748
# Validation score: 0.269411
# Iteration 8, loss = 2.01205268
# Validation score: 0.269896
# Iteration 9, loss = 2.01084241
# Validation score: 0.269667
# Iteration 10, loss = 2.00968802
# Validation score: 0.270126
# Iteration 11, loss = 2.00875756
# Validation score: 0.269156
# Iteration 12, loss = 2.00779103
# Validation score: 0.268314
# Iteration 13, loss = 2.00703977
# Validation score: 0.269845
# Iteration 14, loss = 2.00632180
# Validation score: 0.268926
# Iteration 15, loss = 2.00540897
# Validation score: 0.269667
# Iteration 16, loss = 2.00473821
# Validation score: 0.269462
# Iteration 17, loss = 2.00409512
# Validation score: 0.270586
# Iteration 18, loss = 2.00349104
# Validation score: 0.269411
# Iteration 19, loss = 2.00287435
# Validation score: 0.269590
# Iteration 20, loss = 2.00225234
# Validation score: 0.269692
# Iteration 21, loss = 2.00151283
# Validation score: 0.269590
# Iteration 22, loss = 2.00095897
# Validation score: 0.269437
# Iteration 23, loss = 2.00043257
# Validation score: 0.269718
# Iteration 24, loss = 1.99991094
# Validation score: 0.270509
# Iteration 25, loss = 1.99936617
# Validation score: 0.269335
# Iteration 26, loss = 1.99866107
# Validation score: 0.269360
# Iteration 27, loss = 1.99826531
# Validation score: 0.269743
# Iteration 28, loss = 1.99774232
# Validation score: 0.269003
# Validation score did not improve more than tol=0.000001 for 10 consecutive epochs. Stopping.
#                   FP_P_pred  FP_P_act  wOBA_pred  wOBA_act  so_pred   so_act
# imp_p    starter
# 0.000000 0         0.706347  0.703663   0.312794  0.311112 0.238861 0.237661
#          1         0.673523  0.660869   0.313595  0.321688 0.223147 0.218269
# 1.000000 0         0.658268  0.657086   0.328727  0.332699 0.219259 0.219096
#          1         0.621318  0.617102   0.329531  0.340285 0.201738 0.201246
#           FP_B_pred  FP_B_act  FP_P_pred  FP_P_act
# venue_id
# 1          1.703386  1.700454   0.694004  0.700444
# 2          1.714670  1.799888   0.681327  0.654135
# 3          1.718365  1.785001   0.687431  0.665737
# 4          1.692598  1.704624   0.699381  0.695988
# 5          1.689434  1.678334   0.670739  0.684320
# 7          1.715294  1.731000   0.656929  0.614563
# 10         1.711919  1.658704   0.687449  0.667337
# 12         1.669486  1.604505   0.722254  0.736885
# 14         1.710779  1.780260   0.681233  0.648221
# 15         1.729198  1.741889   0.644988  0.640939
# 17         1.728543  1.721707   0.674083  0.673625
# 19         1.739748  1.984256   0.644953  0.619550
# 22         1.705654  1.744620   0.696153  0.700325
# 31         1.687426  1.711173   0.671952  0.648084
# 32         1.685381  1.705912   0.705486  0.729842
# 680        1.694215  1.613612   0.705990  0.725993
# 2392       1.696096  1.719715   0.688256  0.686924
# 2394       1.689677  1.677759   0.687104  0.671204
# 2395       1.709113  1.652415   0.664595  0.671212
# 2602       1.662988  1.833543   0.701204  0.690900
# 2680       1.699407  1.694247   0.680299  0.683392
# 2681       1.700076  1.766713   0.686672  0.687213
# 2889       1.709944  1.686844   0.659131  0.623957
# 3289       1.676866  1.673326   0.700690  0.698786
# 3309       1.705570  1.739675   0.657304  0.641120
# 3312       1.705605  1.747466   0.699534  0.677641
# 3313       1.712384  1.710649   0.719082  0.720720
# 4169       1.684314  1.685541   0.674974  0.655392
# 4705       1.725839  1.794010   0.694863  0.688986
# 5325       1.712131  1.746134   0.691197  0.680305
#                hr_pred   hr_act
# hr_wfx_decile
# 1             0.029591 0.025028
# 2             0.030562 0.029779
# 3             0.030396 0.029201
# 4             0.030688 0.028352
# 5             0.030773 0.030395
# 6             0.031216 0.033012
# 7             0.031376 0.032679
# 8             0.031573 0.035094
# 9             0.031892 0.036356
# 10            0.032824 0.039690
#     Year  Output   Actual Predicted Multiplier Std. Dev      MSE
# 0    All      b1 0.141353  0.140986   1.002607 0.028453 0.000019
# 1    All      b2 0.044066  0.044019   1.001078 0.008166 0.000002
# 2    All      b3 0.003964  0.003953   1.002690 0.001685 0.000001
# 3    All      bb 0.085058  0.083078   1.023831 0.033436 0.000011
# 4    All      fo 0.126882  0.121016   1.048474 0.031065 0.000052
# 5    All      go 0.225499  0.232321   0.970639 0.059437 0.000075
# 6    All     hbp 0.011386  0.010377   1.097227 0.005149 0.000002
# 7    All      hr 0.031960  0.031089   1.028016 0.013109 0.000004
# 8    All      lo 0.057660  0.057624   1.000624 0.013162 0.000002
# 9    All      po 0.046902  0.047079   0.996238 0.017108 0.000001
# 10   All      so 0.225270  0.228459   0.986041 0.074523 0.000072
# 11   All  is_out 0.682212  0.686497   0.993758 0.039315 0.000092
# 12   All    wOBA 0.318557  0.314280   1.013608 0.040906 0.000078
# 13   All    FP_B 1.726897  1.702882   1.014102 0.249014 0.002798
# 14   All    FP_P 0.675945  0.684152   0.988003 0.171955 0.000399
# 15  2024      b1 0.141807  0.141953   0.998972 0.027628 0.000036
# 16  2024      b2 0.041687  0.043474   0.958902 0.007965 0.000011
# 17  2024      b3 0.003955  0.003719   1.063436 0.001548 0.000002
# 18  2024      bb 0.082776  0.080687   1.025889 0.031950 0.000021
# 19  2024      fo 0.136538  0.126226   1.081691 0.031907 0.000160
# 20  2024      go 0.223763  0.229896   0.973323 0.057472 0.000085
# 21  2024     hbp 0.011137  0.010146   1.097749 0.005161 0.000002
# 22  2024      hr 0.029236  0.029628   0.986760 0.012227 0.000015
# 23  2024      lo 0.057366  0.057373   0.999861 0.013138 0.000008
# 24  2024      po 0.047477  0.047892   0.991335 0.017125 0.000002
# 25  2024      so 0.224258  0.229005   0.979269 0.072551 0.000148
# 26  2024  is_out 0.689401  0.690393   0.998563 0.037864 0.000091
# 27  2024    wOBA 0.308623  0.309268   0.997915 0.039449 0.000105
# 28  2024    FP_B 1.663674  1.670995   0.995619 0.238553 0.005256
# 29  2024    FP_P 0.675507  0.686360   0.984187 0.167455 0.000849
# Graphing _year
# predict_all_51225612864_92056_20250623.sav
# Single Classifier
# Iteration 1, loss = 2.17296587
# Validation score: 0.259916
# Iteration 2, loss = 2.03823833
# Validation score: 0.263668
# Iteration 3, loss = 2.02607602
# Validation score: 0.264485
# Iteration 4, loss = 2.02095638
# Validation score: 0.265608
# Iteration 5, loss = 2.01776708
# Validation score: 0.266246
# Iteration 6, loss = 2.01548106
# Validation score: 0.266348
# Iteration 7, loss = 2.01373954
# Validation score: 0.265608
# Iteration 8, loss = 2.01217130
# Validation score: 0.264791
# Iteration 9, loss = 2.01089720
# Validation score: 0.266297
# Iteration 10, loss = 2.00977168
# Validation score: 0.266757
# Iteration 11, loss = 2.00880925
# Validation score: 0.265863
# Iteration 12, loss = 2.00778016
# Validation score: 0.265583
# Iteration 13, loss = 2.00708694
# Validation score: 0.265455
# Iteration 14, loss = 2.00620569
# Validation score: 0.266859
# Iteration 15, loss = 2.00547603
# Validation score: 0.266833
# Iteration 16, loss = 2.00486125
# Validation score: 0.266170
# Iteration 17, loss = 2.00412971
# Validation score: 0.265940
# Iteration 18, loss = 2.00362428
# Validation score: 0.265634
# Iteration 19, loss = 2.00293742
# Validation score: 0.266961
# Iteration 20, loss = 2.00236963
# Validation score: 0.265915
# Iteration 21, loss = 2.00164544
# Validation score: 0.266068
# Iteration 22, loss = 2.00109179
# Validation score: 0.266578
# Iteration 23, loss = 2.00062891
# Validation score: 0.265634
# Iteration 24, loss = 1.99985957
# Validation score: 0.265251
# Iteration 25, loss = 1.99926255
# Validation score: 0.265379
# Iteration 26, loss = 1.99887172
# Validation score: 0.264715
# Iteration 27, loss = 1.99817131
# Validation score: 0.265481
# Iteration 28, loss = 1.99761027
# Validation score: 0.265276
# Iteration 29, loss = 1.99713727
# Validation score: 0.265557
# Iteration 30, loss = 1.99653932
# Validation score: 0.263898
# Validation score did not improve more than tol=0.000001 for 10 consecutive epochs. Stopping.
#                   FP_P_pred  FP_P_act  wOBA_pred  wOBA_act  so_pred   so_act
# imp_p    starter
# 0.000000 0         0.709922  0.703663   0.307057  0.311112 0.239920 0.237661
#          1         0.667805  0.660869   0.316169  0.321688 0.221108 0.218269
# 1.000000 0         0.689313  0.657086   0.316092  0.332699 0.231599 0.219096
#          1         0.645264  0.617102   0.321905  0.340285 0.211499 0.201246
#           FP_B_pred  FP_B_act  FP_P_pred  FP_P_act
# venue_id
# 1          1.692197  1.700454   0.691828  0.700444
# 2          1.704740  1.799888   0.679995  0.654135
# 3          1.708577  1.785001   0.689542  0.665737
# 4          1.683230  1.704624   0.696368  0.695988
# 5          1.675539  1.678334   0.670978  0.684320
# 7          1.691335  1.731000   0.659116  0.614563
# 10         1.697398  1.658704   0.686939  0.667337
# 12         1.658168  1.604505   0.723424  0.736885
# 14         1.701731  1.780260   0.679712  0.648221
# 15         1.710245  1.741889   0.647149  0.640939
# 17         1.712322  1.721707   0.676892  0.673625
# 19         1.733727  1.984256   0.645790  0.619550
# 22         1.696021  1.744620   0.695380  0.700325
# 31         1.672764  1.711173   0.673801  0.648084
# 32         1.680396  1.705912   0.705684  0.729842
# 680        1.688006  1.613612   0.702396  0.725993
# 2392       1.680034  1.719715   0.686669  0.686924
# 2394       1.673665  1.677759   0.686604  0.671204
# 2395       1.689098  1.652415   0.665713  0.671212
# 2602       1.657566  1.833543   0.703111  0.690900
# 2680       1.678564  1.694247   0.684415  0.683392
# 2681       1.685783  1.766713   0.689583  0.687213
# 2889       1.688920  1.686844   0.660947  0.623957
# 3289       1.664303  1.673326   0.701297  0.698786
# 3309       1.691188  1.739675   0.657845  0.641120
# 3312       1.697731  1.747466   0.694946  0.677641
# 3313       1.710350  1.710649   0.715534  0.720720
# 4169       1.665752  1.685541   0.675486  0.655392
# 4705       1.715530  1.794010   0.692910  0.688986
# 5325       1.698514  1.746134   0.688501  0.680305
#                hr_pred   hr_act
# hr_wfx_decile
# 1             0.028374 0.025028
# 2             0.029424 0.029779
# 3             0.029453 0.029201
# 4             0.029804 0.028352
# 5             0.029795 0.030395
# 6             0.030295 0.033012
# 7             0.030531 0.032679
# 8             0.030849 0.035094
# 9             0.031245 0.036356
# 10            0.032266 0.039690
#     Year  Output   Actual Predicted Multiplier Std. Dev      MSE
# 0    All      b1 0.141353  0.142099   0.994753 0.028749 0.000027
# 1    All      b2 0.044066  0.043491   1.013241 0.009085 0.000009
# 2    All      b3 0.003964  0.003787   1.046768 0.001747 0.000001
# 3    All      bb 0.085058  0.083145   1.023010 0.030887 0.000005
# 4    All      fo 0.126882  0.123368   1.028479 0.031520 0.000039
# 5    All      go 0.225499  0.227599   0.990776 0.060421 0.000042
# 6    All     hbp 0.011386  0.010761   1.058088 0.005555 0.000001
# 7    All      hr 0.031960  0.030203   1.058160 0.013113 0.000006
# 8    All      lo 0.057660  0.057864   0.996466 0.014152 0.000006
# 9    All      po 0.046902  0.049225   0.952791 0.018992 0.000011
# 10   All      so 0.225270  0.228457   0.986046 0.073034 0.000050
# 11   All  is_out 0.682212  0.686514   0.993733 0.038004 0.000065
# 12   All    wOBA 0.318557  0.312841   1.018269 0.041425 0.000094
# 13   All    FP_B 1.726897  1.690143   1.021746 0.254225 0.003171
# 14   All    FP_P 0.675945  0.684154   0.988001 0.168296 0.000263
# 15  2024      b1 0.141807  0.143009   0.991597 0.028096 0.000053
# 16  2024      b2 0.041687  0.042288   0.985797 0.008571 0.000021
# 17  2024      b3 0.003955  0.003619   1.092829 0.001668 0.000001
# 18  2024      bb 0.082776  0.080580   1.027251 0.029505 0.000011
# 19  2024      fo 0.136538  0.129596   1.053563 0.032336 0.000110
# 20  2024      go 0.223763  0.225326   0.993063 0.058212 0.000038
# 21  2024     hbp 0.011137  0.010324   1.078739 0.005463 0.000002
# 22  2024      hr 0.029236  0.028852   1.013298 0.012007 0.000012
# 23  2024      lo 0.057366  0.057879   0.991132 0.013892 0.000008
# 24  2024      po 0.047477  0.049466   0.959796 0.018805 0.000008
# 25  2024      so 0.224258  0.229060   0.979033 0.070436 0.000114
# 26  2024  is_out 0.689401  0.691327   0.997214 0.036089 0.000069
# 27  2024    wOBA 0.308623  0.307018   1.005231 0.038996 0.000122
# 28  2024    FP_B 1.663674  1.654804   1.005360 0.237530 0.006485
# 29  2024    FP_P 0.675507  0.686720   0.983671 0.162283 0.000552
# Graphing _year
# predict_all_51225612864_92057_20250623.sav
# Single Classifier
# Iteration 1, loss = 2.13030888
# Validation score: 0.268646
# Iteration 2, loss = 2.03526884
# Validation score: 0.269539
# Iteration 3, loss = 2.02482623
# Validation score: 0.272066
# Iteration 4, loss = 2.01997253
# Validation score: 0.271632
# Iteration 5, loss = 2.01683342
# Validation score: 0.272857
# Iteration 6, loss = 2.01448990
# Validation score: 0.271785
# Iteration 7, loss = 2.01261773
# Validation score: 0.272985
# Iteration 8, loss = 2.01119205
# Validation score: 0.273036
# Iteration 9, loss = 2.00990899
# Validation score: 0.271862
# Iteration 10, loss = 2.00894772
# Validation score: 0.272551
# Iteration 11, loss = 2.00785414
# Validation score: 0.272296
# Iteration 12, loss = 2.00701600
# Validation score: 0.271734
# Iteration 13, loss = 2.00621031
# Validation score: 0.273112
# Iteration 14, loss = 2.00526927
# Validation score: 0.272168
# Iteration 15, loss = 2.00467356
# Validation score: 0.272679
# Iteration 16, loss = 2.00400404
# Validation score: 0.272015
# Iteration 17, loss = 2.00323437
# Validation score: 0.272934
# Iteration 18, loss = 2.00260099
# Validation score: 0.272168
# Iteration 19, loss = 2.00186581
# Validation score: 0.272066
# Iteration 20, loss = 2.00130528
# Validation score: 0.272143
# Iteration 21, loss = 2.00067653
# Validation score: 0.272653
# Iteration 22, loss = 2.00006262
# Validation score: 0.272245
# Iteration 23, loss = 1.99945089
# Validation score: 0.272168
# Iteration 24, loss = 1.99882336
# Validation score: 0.272347
# Validation score did not improve more than tol=0.000001 for 10 consecutive epochs. Stopping.
#                   FP_P_pred  FP_P_act  wOBA_pred  wOBA_act  so_pred   so_act
# imp_p    starter
# 0.000000 0         0.711572  0.703663   0.314388  0.311112 0.241356 0.237661
#          1         0.673621  0.660869   0.323849  0.321688 0.224164 0.218269
# 1.000000 0         0.690173  0.657086   0.317269  0.332699 0.232336 0.219096
#          1         0.649512  0.617102   0.326486  0.340285 0.213860 0.201246
#           FP_B_pred  FP_B_act  FP_P_pred  FP_P_act
# venue_id
# 1          1.742738  1.700454   0.699089  0.700444
# 2          1.755476  1.799888   0.685544  0.654135
# 3          1.745793  1.785001   0.692066  0.665737
# 4          1.737137  1.704624   0.703309  0.695988
# 5          1.726780  1.678334   0.675851  0.684320
# 7          1.750216  1.731000   0.661855  0.614563
# 10         1.753986  1.658704   0.687089  0.667337
# 12         1.709351  1.604505   0.724312  0.736885
# 14         1.755411  1.780260   0.684627  0.648221
# 15         1.755462  1.741889   0.649880  0.640939
# 17         1.756328  1.721707   0.681575  0.673625
# 19         1.759853  1.984256   0.658175  0.619550
# 22         1.747868  1.744620   0.700375  0.700325
# 31         1.716980  1.711173   0.675556  0.648084
# 32         1.723387  1.705912   0.709681  0.729842
# 680        1.746869  1.613612   0.703870  0.725993
# 2392       1.728494  1.719715   0.692124  0.686924
# 2394       1.734119  1.677759   0.688044  0.671204
# 2395       1.739520  1.652415   0.667704  0.671212
# 2602       1.698602  1.833543   0.705801  0.690900
# 2680       1.737614  1.694247   0.683481  0.683392
# 2681       1.736151  1.766713   0.692840  0.687213
# 2889       1.739997  1.686844   0.662841  0.623957
# 3289       1.718142  1.673326   0.703480  0.698786
# 3309       1.738407  1.739675   0.663001  0.641120
# 3312       1.748705  1.747466   0.701041  0.677641
# 3313       1.757183  1.710649   0.723533  0.720720
# 4169       1.715809  1.685541   0.679924  0.655392
# 4705       1.764406  1.794010   0.697780  0.688986
# 5325       1.755880  1.746134   0.693524  0.680305
#                hr_pred   hr_act
# hr_wfx_decile
# 1             0.031584 0.025028
# 2             0.032470 0.029779
# 3             0.032450 0.029201
# 4             0.032761 0.028352
# 5             0.032802 0.030395
# 6             0.033281 0.033012
# 7             0.033482 0.032679
# 8             0.033751 0.035094
# 9             0.034144 0.036356
# 10            0.034964 0.039690
#     Year  Output   Actual Predicted Multiplier Std. Dev      MSE
# 0    All      b1 0.141353  0.138891   1.017732 0.028349 0.000026
# 1    All      b2 0.044066  0.043911   1.003549 0.008545 0.000007
# 2    All      b3 0.003964  0.004075   0.972882 0.001752 0.000001
# 3    All      bb 0.085058  0.087149   0.976001 0.033060 0.000012
# 4    All      fo 0.126882  0.123186   1.030001 0.030957 0.000031
# 5    All      go 0.225499  0.221926   1.016102 0.057436 0.000027
# 6    All     hbp 0.011386  0.011060   1.029521 0.005094 0.000001
# 7    All      hr 0.031960  0.033169   0.963556 0.014061 0.000008
# 8    All      lo 0.057660  0.058789   0.980797 0.014005 0.000009
# 9    All      po 0.046902  0.047058   0.996674 0.018360 0.000002
# 10   All      so 0.225270  0.230788   0.976090 0.074931 0.000094
# 11   All  is_out 0.682212  0.681746   1.000683 0.037669 0.000051
# 12   All    wOBA 0.318557  0.320049   0.995338 0.041205 0.000063
# 13   All    FP_B 1.726897  1.739765   0.992603 0.256857 0.002534
# 14   All    FP_P 0.675945  0.688150   0.982264 0.172696 0.000500
# 15  2024      b1 0.141807  0.138945   1.020598 0.027354 0.000047
# 16  2024      b2 0.041687  0.043388   0.960800 0.008205 0.000019
# 17  2024      b3 0.003955  0.003855   1.025987 0.001540 0.000001
# 18  2024      bb 0.082776  0.084669   0.977642 0.031715 0.000027
# 19  2024      fo 0.136538  0.128070   1.066116 0.031555 0.000119
# 20  2024      go 0.223763  0.219895   1.017593 0.055352 0.000036
# 21  2024     hbp 0.011137  0.010825   1.028900 0.005083 0.000002
# 22  2024      hr 0.029236  0.032075   0.911481 0.013040 0.000034
# 23  2024      lo 0.057366  0.058507   0.980491 0.013425 0.000017
# 24  2024      po 0.047477  0.048369   0.981556 0.018550 0.000005
# 25  2024      so 0.224258  0.231402   0.969125 0.071888 0.000146
# 26  2024  is_out 0.689401  0.686243   1.004602 0.036186 0.000092
# 27  2024    wOBA 0.308623  0.314972   0.979843 0.039256 0.000183
# 28  2024    FP_B 1.663674  1.709543   0.973169 0.243292 0.009420
# 29  2024    FP_P 0.675507  0.690661   0.978058 0.165647 0.000755
# Graphing _year
# predict_all_51225612864_92058_20250623.sav
# Single Classifier
# KeyboardInterrupt

# %%
# Consider printing out hr rates by hr multiplier deciles?

# %%
all_stat_df = pd.concat(all_stat_list)
all_stat_df = all_stat_df.reset_index(drop=True)

# %%
subset = all_stat_df.query('Year == "2024"').query('Output == "wOBA"').query('1.01 > Multiplier > 0.99').reset_index(drop=True)
pareto_front = pareto_optimal(subset, ['MSE', 'Std. Dev'], ['Minimize', 'Maximize']).sort_values('Std. Dev')
pareto_front

# %% [markdown]
# #####

# %%
# Should we do two models? Predict, get rates, then predict with rates + weather multipliers
