# %% [markdown]
# ### game_df

# %% [markdown]
# ### contest_df

# %% [markdown]
# ### Complete Dataset - Unadjusted

# %% [markdown]
# ### Park Latest

# %% [markdown]
# ### Complete Dataset - Adjusted

# %% [markdown]
# ### Multiplier Dataset

# %% [markdown]
# ### Running Dataset

# %% [markdown]
# ### Base Rates

# %% [markdown]
# ### M01. Park and Weather Factors
# Inputs:
# - Complete Dataset - Unadjusted
#
# Outputs:
# - Base Rates
# - Multiplier Dataset
# - Park Latest  x2

# %% [markdown]
# ### M02. Stat Imputations
# Inputs:
# - Multiplier Dataset
# - Complete Dataset - Adjusted
# - Steamer (both)

# %% [markdown]
# ### M03. Plate Appearances
# Inputs:
# - Multiplier Dataset
# - Complete Dataset - Adjusted
# - Steamer (both)

# %% [markdown]
# ### M04. Base Running
# Inputs:
# - Running Dataset
# - Steamer (hitters)

# %% [markdown]
# ### M06. Pulls
# Inputs:
# - Multiplier Dataset
# - Complete Dataset - Adjusted
# - Steamer (pitchers)

# %% [markdown]
# ### M07. Leverage
# Inputs:
# - Multiplier Dataset
# - Complete Dataset - Adjusted
# - A04. Bullpens

# %% [raw]
# Do we need:
# game_df.csv?
# games.pkl
# Complete Dataset2
# Period Averages
# Steamer Hitters.csv
# Steamer Pitchers.csv
