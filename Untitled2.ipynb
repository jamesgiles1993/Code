# %%
# %run "C:\Users\james\Documents\MLB\Code\U1. Imports.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U2. Utilities.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U3. Classes.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U4. Datasets.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U5. Models.ipynb"

# %%
df = pd.read_csv(os.path.join(baseball_path, "Park and Weather Factors.csv"))

# %%
df.head()
# Out:
#    venue_id  gamePk      date  b1_wfx_unadj_l  b2_wfx_unadj_l  b3_wfx_unadj_l  \
# 0        12  529406  20180329        1.066042        1.061895        0.965359
# 1      4169  529407  20180329        1.025114        1.034510        0.998499
# 2         7  529408  20180329        1.138088        1.029661        1.161747
# 3       680  529409  20180329        1.018981        0.924148        0.847506
# 4        15  529410  20180329        1.022817        1.069100        1.196826
#
#    hr_wfx_unadj_l  bb_wfx_unadj_l  hbp_wfx_unadj_l  so_wfx_unadj_l  \
# 0        1.137272        0.984225         1.224755        0.995178
# 1        0.867993        1.001212         1.255568        0.995658
# 2        0.634644        0.982608         1.209957        0.969042
# 3        0.962482        1.004318         1.043366        0.980891
# 4        1.031189        0.966820         0.934311        1.004168
#
#    fo_wfx_unadj_l  go_wfx_unadj_l  lo_wfx_unadj_l  po_wfx_unadj_l  \
# ...

# %%
df.groupby('venue_id')[[col for col in df.columns if "hr_wfx" in col]].mean()
# Out:
#           hr_wfx_unadj_l  hr_wfx_adj_l  hr_wfx_unadj_r  hr_wfx_adj_r
# venue_id
# 1               1.059498      1.176714        1.070884      1.052360
# 2               1.055311      1.128482        1.030279      1.056436
# 3               0.832552      0.921954        0.870848      0.996602
# 4               1.040930      0.903420        1.044841      1.089617
# 5               1.016867      1.011595        0.948840      0.886986
# 7               0.806585      0.751862        0.766359      0.906873
# 10              0.878320      0.917538        0.892623      0.908935
# 12              0.995734      0.866240        1.000755      0.964767
# 14              1.073241      1.037947        1.025352      1.083577
# 15              0.931439      0.810131        0.893523      0.994518
# 17              0.983522      0.963811        0.968205      1.012215
# 19              1.220490      1.026745        1.140156      1.163063
# ...
