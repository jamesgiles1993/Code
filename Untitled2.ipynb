# %%
pip install opencv-python openmeteo_requests pybaseball pyperclip pyautogui pybaseball paretoset requests-cache pydfs-lineup-optimizer retry_requests
# Out:
# ...
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------- ----------------------- 1.6/3.8 MB 8.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.4/3.8 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 8.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------ --------------------------------- 1.3/8.1 MB 6.7 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.1 MB 7.7 MB/s eta 0:00:01
#    ------------------------ --------------- 5.0/8.1 MB 8.2 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.1 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 8.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/11.6 MB 7.6 MB/s eta 0:00:02
# ...
