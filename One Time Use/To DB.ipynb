# %%
import os
import pandas as pd
from sqlalchemy import create_engine

# %%
folder_path = r'C:\Users\james\Documents\MLB\Database\A01. DraftKings\1. Contests'
db_path = r'C:\Users\james\Documents\MLB\Database\MLBDB.db'

# %%
def read_and_save_files(folder_path, db_path):
    # Create an SQLite database connection
    engine = create_engine(f'sqlite:///{db_path}')
    
    # Get a list of all files in the specified folder
    file_list = os.listdir(folder_path)
    
    # Loop through the files and read them into DataFrames
    for file_name in file_list:
        # Construct the full file path
        file_path = os.path.join(folder_path, file_name)
        
        # Check if the file is a CSV (you can modify this check if your files are in a different format)
        if file_name.endswith('.csv'):
            # Read the CSV file into a DataFrame
            df = pd.read_csv(file_path)
            
            # Extract the table name from the file name (excluding the file extension)
            table_name = os.path.splitext(file_name)[0]
            
            # Save the DataFrame to the SQLite database
            df.to_sql(table_name, engine, if_exists='replace', index=False)
            print(f"Saved '{table_name}' to the database.")

# %%
read_and_save_files(folder_path, db_path)
# Out:
# Saved 'Contests 20230614' to the database.
# Saved 'Contests 20230615' to the database.
# Saved 'Contests 20230616' to the database.
# Saved 'Contests 20230617' to the database.
# Saved 'Contests 20230618' to the database.
# Saved 'Contests 20230619' to the database.
# Saved 'Contests 20230620' to the database.
# Saved 'Contests 20230621' to the database.
# Saved 'Contests 20230622' to the database.
# Saved 'Contests 20230623' to the database.
# Saved 'Contests 20230624' to the database.
# Saved 'Contests 20230625' to the database.
# Saved 'Contests 20230626' to the database.
# Saved 'Contests 20230627' to the database.
# Saved 'Contests 20230628' to the database.
# Saved 'Contests 20230629' to the database.
# Saved 'Contests 20230630' to the database.
# Saved 'Contests 20230701' to the database.
# Saved 'Contests 20230702' to the database.
# Saved 'Contests 20230703' to the database.
# Saved 'Contests 20230704' to the database.
# Saved 'Contests 20230705' to the database.
# ...
