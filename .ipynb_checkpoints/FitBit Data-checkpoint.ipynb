# %%
import pandas as pd
import os

# %%
fitbit_path = r"C:\Users\james\OneDrive\Documents\Physical Activity"

df = pd.read_json(os.path.join(fitbit_path, "exercise-1400.json"))
df
# Out:
#           logId activityName  activityTypeId  \
# 0   49126927570          Run           90009
# 1   49163965109         Walk           90013
# 2   49130631460      Weights            2131
# 3   49189201406          Run           90009
# 4   49198308355      Weights            2131
# ..          ...          ...             ...
# 92  50821209372          Run           90009
# 93  50887022211      Weights            2131
# 94  50908255735         Walk           90013
# 95  50932940265          Run           90009
# 96  50957183545      Weights            2131
#
#                                         activityLevel  averageHeartRate  \
# 0   [{'minutes': 0, 'name': 'sedentary'}, {'minute...             135.0
# 1   [{'minutes': 1, 'name': 'sedentary'}, {'minute...              96.0
# 2   [{'minutes': 7, 'name': 'sedentary'}, {'minute...              87.0
# 3   [{'minutes': 0, 'name': 'sedentary'}, {'minute...             132.0
# ...
