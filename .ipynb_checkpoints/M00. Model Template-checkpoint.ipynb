# %% [markdown]
# # M00. Model Template
# - Description: This is where you write what the model does
# - Type: Model (Don't Change)
# - Run Frequency: Daily/Irregular
# - Created: MM/DD/YYYY
# - Updated: MM/DD/YYYY

# %% [markdown]
# ### Imports

# %% [markdown]
# Import packages, file paths, functions, and models

# %% [markdown]
# ### Data

# %% [markdown]
# Read in **raw** data

# %% [markdown]
# ### Clean

# %% [markdown]
# Clean raw data, ensuring compatibility for merges

# %% [markdown]
# ### Merge

# %% [markdown]
# Merge cleaned datasets

# %% [markdown]
# ### Sample

# %% [markdown]
# Select observations for use in model

# %% [markdown]
# ### Model

# %% [markdown]
# Create models

# %% [markdown]
# ##### Inputs

# %% [markdown]
# Select features and outcomes for use in model

# %% [markdown]
# ##### Train/Test Split

# %% [markdown]
# Split training and test data

# %% [markdown]
# ##### Settings

# %% [markdown]
# Define model parameters

# %% [markdown]
# ##### Train

# %% [markdown]
# Train model

# %% [markdown]
# ##### Predict

# %% [markdown]
# Predict on test data for use in evaluations

# %% [markdown]
# ### Evaluate

# %% [markdown]
# Create tables and plots for use in evaluating the effectiveness of models

# %% [markdown]
# ### Required Follow-Ups:

# %% [markdown]
# List subsequent models to run or datasets to build upon each model update
