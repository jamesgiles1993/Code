# %% [markdown]
# # 002. Night Pipeline
# - This gathers pre-contest data
# - Type: Pipeline
# - Run Frequency: Daily (Pre-Contest)
# - Created: 1/1/2025
# - Updated: 5/29/2025

# %% [markdown]
# ### Imports

# %%
import sys
if not hasattr(sys.modules['__main__'], '__file__'):
    print("Running imports...")
    # %run "C:\Users\james\Documents\MLB\Code\U1. Imports.ipynb"
    # %run "C:\Users\james\Documents\MLB\Code\U2. Utilities.ipynb"
    # %run "C:\Users\james\Documents\MLB\Code\U3. Classes.ipynb"
    # %run "C:\Users\james\Documents\MLB\Code\U4. Datasets.ipynb"
    # %run "C:\Users\james\Documents\MLB\Code\U5. Models.ipynb"
# Out:
# Running imports...
# C:\Users\james\anaconda3\lib\site-packages\pybaseball\statcast.py

# %% [markdown]
# ### Games

# %%
if not hasattr(sys.modules['__main__'], '__file__'):
    all_game_df = create_games(todaysdate, todaysdate, team_dict)
else:
    all_game_df = game_df.copy()

# %% [markdown]
# ### A01. DraftKings

# %%
draftables_only = True

# %%
print("A01. DraftKings")
print(f"draftables_only: {draftables_only}")
# Out:
# A01. DraftKings
# draftables_only: True

# %%
# %run "C:\Users\james\Documents\MLB\Code\A01. DraftKings.ipynb"
# Out:
# Saved 125244
# Saved 125241
# Saved 125138
# CPU times: total: 438 ms
# Wall time: 1.29 s
# CPU times: total: 0 ns
# Wall time: 0 ns

# %% [markdown]
# ### A04. Bullpens

# %%
game_df = all_game_df.copy()

# %%
print("A04. Bullpens:")
print("game_df")

# %%
# %run "C:\Users\james\Documents\MLB\Code\A04. Bullpens.ipynb"

# %% [markdown]
# ### A05. Rosters

# %%
game_df = all_game_df.copy()

# %%
print("A05. Rosters:")
print("game_df")

# %%
# %run "C:\Users\james\Documents\MLB\Code\A05. Rosters.ipynb"

# %% [markdown]
# ### A06. Weather

# %%
game_df = all_game_df.copy()

# %%
print("A06. Weather:")
print(f"todaysdate: {todaysdate}")
print("game_df")
# Out:
# A06. Weather:
# todaysdate: 20250529
# game_df

# %%
# %run "C:\Users\james\Documents\MLB\Code\A06. Weather.ipynb"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21052\1107194591.py in ?()
# ----> 1 game_df.dropna(subset=['location.defaultCoordinates.latitude', 'location.defaultCoordinates.longitude'], inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6666             ax = self._get_axis(agg_axis)
#    6667             indices = ax.get_indexer_for(subset)
#    6668             check = indices == -1
#    6669             if check.any():
# -> 6670                 raise KeyError(np.array(subset)[check].tolist())
#    6671             agg_obj = self.take(indices, axis=agg_axis)
#    6672
#    6673         if thresh is not lib.no_default:
#
# KeyError: ['location.defaultCoordinates.latitude', 'location.defaultCoordinates.longitude']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21052\3611988506.py in ?()
# ----> 1 get_ipython().run_line_magic('run', '"C:\\Users\\james\\Documents\\MLB\\Code\\A06. Weather-Meteo.ipynb"')
#
# ~\AppData\Local\Temp\ipykernel_21052\1107194591.py in ?()
# ----> 1 game_df.dropna(subset=['location.defaultCoordinates.latitude', 'location.defaultCoordinates.longitude'], inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6666             ax = self._get_axis(agg_axis)
#    6667             indices = ax.get_indexer_for(subset)
#    6668             check = indices == -1
#    6669             if check.any():
# -> 6670                 raise KeyError(np.array(subset)[check].tolist())
#    6671             agg_obj = self.take(indices, axis=agg_axis)
#    6672
#    6673         if thresh is not lib.no_default:
#
# KeyError: ['location.defaultCoordinates.latitude', 'location.defaultCoordinates.longitude']

# %% [markdown]
# ### A07. Projections

# %%
scrape_slates = False

# %%
print("A07. Projections:")
print(f"todaysdate: {todaysdate}")
print(f"scrape_slates: {scrape_slates}")
# Out:
# A07. Projections:
# todaysdate: 20250529
# scrape_slates: False

# %%
# %run "C:\Users\james\Documents\MLB\Code\A07. Projections.ipynb"
# Out:
# Scraping slates: False

# %% [markdown]
# ### A08. Odds Sportsbook Review

# %%
game_df = all_game_df.copy()

# %%
print("A08. Odds:")
print("game_df")
# Out:
# A08. Odds Sportsbook Review:
# game_df

# %%
# %run "C:\Users\james\Documents\MLB\Code\A08. Odds.ipynb"

# %% [markdown]
# ### A09. Contest Guides

# %%
game_df = all_game_df.copy()

# %%
print("A09. Contest Guides:")
print("game_df")
# Out:
# A09. Contest Guides:
# game_df

# %%
# %run "C:\Users\james\Documents\MLB\Code\A09. Contest Guides.ipynb"
# Out:
# 20250529
# 177252081
# 177252075
# 177252082
# 177252079
# 177252080
# 177252157
# 177252154
# 177252033
# 177252031
# 177252032

# %% [markdown]
# ### B01. Matchups

# %%
game_df = all_game_df.copy()

# %%
print("B01. Matchups:")
print("game_df")
# Out:
# B01. Matchups:
# game_df

# %%
# %run "C:\Users\james\Documents\MLB\Code\B01. Matchups.ipynb"
# Out:
# CPU times: total: 53.3 s
# Wall time: 58.4 s
# CPU times: total: 3.83 s
# Wall time: 4.03 s
# CPU times: total: 5.72 s
# Wall time: 5.78 s
# 5
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:    4.5s remaining:    6.7s
# CPU times: total: 2.88 s
# Wall time: 5.81 s
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:    5.6s finished
