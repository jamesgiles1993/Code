# %% [markdown]
# # Steamer Historical Weekly Logs <br>
# This should only need to be run once ever <br>
# It takes the Steamer Weekly Log files, which are massive csvs with a ROS projection for each player each week from 2014-2022 and then makes daily projection files from it <br>
# Daily projections use last weekly projection available <br>
# Might need to use this rest of season if I can't scrape FanGraphs <br>
#
# May have gone too far producing model inputs here. Make compatible with A5. Stats

# %%
import pandas as pd
import numpy as np
import os
import datetime

baseball_path = r"C:\Users\james\Documents\MLB\Data"

# %%
# These are the stats we need to use to project
pitcher_list = ['p_L', 'H/9', 'HR/9', 'K/9', 'BB/9']
batter_list = ['b_L', 'b1_rate', 'b2_rate', 'b3_rate', 'hr_rate', 'bb_rate', 'hbp_rate', 'so_rate']

# These are the stats we want to keep
bat_list = ['proj_date', 'mlbamid', 'steamerid', 'firstname', 'lastname', 'Team', 'position', 'bats', 'PA', 'IBB', 'NIBB', 'BB', 'K', 'HBP', 'H', '2B', '3B', 'HR', 'OBP', 'SLG', 'wOBA', 'SB', 'CS']
pitch_list = ['proj_date', 'mlbamid', 'steamerid', 'firstname', 'lastname', 'DBTeamId', 'Throws', 'IP', 'G', 'GS', 'K9', 'BB9', 'H', 'HR']

# %%
# Read in weekly log
hitters = pd.read_csv(os.path.join(baseball_path, "Steamer Weekly Log", "steamer_hitters_weekly_log.csv"))

# Seiya Suzuki wasn't appearing, so I copied his next week projection
duplicate = hitters.query('firstname == "Seiya"').query('lastname == "Suzuki"').query('proj_date == "2022-04-15"')
duplicate['proj_date'] = duplicate['proj_date'].replace("2022-04-15", "2022-04-08")
hitters = pd.concat([hitters, duplicate])
hitters.tail()
# Out:
#         proj_year  postseason   proj_date   mlbamid steamerid firstname  \
# 0            2014           0  2014-06-17  607680.0     12434     Kevin
# 1            2014           0  2014-06-17  493128.0     13047  Munenori
# 2            2014           0  2014-06-17  136660.0      1392      Mark
# 3            2014           0  2014-06-17  408314.0      1736      Jose
# 4            2014           0  2014-06-17  430832.0      1887      Jose
# ...           ...         ...         ...       ...       ...       ...
# 958117       2022           0  2022-09-30  670895.0  sa922180   Alfredo
# 958118       2022           0  2022-09-30  672350.0  sa975161     Yanio
# 958119       2022           0  2022-09-30  665983.0  sa917142    Kelvin
# 958120       2022           0  2022-09-30  666680.0  sa917167     Ruben
# 958121       2022           0  2022-09-30  670030.0  sa917991      Kole
#
#          lastname Team position bats  ...       SLG      wOBA       SB  \
# 0          Pillar  TOR       CF    R  ...  0.374338  0.298854   2.9539
# 1        Kawasaki  TOR       SS    L  ...  0.312114  0.283956   0.0187
# 2          DeRosa  TOR       2b    R  ...  0.350845  0.300232   0.0070
# 3           Reyes  TOR       SS    B  ...  0.421190  0.336366  15.0226
# 4        Bautista  TOR       RF    R  ...  0.523212  0.393728   3.2033
# ...           ...  ...      ...  ...  ...       ...       ...      ...
# 958117  Rodriguez  NaN       SS    R  ...  0.294593  0.248301   0.0085
# 958118      Perez  NaN       OF    R  ...  0.376278  0.288185   0.0151
# 958119    Alarcon  NaN       2B    B  ...  0.252480  0.225984   0.0086
# 958120    Santana  NaN       2B    B  ...  0.254236  0.221738   0.0129
# 958121    Enright  NaN       2B    B  ...  0.279482  0.232709   0.0085
#
#             CS     wSB    UBR  BaseRunning    UZR        R      RBI
# 0       1.6472 -0.0654  0.109       0.0436  0.169   9.4540   9.0755
# 1       0.0089  0.0000  0.000       0.0000  0.000   0.0994   0.0776
# 2       0.0043 -0.0005 -0.002      -0.0029  0.000   0.1040   0.0965
# 3       5.5845  0.7520  0.362       1.1136 -2.532  48.9535  34.2312
# 4       1.7708 -0.1527  0.437       0.2842 -0.951  53.0616  52.8365
# ...        ...     ...    ...          ...    ...      ...      ...
# 958117  0.0035 -0.0001  0.000       0.0009  0.000   0.0819   0.0764
# 958118  0.0062  0.0001  0.000       0.0011  0.000   0.1038   0.1059
# 958119  0.0035 -0.0001  0.000       0.0009  0.000   0.0753   0.0672
# 958120  0.0053  0.0000  0.000       0.0010  0.000   0.0747   0.0684
# 958121  0.0035 -0.0001  0.000       0.0009  0.000   0.0816   0.0798
#
# [958122 rows x 40 columns]

# %%
def clean_hitters(df, bat_list, year, start_month, start_day, end_month, end_day):
    # Keep relevant year and variables
    df = df[df['proj_year'] == year][bat_list]
    
    # These are just the variables we need in the model. This list is just for reference
    batter_list = ['b_L', 'b1_rate', 'b2_rate', 'b3_rate', 'hr_rate', 'bb_rate', 'hbp_rate', 'so_rate']
    
    df['playerid'] = df['steamerid']
    df.rename(columns={'K':'SO'}, inplace=True)
    
    df['Name'] = df['firstname'] + " " + df['lastname']
    
    # Create model inputs
    # df['b_L'] = (df['bats'] == "L").astype('int')
    # df['b1_rate'] = df['1B'] / df['PA']
    # df['b2_rate'] = df['2B'] / df['PA']
    # df['b3_rate'] = df['3B'] / df['PA']
    # df['hr_rate'] = df['HR'] / df['PA']
    # df['bb_rate'] = df['BB'] / df['PA']
    # df['hbp_rate'] = df['HBP'] / df['PA']
    # df['so_rate'] = df['K'] / df['PA']
    
    # Loop over all dates in range
    # Date ranges
    start_date = datetime.date(year, start_month, start_day)
    end_date = datetime.date(year, end_month, end_day)
    
    # Delta time
    delta = datetime.timedelta(days = 1)
    # Loop over time
    while (start_date <= end_date):

        # Destination file name
        file_date = str(start_date).replace("-", "")
        file_name = "Batters_FG_" + file_date + ".csv"
        # If the date has a corresponding projection in the big dateframe
        if str(start_date) in df['proj_date'].unique():
            # Print date
            print(str(start_date))
            # Print if date has a unique projection
            print("Projection")
            
            # Make new dateframe
            weekly = df[df['proj_date'] == str(start_date)]
            
        # If it doesn't
        else:
            # Print date
            print(str(start_date))
            # Print if that date has a unique projection
            print("No projection")
            # Export existing dataframe
            
        # Export
        weekly.to_csv(os.path.join(baseball_path, "FanGraphs", "Batters", file_name), encoding='iso-8859-1')
        
        # Go to next date
        start_date += delta
    
    return df

# %%
hitters_clean = clean_hitters(hitters, bat_list, 2022, 4, 8, 11, 1)
# Out:
# 2022-04-08
# 2022-04-08
# Projection
# 2022-04-09
# No projection
# 2022-04-10
# No projection
# 2022-04-11
# No projection
# 2022-04-12
# No projection
# 2022-04-13
# No projection
# 2022-04-14
# No projection
# 2022-04-15
# Projection
# 2022-04-16
# No projection
# 2022-04-17
# No projection
# 2022-04-18
# No projection
# 2022-04-19
# No projection
# 2022-04-20
# No projection
# 2022-04-21
# No projection
# 2022-04-22
# Projection
# 2022-04-23
# No projection
# 2022-04-24
# No projection
# 2022-04-25
# No projection
# 2022-04-26
# No projection
# 2022-04-27
# No projection
# 2022-04-28
# No projection
# 2022-04-29
# Projection
# 2022-04-30
# No projection
# 2022-05-01
# No projection
# 2022-05-02
# No projection
# 2022-05-03
# No projection
# 2022-05-04
# No projection
# 2022-05-05
# No projection
# 2022-05-06
# Projection
# 2022-05-07
# No projection
# 2022-05-08
# No projection
# 2022-05-09
# No projection
# 2022-05-10
# No projection
# 2022-05-11
# No projection
# 2022-05-12
# No projection
# No projection
# 2022-09-12
# No projection
# 2022-09-13
# No projection
# 2022-09-14
# No projection
# 2022-09-15
# No projection
# 2022-09-16
# Projection
# 2022-09-17
# No projection
# 2022-09-18
# No projection
# 2022-09-19
# No projection
# 2022-09-20
# No projection
# 2022-09-21
# No projection
# 2022-09-22
# No projection
# 2022-09-23
# Projection
# 2022-09-24
# No projection
# 2022-09-25
# No projection
# 2022-09-26
# No projection
# 2022-09-27
# No projection
# 2022-09-28
# No projection
# 2022-09-29
# No projection
# 2022-09-30
# Projection
# 2022-10-01
# No projection
# 2022-10-02
# No projection
# 2022-10-03
# No projection
# 2022-10-04
# No projection
# 2022-10-05
# No projection
# 2022-10-06
# No projection
# 2022-10-07
# No projection
# 2022-10-08
# No projection
# 2022-10-09
# No projection
# 2022-10-10
# No projection
# 2022-10-11
# No projection
# 2022-10-12
# No projection
# 2022-10-13
# No projection
# 2022-10-14
# No projection
# 2022-10-15
# No projection
# 2022-10-16
# No projection
# 2022-10-17
# No projection
# 2022-10-18
# No projection
# 2022-10-19
# No projection
# 2022-10-20
# No projection
# 2022-10-21
# No projection
# 2022-10-22
# No projection
# 2022-10-23
# No projection
# 2022-10-24
# No projection
# 2022-10-25
# No projection
# 2022-10-26
# No projection
# 2022-10-27
# No projection
# 2022-10-28
# No projection
# 2022-10-29
# No projection
# 2022-10-30
# No projection
# 2022-10-31
# No projection
# 2022-11-01
# No projection

# %%
# Read in weekly log
pitchers = pd.read_csv(os.path.join(baseball_path, "Steamer Weekly Log", "steamer_pitchers_weekly_log.csv"))

# %%
# pitch_list = ['proj_date', 'mlbamid', 'steamerid', 'firstname', 'lastname', 'DBTeamId', 'Throws', 'IP', 'G', 'GS', 'K9', 'BB9', 'HR9', 'H']
def clean_pitchers(df, pitch_list, year, start_month, start_day, end_month, end_day):
    # Keep relevant year and variables
    df = df[df['proj_year'] == year][pitch_list]
    # These are just the variables we need in the model. This list is just for reference
    pitcher_list = ['p_L', 'H/9', 'HR/9', 'K/9', 'BB/9']
    
    # Create model inputs
#     df['p_L'] = (df['Throws'] == "L").astype('int')
#     df['H/9'] = df['H'] / df['IP'] * 9 
#     df['HR/9'] = df['HR9']
#     df['K/9'] = df['K9']
#     df['BB/9'] = df['BB9']
    
    df['playerid'] = df['steamerid']
    df['Name'] = df['firstname'] + " " + df['lastname']
    
    df.rename(columns={'K9':'K/9', 'BB9':'BB/9'}, inplace=True)
    
    # Loop over all dates in range
    # Date ranges
    start_date = datetime.date(year, start_month, start_day)
    end_date = datetime.date(year, end_month, end_day)
    
    # Delta time
    delta = datetime.timedelta(days = 1)
    
    # Loop over time
    while (start_date <= end_date):

        # Destination file name
        file_date = str(start_date).replace("-", "")
        file_name = "Pitchers_FG_" + file_date + ".csv"
        
        # If the date has a corresponding projection in the big dateframe
        if str(start_date) in df['proj_date'].unique():
            # Print date
            print(str(start_date))
            # Print if date has a unique projection
            print("Projection")
            
            # Make new dateframe
            weekly = df[df['proj_date'] == str(start_date)]
            
        # If it doesn't
        else:
            # Print date
            print(str(start_date))
            # Print if that date has a unique projection
            print("No projection")
            # Export existing dataframe
            
        # Export
        weekly.to_csv(os.path.join(baseball_path, "FanGraphs", "Pitchers", file_name), encoding='iso-8859-1')
        
        # Go to next date
        start_date += delta
    
    return df

# %%
pitchers_clean = clean_pitchers(pitchers, pitch_list, 2022, 9, 9, 11, 1)
