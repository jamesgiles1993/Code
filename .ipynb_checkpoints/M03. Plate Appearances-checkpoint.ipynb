# %% [markdown]
# # M03. Predict PAs
# - This predicts the outcome of plate appearances
# - Type: Model
# - Run Frequency: Irregular
# - Sources:
#     - MLB API
#     - Steamer
# - Dates:
#     - Created: 4/19/2024
#     - Updated: 4/21/2024

# %% [markdown]
# ### Imports

# %%
# %run "U1. Imports.ipynb"
# %run "U2. Utilities.ipynb"
# %run "U3. Classes.ipynb"
# %run "U4. Datasets.ipynb"
# %run "U5. Models.ipynb"

# %%
# Set option to display numbers without scientific notation
pd.set_option('display.float_format', '{:.6f}'.format)

# %% [markdown]
# ### Data

# %% [markdown]
# ##### Park x Weather Factors

# %%
multiplier_df = pd.read_csv(os.path.join(baseball_path, "Multiplier Dataset.csv"))

# %% [markdown]
# ##### Stats API and Statcast Data

# %% [markdown]
# Create dataset

# %%
# %%time
# complete_dataset = create_pa_inputs(multiplier_df, 2015, 2024, short=50, long=300, adjust=True)

# %% [markdown]
# Write to CSV

# %%
# complete_dataset.to_csv(os.path.join(baseball_path, "nn_dataset.csv"), index=False)

# %% [markdown]
# Read CSV

# %%
complete_dataset = pd.read_csv(os.path.join(baseball_path, "nn_dataset.csv"))

# %% [markdown]
# Scale

# %%
# %%time
complete_dataset[batter_inputs] = scale_batter_stats.transform(complete_dataset[batter_inputs])
complete_dataset[pitcher_inputs] = scale_pitcher_stats.transform(complete_dataset[pitcher_inputs])
# Out:
# CPU times: total: 1.92 s
# Wall time: 1.98 s

# %% [markdown]
# ##### Steamer

# %% [markdown]
# Read in hitters

# %%
steamer_hitters_df = pd.read_csv(os.path.join(baseball_path, "A03. Steamer", "steamer_hitters_weekly_log.csv"), encoding='iso-8859-1')

# %% [markdown]
# Clean

# %%
steamer_hitters_df2 = clean_steamer_hitters(steamer_hitters_df)
steamer_hitters_df2.dropna(subset=batter_stats_fg, inplace=True)
steamer_hitters_df2[batter_stats_fg] = scale_batter_stats_steamer.transform(steamer_hitters_df2[batter_stats_fg])

# %% [markdown]
# Scale

# %%
steamer_hitters_df2[batter_stats_fg] = scale_batter_stats_steamer.transform(steamer_hitters_df2[batter_stats_fg])

# %% [markdown]
# Read in pitchers

# %%
steamer_pitchers_df = pd.read_csv(os.path.join(baseball_path, "A03. Steamer", "steamer_pitchers_weekly_log.csv"), encoding='iso-8859-1')

# %% [markdown]
# Clean

# %%
steamer_pitchers_df2 = clean_steamer_pitchers(steamer_pitchers_df)
steamer_pitchers_df2.dropna(subset=pitcher_stats_fg2, inplace=True)

# %% [markdown]
# Scale

# %%
steamer_pitchers_df2[pitcher_stats_fg] = scale_pitcher_stats_steamer.transform(steamer_pitchers_df2[pitcher_stats_fg])

# %% [markdown]
# ##### Merge

# %% [markdown]
# Format dates

# %%
complete_dataset['date_time'] = pd.to_datetime(complete_dataset['date'], format='%Y%m%d')
complete_dataset['date_time_copy'] = complete_dataset['date_time'].copy()
steamer_hitters_df2['date_time'] = pd.to_datetime(steamer_hitters_df2['date'], format='%Y%m%d')
steamer_pitchers_df2['date_time'] = pd.to_datetime(steamer_pitchers_df2['date'], format='%Y%m%d')

steamer_hitters_df2.rename(columns={'mlbamid': 'batter'}, inplace=True)
steamer_pitchers_df2.rename(columns={'mlbamid': 'pitcher'}, inplace=True)

# %% [markdown]
# Sort to prep for merge

# %%
complete_dataset.sort_values('date_time', inplace=True)
steamer_hitters_df2.sort_values('date_time', inplace=True)
steamer_pitchers_df2.sort_values('date_time', inplace=True)

# %% [markdown]
# Drop unnecessary columns

# %%
steamer_hitters_df2.drop(columns=['date', 'firstname', 'lastname', 'steamerid'], inplace=True)
steamer_pitchers_df2.drop(columns=['date', 'firstname', 'lastname', 'steamerid'], inplace=True)

# %% [markdown]
# Remove missing pitchers (occurs occassionally in 2014)

# %%
steamer_pitchers_df2 = steamer_pitchers_df2[~steamer_pitchers_df2['pitcher'].isna()].reset_index(drop=True)

# %% [markdown]
# Set data types

# %%
complete_dataset['batter'] = complete_dataset['batter'].astype(int).astype(str)
complete_dataset['pitcher'] = complete_dataset['pitcher'].astype(int).astype(str)
steamer_hitters_df2['batter'] = steamer_hitters_df2['batter'].astype(int).astype(str)
steamer_pitchers_df2['pitcher'] = steamer_pitchers_df2['pitcher'].astype(int).astype(str)

# %% [markdown]
# Merge asof most recent date in Steamer

# %%
complete_merged_df = pd.merge_asof(
    complete_dataset,
    steamer_hitters_df2,
    on='date_time',
    by='batter',  # Group by 'batter'
    direction='backward'  # Use 'backward', 'forward', or 'nearest' as appropriate
)
# Correct datetime (might be unnecessary, but I'm not sure which date_time it takes after the merge)
complete_merged_df['date_time'] = complete_merged_df['date_time_copy'].copy()

complete_merged_df = pd.merge_asof(
    complete_merged_df,
    steamer_pitchers_df2,
    on='date_time',
    by='pitcher',  # Group by 'batter'
    direction='backward'  # Use 'backward', 'forward', or 'nearest' as appropriate
)

# %% [markdown]
# ##### Impute

# %% [markdown]
# For players with insufficient sample sizes, stats are imputed

# %% [markdown]
# Option 1: Steamer

# %% [markdown]
# First, remove from dataset if ever missing FG/Steamer stats

# %%
complete_merged_df = complete_merged_df[~complete_merged_df['b1_rate'].isna()]
complete_merged_df = complete_merged_df[~complete_merged_df['H9'].isna()]

# %%
# Add hands to use in imputation
batter_stats_fg_imp = batter_stats_fg + ['b_L', 'p_L']
pitcher_stats_fg_imp = pitcher_stats_fg + ['b_L', 'p_L']

### Batters
# Use Steamer stats to predict API/Statcast stats for those with limited samples
batter_predictions = impute_batter_stats.predict(complete_merged_df.loc[complete_merged_df['pa_b'] < 40, batter_stats_fg_imp])

# Impute inputs with limited sample size with predicted values
complete_merged_df.loc[complete_merged_df['pa_b'] < 40, batter_inputs] = batter_predictions

### Pitchers
# Use Steamer stats to predict API/Statcast stats for those with limited samples
pitcher_predictions = impute_pitcher_stats.predict(complete_merged_df.loc[complete_merged_df['pa_p'] < 40, pitcher_stats_fg_imp])

# Impute inputs with limited sample size with predicted values
complete_merged_df.loc[complete_merged_df['pa_p'] < 40, pitcher_inputs] = pitcher_predictions

# %% [markdown]
# Option 2: 0s

# %%
# # Testing instead of imputing, just weighting with 0s
# complete_merged_df[batter_inputs].fillna(0, inplace=True)
# complete_merged_df[pitcher_inputs].fillna(0, inplace=True)

# # Calculate the weighted average for each column in pitcher_stats
# # Could be simplified, but I wanted to show the steps
# # Weighted average of provided value and 0. PAs and 50-PAs are weights. 
# for col in batter_inputs:
#     complete_merged_df[col] = (complete_merged_df[col] * complete_merged_df['pa_b'] + 0 * (50-complete_merged_df['pa_b']))/50

# # Calculate the weighted average for each column in pitcher_stats
# for col in pitcher_inputs:
#     complete_merged_df[col] = (complete_merged_df[col] * complete_merged_df['pa_p'] + 0 * (50-complete_merged_df['pa_p']))/50

# %% [markdown]
# ### Select Data

# %% [markdown]
# Drop early observations

# %%
complete_merged_df = complete_merged_df[complete_merged_df['game_date'] > '2015-07-01']

# %% [markdown]
# Drop atypical events

# %%
complete_merged_df = complete_merged_df.query('eventsModel != "Cut"')

# %% [markdown]
# Drop observations from inactive parks

# %%
active_parks = list(team_map['VENUE_ID'].astype(int))
complete_merged_df = complete_merged_df[complete_merged_df['venue_id'].astype(int).isin(active_parks)]

# %% [markdown]
# Venue dummies

# %%
complete_merged_df['venue_id2'] = complete_merged_df['venue_id'].copy()
complete_merged_df = pd.get_dummies(complete_merged_df, columns=['venue_id2'], prefix='venue')

# %%
venue_dummy_list = [col for col in complete_merged_df.columns if col.startswith("venue_") and col != "venue_id"]

# %% [markdown]
# Park x weather multiplier

# %%
for event in events_list:
    # Assign multiplier for their 
    complete_merged_df[f'{event}_wfx'] = np.where(complete_merged_df['batSide'] == "L", complete_merged_df[f'{event}_wfx_l'], complete_merged_df[f'{event}_wfx_r'])

# %%
multiplier_inputs = [f'{event}_wfx' for event in events_list]

# %% [markdown]
# Leading dummies

# %%
complete_merged_df['winning'] = (complete_merged_df['preBatterScore'] > complete_merged_df['prePitcherScore']).astype(int)
complete_merged_df['winning_big'] = (complete_merged_df['preBatterScore'] > complete_merged_df['prePitcherScore'] + 3).astype(int)

# %% [markdown]
# Inning dummies

# %%
for inning in range(1, 12):
    complete_merged_df[f'inning_{inning}'] = (complete_merged_df['inning'] == inning).astype(int)
complete_merged_df['inning_11'] = (complete_merged_df['inning'] >= 11).astype(int)

# %%
inning_dummy_list = [col for col in complete_merged_df.columns if col.startswith("inning_")]

# %% [markdown]
# Out dummies

# %%
# complete_merged_df[['description', 'outs', 'outs_pre', 'outs_pa', 'outs_pa_inning', 'outs_0', 'outs_1', 'outs_2']].head()

# %%
for out in range(0, 3):
    complete_merged_df[f'outs_{out}'] = (complete_merged_df['outs_pre'] == out).astype(int)

# %%
out_dummy_list = ['outs_0', 'outs_1', 'outs_2']

# %% [markdown]
# Cumulative variables

# %%
cumulative_inning_list = [col for col in complete_merged_df.columns if col.endswith("_inning")]

# %%
cumulative_inning_list.remove('rbi_inning')

# %%
cumulative_game_list = [col for col in complete_merged_df.columns if col.endswith("_game")]

# %%
cumulative_game_list.remove('rbi_game')

# %% [markdown]
# All Test Inputs

# %%
test_inputs = ['prePitcherScore', 'preBatterScore', 'winning', 'winning_big', 'times_faced'] + cumulative_inning_list + cumulative_game_list + venue_dummy_list + inning_dummy_list + out_dummy_list

# %% [markdown]
# ### Shift

# %% [markdown]
# Many batter and pitcher stats are calculated at the end of the plate appearance. For prediction purposes, we need these stats coming into the plate appearance.

# %% [markdown]
# ##### Batter Inputs

# %% [markdown]
# Sort

# %%
complete_merged_df.sort_values(['date', 'gamePk', 'atBatIndex'], ascending=True, inplace=True)

# %% [markdown]
# Shift

# %%
complete_merged_df[batter_inputs + ['ab_b', 'pa_b', 'imp_b']] = complete_merged_df.groupby(['batter', 'pitchHand'])[batter_inputs + ['ab_b', 'pa_b', 'imp_b']].shift(1)

# %% [markdown]
# ##### Pitcher Inputs

# %% [markdown]
# Sort

# %%
complete_merged_df.sort_values(['date', 'gamePk', 'atBatIndex'], ascending=True, inplace=True)

# %% [markdown]
# Shift

# %%
complete_merged_df[pitcher_inputs + ['ab_p', 'pa_p', 'imp_p']] = complete_merged_df.groupby(['pitcher', 'batSide'])[pitcher_inputs + ['ab_p', 'pa_p', 'imp_p']].shift(1)

# %% [markdown]
# ##### Inning Sums

# %% [markdown]
# Sort

# %%
complete_merged_df.sort_values(['date', 'gamePk', 'atBatIndex'], ascending=True, inplace=True)

# %% [markdown]
# Shift

# %%
complete_merged_df[cumulative_inning_list] = complete_merged_df.groupby(['gamePk', 'inning', 'pitcher'])[cumulative_inning_list].shift(1)
complete_merged_df[cumulative_inning_list] = complete_merged_df[cumulative_inning_list].fillna(0)

# %% [markdown]
# ##### Game Sums

# %% [markdown]
# Sort

# %%
complete_merged_df[cumulative_game_list + ['times_faced']] = complete_merged_df.groupby(['gamePk', 'pitcher'])[cumulative_game_list + ['times_faced']].shift(1)

# %% [markdown]
# Shift

# %%
complete_merged_df[cumulative_game_list + ['times_faced']] = complete_merged_df[cumulative_game_list + ['times_faced']].fillna(0)

# %%
# complete_merged_df.query('date == 20240403').query('halfInning == "top"')[['gamePk', 'inning', 'inning_1', 'inning_2', 'outs_0', 'outs_1', 'outs_2', 'pitcherName', 'batterName', 'eventsModel', 'times_faced', 'faced_inning', 'faced_game', 'preBatterScore']].head(50)

# %% [markdown]
# ### Select Variables

# %%
pa_inputs2 = batter_inputs + pitcher_inputs + hand_inputs + game_state_inputs + imp_inputs + starter_inputs + multiplier_inputs + test_inputs
keep_list = pa_inputs2 + ['pa_b', 'pa_p', 'year', 'venue_id', 'is_out', 'eventsModel', 'batterName', 'pitcherName']

# %%
# Keep relevant variables
model_dataset = complete_merged_df[keep_list]
# Drop if missing information
model_dataset.dropna(subset=pa_inputs2, inplace=True)
model_dataset.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Train/Test Split

# %% [markdown]
# Split

# %%
np.random.seed(42)
model_dataset['split'] = np.random.choice([0, 0, 1], size=len(model_dataset))

# %% [markdown]
# Create masks to identify training and testing datasets

# %% [markdown]
# Note: to train on the entire dataset, you can simply set split = 0 for the entire dataset

# %%
training_mask = (model_dataset['split'] == 0)
testing_mask = (model_dataset['split'] == 1)

# training_out_mask = (model_dataset['is_out'] == 1) & (model_dataset['split'] == 0)
# testing_out_mask = (model_dataset['is_out'] == 1) & (model_dataset['split'] == 1)

# training_safe_mask = (model_dataset['is_out'] == 0) & (model_dataset['split'] == 0)
# testing_safe_mask = (model_dataset['is_out'] == 0) & (model_dataset['split'] == 1)

# %% [markdown]
# Free up memory

# %%
del complete_merged_df, complete_dataset, steamer_hitters_df, steamer_hitters_df2, steamer_pitchers_df, steamer_pitchers_df2, multiplier_df,  batter_predictions, pitcher_predictions

# %% [markdown]
# ### Outs vs. Safe

# %%
len(pa_inputs2)

# %%
# Train a single model
def train_model(i, training_dataset, pa_inputs2, target, layers, activation, alpha, learning_rate, early_stopping, random_state, iters, batch_size):
    model = MLPClassifier(
        hidden_layer_sizes=layers,
        activation=activation,
        verbose=False,
        alpha=alpha,
        learning_rate_init=learning_rate,
        early_stopping=early_stopping,
        random_state=random_state + i,
        max_iter=iters,
        batch_size=batch_size
    )
    model.fit(training_dataset[pa_inputs2], training_dataset[target].values.ravel())
    return model

# %%
# Neural Network Layers
layers = (196,196,196)


# To string
layers_str = ''.join(str(x) for x in layers)
binary_filename = f"predict_binary_{layers_str}_{todaysdate}.sav"
print(binary_filename)

activation='relu' # Other models have been deemed worse than relu
iters = 100
learning_rate = 0.00001
alpha = 0.0001
early_stopping = True
random_state = 100
batch_size='auto'
# batch_size = 32
number_of_models = 16

# %%
##### %%time
# List to store model performance stats
model_stats = []
model_list = []

for i in range(number_of_models):
    # Train the model
    model = train_model(i, model_dataset[training_mask], pa_inputs2, 'is_out', layers, activation, alpha, learning_rate, early_stopping, random_state, iters, batch_size)
    model_list.append(model)
    
    # Predict probabilities
    model_dataset.loc[testing_mask, [f'model_{i}_is_safe_pred', f'model_{i}_is_out_pred']] = model.predict_proba(model_dataset.loc[testing_mask, pa_inputs2].astype(float))

    # Create decile column for current model
    model_dataset.loc[testing_mask, f'model_{i}_decile'] = pd.qcut(model_dataset[testing_mask][f'model_{i}_is_out_pred'], 20, labels=False)

    # Group by decile
    df = model_dataset[testing_mask].groupby(f'model_{i}_decile')[[f'model_{i}_is_out_pred', 'is_out']].mean().reset_index()

    # Calculate projected mean
    pred_mean = df[f'model_{i}_is_out_pred'].mean()
    
    # Calculate actual mean
    act_mean = df['is_out'].mean()
    
    # Calculate mean squared error
    df['error_sq'] = (df[f'model_{i}_is_out_pred'] - df['is_out']) ** 2
    mse = np.mean(df['error_sq'])

    
    # Calculate difference from mean
    df['diff_mean'] = abs(df[f'model_{i}_is_out_pred'] - pred_mean)
    diff_mean = df['diff_mean'].sum()
    

    # Append model stats
    model_stats.append({'model': f'model_{i}', 'index': i, 'mean': act_mean, 'predicted': pred_mean, 'mse': mse, 'diff_mean': diff_mean})
    
                        
    # Graph results
    plt.figure(figsize=(6, 6))  # Make the figure square
    plt.plot(df[f'model_{i}_is_out_pred'], df['is_out'], marker='o', color='black', label='is_out')
    plt.plot(df[f'model_{i}_is_out_pred'], df[f'model_{i}_is_out_pred'], linestyle='--', color='red', label='Ideal')

    # Set limits for both axes
    plt.xlim(.6, .75)
    plt.ylim(.6, .75)

    # plt.xlim(0, 1)
    # plt.ylim(0, 1)

    # Make the aspect ratio equal
    plt.gca().set_aspect('equal', adjustable='box')

    plt.xlabel('Predicted Probability of Out')
    plt.ylabel('Actual Probability of Out')
    plt.title(f'Model {i}: Decile Analysis')
    plt.legend()
    plt.grid()
    plt.show()
                        
    # Print out stats
    print(f"model_{i}", f"index: {i}", f"mean: {act_mean}", f"predicted: {pred_mean}", f"MSE: {mse}", f"Integral: {diff_mean}")
    print("\n")

# %%
# Identify Pareto-optimal models
pareto_optimal = []
for current in model_stats:
    dominated = False
    for other in model_stats:
        if (
            other['mse'] <= current['mse'] and 
            other['diff_mean'] >= current['diff_mean'] and 
            (other['mse'] < current['mse'] or other['diff_mean'] > current['diff_mean'])
        ):
            dominated = True
            break
    if not dominated:
        pareto_optimal.append(current)
        
# Output Pareto-optimal models
print("\nPareto-optimal models:")
for stats in pareto_optimal:
    print(f"Model: {stats['model']}, Mean: {stats['mean']}, Predicted: {stats['predicted']}, Multiplier : {stats['mean'] / stats['predicted']}, MSE: {stats['mse']}, Diff Mean: {stats['diff_mean']:.4f}")

# %%
# 10 relu
mses = []
diff_means = []

for model in model_stats:
    diff_means.append(model['diff_mean'])
    mses.append(model['mse'])
    
np.mean(diff_means), np.mean(mses)

# %%
pickle.dump(model_list[0], open(os.path.join(model_path, "M03. Plate Appearances", binary_filename), 'wb'))
binary_filename

# %%
model_dataset[testing_mask].query('year == 2024')[['is_out', 'model_14_is_out_pred']].mean()

# %% [markdown]
# ### Outs

# %%
# %%time
# Neural network layerss
layers = (10,)
# To string
layers_str = ''.join(str(x) for x in layers)
# Activation method
activation = 'relu'
# Iterations
iters = 100

outs_filename = f"predict_outs_{layers_str}_{todaysdate}.sav"
print(outs_filename)

# Define the individual models in the ensemble
models = [
    MLPClassifier(hidden_layer_sizes=layers, activation='relu', random_state=1, early_stopping=True, learning_rate_init=0.00001, alpha=0.00001, max_iter=iters),
    MLPClassifier(hidden_layer_sizes=layers, activation='relu', random_state=2, early_stopping=True, learning_rate_init=0.00001, alpha=0.00001, max_iter=iters),
    MLPClassifier(hidden_layer_sizes=layers, activation='relu', random_state=3, early_stopping=True, learning_rate_init=0.00001, alpha=0.00001, max_iter=iters),

]

# Create the ensemble classifier using VotingClassifier
predict_outs = VotingClassifier(estimators=[('model'+str(i+1), model) for i, model in enumerate(models)], voting='soft', n_jobs=-2).fit(model_dataset[training_out_mask].reset_index(drop=True)[pa_inputs2], model_dataset[training_out_mask][['eventsModel']].values.ravel())

# Save model
pickle.dump(predict_outs, open(os.path.join(model_path, "M03. Plate Appearances", outs_filename), 'wb'))

# %%
# Predict out types
outs_outputs = list(predict_outs.classes_)
outs_outputs_pred = [x + "_pred" for x in outs_outputs]

model_dataset.loc[testing_out_mask, outs_outputs_pred] = predict_outs.predict_proba(model_dataset[testing_out_mask][pa_inputs2])

# %%
# Create deciles
for var in outs_outputs:
    # Create actual outcome column
    model_dataset.loc[testing_out_mask, f'{var}_act'] = (model_dataset.loc[testing_out_mask, 'eventsModel'] == var).astype(int)
    
    # Create deciles
    model_dataset.loc[testing_out_mask, f'{var}_decile'] = pd.qcut(model_dataset.loc[testing_out_mask, f'{var}_pred'], 10, labels=False)
    
    # Create aggregated dataframe
    globals()[f"{var}_df"] = model_dataset.loc[testing_out_mask].groupby(f'{var}_decile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()
    # globals()[f"{var}_df"] = testing_dataset.query('year >= 2022').loc[mask].groupby(f'{var}_decile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()
    # globals()[f"{var}_df"] = testing_dataset.query('venue_id == 19').loc[mask].groupby(f'{var}_decile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()

# %%
# Create figures
fig, axs = plt.subplots(2, 3, figsize=(12, 8))

for i, var in enumerate(outs_outputs):
    row = i // 3  # Calculate the row index based on the iteration
    col = i % 3   # Calculate the column index based on the iteration
    axs[row, col].plot(globals()[f"{var}_df"][f'{var}_decile'], globals()[f"{var}_df"][f'{var}_pred'], color='red')
    axs[row, col].plot(globals()[f"{var}_df"][f'{var}_decile'], globals()[f"{var}_df"][f'{var}_act'], color='black')
    axs[row, col].set_title(var)
    # axs[row, col].set_ylim(0,0.35)


# Add some space between subplots to prevent overlapping
fig.tight_layout(pad=.0)

# Show the figure
plt.show()

# %% [markdown]
# ### Safe

# %%
# %%time
# Neural network layers
# layers = (174,174,174,174)
# layers = (10,)
# layers = (198,198,198,198,198,198)
layers = (196,196,196,196,196)
# To string
layers_str = ''.join(str(x) for x in layers)
# Activation method
activation = 'relu'
# Iterations
iters = 100
# Alpha
alpha = 0.0001
# Learning Rate
learning_rate = 0.00001
# Batch Size
batch_size='auto'
# batch_size=32
# Random state
random_state = 10
# Number of models
num_models = 3

safe_filename = f"predict_safe_{layers_str}_{todaysdate}.sav"
print(safe_filename)



# Define the individual models in the ensemble
models = [
    MLPClassifier(hidden_layer_sizes=layers, activation=activation, verbose=True, alpha=alpha, learning_rate_init=learning_rate, early_stopping=True, random_state=random_state+i, max_iter=iters, batch_size=batch_size)
    for i in range(num_models)
]

# Create the ensemble classifier using VotingClassifier
predict_safe = VotingClassifier(estimators=[('model'+str(i+1), model) for i, model in enumerate(models)], voting='soft', n_jobs=-2).fit(model_dataset[training_safe_mask][pa_inputs2], model_dataset[training_safe_mask][['eventsModel']].values.ravel())

# Save model
pickle.dump(predict_safe, open(os.path.join(model_path, "M03. Plate Appearances", safe_filename), 'wb'))

# %%
# Predict safe types
safe_outputs = list(predict_safe.classes_)
safe_outputs_pred = [x + "_pred" for x in safe_outputs]

model_dataset.loc[testing_safe_mask, safe_outputs_pred] = predict_safe.predict_proba(model_dataset[testing_safe_mask][pa_inputs2])

# %%
# Create deciles
for var in safe_outputs:    
    # Create actual outcome column
    model_dataset.loc[testing_safe_mask, f'{var}_act'] = (model_dataset.loc[testing_safe_mask, 'eventsModel'] == var).astype(int)
    
    # Create deciles
    model_dataset.loc[testing_safe_mask, f'{var}_decile'] = pd.qcut(model_dataset.loc[testing_safe_mask, f'{var}_pred'], 10, labels=False)
    
    # Create aggregated dataframe
    globals()[f"{var}_df"] = model_dataset.loc[testing_safe_mask].groupby(f'{var}_decile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()
    globals()[f"{var}_df"] = model_dataset.query('year >= 2022').loc[testing_safe_mask].groupby(f'{var}_decile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()
    # globals()[f"{var}_df"] = model_dataset.query('venue_id == 19').loc[testing_safe_mask].groupby(f'{var}_decile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()

# %%
# Create figures
fig, axs = plt.subplots(2, 3, figsize=(12, 8))

for i, var in enumerate(safe_outputs):
    row = i // 3  # Calculate the row index based on the iteration
    col = i % 3   # Calculate the column index based on the iteration
    axs[row, col].plot(globals()[f"{var}_df"][f'{var}_decile'], globals()[f"{var}_df"][f'{var}_act'], color='black')
    axs[row, col].plot(globals()[f"{var}_df"][f'{var}_decile'], globals()[f"{var}_df"][f'{var}_pred'], color='red')
    axs[row, col].set_title(var)
    # axs[row, col].set_ylim(globals()[df_name][f'{var}_act'].min(),globals()[df_name][f'{var}_act'].max())
    

# Add some space between subplots to prevent overlapping
fig.tight_layout(pad=.0)

# Show the figure
plt.show()

# %% [markdown]
# ### All

# %%
# %%time
# Neural network layers
layers = (196,196,196,196,196,196)
layers = (10,)
# To string
layers_str = ''.join(str(x) for x in layers)
# Activation method
activation = 'relu'
# Iterations
iters = 100
# Alpha
alpha = 0.0001
# Learning Rate
learning_rate = 0.00001
# Batch Size
batch_size='auto'
# batch_size=32
# Random state
random_state = 10000
# Number of models
num_models = 5

all_filename = f"predict_all_{layers_str}_{todaysdate}.sav"
print(all_filename)


# Define the individual models in the ensemble
models = [
    MLPClassifier(hidden_layer_sizes=layers, activation=activation, verbose=True, alpha=alpha, learning_rate_init=learning_rate, early_stopping=True, 
                  random_state=random_state+i, max_iter=iters, batch_size=batch_size)
    for i in range(num_models)]

# Create the ensemble classifier using VotingClassifier
predict_all = VotingClassifier(estimators=[('model'+str(i+1), model) for i, model in enumerate(models)], voting='soft', n_jobs=-2).fit(model_dataset[training_mask][pa_inputs2], model_dataset[training_mask][['eventsModel']].values.ravel())

# Save model
pickle.dump(predict_all, open(os.path.join(model_path, "M03. Plate Appearances", all_filename), 'wb'))
# Out:
# predict_all_10_20250129.sav
# CPU times: total: 5.06 s
# Wall time: 6min 11s

# %%
# %%time
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression

# Neural network layers
layers = (196,196,196,196,196,196)
layers = (10,)
# To string
layers_str = ''.join(str(x) for x in layers)
# Activation method
activation = 'relu'
# Iterations
iters = 100
# Alpha
alpha = 0.0001
# Learning Rate
learning_rate = 0.00001
# Batch Size
batch_size='auto'
# batch_size=32
# Random state
random_state = 100000
# Number of models
num_models = 3

all_filename = f"predict_all_{layers_str}_{todaysdate}.sav"
print(all_filename)


# Define the individual models in the ensemble
models = [
    MLPClassifier(hidden_layer_sizes=layers, activation=activation, verbose=True, alpha=alpha, learning_rate_init=learning_rate, early_stopping=True, 
                  random_state=random_state+i, max_iter=iters, batch_size=batch_size)
    for i in range(num_models)]

# Define the meta-model
meta_model = LogisticRegression()

# Create the ensemble classifier using StackingClassifier
predict_all = StackingClassifier(
    estimators=[('model'+str(i+1), model) for i, model in enumerate(models)], 
    final_estimator=meta_model, 
    n_jobs=-2
).fit(model_dataset[training_mask][pa_inputs2], model_dataset[training_mask][['eventsModel']].values.ravel())

# Save model
pickle.dump(predict_all, open(os.path.join(model_path, "M03. Plate Appearances", all_filename), 'wb'))
# Out:
# predict_all_10_20250129.sav
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\joblib\_parallel_backends.py", line 273, in _wrap_func_call
#     return func()
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\joblib\parallel.py", line 589, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\joblib\parallel.py", line 589, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\sklearn\utils\parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\sklearn\model_selection\_validation.py", line 1068, in _fit_and_predict
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 749, in fit
#     return self._fit(X, y, incremental=False)
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 437, in _fit
#     X, y = self._validate_input(X, y, incremental, reset=first_pass)
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 1089, in _validate_input
#     X, y = self._validate_data(
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\sklearn\base.py", line 584, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\sklearn\utils\validation.py", line 1106, in check_X_y
#     X = check_array(
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\sklearn\utils\validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\sklearn\utils\_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "C:\Users\james\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py", line 2083, in __array__
#     values = self._values
#   File "C:\Users\james\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py", line 1046, in _values
#     return ensure_wrapped_if_datetimelike(self.values)
#   File "C:\Users\james\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py", line 12281, in values
#     return self._mgr.as_array()
#   File "C:\Users\james\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\managers.py", line 1656, in as_array
#     arr = self._interleave(dtype=dtype, na_value=na_value)
#   File "C:\Users\james\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\managers.py", line 1689, in _interleave
#     result = np.empty(self.shape, dtype=dtype)
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 1.20 GiB for an array with shape (195, 824696) and data type float64
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\joblib\externals\loky\process_executor.py", line 463, in _process_worker
#     r = call_item()
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\joblib\externals\loky\process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\joblib\parallel.py", line 589, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\joblib\parallel.py", line 589, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\sklearn\utils\parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\sklearn\model_selection\_validation.py", line 986, in cross_val_predict
#     predictions = parallel(
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\sklearn\utils\parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\joblib\parallel.py", line 1952, in __call__
#     return output if self.return_generator else list(output)
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\joblib\parallel.py", line 1595, in _get_outputs
#     yield from self._retrieve()
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\joblib\parallel.py", line 1699, in _retrieve
#     self._raise_error_fast()
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\joblib\parallel.py", line 1734, in _raise_error_fast
#     error_job.get_result(self.timeout)
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\joblib\parallel.py", line 736, in get_result
#     return self._return_or_raise()
#   File "C:\Users\james\anaconda3\envs\MLB\lib\site-packages\joblib\parallel.py", line 754, in _return_or_raise
#     raise self._result
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 1.20 GiB for an array with shape (195, 824696) and data type float64
# """
#
# The above exception was the direct cause of the following exception:
#
# MemoryError                               Traceback (most recent call last)
# File <timed exec>:39
#
# File ~\anaconda3\envs\MLB\lib\site-packages\sklearn\ensemble\_stacking.py:660, in StackingClassifier.fit(self, X, y, sample_weight)
#     658     self.classes_ = self._label_encoder.classes_
#     659     y_encoded = self._label_encoder.transform(y)
# --> 660 return super().fit(X, y_encoded, sample_weight)
#
# File ~\anaconda3\envs\MLB\lib\site-packages\sklearn\ensemble\_stacking.py:252, in _BaseStacking.fit(self, X, y, sample_weight)
#     247         cv.random_state = np.random.RandomState()
#     249     fit_params = (
#     250         {"sample_weight": sample_weight} if sample_weight is not None else None
#     251     )
# --> 252     predictions = Parallel(n_jobs=self.n_jobs)(
#     253         delayed(cross_val_predict)(
#     254             clone(est),
#     255             X,
#     256             y,
#     257             cv=deepcopy(cv),
#     258             method=meth,
#     259             n_jobs=self.n_jobs,
#     260             fit_params=fit_params,
#     261             verbose=self.verbose,
#     262         )
#     263         for est, meth in zip(all_estimators, self.stack_method_)
#     264         if est != "drop"
#     265     )
#     267 # Only not None or not 'drop' estimators will be used in transform.
#     268 # Remove the None from the method as well.
#     269 self.stack_method_ = [
#     270     meth
#     271     for (meth, est) in zip(self.stack_method_, all_estimators)
#     272     if est != "drop"
#     273 ]
#
# File ~\anaconda3\envs\MLB\lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~\anaconda3\envs\MLB\lib\site-packages\joblib\parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File ~\anaconda3\envs\MLB\lib\site-packages\joblib\parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File ~\anaconda3\envs\MLB\lib\site-packages\joblib\parallel.py:1699, in Parallel._retrieve(self)
#    1692 while self._wait_retrieval():
#    1693
#    1694     # If the callback thread of a worker has signaled that its task
#    1695     # triggered an exception, or if the retrieval loop has raised an
#    1696     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1697     # worker traceback.
#    1698     if self._aborting:
# -> 1699         self._raise_error_fast()
#    1700         break
#    1702     # If the next job is not ready for retrieval yet, we just wait for
#    1703     # async callbacks to progress.
#
# File ~\anaconda3\envs\MLB\lib\site-packages\joblib\parallel.py:1734, in Parallel._raise_error_fast(self)
#    1730 # If this error job exists, immediatly raise the error by
#    1731 # calling get_result. This job might not exists if abort has been
#    1732 # called directly or if the generator is gc'ed.
#    1733 if error_job is not None:
# -> 1734     error_job.get_result(self.timeout)
#
# File ~\anaconda3\envs\MLB\lib\site-packages\joblib\parallel.py:736, in BatchCompletionCallBack.get_result(self, timeout)
#     730 backend = self.parallel._backend
#     732 if backend.supports_retrieve_callback:
#     733     # We assume that the result has already been retrieved by the
#     734     # callback thread, and is stored internally. It's just waiting to
#     735     # be returned.
# --> 736     return self._return_or_raise()
#     738 # For other backends, the main thread needs to run the retrieval step.
#     739 try:
#
# File ~\anaconda3\envs\MLB\lib\site-packages\joblib\parallel.py:754, in BatchCompletionCallBack._return_or_raise(self)
#     752 try:
#     753     if self.status == TASK_ERROR:
# --> 754         raise self._result
#     755     return self._result
#     756 finally:
#
# MemoryError: Unable to allocate 1.20 GiB for an array with shape (195, 824696) and data type float64

# %%
# Predict all types
all_outputs = list(predict_all.classes_)
all_outputs_pred = [x + "_pred" for x in all_outputs]

model_dataset.loc[testing_mask, all_outputs_pred] = predict_all.predict_proba(model_dataset[testing_mask][pa_inputs2])

# %%
# Calculate predicted out rate
model_dataset['is_out_pred'] = model_dataset[['so_pred', 'fo_pred', 'go_pred', 'lo_pred', 'po_pred']].sum(axis=1)

# %%
# Set quantiles
quantiles = 20

# Create quantiles
for var in all_outputs + ['is_out']:    
    # Create actual outcome column
    model_dataset.loc[testing_mask, f'{var}_act'] = (model_dataset.loc[testing_mask, 'eventsModel'] == var).astype(int)

    # Create actual is_out value
    if var == "is_out":
        model_dataset.loc[testing_mask, f'{var}_act'] = model_dataset.loc[testing_mask, 'eventsModel'].isin(['so', 'lo', 'po', 'go', 'fo']).astype(int)
    
    # Create deciles
    model_dataset.loc[testing_mask, f'{var}_quantile'] = pd.qcut(model_dataset.loc[testing_mask, f'{var}_pred'], quantiles, labels=False)
    
    # Create aggregated dataframe
    globals()[f"{var}_df"] = model_dataset.loc[testing_mask].groupby(f'{var}_quantile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()
    # globals()[f"{var}_df"] = model_dataset.query('year >= 2022').loc[testing_mask].groupby(f'{var}_quantile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()
    # globals()[f"{var}_df"] = model_dataset.query('venue_id == 19').loc[testing_mask].groupby(f'{var}_quantile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()

# %%
# Create figures
fig, axs = plt.subplots(4, 3, figsize=(12, 16))

for i, var in enumerate(all_outputs + ['is_out']):
    row = i // 3  # Calculate the row index based on the iteration
    col = i % 3   # Calculate the column index based on the iteration
    axs[row, col].plot(globals()[f"{var}_df"][f'{var}_quantile'], globals()[f"{var}_df"][f'{var}_act'], color='black')
    axs[row, col].plot(globals()[f"{var}_df"][f'{var}_quantile'], globals()[f"{var}_df"][f'{var}_pred'], color='red')
    axs[row, col].set_title(var)
    # axs[row, col].set_ylim(globals()[df_name][f'{var}_act'].min(),globals()[df_name][f'{var}_act'].max())
    

# Add some space between subplots to prevent overlapping
fig.tight_layout(pad=.0)

# Show the figure
plt.show()

# %%
# Create figures
fig, axs = plt.subplots(4, 3, figsize=(12, 16))

for i, var in enumerate(all_outputs + ['is_out']):
    row = i // 3  # Calculate the row index based on the iteration
    col = i % 3   # Calculate the column index based on the iteration
    axs[row, col].plot(globals()[f"{var}_df"][f'{var}_quantile'], globals()[f"{var}_df"][f'{var}_act'], color='black')
    axs[row, col].plot(globals()[f"{var}_df"][f'{var}_quantile'], globals()[f"{var}_df"][f'{var}_pred'], color='red')
    axs[row, col].set_title(var)
    # axs[row, col].set_ylim(globals()[df_name][f'{var}_act'].min(),globals()[df_name][f'{var}_act'].max())
    

# Add some space between subplots to prevent overlapping
fig.tight_layout(pad=.0)

# Show the figure
plt.show()

# %%
# 1
model_dataset[testing_mask]['is_out_pred'].describe()
# Out:
# count   515817.000000
# mean         0.680161
# std          0.029052
# min          0.323848
# 25%          0.667359
# 50%          0.683007
# 75%          0.696812
# max          0.980180
# Name: is_out_pred, dtype: float64

# %%
# 5
model_dataset[testing_mask]['is_out_pred'].describe()
# Out:
# count   515817.000000
# mean         0.679763
# std          0.024007
# min          0.531369
# 25%          0.664513
# 50%          0.679555
# 75%          0.694637
# max          0.829881
# Name: is_out_pred, dtype: float64

# %%
# 3
model_dataset[testing_mask]['is_out_pred'].describe()
# Out:
# count   515817.000000
# mean         0.682867
# std          0.036298
# min          0.427456
# 25%          0.660062
# 50%          0.684203
# 75%          0.707112
# max          0.902163
# Name: is_out_pred, dtype: float64

# %%
model_dataset[testing_mask]['is_out_pred'].describe()
# Out:
# count   515817.000000
# mean         0.682867
# std          0.036298
# min          0.427456
# 25%          0.660062
# 50%          0.684203
# 75%          0.707112
# max          0.902163
# Name: is_out_pred, dtype: float64

# %%
# %who
# Out:
# AfterEachExposureStrategy	 Batter	 BeautifulSoup	 By	 ChromeDriverManager	 EC	 GLPK_CMD	 IPython	 Javascript
# Keys	 LinearRegression	 LogisticRegression	 MIMEBase	 MIMEMultipart	 MIMEText	 MIPSolver	 MLPClassifier	 MLPRegressor
# Parallel	 Park	 Path	 Pitcher	 Player	 PlayerFilter	 ProgressiveFantasyPointsStrategy	 PuLPSolver	 RandomFantasyPointsStrategy
# Request	 SVC	 Scoreboard	 Service	 Site	 Sport	 StackingClassifier	 StandardScaler	 TeamStack
# ThreadPoolExecutor	 VotingClassifier	 WebDriverWait	 activation	 active_parks	 all_filename	 all_outputs	 all_outputs_pred	 alpha
# ast	 avg_list	 axs	 b1_df	 b2_df	 b3_df	 base_running_date	 baseball_path	 baserunning_stats
# batch_size	 batter_avg_long	 batter_avg_short	 batter_calc_long	 batter_calc_short	 batter_columns	 batter_info_list	 batter_inputs	 batter_max_long
# batter_max_short	 batter_stats_fg	 batter_stats_fg_imp	 batter_stats_l	 batter_stats_long	 batter_stats_r	 batter_stats_short	 bb_df	 bbref_team
# calc_list	 clean_steamer_hitters	 clean_steamer_pitchers	 clean_weather	 col	 column	 concurrent	 contest_history	 create_box
# create_engine	 create_events	 create_games	 create_pa_inputs	 create_variables	 cumulative_game_list	 cumulative_inning_list	 current_date	 cv2
# datetime	 dateutil	 deepcopy	 delayed	 display	 distutils	 download_path	 encoders	 event
# events_list	 events_list_adj	 fig	 fix_fangraphs	 fo_df	 game_info_list	 game_state_inputs	 gc	 get
# get_optimizer	 glob	 go_df	 hand_inputs	 hbp_df	 hr_df	 html	 i	 imp_inputs
# imported	 impute_batter_stats	 impute_pitcher_stats	 impute_sb_2b	 impute_sb_3b	 impute_sba_2b	 impute_sba_3b	 inning	 inning_dummy_list
# is_out_df	 iters	 joblib	 json	 keep_list	 layers	 layers_str	 learning_rate	 leverage_date
# lo_df	 load_workbook	 mannwhitneyu	 math	 max_list	 merge_datasets	 meta_model	 model_dataset	 model_path
# models	 multiplier_inputs	 name_clean	 new_ids	 np	 num_models	 os	 out	 out_dummy_list
# pa_exclude	 pa_inputs	 pa_inputs2	 pa_list	 pa_share	 paretoset	 park_adjustments	 parser	 partial
# pathlib	 pause_code	 pd	 pickle	 pitcher_avg_long	 pitcher_avg_short	 pitcher_calc_long	 pitcher_calc_short	 pitcher_columns
# pitcher_info_list	 pitcher_inputs	 pitcher_max_long	 pitcher_max_short	 pitcher_stats_fg	 pitcher_stats_fg2	 pitcher_stats_fg_imp	 pitcher_stats_l	 pitcher_stats_long
# pitcher_stats_r	 pitcher_stats_short	 plt	 po_df	 predict_all	 predict_binary	 predict_dp	 predict_errors	 predict_events
# predict_leverage	 predict_out_bases	 predict_outs	 predict_pulls	 predict_safe	 predict_sb_2b	 predict_sb_3b	 predict_sba_2b	 predict_sba_3b
# predict_wfx_l	 predict_wfx_r	 pull_exclude	 pull_inputs	 pull_inputs_game	 pull_inputs_other	 pull_inputs_pre	 pulls_date	 px
# pyautogui	 pyperclip	 pytz	 quantiles	 random	 random_state	 re	 read_chadwick	 remove_accents
# requests	 rolled_sums_list	 rolling_pas	 row	 scale_batter_stats	 scale_batter_stats_steamer	 scale_pitcher_stats	 scale_pitcher_stats_steamer	 selenium
# shutil	 sm	 smf	 smtplib	 so_df	 sqlite3	 ssl	 start_data	 starter_inputs
# stat_imputations_date	 stat_list	 statcast	 statcast_list	 stats	 statsapi	 steal_date	 steal_imputation_date	 team_columns
# team_dict	 team_map	 test_inputs	 test_path	 testing_mask	 testing_out_mask	 testing_safe_mask	 time	 todaysdate
# todaysdate_dash	 todaysdate_dt	 todaysdate_slash	 tqdm	 traceback	 train_test_split	 training_mask	 training_out_mask	 training_safe_mask
# ttest_ind	 unidecode	 urllib	 urlopen	 value	 var	 venue_dummy_list	 venue_inputs	 venue_nums
# warnings	 weather_inputs	 webbrowser	 webdriver	 wfx_date	 winsorize	 x_vect	 xlrd	 y_vect
# year_inputs	 yesterday_dt	 yesterdaysdate	 yesterdaysdate_dash	 yesterdaysdate_slash	 zipfile

# %%
import sys
for name, obj in globals().items():
    print(name, sys.getsizeof(obj))
# Out:
# __name__ 57
# __doc__ 113
# __package__ 16
# __loader__ 16
# __spec__ 16
# __builtin__ 72
# __builtins__ 72
# _ih 664
# _oh 232
# _dh 64
# In 664
# Out 232
# get_ipython 64
# exit 48
# quit 48
# open 136
# _ 28
# __ 51
# ___ 51
# __session__ 111
# _i 131
# _ii 53
# _iii 102
# _i1 175
# ast 72
# concurrent 72
# cv2 72
# datetime 72
# dateutil 72
# distutils 72
# gc 72
# glob 72
# IPython 72
# joblib 72
# json 72
# math 72
# plt 72
# np 72
# os 72
# pd 72
# pathlib 72
# pickle 72
# px 72
# pyautogui 72
# pyperclip 72
# pytz 72
# re 72
# requests 72
# selenium 72
# shutil 72
# sqlite3 72
# statsapi 72
# smf 72
# sm 72
# time 72
# traceback 72
# unidecode 72
# warnings 72
# webbrowser 72
# xlrd 72
# random 72
# urllib 72
# urlopen 136
# Request 1064
# zipfile 72
# BeautifulSoup 1064
# ThreadPoolExecutor 1064
# deepcopy 136
# parser 72
# partial 408
# display 136
# Javascript 1064
# Parallel 1064
# delayed 136
# html 72
# load_workbook 136
# paretoset 136
# Path 896
# statcast 136
# stats 72
# ttest_ind 136
# mannwhitneyu 136
# winsorize 136
# StandardScaler 1064
# LinearRegression 1064
# MLPClassifier 2008
# MLPRegressor 1064
# train_test_split 136
# VotingClassifier 1064
# SVC 1064
# webdriver 72
# By 1064
# Keys 1064
# EC 72
# WebDriverWait 1064
# Service 1064
# ChromeDriverManager 1064
# get 136
# create_engine 136
# tqdm 1064
# GLPK_CMD 1064
# get_optimizer 136
# Site 1064
# Sport 1064
# Player 1064
# TeamStack 1064
# PlayerFilter 1064
# RandomFantasyPointsStrategy 1064
# ProgressiveFantasyPointsStrategy 1064
# AfterEachExposureStrategy 1064
# MIPSolver 1064
# PuLPSolver 1064
# smtplib 72
# ssl 72
# MIMEText 1064
# MIMEMultipart 1064
# MIMEBase 1064
# encoders 72
# model_path 84
# baseball_path 86
# download_path 73
# todaysdate_dt 32
# todaysdate_dash 59
# todaysdate_slash 59
# todaysdate 57
# current_date 48
# yesterday_dt 48
# yesterdaysdate 57
# yesterdaysdate_slash 59
# yesterdaysdate_dash 59
# events_list 152
# events_list_adj 184
# statcast_list 152
# calc_list 120
# max_list 120
# avg_list 192
# stat_list 272
# batter_avg_short 248
# batter_avg_long 248
# batter_calc_short 88
# batter_calc_long 88
# batter_max_short 88
# batter_max_long 88
# batter_stats_short 312
# batter_stats_long 312
# batter_stats_fg 152
# batter_stats_fg_imp 152
# pitcher_avg_short 248
# pitcher_avg_long 248
# pitcher_calc_short 88
# pitcher_calc_long 88
# pitcher_max_short 88
# pitcher_max_long 88
# pitcher_stats_short 312
# pitcher_stats_long 312
# pitcher_stats_fg 120
# pitcher_stats_fg2 152
# pitcher_stats_fg_imp 136
# game_info_list 120
# batter_info_list 120
# pitcher_info_list 120
# pa_list 120
# baserunning_stats 120
# pa_exclude 184
# batter_inputs 472
# pitcher_inputs 472
# batter_stats_l 472
# batter_stats_r 472
# pitcher_stats_l 472
# pitcher_stats_r 472
# hand_inputs 72
# venue_nums 408
# venue_inputs 472
# year_inputs 184
# weather_inputs 120
# game_state_inputs 152
# imp_inputs 72
# starter_inputs 64
# pa_inputs 1312
# rolled_sums_list 160
# pull_inputs_game 152
# pull_inputs_other 64
# pull_inputs_pre 248
# pull_exclude 120
# pull_inputs 248
# team_map 40088
# team_dict 2272
# team_columns 184
# row 28
# bbref_team 52
# column 56
# value 52
# imported 28
# remove_accents 136
# name_clean 136
# fix_fangraphs 136
# read_chadwick 136
# new_ids 136
# contest_history 136
# pa_share 136
# create_games 136
# pause_code 136
# test_path 333
# batter_columns 1184
# pitcher_columns 1152
# Batter 1064
# Pitcher 1064
# Scoreboard 1064
# Park 1064
# create_box 136
# merge_datasets 136
# y_vect 136
# x_vect 136
# clean_weather 136
# create_events 136
# create_variables 136
# park_adjustments 136
# rolling_pas 136
# start_data 136
# clean_steamer_hitters 136
# clean_steamer_pitchers 136
# create_pa_inputs 136
# wfx_date 57
# predict_wfx_l 48
# predict_wfx_r 48
# stat_imputations_date 57
# scale_batter_stats 48
# scale_pitcher_stats 48
# scale_batter_stats_steamer 48
# scale_pitcher_stats_steamer 48
# impute_batter_stats 48
# impute_pitcher_stats 48
# predict_binary 48
# predict_outs 48
# predict_safe 48
# predict_all 48
# base_running_date 57
# predict_errors 48
# predict_dp 48
# predict_out_bases 48
# predict_events 48
# steal_imputation_date 57
# impute_sba_2b 48
# impute_sba_3b 48
# impute_sb_2b 48
# impute_sb_3b 48
# steal_date 57
# predict_sba_2b 48
# predict_sba_3b 48
# predict_sb_2b 48
# predict_sb_3b 48
# pulls_date 57
# predict_pulls 48
# leverage_date 57
# predict_leverage 48
# _i2 163
# _i3 131
# _i4 155
# _i5 134
# _i6 126
# _i7 250
# _i8 183
# _i9 291
# _i10 162
# _i11 185
# _i12 183
# _i13 167
# _i14 553
# _i15 223
# _i16 239
# _i17 156
# _i18 386
# _i19 684
# _i20 201
# _i21 953
# _i22 807
# _i23 136
# _i24 118
# _i25 205
# active_parks 296
# _i26 215
# _i27 161
# venue_dummy_list 312
# _i28 273
# event 51
# _i29 110
# multiplier_inputs 184
# _i30 302
# _i31 257
# inning 28
# _i32 141
# inning_dummy_list 184
# _i33 172
# _i34 164
# out 28
# _i35 96
# out_dummy_list 120
# _i36 144
# cumulative_inning_list 248
# _i37 92
# _i38 140
# cumulative_game_list 248
# _i39 88
# _i40 245
# test_inputs 704
# _i41 143
# _i42 216
# _i43 143
# _i44 217
# _i45 143
# _i46 284
# _i47 208
# _i48 178
# _i49 316
# _i50 306
# pa_inputs2 1616
# keep_list 1680
# _i51 255
# model_dataset 2795053669
# _i52 145
# _i53 473
# training_mask 1546831
# testing_mask 1546831
# training_out_mask 1546831
# testing_out_mask 1546831
# training_safe_mask 1546831
# testing_safe_mask 1546831
# _i54 230
# _i55 1447
# StackingClassifier 1472
# LogisticRegression 1472
# layers 48
# layers_str 51
# activation 53
# iters 28
# alpha 24
# learning_rate 24
# batch_size 53
# random_state 28
# num_models 28
# all_filename 76
# models 88
# meta_model 48
# _i56 283
# all_outputs 144
# all_outputs_pred 184
# _i57 193
# _i58 1178
# quantiles 28
# var 55
# b1_df 624
# b2_df 624
# b3_df 624
# bb_df 624
# fo_df 624
# go_df 624
# hbp_df 624
# hr_df 624
# lo_df 624
# po_df 624
# so_df 624
# is_out_df 624
# _i59 798
# fig 48
# axs 224
# i 28
# col 28
# _i60 106
# _60 863
# _i61 1447
# _i62 283
# _i63 106
# _63 863
# _i64 798
# _i65 1448
# _i66 283
# _i67 193
# _i68 1178
# _i69 798
# _i70 102
# _70 863
# _i71 53
# _i72 131
# sys 72
# name 52
# obj 52
# _i73 131
