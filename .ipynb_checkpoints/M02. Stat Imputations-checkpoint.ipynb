# %% [markdown]
# # M02. Stat Imputations
# - This imputes model inputs using Steamer projections
# - Type: Model
# - Run Frequency: Irregular
# - Sources:
#     - MLB API
#     - Steamer
# - Created: 1/28/2024
# - Updated: 12/17/2024

# %% [markdown]
# Note:
# - Stat imputations have been phased out, replaced with the simpler approach of assigning imputed players median values for API-derived inputs, an imputation flag, and their Steamer projected rates
# - Imputation models proved unreliable and difficult to evaluate, given the significant number of required imputations
# - Code remains to train imputation models in case improved methods can generate more reliable imputations in the future
# - Scalers trained here remain necessary

# %% [markdown]
# ### Imports

# %%
# %run "U1. Imports.ipynb"
# %run "U2. Functions.ipynb"
# %run "U3. Classes.ipynb"
# %run "U4. Datasets.ipynb"
# %run "U5. Models.ipynb"

# %% [markdown]
# ### Data

# %% [markdown]
# ##### Plate Apperances

# %% [markdown]
# Hitters

# %%
hitters_df = pd.read_csv(os.path.join(baseball_path, "Final Dataset.csv"))

# %% [markdown]
# Pitchers

# %%
pitchers_df = hitters_df.copy()

# %% [markdown]
# ##### Steamer

# %% [markdown]
# Hitters

# %%
steamer_hitters_df = pd.read_csv(os.path.join(baseball_path, "A03. Steamer", "steamer_hitters_weekly_log.csv"), encoding='iso-8859-1')

# %% [markdown]
# Pitchers

# %%
steamer_pitchers_df = pd.read_csv(os.path.join(baseball_path, "A03. Steamer", "steamer_pitchers_weekly_log.csv"), encoding='iso-8859-1')

# %% [markdown]
# ### Clean

# %% [markdown]
# ##### Plate Appearances

# %% [markdown]
# Hitters

# %% [markdown]
# Keep one instance of each batter in each game vs. each side

# %%
hitters_df.drop_duplicates(['gamePk', 'batter', 'b_L', 'p_L'], keep='last', inplace=True)

# %% [markdown]
# Keep those with sufficient sample size

# %%
hitters_df = hitters_df[hitters_df['pa_b'] > 40]
hitters_df = hitters_df[~hitters_df[batter_inputs].isin([np.inf, -np.inf]).any(axis=1)]

# %% [markdown]
# Keep relevant columns

# %%
hitters_df = hitters_df[['batter', 'date', 'b_L', 'p_L', 'imp_b'] + batter_inputs]

# %% [markdown]
# Format for merge

# %%
hitters_df['date'] = pd.to_datetime(hitters_df['date'], format='%Y%m%d')
hitters_df['batter'] = hitters_df['batter'].astype(int)

# %% [markdown]
# Pitchers

# %% [markdown]
# Keep one instance of each pitcher in each game vs. each side

# %%
pitchers_df.drop_duplicates(['gamePk', 'pitcher', 'b_L', 'p_L'], keep='last', inplace=True)

# %% [markdown]
# Keep those with sufficient sample size

# %%
pitchers_df = pitchers_df[pitchers_df['pa_p'] > 40]
pitchers_df = pitchers_df[~pitchers_df[pitcher_inputs].isin([np.inf, -np.inf]).any(axis=1)]

# %% [markdown]
# Keep relevant columns

# %%
pitchers_df = pitchers_df[['pitcher', 'date', 'b_L', 'p_L', 'imp_p'] + pitcher_inputs]

# %% [markdown]
# Format for merge

# %%
pitchers_df['date'] = pd.to_datetime(pitchers_df['date'], format='%Y%m%d')
pitchers_df['pitcher'] = pitchers_df['pitcher'].astype(int)

# %% [markdown]
# ##### Steamer

# %% [markdown]
# Hitters

# %%
steamer_hitters_df2 = clean_steamer_hitters(steamer_hitters_df)
steamer_hitters_df2 = steamer_hitters_df2.dropna(subset=batter_stats_fg)

# %% [markdown]
# Format for merge

# %%
steamer_hitters_df2['date'] = pd.to_datetime(steamer_hitters_df2['date'], format='%Y%m%d')
steamer_hitters_df2['mlbamid'] = steamer_hitters_df2['mlbamid'].astype(int)

# %% [markdown]
# Pitchers

# %%
steamer_pitchers_df2 = clean_steamer_pitchers(steamer_pitchers_df)
steamer_pitchers_df2 = steamer_pitchers_df2.dropna(subset=pitcher_stats_fg)

# %% [markdown]
# Format for merge

# %%
steamer_pitchers_df2['date'] = pd.to_datetime(steamer_pitchers_df2['date'], format='%Y%m%d')
steamer_pitchers_df2 = steamer_pitchers_df2[~steamer_pitchers_df2['mlbamid'].isna()]
steamer_pitchers_df2['mlbamid'] = steamer_pitchers_df2['mlbamid'].astype(int)

# %% [markdown]
# ### Merge

# %% [markdown]
# ##### Hitters

# %% [markdown]
# Sort

# %%
hitters_df = hitters_df.sort_values(['batter', 'date'])
steamer_hitters_df2 = steamer_hitters_df2.sort_values(['mlbamid', 'date'])

# %% [markdown]
# Merge

# %%
hitters_df = pd.merge_asof(
    hitters_df.sort_values('date'),
    steamer_hitters_df2[['mlbamid', 'steamerid', 'date'] + batter_stats_fg].sort_values('date'),
    left_on='date',
    right_on='date',
    left_by='batter',
    right_by='mlbamid'
)

# %% [markdown]
# ##### Pitchers

# %% [markdown]
# Sort

# %%
pitchers_df = pitchers_df.sort_values(['pitcher', 'date'])
steamer_pitchers_df2 = steamer_pitchers_df2.sort_values(['mlbamid', 'date'])

# %% [markdown]
# Merge

# %%
pitchers_df = pd.merge_asof(
    pitchers_df.sort_values('date'),
    steamer_pitchers_df2[['mlbamid', 'steamerid', 'date'] + pitcher_stats_fg].sort_values('date'),
    left_on='date',
    right_on='date',
    left_by='pitcher',
    right_by='mlbamid'
)

# %% [markdown]
# ### Sample

# %%
hitters_df = hitters_df[hitters_df['date'].dt.year > 2015]

# %%
pitchers_df = pitchers_df[pitchers_df['date'].dt.year > 2015]

# %% [markdown]
# ### Scaler A. Batter - Plate Appearances

# %% [markdown]
# ##### Inputs

# %% [markdown]
# batter_inputs defined in U1. Imports

# %% [markdown]
# ##### Train

# %% [markdown]
# Create scaler

# %%
batter_stats_scaler = MedianCenterer()

# %% [markdown]
# Fit

# %%
hitters_df[batter_inputs] = batter_stats_scaler.fit_transform(hitters_df[batter_inputs])

# %% [markdown]
# Create directory

# %%
os.makedirs(os.path.join(model_path, "M02. Stat Imputations", todaysdate), exist_ok=True)

# %% [markdown]
# Save

# %%
with open(os.path.join(model_path, "M02. Stat Imputations", todaysdate, "scale_batter_stats.pkl"), "wb") as file:
    pickle.dump(batter_stats_scaler, file)

# %% [markdown]
# ### Scaler B. Pitcher - Plate Appearances

# %% [markdown]
# ##### Inputs

# %% [markdown]
# pitcher_inputs defined in U1. Imports

# %% [markdown]
# ##### Train

# %% [markdown]
# Create scaler

# %%
pitcher_stats_scaler = MedianCenterer()

# %% [markdown]
# Fit

# %%
pitchers_df[pitcher_inputs] = pitcher_stats_scaler.fit_transform(pitchers_df[pitcher_inputs])

# %% [markdown]
# Save

# %%
with open(os.path.join(model_path, "M02. Stat Imputations", todaysdate, "scale_pitcher_stats.pkl"), "wb") as file:
    pickle.dump(pitcher_stats_scaler, file)

# %% [markdown]
# ### Scaler C. Batter - Steamer

# %% [markdown]
# ##### Inputs

# %% [markdown]
# batter_stats_fg defined in U1. Imports

# %% [markdown]
# ##### Train

# %% [markdown]
# Create scaler

# %%
batter_stats_fg_scaler = MedianCenterer()

# %% [markdown]
# Fit

# %%
steamer_hitters_df2[batter_stats_fg] = batter_stats_fg_scaler.fit_transform(steamer_hitters_df2[batter_stats_fg])

# %% [markdown]
# Save

# %%
with open(os.path.join(model_path, "M02. Stat Imputations", todaysdate, "scale_batter_stats_steamer.pkl"), "wb") as file:
    pickle.dump(batter_stats_fg_scaler, file)

# %% [markdown]
# ### Scaler D. Pitcher - Steamer

# %% [markdown]
# ##### Inputs

# %% [markdown]
# pitcher_stats_fg defined in U1. Imports

# %% [markdown]
# ##### Train

# %% [markdown]
# Create scaler

# %%
pitcher_stats_fg_scaler = MedianCenterer()

# %% [markdown]
# Fit

# %%
steamer_pitchers_df2[pitcher_stats_fg] = pitcher_stats_fg_scaler.fit_transform(steamer_pitchers_df2[pitcher_stats_fg])

# %% [markdown]
# Save

# %%
with open(os.path.join(model_path, "M02. Stat Imputations", todaysdate, "scale_pitcher_stats_steamer.pkl"), "wb") as file:
    pickle.dump(pitcher_stats_fg_scaler, file)

# %% [markdown]
# ### Note:
# Imputation models below are deprecated

# %% [markdown]
# ### Impute

# %% [markdown]
# Hitters

# %% [markdown]
# Stat inputs

# %%
batter_stats_fg_imp = batter_stats_fg + ['b_L', 'p_L', 'imp_b']

# %% [markdown]
# Train/Test Split

# %% [markdown]
# Split

# %%
hitters_df['split'] = np.random.choice([0, 0, 1], size=len(hitters_df))

# %% [markdown]
# Create masks to identify training and testing datasets

# %%
training_mask = (hitters_df['split'] == 0)
testing_mask = (hitters_df['split'] == 1)

# %%
hitters_df.tail()
# Out:
#         batter       date    b_L    p_L  imp_b      b1_b      b2_b      b3_b  \
# 657833  671739 2025-09-28   True   True      0  0.048466 -0.002323  0.000308
# 657834  695657 2025-09-28   True  False      0 -0.065490 -0.007413  0.000605
# 657835  676044 2025-09-28   True  False      0  0.010035  0.011780  0.000848
# 657836  701358 2025-09-28  False   True      0 -0.033628  0.000717 -0.000884
# 657837  683737 2025-09-28   True   True      0 -0.041962  0.005150  0.003638
#
#             bb_b      fo_b      go_b     hbp_b      hr_b      lo_b      po_b  \
# 657833 -0.080000 -0.040594  0.155632 -0.000000  0.013274 -0.012417  0.018893
# 657834  0.080000 -0.054990 -0.085868 -0.000000  0.014691 -0.034376  0.014080
# 657835 -0.020000 -0.019971 -0.009638  0.020000 -0.024353  0.008710  0.003828
# 657836  0.080000  0.019070 -0.045000  0.020000 -0.006437 -0.028852 -0.003747
# 657837 -0.020000 -0.003609  0.007183 -0.000000  0.040909 -0.009212 -0.020858
#
#             so_b  estimated_woba_using_speedangle_b  to_left_b  to_middle_b  \
# 657833 -0.060000                          -0.053286  -0.126016     0.034632
# 657834  0.180000                          -0.058106  -0.201774     0.015152
# 657835  0.060000                          -0.064570  -0.011433    -0.175189
# 657836  0.040000                          -0.065040   0.028746    -0.072511
# 657837  0.080000                          -0.003796  -0.136433    -0.112689
#
#         to_right_b  hard_hit_b  barrel_b     iso_b     slg_b     obp_b  \
# 657833    0.108466    0.040000  0.020000  0.019720  0.047175 -0.042910
# 657834    0.203704   -0.140000  0.020000  0.051418 -0.008717 -0.000241
# 657835    0.203704    0.020000 -0.040000 -0.071868 -0.087388 -0.024324
# 657836    0.060847   -0.040000 -0.020000 -0.014729 -0.049142  0.037134
# 657837    0.266204    0.020000  0.060000  0.133671  0.123273 -0.034899
#
#           woba_b  b1_b_long  b2_b_long  b3_b_long  bb_b_long  fo_b_long  \
# 657833 -0.008562   0.013792   0.001430   0.002118  -0.053333  -0.022234
# 657834 -0.002026  -0.050630  -0.007001   0.000934   0.020000  -0.018261
# 657835 -0.045977  -0.012293   0.003934   0.001125  -0.018462  -0.018660
# 657836  0.004732  -0.016359   0.007261   0.000454   0.044088   0.003509
# 657837  0.024777  -0.031130   0.001040   0.002405  -0.008571   0.038652
#
#         go_b_long  hbp_b_long  hr_b_long  lo_b_long  po_b_long  so_b_long  \
# 657833   0.082128    0.004713   0.007547  -0.002948  -0.002704  -0.010000
# 657834  -0.085674   -0.003621   0.057067  -0.017288   0.011648   0.113333
# 657835  -0.033572    0.006764  -0.025623   0.005347   0.005538   0.106410
# 657836  -0.081288    0.013277   0.010330  -0.018238  -0.003231   0.060706
# 657837  -0.034400    0.005665   0.007034  -0.013036  -0.001910   0.054762
#
#         estimated_woba_using_speedangle_b_long  to_left_b_long  \
# 657833                               -0.046420       -0.133158
# 657834                                0.011609       -0.172981
# 657835                               -0.094741       -0.066106
# 657836                               -0.009174       -0.043710
# 657837                               -0.053461       -0.104282
#
#         to_middle_b_long  to_right_b_long  hard_hit_b_long  barrel_b_long  \
# 657833         -0.006272         0.156086         0.046667       0.016667
# 657834         -0.006272         0.195909         0.003333       0.048333
# 657835         -0.113601         0.196363         0.035641      -0.046667
# 657836          0.085360        -0.024994        -0.030389       0.011727
# 657837         -0.010467         0.131406        -0.009048       0.005714
#
#         iso_b_long  slg_b_long  obp_b_long  woba_b_long  mlbamid  steamerid  \
# 657833    0.018835    0.027084   -0.033197    -0.008654   671739      25931
# 657834    0.185562    0.184995    0.007286     0.068895   695657  sa3017170
# 657835   -0.081355   -0.125430   -0.054018    -0.073290   676044  sa3017852
# 657836    0.053418    0.066244    0.049587     0.048511   701358  sa3025358
# 657837    0.026166   -0.002604   -0.033022    -0.017934   683737      26319
#
#         b1_rate  b2_rate  b3_rate  hr_rate  bb_rate  hbp_rate  so_rate  \
# 657833 0.171735 0.049860 0.005980 0.039773 0.056900  0.010000 0.184828
# 657834 0.117970 0.033476 0.003095 0.024917 0.094400  0.017000 0.290308
# 657835 0.133142 0.038612 0.001753 0.038772 0.069000  0.009004 0.328434
# 657836 0.131667 0.027906 0.005215 0.028493 0.063900  0.011000 0.240899
# 657837 0.123585 0.045158 0.003520 0.034559 0.104300  0.010000 0.276870
#
#            woba      slg      obp  split
# 657833 0.351297 0.485310 0.335077      0
# 657834 0.278901 0.334469 0.291715      1
# 657835 0.302256 0.406462 0.291137      0
# 657836 0.267951 0.346331 0.268886      0
# 657837 0.321190 0.413161 0.321547      1

# %%
hitters_df = hitters_df.dropna(subset=batter_inputs).dropna(subset=batter_stats_fg)

# %% [markdown]
# Train

# %%
# %%time
# Define the architecture of the neural network
layers = (50,50)

# Create the MLPRegressor model
batter_imputation_model = MLPRegressor(hidden_layer_sizes=layers, activation='relu', random_state=100, learning_rate_init=0.001, max_iter=100)

# Train the model
batter_imputation_model.fit(hitters_df[training_mask][batter_stats_fg_imp], hitters_df[training_mask][batter_inputs])


# Save the model
os.makedirs(os.path.join(model_path, "M02. Stat Imputations", todaysdate), exist_ok=True)
pickle.dump(batter_imputation_model, open(os.path.join(model_path, "M02. Stat Imputations", todaysdate, "impute_batter_stats.sav"), 'wb'))
# Out:
# CPU times: total: 4min 48s
# Wall time: 36.8 s

# %% [markdown]
# Predict

# %%
y_test_pred = pd.DataFrame(batter_imputation_model.predict(hitters_df[testing_mask][batter_stats_fg_imp]))
y_test_pred.columns = [f"{col}_pred" for col in batter_inputs]
batter_pred_df = pd.concat([hitters_df[testing_mask].reset_index(), y_test_pred], axis=1)

# %% [markdown]
# Evaluate

# %%
### MSEs - Player-level
all_list, imp_list = [], []

for stat in batter_inputs:
    batter_pred_df[f'{stat}_square_error'] = (batter_pred_df[stat] - batter_pred_df[f'{stat}_pred']) ** 2
    all_list.append(batter_pred_df[f'{stat}_square_error'].mean())
    imp_list.append(batter_pred_df[batter_pred_df['imp_b'] == 1][f'{stat}_square_error'].mean())
    
print("MSE All:    ", np.mean(all_list))
print("MSE Imputed:", np.mean(imp_list))


### MSEs - Stat-level
# Identify predicted columns
pred_columns = [col + "_pred" for col in batter_inputs]

# Check if all pred_columns exist in the dataframe
missing_columns = [col for col in pred_columns if col not in batter_pred_df.columns]
if missing_columns:
    raise ValueError(f"Missing expected columns: {missing_columns}")

# Compute means for actual and predicted columns
means_actual = batter_pred_df.query('imp_b == 1')[batter_inputs].mean()
means_pred = batter_pred_df.query('imp_b == 1')[pred_columns].mean()

# Align indices to ensure proper subtraction
means_pred.index = means_actual.index  

# Compute squared errors
squared_errors = (means_actual - means_pred) ** 2

# Compute final MSE
mse = squared_errors.mean()

print("MSE Stats:  ", mse)
# Out:
# MSE All:     0.0022707981710573303
# MSE Imputed: nan
# MSE Stats:   nan

# %% [markdown]
# Pitchers

# %% [markdown]
# Stat inputs

# %%
pitcher_stats_fg_imp = pitcher_stats_fg + ['b_L', 'p_L', 'imp_p']

# %% [markdown]
# Train/Test Split

# %% [markdown]
# Split

# %%
pitchers_df['split'] = np.random.choice([0, 0, 1], size=len(pitchers_df))

# %% [markdown]
# Create masks to identify training and testing datasets

# %%
training_mask = (pitchers_df['split'] == 0)
testing_mask = (pitchers_df['split'] == 1)

# %%
pitchers_df = pitchers_df.dropna(subset=pitcher_inputs).dropna(subset=pitcher_stats_fg)

# %% [markdown]
# Train

# %%
# %%time
# Define the architecture of the neural network
layers = (50,50)

# Create the MLPRegressor model
pitcher_imputation_model = MLPRegressor(hidden_layer_sizes=layers, activation='relu', random_state=1, learning_rate_init=0.001, max_iter=100)

# Train the model
pitcher_imputation_model.fit(pitchers_df[training_mask][pitcher_stats_fg_imp], pitchers_df[training_mask][pitcher_inputs])


# Save the model
os.makedirs(os.path.join(model_path, "M02. Stat Imputations", todaysdate), exist_ok=True)
pickle.dump(pitcher_imputation_model, open(os.path.join(model_path, "M02. Stat Imputations", todaysdate, "impute_pitcher_stats.sav"), 'wb'))
# Out:
# CPU times: total: 1min 44s
# Wall time: 13.6 s

# %% [markdown]
# Predict

# %%
y_test_pred = pd.DataFrame(pitcher_imputation_model.predict(pitchers_df[testing_mask][pitcher_stats_fg_imp]))
y_test_pred.columns = [f"{col}_pred" for col in pitcher_inputs]
pitcher_pred_df = pd.concat([pitchers_df[testing_mask].reset_index(), y_test_pred], axis=1)

# %% [markdown]
# Evaluate

# %%
### MSEs - Player-level
all_list, imp_list = [], []

for stat in pitcher_inputs:
    pitcher_pred_df[f'{stat}_square_error'] = (pitcher_pred_df[stat] - pitcher_pred_df[f'{stat}_pred']) ** 2
    all_list.append(pitcher_pred_df[f'{stat}_square_error'].mean())
    imp_list.append(pitcher_pred_df[pitcher_pred_df['imp_p'] == 1][f'{stat}_square_error'].mean())
    
print("MSE All:    ", np.mean(all_list))
print("MSE Imputed:", np.mean(imp_list))


### MSEs - Stat-level
# Identify predicted columns
pred_columns = [col + "_pred" for col in pitcher_inputs]

# Check if all pred_columns exist in the dataframe
missing_columns = [col for col in pred_columns if col not in pitcher_pred_df.columns]
if missing_columns:
    raise ValueError(f"Missing expected columns: {missing_columns}")

# Compute means for actual and predicted columns
means_actual = pitcher_pred_df.query('imp_p == 1')[pitcher_inputs].mean()
means_pred = pitcher_pred_df.query('imp_p == 1')[pred_columns].mean()

# Align indices to ensure proper subtraction
means_pred.index = means_actual.index  

# Compute squared errors
squared_errors = (means_actual - means_pred) ** 2

# Compute final MSE
mse = squared_errors.mean()

print("MSE Stats:  ", mse)
# Out:
# MSE All:     0.002296019059247391
# MSE Imputed: nan
# MSE Stats:   nan

# %%
pitcher_pred_df.head()
# Out:
#    index  pitcher       date    b_L    p_L  imp_p      b1_p      b2_p  \
# 0  21710   451584 2016-04-03   True  False      0 -0.035792 -0.012658
# 1  21714   595307 2016-04-03   True  False      0  0.084778 -0.010825
# 2  21715   465657 2016-04-03  False  False      0  0.026845 -0.023644
# 3  21721   465657 2016-04-03   True  False      0  0.046636  0.019474
# 4  21723   502042 2016-04-03  False  False      0 -0.025789  0.002840
#
#        b3_p      bb_p      fo_p      go_p     hbp_p      hr_p      lo_p  \
# 0 -0.000625  0.000000 -0.025963 -0.029541 -0.000000  0.015267 -0.010873
# 1  0.000055  0.060000 -0.039298  0.092282  0.000000 -0.009826 -0.020148
# 2 -0.001777  0.040000 -0.044667  0.007624  0.000000 -0.017371 -0.007927
# 3  0.003622 -0.060000  0.007986  0.009036 -0.000000 -0.009638  0.033172
# 4  0.000235  0.060000 -0.059488 -0.061825 -0.000000 -0.002926  0.006047
#
#        po_p      so_p  estimated_woba_using_speedangle_p  to_left_p  \
# 0  0.018707  0.140000                           0.061964   0.007937
# 1  0.001504 -0.100000                           0.050721  -0.115616
# 2 -0.000561  0.080000                           0.033000  -0.123932
# 3  0.008235 -0.000000                          -0.022162   0.016340
# 4 -0.000571  0.140000                           0.062773   0.122222
#
#    to_middle_p  to_right_p  hard_hit_p  barrel_p     iso_p     slg_p  \
# 0    -0.143939    0.151786   -0.020000  0.020000  0.027415 -0.022389
# 1    -0.042588    0.173986    0.000000 -0.020000 -0.044595  0.032626
# 2     0.029138    0.110577   -0.060000 -0.020000 -0.091256 -0.112240
# 3    -0.040998    0.040441   -0.100000 -0.020000 -0.017736  0.016797
# 4    -0.073939   -0.032500    0.000000 -0.020000 -0.004215 -0.031438
#
#       obp_p    woba_p  b1_p_long  b2_p_long  b3_p_long  bb_p_long  fo_p_long  \
# 0 -0.060259 -0.040209  -0.016097  -0.014336  -0.001195   0.002374  -0.045832
# 1  0.097731  0.059354   0.091093   0.001226   0.000159  -0.005271  -0.059644
# 2 -0.002398 -0.040445   0.011106  -0.018198  -0.001415   0.017500  -0.019405
# 3 -0.026358 -0.012865   0.034001   0.006044   0.001411  -0.041891   0.005435
# 4  0.007909 -0.006681   0.002495  -0.006956  -0.000282   0.006667  -0.022182
#
#    go_p_long  hbp_p_long  hr_p_long  lo_p_long  po_p_long  so_p_long  \
# 0   0.036087   -0.010000  -0.012569  -0.002633   0.016820   0.064521
# 1   0.139652   -0.010000  -0.017522  -0.006250  -0.002582  -0.113721
# 2  -0.009426    0.003889  -0.016190  -0.006380  -0.012953   0.068611
# 3   0.057094   -0.010000  -0.009218   0.017492   0.022592  -0.065821
# 4  -0.018873   -0.010000  -0.008957  -0.000178   0.005406   0.070000
#
#    estimated_woba_using_speedangle_p_long  to_left_p_long  to_middle_p_long  \
# 0                               -0.039473       -0.066667         -0.051595
# 1                                0.013429       -0.089372         -0.077199
# 2                                0.007987       -0.018519          0.011368
# 3                               -0.051651       -0.022876         -0.043098
# 4                                0.023578        0.049906         -0.006209
#
#    to_right_p_long  hard_hit_p_long  barrel_p_long  iso_p_long  slg_p_long  \
# 0         0.130159        -0.068767      -0.022785   -0.062300   -0.115680
# 1         0.178468         0.004186      -0.031705   -0.059272    0.015529
# 2         0.019048        -0.031667      -0.015556   -0.076782   -0.102004
# 3         0.077871        -0.023582      -0.020945   -0.028803   -0.010683
# 4        -0.031800        -0.003333      -0.010000   -0.039805   -0.058679
#
#    obp_p_long  woba_p_long       mlbamid steamerid       H9      HR9  \
# 0   -0.055960    -0.070186 451584.000000      7441 7.184896 0.728600
# 1    0.055548     0.030957 595307.000000     12235 9.327462 0.740700
# 2   -0.007445    -0.038381 465657.000000      6941 7.869088 0.745800
# 3   -0.023789    -0.019562 465657.000000      6941 7.869088 0.745800
# 4   -0.021170    -0.032518 502042.000000      6345 7.635047 0.798500
#
#          K9      BB9   GBrate   FBrate   LDrate    SIERA  split  b1_p_pred  \
# 0 10.371000 2.970500 0.430000 0.363000 0.206964 2.950000      1  -0.013387
# 1  6.318900 1.890800 0.551000 0.243000 0.206220 3.400000      1   0.036245
# 2  8.970100 2.586900 0.462000 0.333000 0.204536 3.200000      1   0.013542
# 3  8.970100 2.586900 0.462000 0.333000 0.204536 3.200000      1   0.004637
# 4  9.653500 3.039800 0.460000 0.337000 0.202972 3.360000      1   0.005236
#
#    b2_p_pred  b3_p_pred  bb_p_pred  fo_p_pred  go_p_pred  hbp_p_pred  \
# 0  -0.000038  -0.001219   0.008673  -0.001240  -0.007911    0.009833
# 1   0.008580   0.001350  -0.018295  -0.022757   0.118631    0.005791
# 2   0.003905  -0.001846  -0.027839  -0.013634   0.039026    0.011860
# 3   0.003237  -0.000966  -0.000900  -0.004811   0.030476    0.008844
# 4   0.002442  -0.002551  -0.013328  -0.015958   0.021000    0.013372
#
#    hr_p_pred  lo_p_pred  po_p_pred  so_p_pred  \
# 0   0.001793  -0.004577  -0.003431   0.060505
# 1   0.001598   0.005155  -0.019794  -0.069655
# 2  -0.000543  -0.004647  -0.003485   0.033806
# 3   0.002811  -0.000679  -0.007761   0.013655
# 4  -0.000207  -0.007049  -0.004366   0.049931
#
#    estimated_woba_using_speedangle_p_pred  to_left_p_pred  to_middle_p_pred  \
# 0                               -0.019583       -0.064722         -0.030691
# 1                               -0.012384       -0.078912         -0.038393
# 2                               -0.024041        0.052893          0.003118
# 3                               -0.013564       -0.058062         -0.032048
# 4                               -0.013070        0.053018          0.004194
#
#    to_right_p_pred  hard_hit_p_pred  barrel_p_pred  iso_p_pred  slg_p_pred  \
# 0         0.106176        -0.021486       0.000181   -0.001530   -0.023248
# 1         0.129378         0.043952       0.003716    0.006715    0.039159
# 2        -0.044356         0.001850       0.000110   -0.011346   -0.015146
# 3         0.100631         0.004568       0.002925    0.005202    0.005763
# 4        -0.042773        -0.008306      -0.000075   -0.009507   -0.017494
#
#    obp_p_pred  woba_p_pred  b1_p_long_pred  b2_p_long_pred  b3_p_long_pred  \
# 0   -0.023000    -0.022048       -0.010463       -0.003605        0.003855
# 1    0.001971     0.011143        0.036825        0.006329        0.006274
# 2   -0.031039    -0.024454        0.012063        0.000729        0.003530
# 3   -0.011099    -0.006111        0.006306        0.000102        0.004074
# 4   -0.021900    -0.021436        0.003212       -0.000375        0.003365
#
#    bb_p_long_pred  fo_p_long_pred  go_p_long_pred  hbp_p_long_pred  \
# 0        0.006395       -0.004704       -0.006167        -0.008007
# 1       -0.024933       -0.027855        0.121147        -0.008909
# 2       -0.031147       -0.013186        0.037215        -0.006146
# 3       -0.003338       -0.007894        0.032568        -0.008910
# 4       -0.016103       -0.012964        0.018783        -0.004691
#
#    hr_p_long_pred  lo_p_long_pred  po_p_long_pred  so_p_long_pred  \
# 0       -0.002463       -0.000930       -0.004277        0.041701
# 1       -0.005155        0.011057       -0.024061       -0.080529
# 2       -0.003857        0.000756       -0.004739        0.017465
# 3       -0.001655        0.004130       -0.008583       -0.004089
# 4       -0.003089       -0.000716       -0.004373        0.032406
#
#    estimated_woba_using_speedangle_p_long_pred  to_left_p_long_pred  \
# 0                                    -0.017702            -0.063918
# 1                                    -0.017303            -0.079368
# 2                                    -0.023416             0.050375
# 3                                    -0.013700            -0.056411
# 4                                    -0.015613             0.050465
#
#    to_middle_p_long_pred  to_right_p_long_pred  hard_hit_p_long_pred  \
# 0              -0.019321              0.097366             -0.029758
# 1              -0.027674              0.121772              0.039258
# 2               0.011660             -0.046277             -0.003656
# 3              -0.020265              0.091931             -0.004248
# 4               0.009497             -0.044334             -0.014594
#
#    barrel_p_long_pred  iso_p_long_pred  slg_p_long_pred  obp_p_long_pred  \
# 0           -0.010082        -0.015785        -0.035261        -0.022345
# 1           -0.006676        -0.006891         0.016124         0.000620
# 2           -0.007910        -0.022732        -0.024133        -0.032196
# 3           -0.007663        -0.009519        -0.007285        -0.011147
# 4           -0.008261        -0.022728        -0.026792        -0.025022
#
#    woba_p_long_pred  b1_p_square_error  b2_p_square_error  b3_p_square_error  \
# 0         -0.027039           0.000502           0.000159           0.000000
# 1          0.002117           0.002355           0.000377           0.000002
# 2         -0.029938           0.000177           0.000759           0.000000
# 3         -0.012253           0.001764           0.000264           0.000021
# 4         -0.027478           0.000963           0.000000           0.000008
#
#    bb_p_square_error  fo_p_square_error  go_p_square_error  \
# 0           0.000075           0.000611           0.000468
# 1           0.006130           0.000274           0.000694
# 2           0.004602           0.000963           0.000986
# 3           0.003493           0.000164           0.000460
# 4           0.005377           0.001895           0.006860
#
#    hbp_p_square_error  hr_p_square_error  lo_p_square_error  \
# 0            0.000097           0.000182           0.000040
# 1            0.000034           0.000131           0.000640
# 2            0.000141           0.000283           0.000011
# 3            0.000078           0.000155           0.001146
# 4            0.000179           0.000007           0.000172
#
#    po_p_square_error  so_p_square_error  \
# 0           0.000490           0.006319
# 1           0.000454           0.000921
# 2           0.000009           0.002134
# 3           0.000256           0.000186
# 4           0.000014           0.008112
#
#    estimated_woba_using_speedangle_p_square_error  to_left_p_square_error  \
# 0                                        0.006650                0.005279
# 1                                        0.003982                0.001347
# 2                                        0.003254                0.031267
# 3                                        0.000074                0.005536
# 4                                        0.005752                0.004789
#
#    to_middle_p_square_error  to_right_p_square_error  hard_hit_p_square_error  \
# 0                  0.012825                 0.002080                 0.000002
# 1                  0.000018                 0.001990                 0.001932
# 2                  0.000677                 0.024004                 0.003825
# 3                  0.000080                 0.003623                 0.010935
# 4                  0.006105                 0.000106                 0.000069
#
#    barrel_p_square_error  iso_p_square_error  slg_p_square_error  \
# 0               0.000393            0.000838            0.000001
# 1               0.000562            0.002633            0.000043
# 2               0.000404            0.006386            0.009427
# 3               0.000526            0.000526            0.000122
# 4               0.000397            0.000028            0.000194
#
#    obp_p_square_error  woba_p_square_error  b1_p_long_square_error  \
# 0            0.001388             0.000330                0.000032
# 1            0.009170             0.002324                0.002945
# 2            0.000820             0.000256                0.000001
# 3            0.000233             0.000046                0.000767
# 4            0.000889             0.000218                0.000001
#
#    b2_p_long_square_error  b3_p_long_square_error  bb_p_long_square_error  \
# 0                0.000115                0.000026                0.000016
# 1                0.000026                0.000037                0.000387
# 2                0.000358                0.000024                0.002367
# 3                0.000035                0.000007                0.001486
# 4                0.000043                0.000013                0.000518
#
#    fo_p_long_square_error  go_p_long_square_error  hbp_p_long_square_error  \
# 0                0.001691                0.001785                 0.000004
# 1                0.001011                0.000342                 0.000001
# 2                0.000039                0.002175                 0.000101
# 3                0.000178                0.000602                 0.000001
# 4                0.000085                0.001418                 0.000028
#
#    hr_p_long_square_error  lo_p_long_square_error  po_p_long_square_error  \
# 0                0.000102                0.000003                0.000445
# 1                0.000153                0.000300                0.000461
# 2                0.000152                0.000051                0.000067
# 3                0.000057                0.000179                0.000972
# 4                0.000034                0.000000                0.000096
#
#    so_p_long_square_error  \
# 0                0.000521
# 1                0.001102
# 2                0.002616
# 3                0.003811
# 4                0.001413
#
#    estimated_woba_using_speedangle_p_long_square_error  \
# 0                                             0.000474
# 1                                             0.000944
# 2                                             0.000986
# 3                                             0.001440
# 4                                             0.001536
#
#    to_left_p_long_square_error  to_middle_p_long_square_error  \
# 0                     0.000008                       0.001042
# 1                     0.000100                       0.002453
# 2                     0.004746                       0.000000
# 3                     0.001125                       0.000521
# 4                     0.000000                       0.000247
#
#    to_right_p_long_square_error  hard_hit_p_long_square_error  \
# 0                      0.001075                      0.001522
# 1                      0.003214                      0.001230
# 2                      0.004267                      0.000785
# 3                      0.000198                      0.000374
# 4                      0.000157                      0.000127
#
#    barrel_p_long_square_error  iso_p_long_square_error  \
# 0                    0.000161                 0.002164
# 1                    0.000626                 0.002744
# 2                    0.000058                 0.002921
# 3                    0.000176                 0.000372
# 4                    0.000003                 0.000292
#
#    slg_p_long_square_error  obp_p_long_square_error  woba_p_long_square_error
# 0                 0.006467                 0.001130                  0.001862
# 1                 0.000000                 0.003017                  0.000832
# 2                 0.006064                 0.000613                  0.000071
# 3                 0.000012                 0.000160                  0.000053
# 4                 0.001017                 0.000015                  0.000025

# %%
# event = "woba"  # change this as needed

# pred_col = f"{event}_p_long_pred"
# actual_col = f"{event}_p_long"

# # Filter for imputed pitcher rows
# imp_pitcher_pred_df = pitcher_pred_df[pitcher_pred_df['imp_p'] == 1].copy()

# # Create decile bins
# imp_pitcher_pred_df['quantile'] = pd.qcut(imp_pitcher_pred_df[pred_col], q=10, labels=False)

# # Group by quantile and calculate means
# quantile_means = imp_pitcher_pred_df.groupby('quantile')[[pred_col, actual_col]].mean().reset_index()

# # Plot
# plt.figure(figsize=(6, 6))  # Square plot
# plt.plot(quantile_means[pred_col], quantile_means[actual_col], marker='o')
# plt.plot([-1, 1], [-1, 1], 'r--')  # 45-degree reference line
# plt.xlabel('Avg Predicted Probability')
# plt.ylabel('Avg Actual Probability')
# plt.title(f'Calibration Plot by Decile for {event}')
# plt.xlim(-1, 1)
# plt.ylim(-1, 1)
# plt.gca().set_aspect('equal', adjustable='box')  # Force square axes
# plt.grid(True)
# plt.show()

# %% [markdown]
# ### Required Follow-Ups:
# - M03. Plate Appearances
