# %% [markdown]
# ### Imports

# %%
# %run "C:\Users\james\Documents\MLB\Code\U1. Imports.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U2. Utilities.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U3. Classes.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U4. Datasets.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U5. Models.ipynb"

# %% [markdown]
# ### Games

# %%
all_game_df = create_games(yesterdaysdate, todaysdate, team_dict)

# %% [markdown]
# ### A01. DraftKings

# %%
draftables_only = False

# %%
print("Parameters:")
print(f"todaysdate: {todaysdate}")
print(f"todaysdate_dash: {todaysdate_dash}")
print(f"yesterdaysdate: {yesterdaysdate}")
print(f"draftables_only: {draftables_only}")
# Out:
# Parameters:
# todaysdate: 20250328
# todaysdate_dash: 2025-03-28
# yesterdaysdate: 20250327

# %%
# %run "C:\Users\james\Documents\MLB\Code\A01. DraftKings.ipynb"
# Out:
# 124473
# Saved 124473
# 124472
# Saved 124472
# 124467
# Saved 124467
# CPU times: total: 156 ms
# Wall time: 663 ms
# CPU times: total: 78.1 ms
# Wall time: 2.1 s
# 175193307
# contest-standings-175193307
# ['contest-standings-175193307.zip']
# C:\Users\james\Downloads\contest-standings-175193307.zip
# Zip file unpacked successfully!
# 175193310
# contest-standings-175193310
# ['contest-standings-175193310.zip']
# C:\Users\james\Downloads\contest-standings-175193310.zip
# Zip file unpacked successfully!
# 175193308
# contest-standings-175193308
# ['contest-standings-175193308.zip']
# C:\Users\james\Downloads\contest-standings-175193308.zip
# Zip file unpacked successfully!
# 175193306
# contest-standings-175193306
# ['contest-standings-175193306.csv']
# C:\Users\james\Downloads\contest-standings-175193306.csv
# File copied successfully!
# 175193313
# contest-standings-175193313
# ['contest-standings-175193313.zip']
# C:\Users\james\Downloads\contest-standings-175193313.zip
# Zip file unpacked successfully!
# 175193357
# contest-standings-175193357
# ['contest-standings-175193357.zip']
# C:\Users\james\Downloads\contest-standings-175193357.zip
# Zip file unpacked successfully!
# 175193358
# contest-standings-175193358
# ['contest-standings-175193358.zip']
# C:\Users\james\Downloads\contest-standings-175193358.zip
# Zip file unpacked successfully!
# 175193359
# contest-standings-175193359
# ['contest-standings-175193359.zip']
# C:\Users\james\Downloads\contest-standings-175193359.zip
# Zip file unpacked successfully!
# 175193356
# contest-standings-175193356
# ['contest-standings-175193356.zip']
# C:\Users\james\Downloads\contest-standings-175193356.zip
# Zip file unpacked successfully!
# 175193364
# contest-standings-175193364
# ['contest-standings-175193364.zip']
# C:\Users\james\Downloads\contest-standings-175193364.zip
# Zip file unpacked successfully!
# 175012024
# contest-standings-175012024
# ['contest-standings-175012024.zip']
# C:\Users\james\Downloads\contest-standings-175012024.zip
# Zip file unpacked successfully!
# 175012026
# contest-standings-175012026
# ['contest-standings-175012026.zip']
# C:\Users\james\Downloads\contest-standings-175012026.zip
# Zip file unpacked successfully!
# 175012022
# contest-standings-175012022
# ['contest-standings-175012022.zip']
# C:\Users\james\Downloads\contest-standings-175012022.zip
# Zip file unpacked successfully!
# 175012027
# contest-standings-175012027
# ['contest-standings-175012027.zip']
# C:\Users\james\Downloads\contest-standings-175012027.zip
# Zip file unpacked successfully!
# 175012023
# contest-standings-175012023
# ['contest-standings-175012023.zip']
# C:\Users\james\Downloads\contest-standings-175012023.zip
# Zip file unpacked successfully!
# 175012025
# contest-standings-175012025
# ['contest-standings-175012025.zip']
# C:\Users\james\Downloads\contest-standings-175012025.zip
# Zip file unpacked successfully!

# %% [markdown]
# ### A02. MLB API

# %%
year = int(todaysdate[:4])

# %%
print("Parameters:")
print(f"year: {year}")
# Out:
# Parameters:
# year: 2025

# %%
# %run "C:\Users\james\Documents\MLB\Code\A02. MLB API.ipynb"
# Out:
# This is a large query, it may take a moment to complete
# 100%|██████████| 243/243 [08:48<00:00,  2.17s/it]

# %% [markdown]
# ### A03. Steamer

# %%
print("Parameters:")
print(None)
# Out:
# Parameters:
# None

# %%
# %run "C:\Users\james\Documents\MLB\Code\A03. Steamer.ipynb"
# Out:
# Moved 'C:\Users\james\Downloads\steamer_pitchers_weekly_log.csv' to 'C:\Users\james\Documents\MLB\Database\A03. Steamer'.
# Moved 'C:\Users\james\Downloads\steamer_hitters_weekly_log.csv' to 'C:\Users\james\Documents\MLB\Database\A03. Steamer'.
# Moved 'C:\Users\james\Downloads\steamer_pitchers.csv' to 'C:\Users\james\Documents\MLB\Database\A03. Steamer'.
# Moved 'C:\Users\james\Downloads\steamer_hitters.csv' to 'C:\Users\james\Documents\MLB\Database\A03. Steamer'.

# %% [markdown]
# ### A04. Bullpens

# %%
game_df = all_game_df[(all_game_df['date'] >= todaysdate) & (all_game_df['date'] <= todaysdate)].reset_index(drop=True)

# %%
print("Parameters:")
print("game_df")
# Out:
# Parameters:
# game_df

# %%
# %run "C:\Users\james\Documents\MLB\Code\A04. Bullpens.ipynb"
# Out:
# CPU times: total: 281 ms
# Wall time: 42.5 s

# %% [markdown]
# ### A05. Rosters

# %%
game_df = all_game_df.copy()

# %%
print("Parameters:")
print("game_df (yesterday and today)")
# Out:
# Parameters:
# game_df (yesterday and today)

# %%
# %run "C:\Users\james\Documents\MLB\Code\A05. Rosters.ipynb"
# Out:
# CPU times: total: 141 ms
# Wall time: 20.7 s
# CPU times: total: 62.5 ms
# Wall time: 2.67 s

# %% [markdown]
# ### M01. Park and Weather Factors

# %%
# %%time
# %run "C:\Users\james\Documents\MLB\Code\M01. Park and Weather Factors.ipynb"
# Out:
# Imports already in.
# CPU times: total: 31.2 ms
# Wall time: 44.3 ms
# L
# R
# predict_wfx_l.pkl
# CPU times: total: 0 ns
# Wall time: 0 ns
# predict_wfx_r.pkl
# CPU times: total: 0 ns
# Wall time: 0 ns
# CPU times: total: 12min 6s
# Wall time: 12min 40s

# %%
# Should I recreate yesterday's wfx file? Probably! Should be easy.

# %% [markdown]
# ### A06. Weather

# %%
print("Parameters:")
print(f"todaysdate: {todaysdate}")
print(f"game_df (yesterday and today)")
# Out:
# Parameters:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 print("Parameters:")
# ----> 2 print(f"todaysdate: {todaysdate}")
#       3 print(f"game_df (yesterday and today)")
#
# NameError: name 'todaysdate' is not defined

# %%
# %run "C:\Users\james\Documents\MLB\Code\A06. Weather.ipynb"

# %% [markdown]
# ### A07. Projections

# %%
scrape_slates = True

# %%
print("Parameters:")
print(f"todaysdate: {todaysdate}")
print(f"scrape_slates: {scrape_slates}")
# Out:
# Parameters:
# todaysdate: 20250328
# scrape_slates: True

# %%
# %run "C:\Users\james\Documents\MLB\Code\A07. Projections.ipynb"
# Out:
# Scraping slates: True

# %% [markdown]
# ### A08. Odds Sportsbook Review

# %%
game_df = all_game_df.copy()

# %%
print("Parameters:")
print("game_df (yesterday and today)")
# Out:
# Parameters:
# game_df (yesterday and today)

# %%
# %run "C:\Users\james\Documents\MLB\Code\A08. Odds Sportsbook Review.ipynb"

# %% [markdown]
# ### A09. Contest Guides

# %%
game_df = all_game_df.copy()

# %%
print("Parameters:")
print("game_df (yesterday and today)")
# Out:
# Parameters:
# game_df (yesterday and today)

# %%
# %run "C:\Users\james\Documents\MLB\Code\A09. Contest Guides.ipynb"
# Out:
# 20250327
# 175193307
# 175193310
# 175193308
# 175193306
# 175193313
# 175193357
# 175193358
# 175193359
# 175193356
# 175193364
# 175012024
# 175012026
# 175012022
# 175012027
# 175012023
# 175012025
# 20250328
# 175263055
# 175263057
# 175263056
# 175263054
# 175263058
# 175263045
# 175263039
# 175262561
# 175263040
# 175263046
# 175262985
# 175262988
# 175262983
# 175262984
# 175262989
# 175262987
# 175262986

# %% [markdown]
# ### A10. Player Results

# %%
game_df = all_game_df[(all_game_df['date'] >= yesterdaysdate) & (all_game_df['date'] <= yesterdaysdate)].reset_index(drop=True)

# %%
print("Parameters:")
print("game_df (yesterday)")
# Out:
# Parameters:
# game_df (yesterday)

# %%
# %run "C:\Users\james\Documents\MLB\Code\A10. Player Results.ipynb"
# Out:
# 778557
# 778556
# 778553
# 778555
# 778558
# 778559
# 778561
# 778545
# 778554
# 778562
# 778551
# 778546
# 778552
# 778547
# CPU times: total: 547 ms
# Wall time: 2.79 s

# %% [markdown]
# ### Complete Dataset

# %%
multiplier_df = pd.read_csv(os.path.join(baseball_path, "Multiplier Dataset.csv"))

# %%
# %%time
complete_dataset_adjusted_latest = create_pa_inputs(multiplier_df, 2022, 2025, 50, 300, adjust=True)
# Out:
# CPU times: total: 9min 24s
# Wall time: 9min 31s

# %%
complete_dataset_adjusted_latest = complete_dataset_adjusted_latest[complete_dataset_adjusted_latest['year'].astype('int') >= 2025]

# %%
complete_dataset_adjusted_earlier = pd.read_csv(os.path.join(baseball_path, "Complete Dataset - Adjusted through 2024.csv"))

# %%
complete_dataset = pd.concat([complete_dataset_adjusted_earlier, complete_dataset_adjusted_latest], axis=0)

# %%
complete_dataset.to_csv(os.path.join(baseball_path, "Complete Dataset - Adjusted.csv"), index=False)

# %% [markdown]
# ### B01. Matchups

# %%
game_df = all_game_df.copy()

# %%
print("Parameters:")
print("game_df (yesterday and today)")
# Out:
# Parameters:
# game_df (yesterday and today)

# %%
# %run "C:\Users\james\Documents\MLB\Code\B01. Matchups.ipynb"
# Out:
# CPU times: total: 1min 5s
# Wall time: 1min 13s
# CPU times: total: 3.88 s
# Wall time: 4.12 s
# CPU times: total: 6.25 s
# Wall time: 6.34 s
# 23
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  23 out of  23 | elapsed:   34.7s finished
# CPU times: total: 8.16 s
# Wall time: 35.1 s
