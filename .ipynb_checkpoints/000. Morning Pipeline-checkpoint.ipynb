# %% [markdown]
# ### Imports

# %%
# %run "C:\Users\james\Documents\MLB\Code\U1. Imports.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U2. Utilities.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U3. Classes.ipynb"

# %% [markdown]
# ### Settings

# %%
running_pipeline = True

# %% [markdown]
# ### Games

# %%
all_game_df = read_and_save_games(team_map, generate=True)

# %% [markdown]
# ### 001. DraftKings

# %%
print("Parameters:")
print(f"todaysdate: {todaysdate}")
print(f"todaysdate_dash: {todaysdate_dash}")
print(f"yesterdaysdate: {yesterdaysdate}")

# %%
# %run "C:\Users\james\Documents\MLB\Code\001. DraftKings.ipynb"

# %% [markdown]
# ### 002. MLB API

# %%
year = int(todaysdate[:4])
run_datasets = True

# %%
print("Parameters:")
print(f"year: {year}")
print(f"run_datasets: {run_datasets}")

# %%
# %run "C:\Users\james\Documents\MLB\Code\002. MLB API.ipynb"

# %% [markdown]
# ### 003. Steamer

# %%
print("Parameters:")
print(None)

# %%
# %run "C:\Users\james\Documents\MLB\Code\003. Steamer.ipynb"

# %% [markdown]
# ### 004. Bullpens

# %%
game_df = all_game_df[(all_game_df['date'] >= todaysdate) & (all_game_df['date'] <= todaysdate)].reset_index(drop=True)

# %%
print("Parameters:")
print("game_df")

# %%
# %run "C:\Users\james\Documents\MLB\Code\004. Bullpens.ipynb"

# %% [markdown]
# ### 005. Rosters

# %%
print("Parameters:")
print("game_df")

# %%
# %run "C:\Users\james\Documents\MLB\Code\005. Rosters.ipynb"

# %% [markdown]
# ### 006. Weather

# %%
print("Parameters:")
print(f"todaysdate: {todaysdate}")

# %%
# %run "C:\Users\james\Documents\MLB\Code\006. Weather.ipynb"

# %% [markdown]
# ### 007. Projections

# %%
scrape_slates = True

# %%
print("Parameters:")
print(f"todaysdate: {todaysdate}")
print(f"scrape_slates: {scrape_slates}")

# %%
# %run "C:\Users\james\Documents\MLB\Code\007. Projections.ipynb"

# %%
# Reconsider splitting dashboards into today and yesterday

# %% [markdown]
# ### 006B. Park and Weather Factors.ipynb

# %%
game_df = all_game_df[(all_game_df['date'] >= yesterdaysdate) & (all_game_df['date'] <= yesterdaysdate)].reset_index(drop=True)

# %%
train = False

start_year = 2013
end_year = 2024
short = 50
long = 300
adjust = False    
park_window = 10000
park_window_min = 5000
league_window = 60000
league_window_min = 60000
base_year = 2014

historic = True
run_multiplier_dataset = True

# %%
print("Parameters:")
print("game_df")

print(f"train: {train}")
print(f"start_year: {start_year}")
print(f"end_year: {end_year}")
print(f"short: {short}")
print(f"long: {long}")
print(f"adjust: {adjust}")
print(f"park_window: {park_window}")
print(f"park_window_min: {park_window_min}")
print(f"league_window: {league_window}")
print(f"league_window_min: {league_window_min}")
print(f"base_year: {base_year}")

print(f"historic: {historic}")
print(f"run_multiplier_dataset: {run_multiplier_dataset}")

# %%
# %run "C:\Users\james\Documents\MLB\Code\006B. Park and Weather Factors.ipynb"

# %% [markdown]
# ### 008. Odds Sportsbook Review

# %%
date = yesterdaysdate
date_dash = yesterdaysdate_dash

# %%
print("Parameters:")
print("game_df")
print(f"date: {date}")
print(f"date_dash: {date_dash}")

# %%
# %run "C:\Users\james\Documents\MLB\Code\008. Odds Sportsbook Review.ipynb"

# %% [markdown]
# ### 009. Contest Guides

# %%
date = yesterdaysdate

# %%
print("Parameters:")
print("game_df")
print(f"date: {date}")

# %%
# %run "C:\Users\james\Documents\MLB\Code\009. Contest Guides.ipynb"

# %% [markdown]
# ### 010. Player Results

# %%
print("Parameters:")
print("game_df")

# %%
# %run "C:\Users\james\Documents\MLB\Code\010. Player Results.ipynb"

# %% [markdown]
# ### 011. Matchups

# %%
write_complete_dataset = True

# %%
print("Parameters:")
print("game_df")
print(f"write_complete_dataset: {write_complete_dataset}")

# %%
# %run "C:\Users\james\Documents\MLB\Code\011. Matchups.ipynb"
