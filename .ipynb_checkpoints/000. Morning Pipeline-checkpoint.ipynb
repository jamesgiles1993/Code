# %% [markdown]
# # 000. Morning Pipeline
# - This gathers single-run daily data and extracts updated data from yesterday
# - Type: Pipeline
# - Run Frequency: Daily (Morning)
# - Created: 1/1/2025
# - Updated: 5/29/2025

# %% [markdown]
# ### Imports

# %%
# %run "C:\Users\james\Documents\MLB\Code\U1. Imports.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U2. Utilities.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U3. Classes.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U4. Datasets.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U5. Models.ipynb"

# %% [markdown]
# ### Games

# %% [markdown]
# Replace yesterday's and generate today's

# %%
# %%time
historic_game_df = pd.read_csv(os.path.join(baseball_path, "game_df.csv"))
recent_game_df = create_games(yesterdaysdate, todaysdate, team_dict)
historic_game_df = historic_game_df[~historic_game_df['date'].astype(str).isin([yesterdaysdate, todaysdate])]
all_game_df = pd.concat([historic_game_df, recent_game_df], axis=0)
all_game_df.to_csv(os.path.join(baseball_path, "game_df.csv"), index=False)
# Out:
# CPU times: total: 312 ms
# Wall time: 524 ms

# %% [markdown]
# ### A01. DraftKings

# %%
draftables_only = False

# %%
print("A01. DraftKings:")
print(f"todaysdate: {todaysdate}")
print(f"todaysdate_dash: {todaysdate_dash}")
print(f"yesterdaysdate: {yesterdaysdate}")
print(f"draftables_only: {draftables_only}")
# Out:
# A01. DraftKings:
# todaysdate: 20250613
# todaysdate_dash: 2025-06-13
# yesterdaysdate: 20250612
# draftables_only: False

# %%
# %run "C:\Users\james\Documents\MLB\Code\A01. DraftKings.ipynb"
# Out:
# Saved 129134
# Saved 129133
# Saved 129126
# Saved 129018
# CPU times: total: 344 ms
# Wall time: 1.65 s
# CPU times: total: 375 ms
# Wall time: 2.99 s
# 177660270
# contest-standings-177660270
# ['contest-standings-177660270.zip']
# C:\Users\james\Downloads\contest-standings-177660270.zip
# Zip file unpacked successfully!
# 177660269
# contest-standings-177660269
# ['contest-standings-177660269.zip']
# C:\Users\james\Downloads\contest-standings-177660269.zip
# Zip file unpacked successfully!
# 177660272
# contest-standings-177660272
# ['contest-standings-177660272.zip']
# C:\Users\james\Downloads\contest-standings-177660272.zip
# Zip file unpacked successfully!
# 177660271
# contest-standings-177660271
# ['contest-standings-177660271.zip']
# C:\Users\james\Downloads\contest-standings-177660271.zip
# Zip file unpacked successfully!
# 177660273
# contest-standings-177660273
# ['contest-standings-177660273.zip']
# C:\Users\james\Downloads\contest-standings-177660273.zip
# Zip file unpacked successfully!
# 177660324
# contest-standings-177660324
# ['contest-standings-177660324.zip']
# C:\Users\james\Downloads\contest-standings-177660324.zip
# Zip file unpacked successfully!
# 177660323
# contest-standings-177660323
# ['contest-standings-177660323.zip']
# C:\Users\james\Downloads\contest-standings-177660323.zip
# Zip file unpacked successfully!
# 177660325
# contest-standings-177660325
# ['contest-standings-177660325.zip']
# C:\Users\james\Downloads\contest-standings-177660325.zip
# Zip file unpacked successfully!
# 177660326
# contest-standings-177660326
# ['contest-standings-177660326.zip']
# C:\Users\james\Downloads\contest-standings-177660326.zip
# Zip file unpacked successfully!
# 177660327
# contest-standings-177660327
# ['contest-standings-177660327.zip']
# C:\Users\james\Downloads\contest-standings-177660327.zip
# Zip file unpacked successfully!

# %% [markdown]
# ### A02. MLB API

# %%
year = int(todaysdate[:4])

# %%
print("A02. MLB API:")
print(f"year: {year}")
# Out:
# A02. MLB API:
# year: 2025

# %%
# %run "C:\Users\james\Documents\MLB\Code\A02. MLB API.ipynb"
# Out:
# This is a large query, it may take a moment to complete
# 100%|██████████| 87/87 [04:35<00:00,  3.17s/it]
# CPU times: total: 7min 2s
# Wall time: 4min 42s

# %% [markdown]
# ### A03. Steamer

# %%
print("A03. Steamer:")
# Out:
# A03. Steamer:

# %%
# %run "C:\Users\james\Documents\MLB\Code\A03. Steamer.ipynb"
# Out:
# Moved 'C:\Users\james\Downloads\steamer_pitchers_weekly_log.csv' to 'C:\Users\james\Documents\MLB\Database\A03. Steamer'.
# Moved 'C:\Users\james\Downloads\steamer_hitters_weekly_log.csv' to 'C:\Users\james\Documents\MLB\Database\A03. Steamer'.
# Moved 'C:\Users\james\Downloads\steamer_pitchers.csv' to 'C:\Users\james\Documents\MLB\Database\A03. Steamer'.
# Moved 'C:\Users\james\Downloads\steamer_hitters.csv' to 'C:\Users\james\Documents\MLB\Database\A03. Steamer'.

# %% [markdown]
# ### A04. Bullpens

# %%
game_df = all_game_df[all_game_df['date'].astype(str) == todaysdate].reset_index(drop=True)

# %%
print("A04. Bullpens:")
print("game_df")
# Out:
# A04. Bullpens:
# game_df

# %%
# %run "C:\Users\james\Documents\MLB\Code\A04. Bullpens.ipynb"
# Out:
# CPU times: total: 266 ms
# Wall time: 44.2 s

# %% [markdown]
# ### A05. Rosters

# %%
game_df = all_game_df[(all_game_df['date'].astype(str) >= yesterdaysdate) & (all_game_df['date'].astype(str) <= todaysdate)].reset_index(drop=True)

# %%
print("A05. Rosters:")
print("game_df (yesterday and today)")
# Out:
# A05. Rosters:
# game_df (yesterday and today)

# %%
# %run "C:\Users\james\Documents\MLB\Code\A05. Rosters.ipynb"
# Out:
# CPU times: total: 156 ms
# Wall time: 16 s
# CPU times: total: 93.8 ms
# Wall time: 2.74 s

# %% [markdown]
# ### A06. Weather

# %%
game_df = all_game_df[(all_game_df['date'].astype(str) >= yesterdaysdate) & (all_game_df['date'].astype(str) <= todaysdate)].reset_index(drop=True)

# %%
print("A06. Weather:")
print(f"todaysdate: {todaysdate}")
print(f"game_df (yesterday and today)")
# Out:
# A06. Weather:
# todaysdate: 20250613
# game_df (yesterday and today)

# %%
# %run "C:\Users\james\Documents\MLB\Code\A06. Weather.ipynb"
# Out:
# 20250612
# 20250613
# CPU times: total: 422 ms
# Wall time: 10.7 s

# %% [markdown]
# ### A07. Projections

# %%
scrape_slates = True

# %%
print("A07. Projections:")
print(f"todaysdate: {todaysdate}")
print(f"scrape_slates: {scrape_slates}")
# Out:
# A07. Projections:
# todaysdate: 20250613
# scrape_slates: True

# %%
# %run "C:\Users\james\Documents\MLB\Code\A07. Projections.ipynb"
# Out:
# Scraping slates: True

# %% [markdown]
# ### A08. Odds

# %%
game_df = all_game_df[(all_game_df['date'].astype(str) >= yesterdaysdate) & (all_game_df['date'].astype(str) <= todaysdate)].reset_index(drop=True)

# %%
print("A08. Odds:")
print("game_df (yesterday and today)")
# Out:
# A08. Odds:
# game_df (yesterday and today)

# %%
# %run "C:\Users\james\Documents\MLB\Code\A08. Odds.ipynb"

# %% [markdown]
# ### A09. Contest Guides

# %%
game_df = all_game_df[(all_game_df['date'].astype(str) >= yesterdaysdate) & (all_game_df['date'].astype(str) <= todaysdate)].reset_index(drop=True)

# %%
print("A09. Contest Guides:")
print("game_df (yesterday and today)")
# Out:
# A09. Contest Guides:
# game_df (yesterday and today)

# %%
# %run "C:\Users\james\Documents\MLB\Code\A09. Contest Guides.ipynb"
# Out:
# 20250612
# 177660270
# 177660269
# 177660272
# 177660271
# 177660273
# 177660324
# 177660323
# 177660325
# 177660326
# 177660327
# 20250613
# 177690139
# 177690141
# 177690140
# 177690138
# 177690145
# 177690131
# 177690127
# 177689736
# 177690130
# 177690128
# 177690059
# 177690062
# 177689408
# 177690056
# 177690063
# 177690071
# 177690069
# 177690070
# 177690073
# 177690077
# 177690060
# 177690126

# %% [markdown]
# ### A10. Player Results

# %%
game_df = all_game_df[all_game_df['date'].astype(str) == yesterdaysdate].reset_index(drop=True)

# %%
print("A10. Player Results:")
print("game_df (yesterday)")
# Out:
# A10. Player Results:
# game_df (yesterday)

# %%
# %run "C:\Users\james\Documents\MLB\Code\A10. Player Results.ipynb"
# Out:
# 777544
# 777533
# 777534
# 777540
# 777536
# 777532
# 777541
# 777546
# CPU times: total: 484 ms
# Wall time: 1.81 s

# %% [markdown]
# ### M01. Park and Weather Factors

# %%
print("M01. Park and Weather Factors:")
# Out:
# M01. Park and Weather Factors:

# %%
# %run "C:\Users\james\Documents\MLB\Code\M01. Park and Weather Factors.ipynb"
# Out:
# CPU times: total: 2min 44s
# Wall time: 1min 29s
# CPU times: total: 11.3 s
# Wall time: 34.4 s
# 54849/54849 ━━━━━━━━━━━━━━━━━━━━ 58s 1ms/step
# CPU times: total: 0 ns
# Wall time: 0 ns
# CPU times: total: 45min 28s
# Wall time: 8min 59s
# Short took 16.95 seconds
# Long took 24.90 seconds
# CPU times: total: 5min 2s
# Wall time: 5min 7s

# %% [markdown]
# ### Restart Kernel

# %%
app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}
