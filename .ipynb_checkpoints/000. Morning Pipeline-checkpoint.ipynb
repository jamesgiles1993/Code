# %% [markdown]
# ### Imports

# %%
# %run "C:\Users\james\Documents\MLB\Code\U1. Imports.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U2. Utilities.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U3. Classes.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U4. Datasets.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U5. Models.ipynb"

# %% [markdown]
# ### Games

# %% [markdown]
# Replace yesterday's and generate today's

# %%
# %%time
historic_game_df = pd.read_csv(os.path.join(baseball_path, "game_df.csv"))
recent_game_df = create_games(yesterdaysdate, todaysdate, team_dict)
historic_game_df = historic_game_df[~historic_game_df['date'].astype(str).isin([yesterdaysdate, todaysdate])]
all_game_df = pd.concat([historic_game_df, recent_game_df], axis=0)
all_game_df.to_csv(os.path.join(baseball_path, "game_df.csv"), index=False)

# %% [markdown]
# ### A01. DraftKings

# %%
draftables_only = False

# %%
print("A01. DraftKings:")
print(f"todaysdate: {todaysdate}")
print(f"todaysdate_dash: {todaysdate_dash}")
print(f"yesterdaysdate: {yesterdaysdate}")
print(f"draftables_only: {draftables_only}")

# %%
# %run "C:\Users\james\Documents\MLB\Code\A01. DraftKings.ipynb"

# %% [markdown]
# ### A02. MLB API

# %%
year = int(todaysdate[:4])

# %%
print("A02. MLB API:")
print(f"year: {year}")

# %%
# %run "C:\Users\james\Documents\MLB\Code\A02. MLB API.ipynb"

# %% [markdown]
# ### A03. Steamer

# %%
print("A03. Steamer:")

# %%
# %run "C:\Users\james\Documents\MLB\Code\A03. Steamer.ipynb"

# %% [markdown]
# ### A04. Bullpens

# %%
game_df = all_game_df[all_game_df['date'.astype(str)] == todaysdate].reset_index(drop=True)

# %%
print("A04. Bullpens:")
print("game_df")

# %%
# %run "C:\Users\james\Documents\MLB\Code\A04. Bullpens.ipynb"

# %% [markdown]
# ### A05. Rosters

# %%
game_df = all_game_df[all_game_df['date'.astype(str)] == todaysdate].reset_index(drop=True)

# %%
print("A05. Rosters:")
print("game_df (yesterday and today)")

# %%
# %run "C:\Users\james\Documents\MLB\Code\A05. Rosters.ipynb"

# %% [markdown]
# ### Complete Dataset - Unadjusted

# %%
# %%time
complete_df_unadjusted = create_pa_inputs(None, start_year=2015, end_year=2025, short=50, long=300, adjust=False)

# %%
# %%time
complete_df_unadjusted.to_csv(os.path.join(baseball_path, "Complete Dataset - Unadjusted.csv"), index=False)

# %%
del complete_df_unadjusted

# %% [markdown]
# ### M01. Park and Weather Factors

# %%
print("M01. Park and Weather Factors")

# %%
# %%time
# %run "C:\Users\james\Documents\MLB\Code\M01. Park and Weather Factors.ipynb"

# %% [markdown]
# ### A06. Weather

# %%
game_df = all_game_df[all_game_df['date'.astype(str)] == todaysdate].reset_index(drop=True)

# %%
print("A06. Weather:")
print(f"todaysdate: {todaysdate}")
print(f"game_df (yesterday and today)")

# %%
# %run "C:\Users\james\Documents\MLB\Code\A06. Weather-Meteo.ipynb"

# %% [markdown]
# ### A07. Projections

# %%
scrape_slates = True

# %%
print("A07. Projections:")
print(f"todaysdate: {todaysdate}")
print(f"scrape_slates: {scrape_slates}")

# %%
# %run "C:\Users\james\Documents\MLB\Code\A07. Projections.ipynb"

# %% [markdown]
# ### A08. Odds Sportsbook Review

# %%
game_df = all_game_df[all_game_df['date'.astype(str)] == todaysdate].reset_index(drop=True)

# %%
print("A08. Odds Sportsbook Review:")
print("game_df (yesterday and today)")

# %%
# %run "C:\Users\james\Documents\MLB\Code\A08. Odds Sportsbook Review.ipynb"

# %% [markdown]
# ### A09. Contest Guides

# %%
game_df = all_game_df[all_game_df['date'.astype(str)] == todaysdate].reset_index(drop=True)

# %%
print("A09. Contest Guides:")
print("game_df (yesterday and today)")

# %%
# %run "C:\Users\james\Documents\MLB\Code\A09. Contest Guides.ipynb"

# %% [markdown]
# ### A10. Player Results

# %%
game_df = all_game_df[(all_game_df['date'].astype(str) >= yesterdaysdate) & (all_game_df['date'].astype(str) <= yesterdaysdate)].reset_index(drop=True)

# %%
print("A10. Player Results:")
print("game_df (yesterday)")

# %%
# %run "C:\Users\james\Documents\MLB\Code\A10. Player Results.ipynb"

# %% [markdown]
# ### Complete Dataset - Adjusted

# %%
multiplier_df = pd.read_csv(os.path.join(baseball_path, "Multiplier Dataset.csv"))

# %%
generic_venue_list = [2523, 2529]

for event in events_list:
    for side in ["l", "r"]:
        col = f"{event}_wfx_{side}"
        generic_col = f"{event}_generic_wfx_{side}"

        if col in multiplier_df.columns and generic_col in multiplier_df.columns:
            mask = multiplier_df["venue_id"].isin(generic_venue_list)
            multiplier_df.loc[mask, col] = multiplier_df.loc[mask, generic_col]

# %%
# %%time
complete_df_adjusted = create_pa_inputs(multiplier_df, start_year=2015, end_year=2025, short=50, long=300, adjust=True)

# %%
# %%time
complete_df_adjusted.to_csv(os.path.join(baseball_path, "Complete Dataset - Adjusted.csv"), index=False)

# %%
del complete_dataset_adjusted

# %% [markdown]
# ### B01. Matchups

# %%
game_df = all_game_df[(all_game_df['date'].astype(str) >= yesterdaysdate) & (all_game_df['date'].astype(str) <= yesterdaysdate)].reset_index(drop=True)

# %%
print("B01. Matchups:")
print("game_df (yesterday and today)")

# %%
# %run "C:\Users\james\Documents\MLB\Code\B01. Matchups.ipynb"
