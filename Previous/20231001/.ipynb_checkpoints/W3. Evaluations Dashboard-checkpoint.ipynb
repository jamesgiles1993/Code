# %%
### Imports

# %%
import ast
import datetime
import dateutil.parser
import distutils.dir_util
import glob
import IPython.display
import json
import math
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import pathlib
import pickle
import pyautogui
import pytz
import re
import requests
import selenium
import shutil
import statsapi
import statsmodels.formula.api as smf
import time
import unidecode
import warnings
import webbrowser
import xlrd
import random
import urllib
from urllib.request import urlopen, Request
import zipfile

from bs4 import BeautifulSoup
from datetime import date
from IPython.display import display, Javascript
from joblib import Parallel, delayed
from pathlib import Path
from scipy import stats
from sklearn.preprocessing import StandardScaler
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium import webdriver
from openpyxl import load_workbook
from functools import partial

from statsapi import get
from pydfs_lineup_optimizer import get_optimizer, Site, Sport, Player, TeamStack, PlayerFilter, RandomFantasyPointsStrategy

os.chdir(r"C:\Users\james\Documents\MLB\Code")

# from Utilities import *
# from Classes import *
# from simulation_functions_three import *

import smtplib
import ssl
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.base import MIMEBase
from email import encoders

# Ensure the warning is ignored only once
warnings.simplefilter(action="ignore")

# Display the DataFrame
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)

# Set paths
model_path = r"C:\Users\james\Documents\MLB\Code\Models"
baseball_path = r"C:\Users\james\Documents\MLB\Data2"
download_path = r"C:\Users\james\Downloads"

# %%
# Today's Date
# YYYY-MM-DD (datetime)
todaysdate_dt = datetime.date.today()

# YYYY-MM-DD (string)
todaysdate_dash = str(todaysdate_dt)

# MM/DD/YYYY
todaysdate_slash = todaysdate_dash.split("-")
todaysdate_slash = todaysdate_slash[1] + "/" + todaysdate_slash[2] + "/" + todaysdate_slash[0]

# YYYYMMDD
todaysdate = todaysdate_dash.replace("-", "")

## MM-DD-YYYY
todaysdate_dash = todaysdate[:4] + "-" + todaysdate[4:6] + "-" + todaysdate[6:]

# %%
# This reads in a map of team name, codes, and the shorthand MLB uses in their URLs
team_map = pd.read_csv(os.path.join(baseball_path, "Utilities", "Team Map.csv"))

# We just need teams right now
team_map = team_map[['FULLNAME', 'BBREFTEAM', 'MLBURL', 'FANGRAPHSTEAM', 'VENUE_ID', 'SFBBTEAM', 'DKTEAM', 'ROTOWIRETEAM', 'FANPROSTEAM']]

# %%
# Read in history file        
history = pd.read_csv(os.path.join(baseball_path, "Utilities", "Contests.csv"))

# Sort by date, then draft group, then fee
history.sort_values(['date', 'draftGroupId', 'entryFee'], ascending=False)
# Keep only one observation per draft group 
history.drop_duplicates('draftGroupId', keep='first', inplace=True)

history_full = history.copy()
history = history.query('result == 1').query('payout == 1').query('salary == 1')


history = history.reset_index(drop=True)
history['date'] = history['date'].astype('int').astype('str')

# %%
# %run "11. Projections.ipynb"
# %run "Utilities.ipynb"

# %%
# %run "B1. Evaluate Scores.ipynb"

# %%
merged_df = gambling_dashboard(team_map, "20220401", "20230816")

merged_df['BetWin$Exp'] = np.where(merged_df['AwayWin$Exp'] > merged_df['HomeWin$Exp'], merged_df['AwayWin$Exp'], merged_df['HomeWin$Exp'])
merged_df['BetWin$Act'] = np.where(merged_df['AwayWin$Exp'] > merged_df['HomeWin$Exp'], merged_df['AwayWin$Act'], merged_df['HomeWin$Act'])

# %%
bet_df = merged_df[merged_df['BetWin$Exp'] > 100]
bet_df.describe()
# Out:
#               Away         Home     AwayWin%     HomeWin%  AwayWin$Exp  \
# count  1182.000000  1182.000000  1182.000000  1182.000000  1182.000000
# mean      4.075728     4.236228     0.460382     0.539618    98.779003
# std       0.565927     0.571270     0.054712     0.054712    27.076764
# min       2.721000     2.691000     0.299000     0.354000    47.912048
# 25%       3.677250     3.842250     0.422000     0.502000    77.141548
# 50%       4.054500     4.177000     0.460000     0.540000    90.122500
# 75%       4.431750     4.563750     0.498000     0.578000   116.840000
# max       5.991000     6.853000     0.646000     0.701000   210.600000
#
#        HomeWin$Exp  AwayWin$Act  HomeWin$Act   BetWin$Exp   BetWin$Act
# count  1182.000000  1182.000000  1182.000000  1182.000000  1182.000000
# mean    101.566927    95.586046    95.523967   121.652954    96.319131
# std      24.722184   105.883675    94.305730    18.632732   114.161884
# min      51.538776     0.000000     0.000000   100.027586     0.000000
# 25%      82.087064     0.000000     0.000000   106.961619     0.000000
# 50%     100.827291     0.000000   136.363636   117.130500     0.000000
# 75%     117.433500   190.909091   176.335878   131.358750   215.000000
# max     211.820000   380.000000   340.000000   211.820000   380.000000

# %% [markdown]
# 92.783927

# %%
# This doesn't quite work
# Perform one-sample t-test
t_stat, p_value = stats.ttest_1samp(bet_df['BetWin$Act'], 100)

print(p_value)

# Set the significance level (alpha)
alpha = 0.05


# Check if the p-value is less than alpha
if (p_value < alpha) and np.mean(bet_df['BetWin$Act']) > 100:
    print("The average value is statistically greater than 100.")
else:
    print("The average value is not statistically greater than 100.")
# Out:
# 0.007285041036455769
# The average value is not statistically greater than 100.

# %%
# %run "B2. Evaluate Projections.ipynb"

# %%
# Run all
history.reset_index(drop=True, inplace=True)
daily_comparable_dfs = []
daily_complete_dfs = []
for i in range(len(history)): 
    # Extract date and contestKey
    date = str(history['date'][i])
    date = date.replace(".0", "")
    contestKey = history['contestKey'][i]
    print(date, contestKey)
    if date <= "20230816":
        try:
            # Read in projection evaluations
            complete_df = evaluate_projections_post(contestKey)
            daily_complete_dfs.append(complete_df)
            # Make comparable
            comparable_df = compare_projections(complete_df)
            if len(comparable_df) > 30:
                daily_comparable_dfs.append(comparable_df)
        except:
            pass

print("Complete")
all_df = pd.concat(daily_comparable_dfs, axis=0)
all_df = compare_projections(all_df)


all_df_complete = pd.concat(daily_complete_dfs, axis=0)
# Out:
# 20230816 148317020
# 20230816 148316950
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# 9       Corbin Carroll
# 55          Luke Raley
# 67      Patrick Bailey
# 75    Brandon Crawford
# 78          Rene Pinto
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Roto: 66.789652
# 2. MSE_DFF: 72.21727876000001
# 3. MSE_Me: 75.51068288916667
# There were 75 players we all projected.
# I beat DFF on 53.3% of players (Batters: 52.2%, Pitchers: 62.5%).
# I beat RotoWire on 49.3% of players (Batters: 49.3%, Pitchers: 50.0%).
#
#
# 20230816 148316896
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# 119    Cedric Mullins
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Roto: 55.858046540880494
# 2. MSE_Me: 56.08990869198115
# 3. MSE_DFF: 56.47954483018867
# There were 159 players we all projected.
# I beat DFF on 52.2% of players (Batters: 52.4%, Pitchers: 50.0%).
# I beat RotoWire on 50.3% of players (Batters: 49.7%, Pitchers: 56.2%).
#
#
# 20230815 148253677
# 20230815 148253613
# RotoWire Didn't Merge:
# 257    Taylor Rogers
# Name: Name, dtype: object
# DFF Didn't Merge:
# 204        Joey Wiemer
# 219    Joshua Palacios
# 257      Taylor Rogers
# 258       Heliot Ramos
# Name: Name, dtype: object
# Rankings:
# 1. MSE_DFF: 49.91075494509802
# 2. MSE_Roto: 50.083396078431385
# 3. MSE_Me: 50.91720050813725
# There were 255 players we all projected.
# I beat DFF on 54.5% of players (Batters: 55.7%, Pitchers: 44.0%).
# I beat RotoWire on 51.0% of players (Batters: 51.3%, Pitchers: 48.0%).
#
#
# 20230814 148188562
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# 33    Harold Ramirez
# 35     Manuel Margot
# 36       Curtis Mead
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: 43.3213773117361
# 2. MSE_Roto: 45.08683055555556
# 3. MSE_DFF: 45.65048169444444
# There were 36 players we all projected.
# I beat DFF on 66.7% of players (Batters: 62.5%, Pitchers: 100.0%).
# I beat RotoWire on 69.4% of players (Batters: 65.6%, Pitchers: 100.0%).
#
#
# 20230814 148188487
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# 51       Nolan Gorman
# 136        J.D. Davis
# 145    Harold Ramirez
# 158        Luis Matos
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Roto: 64.09102628205127
# 2. MSE_DFF: 64.63679581410256
# 3. MSE_Me: 69.21316325399037
# There were 156 players we all projected.
# I beat DFF on 49.4% of players (Batters: 50.0%, Pitchers: 43.8%).
# I beat RotoWire on 49.4% of players (Batters: 50.0%, Pitchers: 43.8%).
#
#
# 20230813 148133649
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_Roto: 42.242078481012655
# 2. MSE_DFF: 42.66946698734175
# 3. MSE_Me: 47.190479626424036
# There were 79 players we all projected.
# I beat DFF on 51.9% of players (Batters: 53.5%, Pitchers: 37.5%).
# I beat RotoWire on 48.1% of players (Batters: 49.3%, Pitchers: 37.5%).
#
#
# 20230813 148133609
# RotoWire Didn't Merge:
# 12      Luke Weaver
# 15    Andre Jackson
# Name: Name, dtype: object
# DFF Didn't Merge:
# 12       Luke Weaver
# 15     Andre Jackson
# 17     Jack Suwinski
# 66    Endy Rodriguez
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Roto: 52.127967741935464
# 2. MSE_DFF: 52.8963262451613
# 3. MSE_Me: 55.54923155835487
# There were 155 players we all projected.
# I beat DFF on 57.4% of players (Batters: 57.4%, Pitchers: 57.1%).
# I beat RotoWire on 52.3% of players (Batters: 51.8%, Pitchers: 57.1%).
#
#
# 20230812 148066125
# 20230812 148066079
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_Me: 52.14744045083334
# 2. MSE_DFF: 53.256152000000014
# 3. MSE_Roto: 54.12147543859647
# There were 57 players we all projected.
# I beat DFF on 61.4% of players (Batters: 61.5%, Pitchers: 60.0%).
# I beat RotoWire on 57.9% of players (Batters: 57.7%, Pitchers: 60.0%).
#
#
# 20230812 148066038
# 20230812 148065997
# RotoWire Didn't Merge:
# 0    Spencer Strider
# 9      Jose Quintana
# Name: Name, dtype: object
# DFF Didn't Merge:
# 10              Jhony Brito
# 12              Denyi Reyes
# 45              Jake Rogers
# 53          Abraham Almonte
# 55              Javier Baez
# 63           Miguel Cabrera
# 73           Harold Ramirez
# 88                Bo Naylor
# 90             Will Brennan
# 91             Ben Rortvedt
# 98    Christian Bethancourt
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Roto: 71.37525842696628
# 2. MSE_Me: 71.41135006044946
# 3. MSE_DFF: 71.80196711235952
# There were 89 players we all projected.
# I beat DFF on 49.4% of players (Batters: 48.1%, Pitchers: 62.5%).
# I beat RotoWire on 47.2% of players (Batters: 45.7%, Pitchers: 62.5%).
#
#
# 20230811 148027956
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_DFF: 50.21646674137933
# 2. MSE_Roto: 50.41112931034482
# 3. MSE_Me: 52.19023807745693
# There were 58 players we all projected.
# I beat DFF on 60.3% of players (Batters: 63.5%, Pitchers: 33.3%).
# I beat RotoWire on 58.6% of players (Batters: 61.5%, Pitchers: 33.3%).
#
#
# 20230811 148027938
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_Roto: 59.81991948051947
# 2. MSE_DFF: 60.122703649350655
# 3. MSE_Me: 63.693839774999994
# There were 77 players we all projected.
# I beat DFF on 53.2% of players (Batters: 55.1%, Pitchers: 37.5%).
# I beat RotoWire on 49.4% of players (Batters: 50.7%, Pitchers: 37.5%).
#
#
# 20230811 148027853
# RotoWire Didn't Merge:
# 186    Alex Lange
# Name: Name, dtype: object
# DFF Didn't Merge:
# 186        Alex Lange
# 244    Jonathan Arauz
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Roto: 68.69350509803922
# 2. MSE_DFF: 69.36989713333332
# 3. MSE_Me: 74.95031762703918
# There were 255 players we all projected.
# I beat DFF on 47.8% of players (Batters: 49.3%, Pitchers: 34.6%).
# I beat RotoWire on 50.2% of players (Batters: 51.5%, Pitchers: 38.5%).
#
#
# 20230810 147965501
# RotoWire Didn't Merge:
# 3    Alex Vesia
# Name: Name, dtype: object
# DFF Didn't Merge:
# 3        Alex Vesia
# 13    J.D. Martinez
# 70       Alan Trejo
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: 40.09656259422077
# 2. MSE_Roto: 45.51634155844155
# 3. MSE_DFF: 45.888805129870136
# There were 77 players we all projected.
# I beat DFF on 58.4% of players (Batters: 57.1%, Pitchers: 71.4%).
# I beat RotoWire on 55.8% of players (Batters: 54.3%, Pitchers: 71.4%).
#
#
# 20230810 147965440
# RotoWire Didn't Merge:
# 80    Alex Lange
# Name: Name, dtype: object
# DFF Didn't Merge:
# 80    Alex Lange
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: 42.11858247656251
# 2. MSE_DFF: 43.031214887500006
# 3. MSE_Roto: 44.60875
# There were 80 players we all projected.
# I beat DFF on 61.3% of players (Batters: 59.7%, Pitchers: 75.0%).
# I beat RotoWire on 65.0% of players (Batters: 65.3%, Pitchers: 62.5%).
#
#
# 20230809 147920010
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_Roto: 32.15517586206896
# 2. MSE_DFF: 33.54894600000001
# 3. MSE_Me: 35.24431236163793
# There were 58 players we all projected.
# I beat DFF on 46.6% of players (Batters: 48.1%, Pitchers: 33.3%).
# I beat RotoWire on 36.2% of players (Batters: 36.5%, Pitchers: 33.3%).
#
#
# 20230809 147919946
# RotoWire Didn't Merge:
# 58    Lucas Erceg
# Name: Name, dtype: object
# DFF Didn't Merge:
# 58    Lucas Erceg
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: 40.80655782525426
# 2. MSE_DFF: 44.66918138983054
# 3. MSE_Roto: 46.640493220338975
# There were 59 players we all projected.
# I beat DFF on 50.8% of players (Batters: 52.8%, Pitchers: 33.3%).
# I beat RotoWire on 50.8% of players (Batters: 54.7%, Pitchers: 16.7%).
#
#
# 20230809 147919888
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# 160    Oswaldo Cabrera
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: 42.61121840302557
# 2. MSE_Roto: 42.856628977272734
# 3. MSE_DFF: 43.4574434375
# There were 176 players we all projected.
# I beat DFF on 57.4% of players (Batters: 57.6%, Pitchers: 55.6%).
# I beat RotoWire on 55.1% of players (Batters: 55.1%, Pitchers: 55.6%).
#
#
# 20230808 147861327
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# 25    Kike Hernandez
# 71          Sam Huff
# 73    Garrett Cooper
# Name: Name, dtype: object
# Rankings:
# 1. MSE_DFF: 50.487348116883126
# 2. MSE_Roto: 51.190754545454546
# 3. MSE_Me: 53.24716987633116
# There were 77 players we all projected.
# I beat DFF on 51.9% of players (Batters: 53.6%, Pitchers: 37.5%).
# I beat RotoWire on 58.4% of players (Batters: 60.9%, Pitchers: 37.5%).
#
#
# 20230808 147861263
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# 68     Kike Hernandez
# 203          Sam Huff
# 210    Garrett Cooper
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: 54.19211488065975
# 2. MSE_DFF: 55.3703996898148
# 3. MSE_Roto: 55.70476527777781
# There were 216 players we all projected.
# I beat DFF on 57.4% of players (Batters: 58.2%, Pitchers: 50.0%).
# I beat RotoWire on 56.0% of players (Batters: 56.2%, Pitchers: 54.5%).
#
#
# 20230807 147802179
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_Me: 61.952633933820756
# 2. MSE_DFF: 66.17637205031448
# 3. MSE_Roto: 66.74105723270439
# There were 159 players we all projected.
# I beat DFF on 51.6% of players (Batters: 52.1%, Pitchers: 46.7%).
# I beat RotoWire on 52.8% of players (Batters: 54.2%, Pitchers: 40.0%).
#
#
# 20230806 147755822
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_Roto: 74.38169250000001
# 2. MSE_DFF: 77.90606275
# 3. MSE_Me: 78.247950633375
# There were 40 players we all projected.
# I beat DFF on 60.0% of players (Batters: 61.1%, Pitchers: 50.0%).
# I beat RotoWire on 45.0% of players (Batters: 44.4%, Pitchers: 50.0%).
#
#
# 20230806 147755769
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_DFF: 59.31078058256883
# 2. MSE_Roto: 59.52972431192658
# 3. MSE_Me: 60.62307893793572
# There were 218 players we all projected.
# I beat DFF on 52.3% of players (Batters: 52.6%, Pitchers: 50.0%).
# I beat RotoWire on 50.0% of players (Batters: 49.5%, Pitchers: 54.5%).
#
#
# 20230805 147744804
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_Me: 50.78283530090519
# 2. MSE_DFF: 52.45008111206895
# 3. MSE_Roto: 54.07124655172417
# There were 116 players we all projected.
# I beat DFF on 59.5% of players (Batters: 59.4%, Pitchers: 60.0%).
# I beat RotoWire on 54.3% of players (Batters: 53.8%, Pitchers: 60.0%).
#
#
# 20230805 147701665
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# 94    Chad Wallach
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: 49.92737021580132
# 2. MSE_Roto: 50.83158269230767
# 3. MSE_DFF: 50.85918707051281
# There were 156 players we all projected.
# I beat DFF on 52.6% of players (Batters: 52.9%, Pitchers: 50.0%).
# I beat RotoWire on 53.2% of players (Batters: 53.6%, Pitchers: 50.0%).
#
#
# 20230805 147701611
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# 23    Chad Wallach
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: 31.368052045000002
# 2. MSE_DFF: 31.887609684210528
# 3. MSE_Roto: 31.926436842105264
# There were 38 players we all projected.
# I beat DFF on 47.4% of players (Batters: 47.1%, Pitchers: 50.0%).
# I beat RotoWire on 52.6% of players (Batters: 50.0%, Pitchers: 75.0%).
#
#
# 20230805 147701581
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_Me: 59.430948862754235
# 2. MSE_DFF: 61.3341233220339
# 3. MSE_Roto: 64.05237796610169
# There were 59 players we all projected.
# I beat DFF on 61.0% of players (Batters: 60.4%, Pitchers: 66.7%).
# I beat RotoWire on 52.5% of players (Batters: 50.9%, Pitchers: 66.7%).
#
#
# 20230804 147660584
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_DFF: 74.27156061538463
# 2. MSE_Roto: 78.0952153846154
# 3. MSE_Me: 83.99466979326921
# There were 39 players we all projected.
# I beat DFF on 23.1% of players (Batters: 22.9%, Pitchers: 25.0%).
# I beat RotoWire on 33.3% of players (Batters: 37.1%, Pitchers: 0.0%).
#
#
# 20230804 147660489
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# 118    Josh Palacios
# 191      Vinny Capra
# Name: Name, dtype: object
# Rankings:
# 1. MSE_DFF: 60.83529792990654
# 2. MSE_Roto: 61.295627570093444
# 3. MSE_Me: 63.547209663878505
# There were 214 players we all projected.
# I beat DFF on 47.2% of players (Batters: 50.0%, Pitchers: 22.7%).
# I beat RotoWire on 46.3% of players (Batters: 49.0%, Pitchers: 22.7%).
#
#
# 20230803 147591455
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_Roto: 47.65055299145298
# 2. MSE_DFF: 47.69569647008547
# 3. MSE_Me: 48.98943422557691
# There were 117 players we all projected.
# I beat DFF on 52.1% of players (Batters: 54.3%, Pitchers: 33.3%).
# I beat RotoWire on 50.4% of players (Batters: 52.4%, Pitchers: 33.3%).
#
#
# 20230803 147591395
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_DFF: 50.31209151948051
# 2. MSE_Me: 50.823422955844144
# 3. MSE_Roto: 53.843844155844174
# There were 77 players we all projected.
# I beat DFF on 58.4% of players (Batters: 59.4%, Pitchers: 50.0%).
# I beat RotoWire on 62.3% of players (Batters: 65.2%, Pitchers: 37.5%).
#
#
# 20230802 147553313
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_DFF: 41.218972
# 2. MSE_Roto: 41.581871794871795
# 3. MSE_Me: 50.94238757147438
# There were 39 players we all projected.
# I beat DFF on 41.0% of players (Batters: 45.7%, Pitchers: 0.0%).
# I beat RotoWire on 41.0% of players (Batters: 42.9%, Pitchers: 25.0%).
#
#
# 20230802 147553272
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_Roto: 51.13486923076924
# 2. MSE_DFF: 54.832789
# 3. MSE_Me: 61.39715028788459
# There were 39 players we all projected.
# I beat DFF on 41.0% of players (Batters: 37.1%, Pitchers: 75.0%).
# I beat RotoWire on 38.5% of players (Batters: 34.3%, Pitchers: 75.0%).
#
#
# 20230802 147553229
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_DFF: 56.076360379746845
# 2. MSE_Roto: 57.603203797468375
# 3. MSE_Me: 58.21105925867088
# There were 79 players we all projected.
# I beat DFF on 49.4% of players (Batters: 49.3%, Pitchers: 50.0%).
# I beat RotoWire on 55.7% of players (Batters: 57.7%, Pitchers: 37.5%).
#
#
# 20230802 147553174
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_Roto: 69.91507692307697
# 2. MSE_DFF: 70.31239964102562
# 3. MSE_Me: 73.33834013272437
# There were 156 players we all projected.
# I beat DFF on 56.4% of players (Batters: 58.9%, Pitchers: 33.3%).
# I beat RotoWire on 57.7% of players (Batters: 60.3%, Pitchers: 33.3%).
#
#
# 20230801 147491846
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# 246    Isan Diaz
# Name: Name, dtype: object
# Rankings:
# 1. MSE_DFF: 65.20855305597017
# 2. MSE_Roto: 66.00915111940299
# 3. MSE_Me: 67.8023038957369
# There were 268 players we all projected.
# I beat DFF on 50.7% of players (Batters: 51.0%, Pitchers: 48.1%).
# I beat RotoWire on 49.6% of players (Batters: 49.4%, Pitchers: 51.9%).
#
#
# 20230731 147446392
# RotoWire Didn't Merge:
# 39    Taylor Rogers
# Name: Name, dtype: object
# DFF Didn't Merge:
# 39    Taylor Rogers
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: 28.641202735187495
# 2. MSE_Roto: 31.542600000000004
# 3. MSE_DFF: 32.23134094999999
# There were 40 players we all projected.
# I beat DFF on 60.0% of players (Batters: 58.3%, Pitchers: 75.0%).
# I beat RotoWire on 52.5% of players (Batters: 52.8%, Pitchers: 50.0%).
#
#
# 20230731 147446306
# RotoWire Didn't Merge:
# 175    Taylor Rogers
# Name: Name, dtype: object
# DFF Didn't Merge:
# 175    Taylor Rogers
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: 43.80649427306181
# 2. MSE_Roto: 44.06756966292135
# 3. MSE_DFF: 44.24245607303371
# There were 178 players we all projected.
# I beat DFF on 51.7% of players (Batters: 52.5%, Pitchers: 44.4%).
# I beat RotoWire on 49.4% of players (Batters: 50.0%, Pitchers: 44.4%).
#
#
# 20230730 147389357
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# 46         Sam Huff
# 69    Marco Luciano
# 73     Jose Herrera
# Name: Name, dtype: object
# Rankings:
# 1. MSE_DFF: 43.24574545454546
# 2. MSE_Roto: 45.59336883116884
# 3. MSE_Me: 47.61016368860389
# There were 77 players we all projected.
# I beat DFF on 42.9% of players (Batters: 44.9%, Pitchers: 25.0%).
# I beat RotoWire on 50.6% of players (Batters: 49.3%, Pitchers: 62.5%).
#
#
# 20230730 147369756
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_DFF: 45.5290569245283
# 2. MSE_Me: 45.88850567581761
# 3. MSE_Roto: 45.90641949685533
# There were 159 players we all projected.
# I beat DFF on 59.1% of players (Batters: 60.1%, Pitchers: 50.0%).
# I beat RotoWire on 59.1% of players (Batters: 60.1%, Pitchers: 50.0%).
#
#
# 20230729 147335326
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_Me: 46.60686316506409
# 2. MSE_Roto: 49.86611282051282
# 3. MSE_DFF: 50.38536005128205
# There were 39 players we all projected.
# I beat DFF on 66.7% of players (Batters: 68.6%, Pitchers: 50.0%).
# I beat RotoWire on 56.4% of players (Batters: 57.1%, Pitchers: 50.0%).
#
#
# 20230729 147335314
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_Roto: 49.09383205128204
# 2. MSE_DFF: 50.32710176923077
# 3. MSE_Me: 50.405869670288475
# There were 78 players we all projected.
# I beat DFF on 52.6% of players (Batters: 52.1%, Pitchers: 57.1%).
# I beat RotoWire on 52.6% of players (Batters: 53.5%, Pitchers: 42.9%).
#
#
# 20230729 147335284
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_DFF: 66.41242867704275
# 2. MSE_Roto: 66.68549922178991
# 3. MSE_Me: 68.7443294840759
# There were 257 players we all projected.
# I beat DFF on 54.1% of players (Batters: 53.9%, Pitchers: 56.0%).
# I beat RotoWire on 52.1% of players (Batters: 53.9%, Pitchers: 36.0%).
#
#
# 20230729 147335242
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# 20230728 147290897
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_Roto: 29.814983750000003
# 2. MSE_Me: 30.165840335218746
# 3. MSE_DFF: 30.287781249999988
# There were 80 players we all projected.
# I beat DFF on 55.0% of players (Batters: 55.6%, Pitchers: 50.0%).
# I beat RotoWire on 55.0% of players (Batters: 54.2%, Pitchers: 62.5%).
#
#
# 20230728 147290813
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# 259    Andrew Velazquez
# Name: Name, dtype: object
# Rankings:
# 1. MSE_DFF: 47.63938628158846
# 2. MSE_Roto: 48.62617220216608
# 3. MSE_Me: 49.44842120539714
# There were 277 players we all projected.
# I beat DFF on 50.5% of players (Batters: 51.6%, Pitchers: 40.7%).
# I beat RotoWire on 53.8% of players (Batters: 55.2%, Pitchers: 40.7%).
#
#
# 20230727 147238552
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# 40       DJ Stewart
# 43    Gabriel Arias
# 59     Omar Narvaez
# Name: Name, dtype: object
# Rankings:
# 1. MSE_DFF: 49.0244298245614
# 2. MSE_Roto: 50.026428070175456
# 3. MSE_Me: 53.77210237723684
# There were 57 players we all projected.
# I beat DFF on 50.9% of players (Batters: 49.0%, Pitchers: 66.7%).
# I beat RotoWire on 52.6% of players (Batters: 51.0%, Pitchers: 66.7%).
#
#
# 20230726 147199084
# RotoWire Didn't Merge:
# 0     Lance Lynn
# 59     Joe Kelly
# Name: Name, dtype: object
# DFF Didn't Merge:
# 59    Joe Kelly
# Name: Name, dtype: object
# Rankings:
# 1. MSE_DFF: 68.78956896551722
# 2. MSE_Me: 71.64545121853448
# 3. MSE_Roto: 73.68434482758622
# There were 58 players we all projected.
# I beat DFF on 41.4% of players (Batters: 41.5%, Pitchers: 40.0%).
# I beat RotoWire on 48.3% of players (Batters: 45.3%, Pitchers: 80.0%).
#
#
# 20230726 147199053
# RotoWire Didn't Merge:
# 34    Carlos Santana
# Name: Name, dtype: object
# DFF Didn't Merge:
# 0            Zac Gallen
# 1          Johan Oviedo
# 2         Tony Gonsolin
# 3         Yusei Kikuchi
# 4             Seth Lugo
# 5         Jack Flaherty
# 6          Mookie Betts
# 7      Christian Walker
# 8      Paul Goldschmidt
# 9       Freddie Freeman
# 10      Brendan Donovan
# 11        Lars Nootbaar
# 12          Bo Bichette
# 13       Corbin Carroll
# 14    Vladimir Guerrero
# 15      George Springer
# 16          Ketel Marte
# 17         Nolan Gorman
# 18        Jack Suwinski
# 19        Tyler O'Neill
# 20            Max Muncy
# 21       Fernando Tatis
# 22         Matt Chapman
# 23        J.D. Martinez
# 24      Geraldo Perdomo
# 25        Alec Burleson
# 26         Chris Taylor
# 27        Manny Machado
# 28      Emmanuel Rivera
# 29         Brandon Belt
# 30       Bryan Reynolds
# 31         Ha-Seong Kim
# 32      Whit Merrifield
# 33         James Outman
# 34       Carlos Santana
# 35          Alek Thomas
# 36         Danny Jansen
# 37          Paul DeJong
# 38       Andrew Knizner
# 39        Jake McCarthy
# 40      Xander Bogaerts
# 41        Trent Grisham
# 42      Dominic Canzone
# 43          Henry Davis
# 44       Daulton Varsho
# 45     Jake Cronenworth
# 46        Austin Barnes
# 47        Taylor Motter
# 48         Miguel Rojas
# 49         Jared Triolo
# 50       Luis Campusano
# 51         Gary Sanchez
# 52         Cavan Biggio
# 53       Endy Rodriguez
# 54       Taylor Kohlwey
# 55         Jose Herrera
# 56        Nick Gonzales
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: nan
# 2. MSE_DFF: nan
# 3. MSE_Roto: nan
# There were 0 players we all projected.
# I beat DFF on nan% of players (Batters: nan%, Pitchers: nan%).
# I beat RotoWire on nan% of players (Batters: nan%, Pitchers: nan%).
#
#
# 20230726 147199008
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# 0                         Joe Ryan
# 1                   Freddy Peralta
# 2                  Sandy Alcantara
# 3                       Zach Eflin
# 4                       Alec Marsh
# 5                     Bryce Miller
# 6                   Gavin Williams
# 7                    Peter Lambert
# 8                       Ben Lively
# 9                       Jake Irvin
# 10                 Elly De La Cruz
# 11                Christian Yelich
# 12               Jeimer Candelario
# 13                       CJ Abrams
# 14                     Nolan Jones
# 15                    Ryan McMahon
# 16                  Edouard Julien
# 17                  Randal Grichuk
# 18                   Carlos Correa
# 19                 Julio Rodriguez
# 20                     Jake Fraley
# 21                       TJ Friedl
# 22                      Bobby Witt
# 23                    Jose Ramirez
# 24                     Lane Thomas
# 25                     MJ Melendez
# 26                     Matt McLain
# 27                      Joey Votto
# 28                    Keibert Ruiz
# 29                      Max Kepler
# 30                  Eugenio Suarez
# 31                  Ezequiel Tovar
# 32                     Josh Naylor
# 33                    Matt Wallner
# 34                  Trevor Larnach
# 35                    Willi Castro
# 36                       Mike Ford
# 37                   Brenton Doyle
# 38                  Andres Gimenez
# 39                   Dominic Smith
# 40                   Maikel Garcia
# 41                  Jonathan India
# 42               William Contreras
# 43                  Michael Toglia
# 44               Teoscar Hernandez
# 45                     Jorge Soler
# 46                    Brandon Lowe
# 47                 Corey Dickerson
# 48                    Willy Adames
# 49                     Steven Kwan
# 50                Elehuris Montero
# 51                   Wander Franco
# 52                    Joey Meneses
# 53                  Salvador Perez
# 54                       Alex Call
# 55                 Randy Arozarena
# 56                      Luke Raley
# 57                    Abraham Toro
# 58                     Luis Garcia
# 59                   Harold Castro
# 60                     Will Benson
# 61                   Gabriel Arias
# 62                       Josh Lowe
# 63                       Ty France
# 64                     Drew Waters
# 65                   Jesus Sanchez
# 66                  Michael Massey
# 67                     Dylan Moore
# 68                     Kolten Wong
# 69                     Joey Wiemer
# 70                      Tom Murphy
# 71                      Joey Gallo
# 72                    Cade Marlowe
# 73                   Tyler Freeman
# 74                   Tyrone Taylor
# 75                Bryan De La Cruz
# 76                   Isaac Paredes
# 77                    Will Brennan
# 78                    Brice Turang
# 79    Christian Encarnacion-Strand
# 80                     Luis Arraez
# 81                     Sal Frelick
# 82                    Austin Wynns
# 83                Tyler Stephenson
# 84                     Nick Pratto
# 85                       Jose Siri
# 86                   Freddy Fermin
# 87               Andruw Monasterio
# 88                    Yuli Gurriel
# 89                  Harold Ramirez
# 90                      Kyle Isbel
# 91                     Kyle Farmer
# 92               Christian Vazquez
# 93                     Joey Wendle
# 94                     Myles Straw
# 95                       Jon Berti
# 96           Christian Bethancourt
# 97                       David Fry
# 98                 Jacob Stallings
# 99                      Dane Myers
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: nan
# 2. MSE_DFF: nan
# 3. MSE_Roto: nan
# There were 0 players we all projected.
# I beat DFF on nan% of players (Batters: nan%, Pitchers: nan%).
# I beat RotoWire on nan% of players (Batters: nan%, Pitchers: nan%).
#
#
# 20230726 147198950
# RotoWire Didn't Merge:
# 1     Lance Lynn
# 99     Joe Kelly
# Name: Name, dtype: object
# DFF Didn't Merge:
# 99    Joe Kelly
# Name: Name, dtype: object
# Rankings:
# 1. MSE_DFF: 55.55693877551023
# 2. MSE_Me: 57.340755224591845
# 3. MSE_Roto: 58.14544693877549
# There were 98 players we all projected.
# I beat DFF on 48.0% of players (Batters: 50.6%, Pitchers: 22.2%).
# I beat RotoWire on 46.9% of players (Batters: 49.4%, Pitchers: 22.2%).
#
#
# 20230725 147149218
# RotoWire Didn't Merge:
# 136      Amed Rosario
# 150    Carlos Santana
# Name: Name, dtype: object
# DFF Didn't Merge:
# 160    Christian Arroyo
# 186       Jordan Luplow
# Name: Name, dtype: object
# Rankings:
# 1. MSE_DFF: 57.17692796610168
# 2. MSE_Roto: 57.551683898305065
# 3. MSE_Me: 59.443580048930095
# There were 236 players we all projected.
# I beat DFF on 54.2% of players (Batters: 54.7%, Pitchers: 50.0%).
# I beat RotoWire on 52.5% of players (Batters: 52.8%, Pitchers: 50.0%).
#
#
# 20230724 147105607
# RotoWire Didn't Merge:
# 39    Carlos Santana
# Name: Name, dtype: object
# DFF Didn't Merge:
# 23       Dylan Carlson
# 46       Taylor Motter
# 49    Santiago Espinal
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: 64.95087961785715
# 2. MSE_Roto: 65.07474464285715
# 3. MSE_DFF: 66.79995535714285
# There were 56 players we all projected.
# I beat DFF on 57.1% of players (Batters: 58.0%, Pitchers: 50.0%).
# I beat RotoWire on 50.0% of players (Batters: 50.0%, Pitchers: 50.0%).
#
#
# 20230724 147105516
# RotoWire Didn't Merge:
# 61       Amed Rosario
# 110    Carlos Santana
# Name: Name, dtype: object
# DFF Didn't Merge:
# 28        Dylan Carlson
# 138       Taylor Motter
# 145    Santiago Espinal
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Roto: 49.81512662337661
# 2. MSE_Me: 50.35083021943183
# 3. MSE_DFF: 50.67298701298703
# There were 154 players we all projected.
# I beat DFF on 55.2% of players (Batters: 55.1%, Pitchers: 56.2%).
# I beat RotoWire on 50.6% of players (Batters: 50.0%, Pitchers: 56.2%).
#
#
# 20230723 147065551
# RotoWire Didn't Merge:
# 16    Carlos Santana
# Name: Name, dtype: object
# DFF Didn't Merge:
# 0             Bryan Woo
# 1           Luis Medina
# 2          Mitch Keller
# 3          Hunter Brown
# 4        Tyler Anderson
# 5           Alek Manoah
# 6         Shohei Ohtani
# 7       George Springer
# 8           Taylor Ward
# 9          Luis Rengifo
# 10    Vladimir Guerrero
# 11         Matt Chapman
# 12       Bryan Reynolds
# 13       Mike Moustakas
# 14          Bo Bichette
# 15         Brandon Belt
# 16       Carlos Santana
# 17     Andrew McCutchen
# 18           Connor Joe
# 19          Kyle Tucker
# 20        J.P. Crawford
# 21      Eduardo Escobar
# 22          Cal Raleigh
# 23           Seth Brown
# 24          Matt Thaiss
# 25       Daulton Varsho
# 26            Mike Ford
# 27         Trey Cabbage
# 28        Mickey Moniak
# 29         Jared Triolo
# 30          Henry Davis
# 31      Julio Rodriguez
# 32         Danny Jansen
# 33     Andrew Velazquez
# 34          Yainer Diaz
# 35         Alex Bregman
# 36      Whit Merrifield
# 37            JJ Bleday
# 38          Corey Julks
# 39            Tony Kemp
# 40       Mauricio Dubon
# 41      Kevin Kiermaier
# 42    Teoscar Hernandez
# 43      Taylor Trammell
# 44       Eugenio Suarez
# 45       Chas McCormick
# 46           Jose Abreu
# 47        Jace Peterson
# 48         Bligh Madris
# 49       Liover Peguero
# 50          Kolten Wong
# 51          Cody Thomas
# 52        Nick Gonzales
# 53        Austin Hedges
# 54         Aledmys Diaz
# 55          Jordan Diaz
# 56           Zack Gelof
# 57          Jeremy Pena
# 58            Ty France
# 59     Tyler Soderstrom
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: nan
# 2. MSE_DFF: nan
# 3. MSE_Roto: nan
# There were 0 players we all projected.
# I beat DFF on nan% of players (Batters: nan%, Pitchers: nan%).
# I beat RotoWire on nan% of players (Batters: nan%, Pitchers: nan%).
#
#
# 20230723 147051083
# RotoWire Didn't Merge:
# 2    Lucas Giolito
# Name: Name, dtype: object
# DFF Didn't Merge:
# 14     Xzavion Curry
# 110     Matt Wallner
# 140      Sal Frelick
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Roto: 50.051060103626966
# 2. MSE_DFF: 50.594857512953375
# 3. MSE_Me: 50.93390957849737
# There were 193 players we all projected.
# I beat DFF on 48.2% of players (Batters: 48.0%, Pitchers: 50.0%).
# I beat RotoWire on 49.7% of players (Batters: 50.3%, Pitchers: 44.4%).
#
#
# 20230722 147020665
# RotoWire Didn't Merge:
# 64      Amed Rosario
# 71    Carlos Santana
# Name: Name, dtype: object
# DFF Didn't Merge:
# 98       Grae Kessinger
# 99     Andrew Velazquez
# 110         Jake Meyers
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: 40.57520300741227
# 2. MSE_DFF: 46.8364692982456
# 3. MSE_Roto: 46.94511754385964
# There were 114 players we all projected.
# I beat DFF on 69.3% of players (Batters: 69.6%, Pitchers: 66.7%).
# I beat RotoWire on 69.3% of players (Batters: 69.6%, Pitchers: 66.7%).
#
#
# 20230722 147020623
# RotoWire Didn't Merge:
# 19    Carlos Santana
# Name: Name, dtype: object
# DFF Didn't Merge:
# 22      Grae Kessinger
# 25    Andrew Velazquez
# 33         Jake Meyers
# Name: Name, dtype: object
# Rankings:
# 1. MSE_DFF: 33.79131944444445
# 2. MSE_Me: 34.66591082437499
# 3. MSE_Roto: 35.89596666666666
# There were 36 players we all projected.
# I beat DFF on 52.8% of players (Batters: 56.2%, Pitchers: 25.0%).
# I beat RotoWire on 63.9% of players (Batters: 65.6%, Pitchers: 50.0%).
#
#
# 20230722 147020525
# RotoWire Didn't Merge:
# 50    Kike Hernandez
# Name: Name, dtype: object
# DFF Didn't Merge:
# 0                    Logan Gilbert
# 1                    Kevin Gausman
# 2                 Shane McClanahan
# 3                     Max Scherzer
# 4                     James Paxton
# 5                Grayson Rodriguez
# 6                     Dane Dunning
# 7                     Bobby Miller
# 8               Brandon Williamson
# 9                      Ketel Marte
# 10                  Corbin Carroll
# 11                Christian Walker
# 12                  Brandon Pfaadt
# 13                    Mookie Betts
# 14                   Spencer Steer
# 15                 Lourdes Gurriel
# 16                     Matt McLain
# 17                 Freddie Freeman
# 18                 Emmanuel Rivera
# 19                       Max Muncy
# 20                  Jonathan India
# 21                   Evan Longoria
# 22                   Adolis Garcia
# 23                   Justin Turner
# 24                Francisco Lindor
# 25                      Yandy Diaz
# 26                   Rafael Devers
# 27                   Marcus Semien
# 28                   Brandon Nimmo
# 29                      Joey Votto
# 30                Masataka Yoshida
# 31                     Pete Alonso
# 32                   J.D. Martinez
# 33                      Jonah Heim
# 34                 Randy Arozarena
# 35                      Will Smith
# 36                  Nathaniel Lowe
# 37                       TJ Friedl
# 38                    Carson Kelly
# 39               Francisco Alvarez
# 40               Vladimir Guerrero
# 41                   Jason Heyward
# 42                      Nick Ahmed
# 43                     Jake Fraley
# 44                       Josh Jung
# 45                      Mark Canha
# 46                    Jarren Duran
# 47                Travis Jankowski
# 48                 George Springer
# 49                    Matt Chapman
# 50                  Kike Hernandez
# 51                    Alex Verdugo
# 52               Anthony Santander
# 53                    Jorge Alfaro
# 54                     Austin Hays
# 55                    Mitch Garver
# 56                      Luke Raley
# 57                   David Peralta
# 58                     Bo Bichette
# 59                   Triston Casas
# 60    Christian Encarnacion-Strand
# 61                    Brandon Belt
# 62                      DJ Stewart
# 63                   Wander Franco
# 64                Gunnar Henderson
# 65                    Brandon Lowe
# 66                Ryan Mountcastle
# 67                      Brett Baty
# 68                   J.P. Crawford
# 69                    James Outman
# 70                  Ezequiel Duran
# 71                  Eugenio Suarez
# 72                Tyler Stephenson
# 73                   Jake McCarthy
# 74                 Julio Rodriguez
# 75                     Cal Raleigh
# 76                     Will Benson
# 77                       Mike Ford
# 78                     Jeff McNeil
# 79                        Yu Chang
# 80                 Adley Rutschman
# 81               Teoscar Hernandez
# 82                       Jose Siri
# 83                   Leody Taveras
# 84                   Isaac Paredes
# 85                     Ramon Urias
# 86                     Aaron Hicks
# 87                  Daulton Varsho
# 88                    Miguel Rojas
# 89                    Mark Vientos
# 90                    James McCann
# 91                       Josh Lowe
# 92                    Cavan Biggio
# 93                     Dylan Moore
# 94                     Jorge Mateo
# 95                  Alejandro Kirk
# 96                 Kevin Kiermaier
# 97                       Ty France
# 98                     Kolten Wong
# 99                      Rene Pinto
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: nan
# 2. MSE_DFF: nan
# 3. MSE_Roto: nan
# There were 0 players we all projected.
# I beat DFF on nan% of players (Batters: nan%, Pitchers: nan%).
# I beat RotoWire on nan% of players (Batters: nan%, Pitchers: nan%).
#
#
# 20230721 146982102
# RotoWire Didn't Merge:
# 12    Carlos Santana
# Name: Name, dtype: object
# DFF Didn't Merge:
# 43      Seth Brown
# 56    Cavan Biggio
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Roto: 71.10262363636363
# 2. MSE_DFF: 71.60904545454548
# 3. MSE_Me: 78.4010090132727
# There were 55 players we all projected.
# I beat DFF on 47.3% of players (Batters: 49.0%, Pitchers: 33.3%).
# I beat RotoWire on 45.5% of players (Batters: 44.9%, Pitchers: 50.0%).
#
#
# 20230721 146982096
# RotoWire Didn't Merge:
# 3    Lance Lynn
# Name: Name, dtype: object
# DFF Didn't Merge:
# Series([], Name: Name, dtype: object)
# Rankings:
# 1. MSE_Roto: 63.55144210526316
# 2. MSE_DFF: 65.56644736842105
# 3. MSE_Me: 73.03211757399124
# There were 57 players we all projected.
# I beat DFF on 31.6% of players (Batters: 30.8%, Pitchers: 40.0%).
# I beat RotoWire on 38.6% of players (Batters: 40.4%, Pitchers: 20.0%).
#
#
# 20230721 146982078
# RotoWire Didn't Merge:
# 0                Zach Eflin
# 1           Braxton Garrett
# 2              Kyle Bradish
# 3               Reese Olson
# 4             Peter Lambert
# 5                 Seth Lugo
# 6              Riley Greene
# 7            Fernando Tatis
# 8                 Juan Soto
# 9             Manny Machado
# 10         Jurickson Profar
# 11             Ryan McMahon
# 12          Randy Arozarena
# 13              Jorge Soler
# 14                C.J. Cron
# 15             Ha-Seong Kim
# 16            Wander Franco
# 17         Gunnar Henderson
# 18               Yandy Diaz
# 19               Luke Raley
# 20           Zach McKinstry
# 21        Anthony Santander
# 22              Kris Bryant
# 23             Ryan O'Hearn
# 24           Randal Grichuk
# 25          Kerry Carpenter
# 26        Spencer Torkelson
# 27          Adley Rutschman
# 28           Garrett Cooper
# 29            Isaac Paredes
# 30         Jake Cronenworth
# 31            Jesus Sanchez
# 32           Ezequiel Tovar
# 33              Luis Arraez
# 34         Ryan Mountcastle
# 35              Jean Segura
# 36            Trent Grisham
# 37               Elias Diaz
# 38          Xander Bogaerts
# 39             Brandon Lowe
# 40              Austin Hays
# 41              Nick Fortes
# 42            Matt Vierling
# 43              Akil Baddoo
# 44               Nick Maton
# 45         Bryan De La Cruz
# 46                Jose Siri
# 47            Brenton Doyle
# 48           Taylor Kohlwey
# 49           Luis Campusano
# 50              Javier Baez
# 51               Alan Trejo
# 52          Jordan Westburg
# 53             Adam Frazier
# 54              Joey Wendle
# 55              Jake Rogers
# 56    Christian Bethancourt
# 57           Harold Ramirez
# 58            Colton Cowser
# 59               Dane Myers
# Name: Name, dtype: object
# DFF Didn't Merge:
# 0                Zach Eflin
# 1           Braxton Garrett
# 2              Kyle Bradish
# 3               Reese Olson
# 4             Peter Lambert
# 5                 Seth Lugo
# 6              Riley Greene
# 7            Fernando Tatis
# 8                 Juan Soto
# 9             Manny Machado
# 10         Jurickson Profar
# 11             Ryan McMahon
# 12          Randy Arozarena
# 13              Jorge Soler
# 14                C.J. Cron
# 15             Ha-Seong Kim
# 16            Wander Franco
# 17         Gunnar Henderson
# 18               Yandy Diaz
# 19               Luke Raley
# 20           Zach McKinstry
# 21        Anthony Santander
# 22              Kris Bryant
# 23             Ryan O'Hearn
# 24           Randal Grichuk
# 25          Kerry Carpenter
# 26        Spencer Torkelson
# 27          Adley Rutschman
# 28           Garrett Cooper
# 29            Isaac Paredes
# 30         Jake Cronenworth
# 31            Jesus Sanchez
# 32           Ezequiel Tovar
# 33              Luis Arraez
# 34         Ryan Mountcastle
# 35              Jean Segura
# 36            Trent Grisham
# 37               Elias Diaz
# 38          Xander Bogaerts
# 39             Brandon Lowe
# 40              Austin Hays
# 41              Nick Fortes
# 42            Matt Vierling
# 43              Akil Baddoo
# 44               Nick Maton
# 45         Bryan De La Cruz
# 46                Jose Siri
# 47            Brenton Doyle
# 48           Taylor Kohlwey
# 49           Luis Campusano
# 50              Javier Baez
# 51               Alan Trejo
# 52          Jordan Westburg
# 53             Adam Frazier
# 54              Joey Wendle
# 55              Jake Rogers
# 56    Christian Bethancourt
# 57           Harold Ramirez
# 58            Colton Cowser
# 59               Dane Myers
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: nan
# 2. MSE_DFF: nan
# 3. MSE_Roto: nan
# There were 0 players we all projected.
# I beat DFF on nan% of players (Batters: nan%, Pitchers: nan%).
# I beat RotoWire on nan% of players (Batters: nan%, Pitchers: nan%).
#
#
# 20230721 146982016
# RotoWire Didn't Merge:
# 10         Lance Lynn
# 92     Carlos Santana
# 105      Amed Rosario
# Name: Name, dtype: object
# DFF Didn't Merge:
# 180      Seth Brown
# 196    Cavan Biggio
# Name: Name, dtype: object
# Rankings:
# 1. MSE_DFF: 68.71015402843602
# 2. MSE_Roto: 68.91008293838863
# 3. MSE_Me: 74.03037460132701
# There were 211 players we all projected.
# I beat DFF on 46.4% of players (Batters: 46.8%, Pitchers: 42.9%).
# I beat RotoWire on 46.9% of players (Batters: 47.9%, Pitchers: 38.1%).
#
#
# 20230720 146936238
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# 0        Marcus Stroman
# 1          Hogan Harris
# 2           Steven Matz
# 3           J.P. France
# 4      Paul Goldschmidt
# 5     Willson Contreras
# 6         Nolan Arenado
# 7           Kyle Tucker
# 8         Lars Nootbaar
# 9         Tyler O'Neill
# 10         Nolan Gorman
# 11        Jordan Walker
# 12         Seiya Suzuki
# 13             Ian Happ
# 14       Chas McCormick
# 15         Alex Bregman
# 16       Cody Bellinger
# 17       Mauricio Dubon
# 18            JJ Bleday
# 19            Tony Kemp
# 20           Jose Abreu
# 21          Yainer Diaz
# 22         Nico Hoerner
# 23          Paul DeJong
# 24          Jeremy Pena
# 25           Seth Brown
# 26          Jordan Diaz
# 27        Alec Burleson
# 28    Christopher Morel
# 29       Patrick Wisdom
# 30          Corey Julks
# 31            Yan Gomes
# 32        Jace Peterson
# 33         Aledmys Diaz
# 34          Jake Meyers
# 35           Zack Gelof
# 36         Trey Mancini
# 37     Tyler Soderstrom
# 38          Cody Thomas
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: nan
# 2. MSE_DFF: nan
# 3. MSE_Roto: nan
# There were 0 players we all projected.
# I beat DFF on nan% of players (Batters: nan%, Pitchers: nan%).
# I beat RotoWire on nan% of players (Batters: nan%, Pitchers: nan%).
#
#
# 20230720 146936156
# RotoWire Didn't Merge:
# 99    Raimel Tapia
# Name: Name, dtype: object
# DFF Didn't Merge:
# 112    Jordan Luplow
# 117     Matt Wallner
# 118     Cade Marlowe
# 138    Alfonso Rivas
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: 60.03352666679631
# 2. MSE_Roto: 60.1730540740741
# 3. MSE_DFF: 61.54
# There were 135 players we all projected.
# I beat DFF on 37.0% of players (Batters: 34.7%, Pitchers: 57.1%).
# I beat RotoWire on 46.7% of players (Batters: 47.9%, Pitchers: 35.7%).
#
#
# 20230719 146900317
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# 15    Salvador Perez
# 42      Matt Wallner
# 43      Willi Castro
# 59        Tom Murphy
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: 47.65379247598215
# 2. MSE_Roto: 50.18885714285714
# 3. MSE_DFF: 51.13607142857142
# There were 56 players we all projected.
# I beat DFF on 55.4% of players (Batters: 54.0%, Pitchers: 66.7%).
# I beat RotoWire on 60.7% of players (Batters: 60.0%, Pitchers: 66.7%).
#
#
# 20230719 146900263
# RotoWire Didn't Merge:
# 93    Kike Hernandez
# Name: Name, dtype: object
# DFF Didn't Merge:
# 0             Ken Waldichuk
# 1           Sandy Alcantara
# 2              Brayan Bello
# 3               Dean Kremer
# 4                  Jon Gray
# 5              Zack Littell
# 6               Julio Urias
# 7              Mookie Betts
# 8             Dakota Hudson
# 9             Austin Gomber
# 10          Freddie Freeman
# 11              Kris Bryant
# 12              Kyle Tucker
# 13                C.J. Cron
# 14             Ryan McMahon
# 15             Corey Seager
# 16           Brandon Bielak
# 17         Jurickson Profar
# 18                Max Muncy
# 19               Will Smith
# 20        Anthony Santander
# 21         Paul Goldschmidt
# 22              Jeremy Pena
# 23               Luke Raley
# 24               Yandy Diaz
# 25               Elias Diaz
# 26         Gunnar Henderson
# 27            Marcus Semien
# 28           Mauricio Dubon
# 29            Adolis Garcia
# 30           Chas McCormick
# 31              Jorge Soler
# 32          Brendan Donovan
# 33             Alex Bregman
# 34            Lars Nootbaar
# 35            Nolan Arenado
# 36             Nolan Gorman
# 37               Jose Abreu
# 38            Jason Heyward
# 39         Ryan Mountcastle
# 40            David Peralta
# 41             James Outman
# 42              Austin Hays
# 43           Ezequiel Tovar
# 44                Jose Siri
# 45               Jonah Heim
# 46             Brandon Lowe
# 47           Nathaniel Lowe
# 48          Jordan Westburg
# 49              Jake Meyers
# 50              Corey Julks
# 51              Aaron Hicks
# 52                Josh Jung
# 53                Josh Lowe
# 54            Isaac Paredes
# 55            Jesus Sanchez
# 56            Rafael Devers
# 57            Brenton Doyle
# 58           Michael Toglia
# 59              Luis Arraez
# 60            Austin Barnes
# 61              Jorge Mateo
# 62            Harold Castro
# 63             Alex Verdugo
# 64            Alec Burleson
# 65         Masataka Yoshida
# 66         Martin Maldonado
# 67            Manuel Margot
# 68              Paul DeJong
# 69         Bryan De La Cruz
# 70          Robbie Grossman
# 71             Miguel Rojas
# 72             James McCann
# 73              Ramon Urias
# 74            Justin Turner
# 75            Rob Refsnyder
# 76                Tony Kemp
# 77               Seth Brown
# 78             Taylor Walls
# 79              Jordan Diaz
# 80            Dylan Carlson
# 81             Yuli Gurriel
# 82            Leody Taveras
# 83                JJ Bleday
# 84                Jon Berti
# 85              Adam Duvall
# 86         Travis Jankowski
# 87              Joey Wendle
# 88             Ivan Herrera
# 89    Christian Bethancourt
# 90          Shea Langeliers
# 91              Connor Wong
# 92         Tyler Soderstrom
# 93           Kike Hernandez
# 94                 Yu Chang
# 95          Jacob Stallings
# 96            Jace Peterson
# 97               Nick Allen
# 98               Dane Myers
# 99              Cody Thomas
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: nan
# 2. MSE_DFF: nan
# 3. MSE_Roto: nan
# There were 0 players we all projected.
# I beat DFF on nan% of players (Batters: nan%, Pitchers: nan%).
# I beat RotoWire on nan% of players (Batters: nan%, Pitchers: nan%).
#
#
# 20230719 146900195
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# 58     Salvador Perez
# 73       David Villar
# 120      Willi Castro
# 125      Matt Wallner
# 157        Tom Murphy
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: 49.66486756447712
# 2. MSE_Roto: 54.138190196078426
# 3. MSE_DFF: 54.955032679738615
# There were 153 players we all projected.
# I beat DFF on 61.4% of players (Batters: 61.3%, Pitchers: 62.5%).
# I beat RotoWire on 64.1% of players (Batters: 64.2%, Pitchers: 62.5%).
#
#
# 20230718 146859348
# RotoWire Didn't Merge:
# 5    Joe Jacques
# Name: Name, dtype: object
# DFF Didn't Merge:
# 5    Joe Jacques
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: 73.93640614538134
# 2. MSE_DFF: 77.96444915254236
# 3. MSE_Roto: 81.3927779661017
# There were 59 players we all projected.
# I beat DFF on 57.6% of players (Batters: 57.4%, Pitchers: 60.0%).
# I beat RotoWire on 64.4% of players (Batters: 64.8%, Pitchers: 60.0%).
#
#
# 20230718 146859345
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# 77    Miles Mastrobuoni
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Roto: 73.94194285714288
# 2. MSE_DFF: 74.7589285714286
# 3. MSE_Me: 84.05257914837661
# There were 77 players we all projected.
# I beat DFF on 51.9% of players (Batters: 52.9%, Pitchers: 42.9%).
# I beat RotoWire on 49.4% of players (Batters: 51.4%, Pitchers: 28.6%).
#
#
# 20230718 146859291
# RotoWire Didn't Merge:
# 1       Lucas Giolito
# 28        Joe Jacques
# 77       Amed Rosario
# 128    Carlos Santana
# Name: Name, dtype: object
# DFF Didn't Merge:
# 28           Joe Jacques
# 99         Wilmer Flores
# 189          Curt Casali
# 216           Mark Canha
# 229        Casey Schmitt
# 272    Miles Mastrobuoni
# Name: Name, dtype: object
# Rankings:
# 1. MSE_DFF: 87.46263888888892
# 2. MSE_Roto: 90.26848481481493
# 3. MSE_Me: 92.87014273901849
# There were 270 players we all projected.
# I beat DFF on 53.7% of players (Batters: 54.7%, Pitchers: 44.0%).
# I beat RotoWire on 57.8% of players (Batters: 59.2%, Pitchers: 44.0%).
#
#
# 20230717 146815647
# RotoWire Didn't Merge:
# Series([], Name: Name, dtype: object)
# DFF Didn't Merge:
# 5     Brennan Bernardino
# 26         Oswald Peraza
# 57          Jose Trevino
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Roto: 42.57595
# 2. MSE_Me: 43.71913778383928
# 3. MSE_DFF: 44.54910714285715
# There were 56 players we all projected.
# I beat DFF on 66.1% of players (Batters: 68.6%, Pitchers: 40.0%).
# ...
# 2. MSE_DFF: 46.91213815789473
# 3. MSE_Roto: 64.43955131578944
# There were 76 players we all projected.
# I beat DFF on 56.6% of players (Batters: 58.8%, Pitchers: 37.5%).
# I beat RotoWire on 68.4% of players (Batters: 72.1%, Pitchers: 37.5%).
#
#
# 20220429 126297716
# RotoWire Didn't Merge:
# 0         Frankie Montas
# 2           Corey Kluber
# 4          Lucas Giolito
# 7      Madison Bumgarner
# 12      Garrett Richards
# 14           Dylan Bundy
# 15        Tyler Anderson
# 22             Rich Hill
# 24         Aaron Sanchez
# 25            Connor Joe
# 26             Juan Soto
# 33            Tommy Pham
# 37           Trea Turner
# 40          Tyler Naquin
# 41     Willson Contreras
# 43          Sam Hilliard
# 47         Rafael Ortega
# 55       Jonathan Villar
# 56       Xander Bogaerts
# 58           Kolten Wong
# 61         Brandon Marsh
# 65        Mike Moustakas
# 66         Justin Turner
# 72             Josh Bell
# 74      Andrew McCutchen
# 76         Brandon Drury
# 78           Aaron Hicks
# 83           Nelson Cruz
# 84           Kyle Farmer
# 86          Kole Calhoun
# 87     Andrew Benintendi
# 90         David Peralta
# 96       Whit Merrifield
# 99       Lourdes Gurriel
# 100        Hunter Dozier
# 109         Trey Mancini
# 113       Carlos Santana
# 114       Hunter Renfroe
# 115     Travis Demeritte
# 116          Jean Segura
# 122      Robbie Grossman
# 123       Daulton Varsho
# 124        Jason Heyward
# 131           Derek Hill
# 135          Luis Arraez
# 136      Franchy Cordero
# 137         Yuli Gurriel
# 139        Maikel Franco
# 142            Darin Ruf
# 144         Tim Locastro
# 145          Adam Duvall
# 147       Willie Calhoun
# 149      Jonathan Schoop
# 152        Alfonso Rivas
# 153         Lorenzo Cain
# 154       Harrison Bader
# 157    Jeimer Candelario
# 162        Albert Pujols
# 163        Franmil Reyes
# 167       Cody Bellinger
# 169      Eduardo Escobar
# 172        Jace Peterson
# 173          Owen Miller
# 174       Jackie Bradley
# 175          Gio Urshela
# 177    Guillermo Heredia
# 178        Cooper Hummel
# 179    Robinson Chirinos
# 180        Aramis Garcia
# 181          Chad Pinder
# 188           Jed Lowrie
# 190           Matt Duffy
# 192            Jose Siri
# 193      Kevin Kiermaier
# 194    William Contreras
# 195          Sean Murphy
# 197          Mike Zunino
# 198         Zack Collins
# 201        Sheldon Neuse
# 203       Dansby Swanson
# 205       Didi Gregorius
# 208       Brett Phillips
# 209          Tyler Nevin
# 210         Raimel Tapia
# 211        Ernie Clement
# 214        Yadier Molina
# 215        Josh Harrison
# 218         Elvis Andrus
# 220         James McCann
# 221      Alcides Escobar
# 223        Austin Hedges
# 224      Tucker Barnhart
# 225       Billy McKinney
# 226      Richie Palacios
# 230         Camilo Doval
# 231       Cristian Pache
# 232         Jason Vosler
# Name: Name, dtype: object
# DFF Didn't Merge:
# 21          Jimmy Herget
# 55       Jonathan Villar
# 128       Austin Meadows
# 140     Christian Arroyo
# 144         Tim Locastro
# 152        Alfonso Rivas
# 178        Cooper Hummel
# 190           Matt Duffy
# 192            Jose Siri
# 194    William Contreras
# 197          Mike Zunino
# 207         Ryan McKenna
# 209          Tyler Nevin
# 211        Ernie Clement
# 219         Taylor Walls
# 222       David Fletcher
# 229       Tyler Heineman
# 230         Camilo Doval
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Roto: 54.8646808
# 2. MSE_DFF: 55.85469999999998
# 3. MSE_Me: 57.33794635179994
# There were 125 players we all projected.
# I beat DFF on 53.6% of players (Batters: 55.0%, Pitchers: 42.9%).
# I beat RotoWire on 54.4% of players (Batters: 55.9%, Pitchers: 42.9%).
#
#
# 20220428 126241351
# RotoWire Didn't Merge:
# 0       Justin Verlander
# 3            Tyler Mahle
# 8        Jameson Taillon
# 15          Chris Flexen
# 17             Juan Soto
# 18           Nelson Cruz
# 20          Jesse Winker
# 22            Tommy Pham
# 25             Josh Bell
# 40          Trey Mancini
# 47          Tyler Naquin
# 49      Daniel Vogelbach
# 50            Connor Joe
# 51          Kole Calhoun
# 55         Maikel Franco
# 59      Jurickson Profar
# 62           Gio Urshela
# 64          Abraham Toro
# 65      Andrew McCutchen
# 67           Eric Hosmer
# 68          Rougned Odor
# 70       Jonathan Schoop
# 71          Adam Frazier
# 77        Michael Chavis
# 78          Miguel Rojas
# 79        Hunter Renfroe
# 80       Robbie Grossman
# 81      Yadiel Hernandez
# 82     Andrew Benintendi
# 85         Brandon Drury
# 86            Derek Hill
# 90           Colin Moran
# 91             Ben Gamel
# 92        Brian Anderson
# 95        Mike Moustakas
# 98       Whit Merrifield
# 100          Jean Segura
# 101          Luis Arraez
# 105           Joey Gallo
# 106           AJ Pollock
# 107           Matt Beaty
# 108       Carlos Santana
# 111         Sam Hilliard
# 113          Kolten Wong
# 114         Jorge Alfaro
# 115       Willie Calhoun
# 116          Kyle Farmer
# 117         Willi Castro
# 119       Diego Castillo
# 120        Josh VanMeter
# 123         Yuli Gurriel
# 125         Lorenzo Cain
# 128         Luis Torrens
# 133         Payton Henry
# 137       Didi Gregorius
# 143        Matt Vierling
# 144         Tim Locastro
# 145       Brett Phillips
# 146      Marwin Gonzalez
# 147            Jose Siri
# 148          Roman Quinn
# 149        Harold Castro
# 151      Mark Kolozsvary
# 152        Cam Gallagher
# 153        Reese McGuire
# 154      Tucker Barnhart
# Name: Name, dtype: object
# DFF Didn't Merge:
# 13    Austin Gomber
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: 38.41132828070226
# 2. MSE_DFF: 41.30398876404493
# 3. MSE_Roto: 46.16622584269661
# There were 89 players we all projected.
# I beat DFF on 55.1% of players (Batters: 51.3%, Pitchers: 81.8%).
# I beat RotoWire on 66.3% of players (Batters: 65.4%, Pitchers: 72.7%).
#
#
# 20220426 126170759
# RotoWire Didn't Merge:
# 5               Jordan Lyles
# 8               Taylor Hearn
# 14             Chris Bassitt
# 16             Jake Odorizzi
# 19                 Juan Soto
# 20            Dallas Keuchel
# 23            Daulton Varsho
# 26             David Peralta
# 27               Nelson Cruz
# 29                 Josh Bell
# 33               Trea Turner
# 34         Willson Contreras
# 44             Justin Turner
# 52             Hunter Dozier
# 54        Michael Hermosillo
# 57           Whit Merrifield
# 58           Robbie Grossman
# 62              Niko Goodrum
# 63                AJ Pollock
# 65         Andrew Benintendi
# 75                 Jose Siri
# 78               Adam Duvall
# 79           Frank Schwindel
# 82           Xander Bogaerts
# 88             J.D. Martinez
# 89            Alex Dickerson
# 91          Yadiel Hernandez
# 95           Jonathan Schoop
# 97            Cody Bellinger
# 100           Carlos Santana
# 101             Amed Rosario
# 105            Franmil Reyes
# 106             Yuli Gurriel
# 107             Zack Collins
# 108            Maikel Franco
# 110                Darin Ruf
# 112         Stephen Piscotty
# 116            Dominic Smith
# 117               Adam Engel
# 120             Brandon Belt
# 121           Brian Anderson
# 122        Jeimer Candelario
# 127              Gio Urshela
# 128            Brandon Marsh
# 129              Sean Murphy
# 130           Dansby Swanson
# 131             Rougned Odor
# 132        Adalberto Mondesi
# 133             Trey Mancini
# 135            Sheldon Neuse
# 140         Travis Demeritte
# 143             Kole Calhoun
# 145          Eduardo Escobar
# 150             Elvis Andrus
# 153            Josh Harrison
# 156           Willie Calhoun
# 157           Harrison Bader
# 159            Oscar Mercado
# 160               Joey Gallo
# 161               Derek Hill
# 162              Owen Miller
# 163             Raimel Tapia
# 164            Danny Mendick
# 166          Alcides Escobar
# 168           Jackie Bradley
# 169              Kurt Suzuki
# 171            Austin Hedges
# 177            Ernie Clement
# 179             James McCann
# 180               Matt Duffy
# 181          Tucker Barnhart
# 183    Christian Bethancourt
# 184           Bradley Zimmer
# 186        Robinson Chirinos
# 192           Cristian Pache
# 195             Jason Vosler
# 196             Gosuke Katoh
# 199             Camilo Doval
# Name: Name, dtype: object
# DFF Didn't Merge:
# 62         Niko Goodrum
# 75            Jose Siri
# 116       Dominic Smith
# 121      Brian Anderson
# 151          Jonah Heim
# 161          Derek Hill
# 164       Danny Mendick
# 165        Jose Herrera
# 169         Kurt Suzuki
# 172    Christian Arroyo
# 176     Brendan Donovan
# 180          Matt Duffy
# 187      Gleyber Torres
# 189      Andrew Knizner
# 196        Gosuke Katoh
# 199        Camilo Doval
# Name: Name, dtype: object
# Rankings:
# 1. MSE_DFF: 65.61922413793103
# 2. MSE_Roto: 65.99608965517241
# 3. MSE_Me: 68.9054535200431
# There were 116 players we all projected.
# I beat DFF on 49.1% of players (Batters: 52.0%, Pitchers: 31.2%).
# I beat RotoWire on 56.9% of players (Batters: 60.0%, Pitchers: 37.5%).
#
#
# 20220424 126104770
# 20220423 126063098
# RotoWire Didn't Merge:
# 1      Noah Syndergaard
# 5     Elieser Hernandez
# 6        Tyler Anderson
# 8       Trevor Williams
# 9         David Peralta
# 10      Spenser Watkins
# 12       Daulton Varsho
# 21          Trea Turner
# 25        Justin Turner
# 31         Trey Mancini
# 34        Dominic Smith
# 39      Eduardo Escobar
# 43        Brandon Marsh
# 50          Eric Hosmer
# 51         Rougned Odor
# 54        Hunter Dozier
# 55       Brian Anderson
# 58       Cody Bellinger
# 61     Jurickson Profar
# 62      Whit Merrifield
# 63    Andrew Benintendi
# 67         Abraham Toro
# 69       Alex Dickerson
# 71       Carlos Santana
# 73         Adam Frazier
# 74          Adam Duvall
# 76       Dansby Swanson
# 77           Tyler Wade
# 78         Jorge Alfaro
# 79    Adalberto Mondesi
# 82            Wil Myers
# 85         Payton Henry
# 88         Ryan O'Hearn
# Name: Name, dtype: object
# DFF Didn't Merge:
# 34      Dominic Smith
# 42    Geraldo Perdomo
# 55     Brian Anderson
# 65          Jon Berti
# 78       Jorge Alfaro
# 88       Ryan O'Hearn
# Name: Name, dtype: object
# Rankings:
# 1. MSE_DFF: 98.91754629629628
# 2. MSE_Me: 100.26884200379628
# 3. MSE_Roto: 101.71042592592593
# There were 54 players we all projected.
# I beat DFF on 57.4% of players (Batters: 57.1%, Pitchers: 60.0%).
# I beat RotoWire on 57.4% of players (Batters: 57.1%, Pitchers: 60.0%).
#
#
# 20220422 126022978
# RotoWire Didn't Merge:
# 0       Justin Verlander
# 3           Corey Kluber
# 5        Jameson Taillon
# 8          Michael Wacha
# 13            Adam Oller
# 16          Chris Flexen
# 18              Sam Long
# 21        Ross Stripling
# 24             Juan Soto
# 25           Nelson Cruz
# 34          Jesse Winker
# 40           Trea Turner
# 43           Jean Segura
# 47       Lourdes Gurriel
# 51             Darin Ruf
# 52             Josh Bell
# 54       Eduardo Escobar
# 55          Trey Mancini
# 66      Andrew McCutchen
# 71          Brandon Belt
# 73        Hunter Renfroe
# 81           Luis Arraez
# 82           Gio Urshela
# 89         Cooper Hummel
# 96         Matt Davidson
# 99         Bobby Bradley
# 100        Justin Turner
# 102         James McCann
# 103        Franmil Reyes
# 105         Zack Collins
# 106         Raimel Tapia
# 108        Maikel Franco
# 109         Abraham Toro
# 110           AJ Pollock
# 112         Miguel Rojas
# 114           Joey Gallo
# 117       Daulton Varsho
# 118            Luke Voit
# 121           Matt Duffy
# 125          Eric Hosmer
# 128     Jurickson Profar
# 133         Lorenzo Cain
# 134      Xander Bogaerts
# 137         Kole Calhoun
# 138          Sean Murphy
# 140         Adam Frazier
# 144         Amed Rosario
# 145       Bradley Zimmer
# 146    Guillermo Heredia
# 147          Ji-Man Choi
# 148          Kolten Wong
# 154    Robinson Chirinos
# 158         Elvis Andrus
# 160       Cody Bellinger
# 161       Brian Anderson
# 164    Andrew Benintendi
# 168         Yuli Gurriel
# 169      Whit Merrifield
# 171       Carlos Santana
# 172      Alcides Escobar
# 174        Hunter Dozier
# 176       Dansby Swanson
# 180        Sheldon Neuse
# 182          Travis Shaw
# 185          Mike Zunino
# 186        Johan Camargo
# 189       Willie Calhoun
# 190            Wil Myers
# 193     Travis Demeritte
# 195       Jackie Bradley
# 202    Adalberto Mondesi
# 203      Kevin Kiermaier
# 204        Reese McGuire
# 208         Austin Allen
# 209       Cristian Pache
# 211         Camilo Doval
# 212             A.J. Puk
# Name: Name, dtype: object
# DFF Didn't Merge:
# 117     Daulton Varsho
# 130       Ryan Jeffers
# 135         Nick Ahmed
# 145     Bradley Zimmer
# 161     Brian Anderson
# 188    Bryan Lavastida
# 196       Jose Herrera
# 204      Reese McGuire
# 207    Mickey McDonald
# 208       Austin Allen
# 211       Camilo Doval
# 212           A.J. Puk
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: 52.02714610026719
# 2. MSE_DFF: 52.87591603053434
# 3. MSE_Roto: 55.857338931297704
# There were 131 players we all projected.
# I beat DFF on 47.3% of players (Batters: 47.0%, Pitchers: 50.0%).
# I beat RotoWire on 61.1% of players (Batters: 61.5%, Pitchers: 57.1%).
#
#
# 20220418 125853939
# RotoWire Didn't Merge:
# 0             Frankie Montas
# 6                Sean Manaea
# 7           Michael Lorenzen
# 11             Zach Thompson
# 12                 Chad Kuhl
# 14           Spenser Watkins
# 16                Connor Joe
# 27          Andrew McCutchen
# 30         Willson Contreras
# 31               Trea Turner
# 35              Sam Hilliard
# 37          Daniel Vogelbach
# 39             Matt Vierling
# 40               Jean Segura
# 41            Hunter Renfroe
# 49            Michael Chavis
# 53               Kolten Wong
# 54                Tommy Pham
# 56               Kyle Farmer
# 65              Trey Mancini
# 66           Frank Schwindel
# 68             Justin Turner
# 71             Brandon Marsh
# 72              Lorenzo Cain
# 73              Kevin Newman
# 74                 Luke Voit
# 76              Rougned Odor
# 77        Michael Hermosillo
# 79              Jorge Alfaro
# 80               Adam Duvall
# 82            Jake Marisnick
# 85           Domingo Acevedo
# 88               Cole Tucker
# 89                 Wil Myers
# 90              Yuli Gurriel
# 92             Brandon Drury
# 94               Ji-Man Choi
# 95             Jace Peterson
# 97            Diego Castillo
# 98              Elvis Andrus
# 102           Cody Bellinger
# 105              Mike Zunino
# 106         Aristides Aquino
# 107              Sean Murphy
# 109          Kevin Kiermaier
# 110         Jurickson Profar
# 111              Colin Moran
# 113           Billy McKinney
# 115                Jose Siri
# 117           Dansby Swanson
# 119               Tyler Wade
# 123        Guillermo Heredia
# 126            Sheldon Neuse
# 127           Brett Phillips
# 128    Christian Bethancourt
# Name: Name, dtype: object
# DFF Didn't Merge:
# 43                 Max Muncy
# 81                 Yan Gomes
# 85           Domingo Acevedo
# 87              Bryson Stott
# 111              Colin Moran
# 112            Jack Mayfield
# 115                Jose Siri
# 120              Alejo Lopez
# 127           Brett Phillips
# 128    Christian Bethancourt
# Name: Name, dtype: object
# Rankings:
# 1. MSE_Me: 54.96448383630279
# 2. MSE_DFF: 56.30524647887323
# 3. MSE_Roto: 70.0081281690141
# There were 71 players we all projected.
# I beat DFF on 53.5% of players (Batters: 52.4%, Pitchers: 62.5%).
# I beat RotoWire on 66.2% of players (Batters: 66.7%, Pitchers: 62.5%).
#
#
# 20220416 125807481
# 20220408 125492391
# RotoWire Didn't Merge:
# 5            Sean Manaea
# 6          Jake Odorizzi
# 8              Juan Soto
# 9            Nelson Cruz
# 14             Josh Bell
# 19            Tommy Pham
# 27             Luke Voit
# 28         Cooper Hummel
# 31         David Peralta
# 38          Tyler Naquin
# 40        Daulton Varsho
# 45        Mike Moustakas
# 47         Maikel Franco
# 51       Lourdes Gurriel
# 53           Adam Duvall
# 55           Eric Hosmer
# 57            Jose Rojas
# 59             Wil Myers
# 61          Jorge Alfaro
# 62          Kole Calhoun
# 64      Jurickson Profar
# 65       Eduardo Escobar
# 67           Kyle Farmer
# 70           Kurt Suzuki
# 76        Willie Calhoun
# 77        Dansby Swanson
# 78             Jose Siri
# 79       Alcides Escobar
# 80    Dee Strange-Gordon
# 81         Brandon Marsh
# 84            Drew Ellis
# 86            Tyler Wade
# Name: Name, dtype: object
# Complete
# Rankings:
# 1. MSE_DFF: 57.83618635817924
# 2. MSE_Roto: 58.280877891309586
# 3. MSE_Me: 58.69348453205978
# There were 28871 players we all projected.
# I beat DFF on 51.5% of players (Batters: 52.2%, Pitchers: 45.5%).
# I beat RotoWire on 53.3% of players (Batters: 54.1%, Pitchers: 46.5%).

# %% [markdown]
# Complete
# Rankings:
# 1. MSE_DFF: 57.83618635817924
# 2. MSE_Roto: 58.280877891309586
# 3. MSE_Me: 58.69348453205978
# There were 28871 players we all projected.
# I beat DFF on 51.5% of players (Batters: 52.2%, Pitchers: 45.5%).
# I beat RotoWire on 53.3% of players (Batters: 54.1%, Pitchers: 46.5%).

# %%
# %run "B3. Evaluate Payouts.ipynb"

# %%
history = history[history['entryFee'] == 4]
history = history[history['date'] <= "20230816"]

# %%
# Create list of contests
contestKeys = list(history['contestKey']) 
print(len(contestKeys))

# Run all in parallel
all_sims = Parallel(n_jobs=-2, verbose=5)(delayed(read_sims2)(contestKey) for contestKey in contestKeys)

# Create dataframe with every payout for each lineup
payout_df = pd.concat(all_sims, axis=0)

# Print average payout across every possible lineup
payout_df['Payout'].mean()
# Out:
# 267
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 15 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  42 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-2)]: Done 132 tasks      | elapsed:   20.4s
# [Parallel(n_jobs=-2)]: Done 267 out of 267 | elapsed:  1.1min finished
# 4.055076983044241

# %%
# 4.055076983044241

# %%
metrics = ['AvgPointsPerGame', 'Sim STD', 'Plus1', 'Plus2', 'Plus3', 'Plus4', 'Plus5', 'Tail', 'Rarity', 'Batter', 'Pitcher', 'Choose', 'Choose2']

# %%
# %%time
payout_df = add_metrics(payout_df)
# Out:
# AvgPointsPerGame
# Sim STD
# Plus1
# Plus2
# Plus3
# Plus4
# Plus5
# Tail
# Rarity
# Batter
# Pitcher
# Choose
# Choose2
# CPU times: total: 6.39 s
# Wall time: 6.62 s

# %%
lineups = 10
for metric in metrics:
    profit = evaluate_metric(f'{metric} Rank', lineups)
    print("With the {} metric, the top {} lineups would average a profit of ${:.2f}.".format(metric, lineups, profit))
# Out:
# With the AvgPointsPerGame metric, the top 10 lineups would average a profit of $0.79.
# With the Sim STD metric, the top 10 lineups would average a profit of $-0.08.
# With the Plus1 metric, the top 10 lineups would average a profit of $0.60.
# With the Plus2 metric, the top 10 lineups would average a profit of $0.57.
# With the Plus3 metric, the top 10 lineups would average a profit of $0.34.
# With the Plus4 metric, the top 10 lineups would average a profit of $0.30.
# With the Plus5 metric, the top 10 lineups would average a profit of $0.29.
# With the Tail metric, the top 10 lineups would average a profit of $-0.28.
# With the Rarity metric, the top 10 lineups would average a profit of $-1.20.
# With the Batter metric, the top 10 lineups would average a profit of $-0.48.
# With the Pitcher metric, the top 10 lineups would average a profit of $-1.40.
# With the Choose metric, the top 10 lineups would average a profit of $-0.52.
# With the Choose2 metric, the top 10 lineups would average a profit of $-0.77.

# %% [markdown]
# With the AvgPointsPerGame metric, the top 10 lineups would average a profit of $0.79.
# With the Sim STD metric, the top 10 lineups would average a profit of $-0.08.
# With the Plus1 metric, the top 10 lineups would average a profit of $0.60.
# With the Plus2 metric, the top 10 lineups would average a profit of $0.57.
# With the Plus3 metric, the top 10 lineups would average a profit of $0.34.
# With the Plus4 metric, the top 10 lineups would average a profit of $0.30.
# With the Plus5 metric, the top 10 lineups would average a profit of $0.29.
# With the Tail metric, the top 10 lineups would average a profit of $-0.28.
# With the Rarity metric, the top 10 lineups would average a profit of $-1.20.
# With the Batter metric, the top 10 lineups would average a profit of $-0.48.
# With the Pitcher metric, the top 10 lineups would average a profit of $-1.40.
# With the Choose metric, the top 10 lineups would average a profit of $-0.52.
# With the Choose2 metric, the top 10 lineups would average a profit of $-0.77.

# %%
plot_payouts("Choose2")

# %%
len(payout_df)
# Out:
# 51310
