# %% [markdown]
# # M06. Park and Weather Factors
# This creates estimate of event rate multipliers based on park and weather conditions
# - Type: Model
# - Run Frequency: Irregular
# - Sources:
#     - MLB API
# - Dates:
#     - Created: 4/19/2024
#     - Updated: 4/21/2024

# %% [markdown]
# ### Imports

# %%
# %run "U1. Imports.ipynb"
# %run "U2. Utilities.ipynb"
# %run "U3. Classes.ipynb"

# %%
# %run "A02. MLB API.ipynb"
# %run "A03. Steamer.ipynb"

# %% [markdown]
# ### Read

# %% [markdown]
# Read in complete dataset (through 2023)

# %%
df = pd.read_csv(r"C:\Users\james\Documents\MLB\Database\Complete Dataset.csv")

# %% [markdown]
# ### Dataset

# %% [markdown]
# Create dataset of plays with rolling stats

# %%
complete_dataset = create_pa_inputs(park_factors, team_map, 2015, 2023, short=50, long=300, adjust=True)

# %% [markdown]
# Remove imputed players

# %%
unimputed_df = complete_dataset.query('imp_b == 0 and imp_p == 0')

# %% [markdown]
# Remove park adjustments from outcomes

# %%
for stat in events_list:
    unimputed_df[stat] = (unimputed_df[stat] > 0).astype(int)

# %% [markdown]
# Create game averages

# %%
events_list_b = [f"{event}_b" for event in events_list]
events_list_p = [f"{event}_p" for event in events_list]

# %%
game_df = unimputed_df.groupby(['gamePk', 'venue_id', 'batSide'])[events_list + events_list_b + events_list_p + ['x_vect', 'y_vect', 'temperature'] + year_inputs].mean().reset_index()
venue_dummies = pd.get_dummies(game_df['venue_id'], prefix='venue').astype(int)
game_df = pd.concat([game_df, venue_dummies], axis=1)
game_df = game_df.dropna().reset_index(drop=True)
game_df['lefty'] = (game_df['batSide'] == "L").astype(int)

# %%
# Step 2: Create interaction terms
interaction_terms = []
for col1 in ['x_vect', 'y_vect', 'temperature'] + year_inputs:
    for col2 in list(venue_dummies.columns) + ['lefty']:
        interaction_name = col1 + '_' + col2
        game_df[interaction_name] = game_df[col1] * game_df[col2]
        interaction_terms.append(interaction_name)

game_df['x_vect_temperature'] = game_df['x_vect'] * game_df['temperature']
game_df['y_vect_temperature'] = game_df['y_vect'] * game_df['temperature']
game_df['x_vect_y_vect'] = np.abs(game_df['x_vect']) * game_df['y_vect']
interaction_terms.extend(['x_vect_temperature', 'y_vect_temperature', 'x_vect_y_vect'])

# %% [markdown]
# ### Regressions

# %% [markdown]
# ##### 1B

# %%
# Step 3: Define features and target variable
X = game_df[['b1_b', 'b1_p', 'x_vect', 'y_vect', 'temperature'] + year_inputs + interaction_terms] 
y = game_df['b1']

# Step 4: Fit a linear regression model
b1_model = LinearRegression()
b1_model.fit(X, y)

pickle.dump(b1_model, open(os.path.join(model_path, f"Weather Model - b1 {todaysdate}"), 'wb'))


X_copy = X.copy()

# Replace for predicting with average
X_copy['b1_b'] = X_copy['b1_b'].mean()
X_copy['b1_p'] = X_copy['b1_p'].mean()

# Step 5: Make predictions
predictions = b1_model.predict(X_copy[['b1_b', 'b1_p', 'x_vect', 'y_vect', 'temperature'] + year_inputs + interaction_terms])

# Step 6: Calculate deciles based on predicted 
game_df['predicted_b1'] = predictions
game_df['decile_b1'] = pd.qcut(game_df['predicted_b1'], 10, labels=False)

# %%
['b1_b', 'b1_p', 'x_vect', 'y_vect', 'temperature'] + year_inputs + interaction_terms
# Out:
# ['b1_b',
#  'b1_p',
#  'x_vect',
#  'y_vect',
#  'temperature',
#  'year_2015',
#  'year_2016',
#  'year_2017',
#  'year_2018',
#  'year_2019',
#  'year_2020',
#  'year_2021',
#  'year_2022',
#  'year_2023',
#  'x_vect_venue_1',
#  'x_vect_venue_10',
#  'x_vect_venue_12',
#  'x_vect_venue_13',
#  'x_vect_venue_14',
#  'x_vect_venue_15',
#  'x_vect_venue_16',
#  'x_vect_venue_17',
#  'x_vect_venue_19',
#  'x_vect_venue_2',
#  'x_vect_venue_22',
#  'x_vect_venue_2392',
#  'x_vect_venue_2394',
#  'x_vect_venue_2395',
#  'x_vect_venue_24',
#  'x_vect_venue_2500',
#  'x_vect_venue_2503',
#  'x_vect_venue_2504',
#  'x_vect_venue_2507',
#  'x_vect_venue_2508',
#  'x_vect_venue_2511',
#  'x_vect_venue_2513',
#  'x_vect_venue_2514',
#  'x_vect_venue_2516',
#  'x_vect_venue_2518',
#  'x_vect_venue_2520',
#  'x_vect_venue_2523',
#  'x_vect_venue_2526',
#  'x_vect_venue_2529',
#  'x_vect_venue_2530',
#  'x_vect_venue_2532',
#  'x_vect_venue_2534',
#  'x_vect_venue_2535',
#  'x_vect_venue_2536',
#  'x_vect_venue_2542',
#  'x_vect_venue_2602',
#  'x_vect_venue_2603',
#  'x_vect_venue_2680',
#  'x_vect_venue_2681',
#  'x_vect_venue_2700',
#  'x_vect_venue_2701',
#  'x_vect_venue_2722',
#  'x_vect_venue_2723',
#  'x_vect_venue_2724',
#  'x_vect_venue_2735',
#  'x_vect_venue_2756',
#  'x_vect_venue_2766',
#  'x_vect_venue_2769',
#  'x_vect_venue_2781',
#  'x_vect_venue_2856',
#  'x_vect_venue_2858',
#  'x_vect_venue_2861',
#  'x_vect_venue_2862',
#  'x_vect_venue_2889',
#  'x_vect_venue_3',
#  'x_vect_venue_31',
#  'x_vect_venue_32',
#  'x_vect_venue_3289',
#  'x_vect_venue_3309',
#  'x_vect_venue_3312',
#  'x_vect_venue_3313',
#  'x_vect_venue_3809',
#  'x_vect_venue_3834',
#  'x_vect_venue_4',
#  'x_vect_venue_4169',
#  'x_vect_venue_4249',
#  'x_vect_venue_4309',
#  'x_vect_venue_4510',
#  'x_vect_venue_4629',
#  'x_vect_venue_4669',
#  'x_vect_venue_4670',
#  'x_vect_venue_4705',
#  'x_vect_venue_4960',
#  'x_vect_venue_5',
#  'x_vect_venue_5000',
#  'x_vect_venue_5010',
#  'x_vect_venue_5315',
#  'x_vect_venue_5325',
#  'x_vect_venue_5340',
#  'x_vect_venue_5365',
#  'x_vect_venue_5380',
#  'x_vect_venue_5381',
#  'x_vect_venue_5445',
#  'x_vect_venue_680',
#  'x_vect_venue_7',
#  'x_vect_lefty',
#  'y_vect_venue_1',
#  'y_vect_venue_10',
#  'y_vect_venue_12',
#  'y_vect_venue_13',
#  'y_vect_venue_14',
#  'y_vect_venue_15',
#  'y_vect_venue_16',
#  'y_vect_venue_17',
#  'y_vect_venue_19',
#  'y_vect_venue_2',
#  'y_vect_venue_22',
#  'y_vect_venue_2392',
#  'y_vect_venue_2394',
#  'y_vect_venue_2395',
#  'y_vect_venue_24',
#  'y_vect_venue_2500',
#  'y_vect_venue_2503',
#  'y_vect_venue_2504',
#  'y_vect_venue_2507',
#  'y_vect_venue_2508',
#  'y_vect_venue_2511',
#  'y_vect_venue_2513',
#  'y_vect_venue_2514',
#  'y_vect_venue_2516',
#  'y_vect_venue_2518',
#  'y_vect_venue_2520',
#  'y_vect_venue_2523',
#  'y_vect_venue_2526',
#  'y_vect_venue_2529',
#  'y_vect_venue_2530',
#  'y_vect_venue_2532',
#  'y_vect_venue_2534',
#  'y_vect_venue_2535',
#  'y_vect_venue_2536',
#  'y_vect_venue_2542',
#  'y_vect_venue_2602',
#  'y_vect_venue_2603',
#  'y_vect_venue_2680',
#  'y_vect_venue_2681',
#  'y_vect_venue_2700',
#  'y_vect_venue_2701',
#  'y_vect_venue_2722',
#  'y_vect_venue_2723',
#  'y_vect_venue_2724',
#  'y_vect_venue_2735',
#  'y_vect_venue_2756',
#  'y_vect_venue_2766',
#  'y_vect_venue_2769',
#  'y_vect_venue_2781',
#  'y_vect_venue_2856',
#  'y_vect_venue_2858',
#  'y_vect_venue_2861',
#  'y_vect_venue_2862',
#  'y_vect_venue_2889',
#  'y_vect_venue_3',
#  'y_vect_venue_31',
#  'y_vect_venue_32',
#  'y_vect_venue_3289',
#  'y_vect_venue_3309',
#  'y_vect_venue_3312',
#  'y_vect_venue_3313',
#  'y_vect_venue_3809',
#  'y_vect_venue_3834',
#  'y_vect_venue_4',
#  'y_vect_venue_4169',
#  'y_vect_venue_4249',
#  'y_vect_venue_4309',
#  'y_vect_venue_4510',
#  'y_vect_venue_4629',
#  'y_vect_venue_4669',
#  'y_vect_venue_4670',
#  'y_vect_venue_4705',
#  'y_vect_venue_4960',
#  'y_vect_venue_5',
#  'y_vect_venue_5000',
#  'y_vect_venue_5010',
#  'y_vect_venue_5315',
#  'y_vect_venue_5325',
#  'y_vect_venue_5340',
#  'y_vect_venue_5365',
#  'y_vect_venue_5380',
#  'y_vect_venue_5381',
#  'y_vect_venue_5445',
#  'y_vect_venue_680',
#  'y_vect_venue_7',
#  'y_vect_lefty',
#  'temperature_venue_1',
#  'temperature_venue_10',
#  'temperature_venue_12',
#  'temperature_venue_13',
#  'temperature_venue_14',
#  'temperature_venue_15',
#  'temperature_venue_16',
#  'temperature_venue_17',
#  'temperature_venue_19',
#  'temperature_venue_2',
#  'temperature_venue_22',
#  'temperature_venue_2392',
#  'temperature_venue_2394',
#  'temperature_venue_2395',
#  'temperature_venue_24',
#  'temperature_venue_2500',
#  'temperature_venue_2503',
#  'temperature_venue_2504',
#  'temperature_venue_2507',
#  'temperature_venue_2508',
#  'temperature_venue_2511',
#  'temperature_venue_2513',
#  'temperature_venue_2514',
#  'temperature_venue_2516',
#  'temperature_venue_2518',
#  'temperature_venue_2520',
#  'temperature_venue_2523',
#  'temperature_venue_2526',
#  'temperature_venue_2529',
#  'temperature_venue_2530',
#  'temperature_venue_2532',
#  'temperature_venue_2534',
#  'temperature_venue_2535',
#  'temperature_venue_2536',
#  'temperature_venue_2542',
#  'temperature_venue_2602',
#  'temperature_venue_2603',
#  'temperature_venue_2680',
#  'temperature_venue_2681',
#  'temperature_venue_2700',
#  'temperature_venue_2701',
#  'temperature_venue_2722',
#  'temperature_venue_2723',
#  'temperature_venue_2724',
#  'temperature_venue_2735',
#  'temperature_venue_2756',
#  'temperature_venue_2766',
#  'temperature_venue_2769',
#  'temperature_venue_2781',
#  'temperature_venue_2856',
#  'temperature_venue_2858',
#  'temperature_venue_2861',
#  'temperature_venue_2862',
#  'temperature_venue_2889',
#  'temperature_venue_3',
#  'temperature_venue_31',
#  'temperature_venue_32',
#  'temperature_venue_3289',
#  'temperature_venue_3309',
#  'temperature_venue_3312',
#  'temperature_venue_3313',
#  'temperature_venue_3809',
#  'temperature_venue_3834',
#  'temperature_venue_4',
#  'temperature_venue_4169',
#  'temperature_venue_4249',
#  'temperature_venue_4309',
#  'temperature_venue_4510',
#  'temperature_venue_4629',
#  'temperature_venue_4669',
#  'temperature_venue_4670',
#  'temperature_venue_4705',
#  'temperature_venue_4960',
#  'temperature_venue_5',
#  'temperature_venue_5000',
#  'temperature_venue_5010',
#  'temperature_venue_5315',
#  'temperature_venue_5325',
#  'temperature_venue_5340',
#  'temperature_venue_5365',
#  'temperature_venue_5380',
#  'temperature_venue_5381',
#  'temperature_venue_5445',
#  'temperature_venue_680',
#  'temperature_venue_7',
#  'temperature_lefty',
#  'year_2015_venue_1',
#  'year_2015_venue_10',
#  'year_2015_venue_12',
#  'year_2015_venue_13',
#  'year_2015_venue_14',
#  'year_2015_venue_15',
#  'year_2015_venue_16',
#  'year_2015_venue_17',
#  'year_2015_venue_19',
#  'year_2015_venue_2',
#  'year_2015_venue_22',
#  'year_2015_venue_2392',
#  'year_2015_venue_2394',
#  'year_2015_venue_2395',
#  'year_2015_venue_24',
#  'year_2015_venue_2500',
#  'year_2015_venue_2503',
#  'year_2015_venue_2504',
#  'year_2015_venue_2507',
#  'year_2015_venue_2508',
#  'year_2015_venue_2511',
#  'year_2015_venue_2513',
#  'year_2015_venue_2514',
#  'year_2015_venue_2516',
#  'year_2015_venue_2518',
#  'year_2015_venue_2520',
#  'year_2015_venue_2523',
#  'year_2015_venue_2526',
#  'year_2015_venue_2529',
#  'year_2015_venue_2530',
#  'year_2015_venue_2532',
#  'year_2015_venue_2534',
#  'year_2015_venue_2535',
#  'year_2015_venue_2536',
#  'year_2015_venue_2542',
#  'year_2015_venue_2602',
#  'year_2015_venue_2603',
#  'year_2015_venue_2680',
#  'year_2015_venue_2681',
#  'year_2015_venue_2700',
#  'year_2015_venue_2701',
#  'year_2015_venue_2722',
#  'year_2015_venue_2723',
#  'year_2015_venue_2724',
#  'year_2015_venue_2735',
#  'year_2015_venue_2756',
#  'year_2015_venue_2766',
#  'year_2015_venue_2769',
#  'year_2015_venue_2781',
#  'year_2015_venue_2856',
#  'year_2015_venue_2858',
#  'year_2015_venue_2861',
#  'year_2015_venue_2862',
#  'year_2015_venue_2889',
#  'year_2015_venue_3',
#  'year_2015_venue_31',
#  'year_2015_venue_32',
#  'year_2015_venue_3289',
#  'year_2015_venue_3309',
#  'year_2015_venue_3312',
#  'year_2015_venue_3313',
#  'year_2015_venue_3809',
#  'year_2015_venue_3834',
#  'year_2015_venue_4',
#  'year_2015_venue_4169',
#  'year_2015_venue_4249',
#  'year_2015_venue_4309',
#  'year_2015_venue_4510',
#  'year_2015_venue_4629',
#  'year_2015_venue_4669',
#  'year_2015_venue_4670',
#  'year_2015_venue_4705',
#  'year_2015_venue_4960',
#  'year_2015_venue_5',
#  'year_2015_venue_5000',
#  'year_2015_venue_5010',
#  'year_2015_venue_5315',
#  'year_2015_venue_5325',
#  'year_2015_venue_5340',
#  'year_2015_venue_5365',
#  'year_2015_venue_5380',
#  'year_2015_venue_5381',
#  'year_2015_venue_5445',
#  'year_2015_venue_680',
#  'year_2015_venue_7',
#  'year_2015_lefty',
#  'year_2016_venue_1',
#  'year_2016_venue_10',
#  'year_2016_venue_12',
#  'year_2016_venue_13',
#  'year_2016_venue_14',
#  'year_2016_venue_15',
#  'year_2016_venue_16',
#  'year_2016_venue_17',
#  'year_2016_venue_19',
#  'year_2016_venue_2',
#  'year_2016_venue_22',
#  'year_2016_venue_2392',
#  'year_2016_venue_2394',
#  'year_2016_venue_2395',
#  'year_2016_venue_24',
#  'year_2016_venue_2500',
#  'year_2016_venue_2503',
#  'year_2016_venue_2504',
#  'year_2016_venue_2507',
#  'year_2016_venue_2508',
#  'year_2016_venue_2511',
#  'year_2016_venue_2513',
#  'year_2016_venue_2514',
#  'year_2016_venue_2516',
#  'year_2016_venue_2518',
#  'year_2016_venue_2520',
#  'year_2016_venue_2523',
#  'year_2016_venue_2526',
#  'year_2016_venue_2529',
#  'year_2016_venue_2530',
#  'year_2016_venue_2532',
#  'year_2016_venue_2534',
#  'year_2016_venue_2535',
#  'year_2016_venue_2536',
#  'year_2016_venue_2542',
#  'year_2016_venue_2602',
#  'year_2016_venue_2603',
#  'year_2016_venue_2680',
#  'year_2016_venue_2681',
#  'year_2016_venue_2700',
#  'year_2016_venue_2701',
#  'year_2016_venue_2722',
#  'year_2016_venue_2723',
#  'year_2016_venue_2724',
#  'year_2016_venue_2735',
#  'year_2016_venue_2756',
#  'year_2016_venue_2766',
#  'year_2016_venue_2769',
#  'year_2016_venue_2781',
#  'year_2016_venue_2856',
#  'year_2016_venue_2858',
#  'year_2016_venue_2861',
#  'year_2016_venue_2862',
#  'year_2016_venue_2889',
#  'year_2016_venue_3',
#  'year_2016_venue_31',
#  'year_2016_venue_32',
#  'year_2016_venue_3289',
#  'year_2016_venue_3309',
#  'year_2016_venue_3312',
#  'year_2016_venue_3313',
#  'year_2016_venue_3809',
#  'year_2016_venue_3834',
#  'year_2016_venue_4',
#  'year_2016_venue_4169',
#  'year_2016_venue_4249',
#  'year_2016_venue_4309',
#  'year_2016_venue_4510',
#  'year_2016_venue_4629',
#  'year_2016_venue_4669',
#  'year_2016_venue_4670',
#  'year_2016_venue_4705',
#  'year_2016_venue_4960',
#  'year_2016_venue_5',
#  'year_2016_venue_5000',
#  'year_2016_venue_5010',
#  'year_2016_venue_5315',
#  'year_2016_venue_5325',
#  'year_2016_venue_5340',
#  'year_2016_venue_5365',
#  'year_2016_venue_5380',
#  'year_2016_venue_5381',
#  'year_2016_venue_5445',
#  'year_2016_venue_680',
#  'year_2016_venue_7',
#  'year_2016_lefty',
#  'year_2017_venue_1',
#  'year_2017_venue_10',
#  'year_2017_venue_12',
#  'year_2017_venue_13',
#  'year_2017_venue_14',
#  'year_2017_venue_15',
#  'year_2017_venue_16',
#  'year_2017_venue_17',
#  'year_2017_venue_19',
#  'year_2017_venue_2',
#  'year_2017_venue_22',
#  'year_2017_venue_2392',
#  'year_2017_venue_2394',
#  'year_2017_venue_2395',
#  'year_2017_venue_24',
#  'year_2017_venue_2500',
#  'year_2017_venue_2503',
#  'year_2017_venue_2504',
#  'year_2017_venue_2507',
#  'year_2017_venue_2508',
#  'year_2017_venue_2511',
#  'year_2017_venue_2513',
#  'year_2017_venue_2514',
#  'year_2017_venue_2516',
#  'year_2017_venue_2518',
#  'year_2017_venue_2520',
#  'year_2017_venue_2523',
#  'year_2017_venue_2526',
#  'year_2017_venue_2529',
#  'year_2017_venue_2530',
#  'year_2017_venue_2532',
#  'year_2017_venue_2534',
#  'year_2017_venue_2535',
#  'year_2017_venue_2536',
#  'year_2017_venue_2542',
#  'year_2017_venue_2602',
#  'year_2017_venue_2603',
#  'year_2017_venue_2680',
#  'year_2017_venue_2681',
#  'year_2017_venue_2700',
#  'year_2017_venue_2701',
#  'year_2017_venue_2722',
#  'year_2017_venue_2723',
#  'year_2017_venue_2724',
#  'year_2017_venue_2735',
#  'year_2017_venue_2756',
#  'year_2017_venue_2766',
#  'year_2017_venue_2769',
#  'year_2017_venue_2781',
#  'year_2017_venue_2856',
#  'year_2017_venue_2858',
#  'year_2017_venue_2861',
#  'year_2017_venue_2862',
#  'year_2017_venue_2889',
#  'year_2017_venue_3',
#  'year_2017_venue_31',
#  'year_2017_venue_32',
#  'year_2017_venue_3289',
#  'year_2017_venue_3309',
#  'year_2017_venue_3312',
#  'year_2017_venue_3313',
#  'year_2017_venue_3809',
#  'year_2017_venue_3834',
#  'year_2017_venue_4',
#  'year_2017_venue_4169',
#  'year_2017_venue_4249',
#  'year_2017_venue_4309',
#  'year_2017_venue_4510',
#  'year_2017_venue_4629',
#  'year_2017_venue_4669',
#  'year_2017_venue_4670',
#  'year_2017_venue_4705',
#  'year_2017_venue_4960',
#  'year_2017_venue_5',
#  'year_2017_venue_5000',
#  'year_2017_venue_5010',
#  'year_2017_venue_5315',
#  'year_2017_venue_5325',
#  'year_2017_venue_5340',
#  'year_2017_venue_5365',
#  'year_2017_venue_5380',
#  'year_2017_venue_5381',
#  'year_2017_venue_5445',
#  'year_2017_venue_680',
#  'year_2017_venue_7',
#  'year_2017_lefty',
#  'year_2018_venue_1',
#  'year_2018_venue_10',
#  'year_2018_venue_12',
#  'year_2018_venue_13',
#  'year_2018_venue_14',
#  'year_2018_venue_15',
#  'year_2018_venue_16',
#  'year_2018_venue_17',
#  'year_2018_venue_19',
#  'year_2018_venue_2',
#  'year_2018_venue_22',
#  'year_2018_venue_2392',
#  'year_2018_venue_2394',
#  'year_2018_venue_2395',
#  'year_2018_venue_24',
#  'year_2018_venue_2500',
#  'year_2018_venue_2503',
#  'year_2018_venue_2504',
#  'year_2018_venue_2507',
#  'year_2018_venue_2508',
#  'year_2018_venue_2511',
#  'year_2018_venue_2513',
#  'year_2018_venue_2514',
#  'year_2018_venue_2516',
#  'year_2018_venue_2518',
#  'year_2018_venue_2520',
#  'year_2018_venue_2523',
#  'year_2018_venue_2526',
#  'year_2018_venue_2529',
#  'year_2018_venue_2530',
#  'year_2018_venue_2532',
#  'year_2018_venue_2534',
#  'year_2018_venue_2535',
#  'year_2018_venue_2536',
#  'year_2018_venue_2542',
#  'year_2018_venue_2602',
#  'year_2018_venue_2603',
#  'year_2018_venue_2680',
#  'year_2018_venue_2681',
#  'year_2018_venue_2700',
#  'year_2018_venue_2701',
#  'year_2018_venue_2722',
#  'year_2018_venue_2723',
#  'year_2018_venue_2724',
#  'year_2018_venue_2735',
#  'year_2018_venue_2756',
#  'year_2018_venue_2766',
#  'year_2018_venue_2769',
#  'year_2018_venue_2781',
#  'year_2018_venue_2856',
#  'year_2018_venue_2858',
#  'year_2018_venue_2861',
#  'year_2018_venue_2862',
#  'year_2018_venue_2889',
#  'year_2018_venue_3',
#  'year_2018_venue_31',
#  'year_2018_venue_32',
#  'year_2018_venue_3289',
#  'year_2018_venue_3309',
#  'year_2018_venue_3312',
#  'year_2018_venue_3313',
#  'year_2018_venue_3809',
#  'year_2018_venue_3834',
#  'year_2018_venue_4',
#  'year_2018_venue_4169',
#  'year_2018_venue_4249',
#  'year_2018_venue_4309',
#  'year_2018_venue_4510',
#  'year_2018_venue_4629',
#  'year_2018_venue_4669',
#  'year_2018_venue_4670',
#  'year_2018_venue_4705',
#  'year_2018_venue_4960',
#  'year_2018_venue_5',
#  'year_2018_venue_5000',
#  'year_2018_venue_5010',
#  'year_2018_venue_5315',
#  'year_2018_venue_5325',
#  'year_2018_venue_5340',
#  'year_2018_venue_5365',
#  'year_2018_venue_5380',
#  'year_2018_venue_5381',
#  'year_2018_venue_5445',
#  'year_2018_venue_680',
#  'year_2018_venue_7',
#  'year_2018_lefty',
#  'year_2019_venue_1',
#  'year_2019_venue_10',
#  'year_2019_venue_12',
#  'year_2019_venue_13',
#  'year_2019_venue_14',
#  'year_2019_venue_15',
#  'year_2019_venue_16',
#  'year_2019_venue_17',
#  'year_2019_venue_19',
#  'year_2019_venue_2',
#  'year_2019_venue_22',
#  'year_2019_venue_2392',
#  'year_2019_venue_2394',
#  'year_2019_venue_2395',
#  'year_2019_venue_24',
#  'year_2019_venue_2500',
#  'year_2019_venue_2503',
#  'year_2019_venue_2504',
#  'year_2019_venue_2507',
#  'year_2019_venue_2508',
#  'year_2019_venue_2511',
#  'year_2019_venue_2513',
#  'year_2019_venue_2514',
#  'year_2019_venue_2516',
#  'year_2019_venue_2518',
#  'year_2019_venue_2520',
#  'year_2019_venue_2523',
#  'year_2019_venue_2526',
#  'year_2019_venue_2529',
#  'year_2019_venue_2530',
#  'year_2019_venue_2532',
#  'year_2019_venue_2534',
#  'year_2019_venue_2535',
#  'year_2019_venue_2536',
#  'year_2019_venue_2542',
#  'year_2019_venue_2602',
#  'year_2019_venue_2603',
#  'year_2019_venue_2680',
#  'year_2019_venue_2681',
#  'year_2019_venue_2700',
#  'year_2019_venue_2701',
#  'year_2019_venue_2722',
#  'year_2019_venue_2723',
#  'year_2019_venue_2724',
#  'year_2019_venue_2735',
#  'year_2019_venue_2756',
#  'year_2019_venue_2766',
#  'year_2019_venue_2769',
#  'year_2019_venue_2781',
#  'year_2019_venue_2856',
#  'year_2019_venue_2858',
#  'year_2019_venue_2861',
#  'year_2019_venue_2862',
#  'year_2019_venue_2889',
#  'year_2019_venue_3',
#  'year_2019_venue_31',
#  'year_2019_venue_32',
#  'year_2019_venue_3289',
#  'year_2019_venue_3309',
#  'year_2019_venue_3312',
#  'year_2019_venue_3313',
#  'year_2019_venue_3809',
#  'year_2019_venue_3834',
#  'year_2019_venue_4',
#  'year_2019_venue_4169',
#  'year_2019_venue_4249',
#  'year_2019_venue_4309',
#  'year_2019_venue_4510',
#  'year_2019_venue_4629',
#  'year_2019_venue_4669',
#  'year_2019_venue_4670',
#  'year_2019_venue_4705',
#  'year_2019_venue_4960',
#  'year_2019_venue_5',
#  'year_2019_venue_5000',
#  'year_2019_venue_5010',
#  'year_2019_venue_5315',
#  'year_2019_venue_5325',
#  'year_2019_venue_5340',
#  'year_2019_venue_5365',
#  'year_2019_venue_5380',
#  'year_2019_venue_5381',
#  'year_2019_venue_5445',
#  'year_2019_venue_680',
#  'year_2019_venue_7',
#  'year_2019_lefty',
#  'year_2020_venue_1',
#  'year_2020_venue_10',
#  'year_2020_venue_12',
#  'year_2020_venue_13',
#  'year_2020_venue_14',
#  'year_2020_venue_15',
#  'year_2020_venue_16',
#  'year_2020_venue_17',
#  'year_2020_venue_19',
#  'year_2020_venue_2',
#  'year_2020_venue_22',
#  'year_2020_venue_2392',
#  'year_2020_venue_2394',
#  'year_2020_venue_2395',
#  'year_2020_venue_24',
#  'year_2020_venue_2500',
#  'year_2020_venue_2503',
#  'year_2020_venue_2504',
#  'year_2020_venue_2507',
#  'year_2020_venue_2508',
#  'year_2020_venue_2511',
#  'year_2020_venue_2513',
#  'year_2020_venue_2514',
#  'year_2020_venue_2516',
#  'year_2020_venue_2518',
#  'year_2020_venue_2520',
#  'year_2020_venue_2523',
#  'year_2020_venue_2526',
#  'year_2020_venue_2529',
#  'year_2020_venue_2530',
#  'year_2020_venue_2532',
#  'year_2020_venue_2534',
#  'year_2020_venue_2535',
#  'year_2020_venue_2536',
#  'year_2020_venue_2542',
#  'year_2020_venue_2602',
#  'year_2020_venue_2603',
#  'year_2020_venue_2680',
#  'year_2020_venue_2681',
#  'year_2020_venue_2700',
#  'year_2020_venue_2701',
#  'year_2020_venue_2722',
#  'year_2020_venue_2723',
#  'year_2020_venue_2724',
#  'year_2020_venue_2735',
#  'year_2020_venue_2756',
#  'year_2020_venue_2766',
#  'year_2020_venue_2769',
#  'year_2020_venue_2781',
#  'year_2020_venue_2856',
#  'year_2020_venue_2858',
#  'year_2020_venue_2861',
#  'year_2020_venue_2862',
#  'year_2020_venue_2889',
#  'year_2020_venue_3',
#  'year_2020_venue_31',
#  'year_2020_venue_32',
#  'year_2020_venue_3289',
#  'year_2020_venue_3309',
#  'year_2020_venue_3312',
#  'year_2020_venue_3313',
#  'year_2020_venue_3809',
#  'year_2020_venue_3834',
#  'year_2020_venue_4',
#  'year_2020_venue_4169',
#  'year_2020_venue_4249',
#  'year_2020_venue_4309',
#  'year_2020_venue_4510',
#  'year_2020_venue_4629',
#  'year_2020_venue_4669',
#  'year_2020_venue_4670',
#  'year_2020_venue_4705',
#  'year_2020_venue_4960',
#  'year_2020_venue_5',
#  'year_2020_venue_5000',
#  'year_2020_venue_5010',
#  'year_2020_venue_5315',
#  'year_2020_venue_5325',
#  'year_2020_venue_5340',
#  'year_2020_venue_5365',
#  'year_2020_venue_5380',
#  'year_2020_venue_5381',
#  'year_2020_venue_5445',
#  'year_2020_venue_680',
#  'year_2020_venue_7',
#  'year_2020_lefty',
#  'year_2021_venue_1',
#  'year_2021_venue_10',
#  'year_2021_venue_12',
#  'year_2021_venue_13',
#  'year_2021_venue_14',
#  'year_2021_venue_15',
#  'year_2021_venue_16',
#  'year_2021_venue_17',
#  'year_2021_venue_19',
#  'year_2021_venue_2',
#  'year_2021_venue_22',
#  'year_2021_venue_2392',
#  'year_2021_venue_2394',
#  'year_2021_venue_2395',
#  'year_2021_venue_24',
#  'year_2021_venue_2500',
#  'year_2021_venue_2503',
#  'year_2021_venue_2504',
#  'year_2021_venue_2507',
#  'year_2021_venue_2508',
#  'year_2021_venue_2511',
#  'year_2021_venue_2513',
#  'year_2021_venue_2514',
#  'year_2021_venue_2516',
#  'year_2021_venue_2518',
#  'year_2021_venue_2520',
#  'year_2021_venue_2523',
#  'year_2021_venue_2526',
#  'year_2021_venue_2529',
#  'year_2021_venue_2530',
#  'year_2021_venue_2532',
#  'year_2021_venue_2534',
#  'year_2021_venue_2535',
#  'year_2021_venue_2536',
#  'year_2021_venue_2542',
#  'year_2021_venue_2602',
#  'year_2021_venue_2603',
#  'year_2021_venue_2680',
#  'year_2021_venue_2681',
#  'year_2021_venue_2700',
#  'year_2021_venue_2701',
#  'year_2021_venue_2722',
#  'year_2021_venue_2723',
#  'year_2021_venue_2724',
#  'year_2021_venue_2735',
#  'year_2021_venue_2756',
#  'year_2021_venue_2766',
#  'year_2021_venue_2769',
#  'year_2021_venue_2781',
#  'year_2021_venue_2856',
#  'year_2021_venue_2858',
#  'year_2021_venue_2861',
#  'year_2021_venue_2862',
#  'year_2021_venue_2889',
#  'year_2021_venue_3',
#  'year_2021_venue_31',
#  'year_2021_venue_32',
#  'year_2021_venue_3289',
#  'year_2021_venue_3309',
#  'year_2021_venue_3312',
#  'year_2021_venue_3313',
#  'year_2021_venue_3809',
#  'year_2021_venue_3834',
#  'year_2021_venue_4',
#  'year_2021_venue_4169',
#  'year_2021_venue_4249',
#  'year_2021_venue_4309',
#  'year_2021_venue_4510',
#  'year_2021_venue_4629',
#  'year_2021_venue_4669',
#  'year_2021_venue_4670',
#  'year_2021_venue_4705',
#  'year_2021_venue_4960',
#  'year_2021_venue_5',
#  'year_2021_venue_5000',
#  'year_2021_venue_5010',
#  'year_2021_venue_5315',
#  'year_2021_venue_5325',
#  'year_2021_venue_5340',
#  'year_2021_venue_5365',
#  'year_2021_venue_5380',
#  'year_2021_venue_5381',
#  'year_2021_venue_5445',
#  'year_2021_venue_680',
#  'year_2021_venue_7',
#  'year_2021_lefty',
#  'year_2022_venue_1',
#  'year_2022_venue_10',
#  'year_2022_venue_12',
#  'year_2022_venue_13',
#  'year_2022_venue_14',
#  'year_2022_venue_15',
#  'year_2022_venue_16',
#  'year_2022_venue_17',
#  'year_2022_venue_19',
#  'year_2022_venue_2',
#  'year_2022_venue_22',
#  'year_2022_venue_2392',
#  'year_2022_venue_2394',
#  'year_2022_venue_2395',
#  'year_2022_venue_24',
#  'year_2022_venue_2500',
#  'year_2022_venue_2503',
#  'year_2022_venue_2504',
#  'year_2022_venue_2507',
#  'year_2022_venue_2508',
#  'year_2022_venue_2511',
#  'year_2022_venue_2513',
#  'year_2022_venue_2514',
#  'year_2022_venue_2516',
#  'year_2022_venue_2518',
#  'year_2022_venue_2520',
#  'year_2022_venue_2523',
#  'year_2022_venue_2526',
#  'year_2022_venue_2529',
#  'year_2022_venue_2530',
#  'year_2022_venue_2532',
#  'year_2022_venue_2534',
#  'year_2022_venue_2535',
#  'year_2022_venue_2536',
#  'year_2022_venue_2542',
#  'year_2022_venue_2602',
#  'year_2022_venue_2603',
#  'year_2022_venue_2680',
#  'year_2022_venue_2681',
#  'year_2022_venue_2700',
#  'year_2022_venue_2701',
#  'year_2022_venue_2722',
#  'year_2022_venue_2723',
#  'year_2022_venue_2724',
#  'year_2022_venue_2735',
#  'year_2022_venue_2756',
#  'year_2022_venue_2766',
#  'year_2022_venue_2769',
#  'year_2022_venue_2781',
#  'year_2022_venue_2856',
#  'year_2022_venue_2858',
#  'year_2022_venue_2861',
#  'year_2022_venue_2862',
#  'year_2022_venue_2889',
#  'year_2022_venue_3',
#  'year_2022_venue_31',
#  'year_2022_venue_32',
#  'year_2022_venue_3289',
#  'year_2022_venue_3309',
#  'year_2022_venue_3312',
#  'year_2022_venue_3313',
#  'year_2022_venue_3809',
#  'year_2022_venue_3834',
#  'year_2022_venue_4',
#  'year_2022_venue_4169',
#  'year_2022_venue_4249',
#  'year_2022_venue_4309',
#  'year_2022_venue_4510',
#  'year_2022_venue_4629',
#  'year_2022_venue_4669',
#  'year_2022_venue_4670',
#  'year_2022_venue_4705',
#  'year_2022_venue_4960',
#  'year_2022_venue_5',
#  'year_2022_venue_5000',
#  'year_2022_venue_5010',
#  'year_2022_venue_5315',
#  'year_2022_venue_5325',
#  'year_2022_venue_5340',
#  'year_2022_venue_5365',
#  'year_2022_venue_5380',
#  'year_2022_venue_5381',
#  'year_2022_venue_5445',
#  'year_2022_venue_680',
#  'year_2022_venue_7',
#  'year_2022_lefty',
#  'year_2023_venue_1',
#  'year_2023_venue_10',
#  'year_2023_venue_12',
#  'year_2023_venue_13',
#  'year_2023_venue_14',
#  'year_2023_venue_15',
#  'year_2023_venue_16',
#  'year_2023_venue_17',
#  'year_2023_venue_19',
#  'year_2023_venue_2',
#  'year_2023_venue_22',
#  'year_2023_venue_2392',
#  'year_2023_venue_2394',
#  'year_2023_venue_2395',
#  'year_2023_venue_24',
#  'year_2023_venue_2500',
#  'year_2023_venue_2503',
#  'year_2023_venue_2504',
#  'year_2023_venue_2507',
#  'year_2023_venue_2508',
#  'year_2023_venue_2511',
#  'year_2023_venue_2513',
#  'year_2023_venue_2514',
#  'year_2023_venue_2516',
#  'year_2023_venue_2518',
#  'year_2023_venue_2520',
#  'year_2023_venue_2523',
#  'year_2023_venue_2526',
#  'year_2023_venue_2529',
#  'year_2023_venue_2530',
#  'year_2023_venue_2532',
#  'year_2023_venue_2534',
#  'year_2023_venue_2535',
#  'year_2023_venue_2536',
#  'year_2023_venue_2542',
#  'year_2023_venue_2602',
#  'year_2023_venue_2603',
#  'year_2023_venue_2680',
#  'year_2023_venue_2681',
#  'year_2023_venue_2700',
#  ...]

# %% [markdown]
# ##### 2B

# %%
# Step 3: Define features and target variable
X = game_df[['b2_b', 'b2_p', 'x_vect', 'y_vect', 'temperature'] + year_inputs + interaction_terms] 
y = game_df['b2']

# Step 4: Fit a linear regression model
b2_model = LinearRegression()
b2_model.fit(X, y)

pickle.dump(b2_model, open(os.path.join(model_path, f"Weather Model - b2 {todaysdate}"), 'wb'))


X_copy = X.copy()

# Replace for predicting with average
X_copy['b2_b'] = X_copy['b2_b'].mean()
X_copy['b2_p'] = X_copy['b2_p'].mean()

# Step 5: Make predictions
predictions = b2_model.predict(X_copy)

# Step 6: Calculate deciles based on predicted 
game_df['predicted_b2'] = predictions
game_df['decile_b2'] = pd.qcut(game_df['predicted_b2'], 10, labels=False)

# %% [markdown]
# ##### 3B

# %%
# Step 3: Define features and target variable
X = game_df[['b3_b', 'b3_p', 'x_vect', 'y_vect', 'temperature'] + year_inputs + interaction_terms] 
y = game_df['b3']

# Step 4: Fit a linear regression model
b3_model = LinearRegression()
b3_model.fit(X, y)

pickle.dump(b3_model, open(os.path.join(model_path, f"Weather Model - b3 {todaysdate}"), 'wb'))


X_copy = X.copy()

# Replace for predicting with average
X_copy['b3_b'] = X_copy['b3_b'].mean()
X_copy['b3_p'] = X_copy['b3_p'].mean()

# Step 5: Make predictions
predictions = b3_model.predict(X_copy)

# Step 6: Calculate deciles based on predicted 
game_df['predicted_b3'] = predictions
game_df['decile_b3'] = pd.qcut(game_df['predicted_b3'], 10, labels=False)

# %% [markdown]
# ##### HR

# %%
# Step 3: Define features and target variable
# X = game_df.drop(columns=['hr', 'batSide', 'gamePk'])
X = game_df[['hr_b', 'hr_p', 'x_vect', 'y_vect', 'temperature'] + year_inputs + interaction_terms] 
y = game_df['hr']

# Step 4: Fit a linear regression model
hr_model = LinearRegression()
hr_model.fit(X, y)

pickle.dump(hr_model, open(os.path.join(model_path, f"Weather Model - hr {todaysdate}"), 'wb'))


X_copy = X.copy()

# Replace for predicting with average
X_copy['hr_b'] = X_copy['hr_b'].mean()
X_copy['hr_p'] = X_copy['hr_p'].mean()

# Step 5: Make predictions
predictions = hr_model.predict(X_copy)

# Step 6: Calculate deciles based on predicted hr
game_df['predicted_hr'] = predictions
game_df['decile_hr'] = pd.qcut(game_df['predicted_hr'], 10, labels=False)

# %% [markdown]
# ##### BB

# %%
# Step 3: Define features and target variable
X = game_df[['bb_b', 'bb_p', 'x_vect', 'y_vect', 'temperature'] + year_inputs + interaction_terms] 
y = game_df['bb']

# Step 4: Fit a linear regression model
bb_model = LinearRegression()
bb_model.fit(X, y)

pickle.dump(bb_model, open(os.path.join(model_path, f"Weather Model - bb {todaysdate}"), 'wb'))


X_copy = X.copy()

# Replace for predicting with average
X_copy['bb_b'] = X_copy['bb_b'].mean()
X_copy['bb_p'] = X_copy['bb_p'].mean()

# Step 5: Make predictions
predictions = bb_model.predict(X_copy)

# Step 6: Calculate deciles based on predicted 
game_df['predicted_bb'] = predictions
game_df['decile_bb'] = pd.qcut(game_df['predicted_bb'], 10, labels=False)

# %% [markdown]
# ##### HBP

# %%
# Step 3: Define features and target variable
X = game_df[['hbp_b', 'hbp_p', 'x_vect', 'y_vect', 'temperature'] + year_inputs + interaction_terms] 
y = game_df['hbp']

# Step 4: Fit a linear regression model
hbp_model = LinearRegression()
hbp_model.fit(X, y)

pickle.dump(hbp_model, open(os.path.join(model_path, f"Weather Model - hbp {todaysdate}"), 'wb'))


X_copy = X.copy()

# Replace for predicting with average
X_copy['hbp_b'] = X_copy['hbp_b'].mean()
X_copy['hbp_p'] = X_copy['hbp_p'].mean()

# Step 5: Make predictions
predictions = hbp_model.predict(X_copy)

# Step 6: Calculate deciles based on predicted 
game_df['predicted_hbp'] = predictions
game_df['decile_hbp'] = pd.qcut(game_df['predicted_hbp'], 10, labels=False)

# %% [markdown]
# ##### SO

# %%
# Step 3: Define features and target variable
X = game_df[['so_b', 'so_p', 'x_vect', 'y_vect', 'temperature'] + year_inputs + interaction_terms] 
y = game_df['so']

# Step 4: Fit a linear regression model
so_model = LinearRegression()
so_model.fit(X, y)

pickle.dump(so_model, open(os.path.join(model_path, f"Weather Model - so {todaysdate}"), 'wb'))


X_copy = X.copy()

# Replace sor predicting with average
X_copy['so_b'] = X_copy['so_b'].mean()
X_copy['so_p'] = X_copy['so_p'].mean()

# Step 5: Make predictions
predictions = so_model.predict(X_copy)

# Step 6: Calculate deciles based on predicted 
game_df['predicted_so'] = predictions
game_df['decile_so'] = pd.qcut(game_df['predicted_so'], 10, labels=False)

# %% [markdown]
# ##### FO

# %%
# Step 3: Define features and target variable
X = game_df[['fo_b', 'fo_p', 'x_vect', 'y_vect', 'temperature'] + year_inputs + interaction_terms] 
y = game_df['fo']

# Step 4: Fit a linear regression model
fo_model = LinearRegression()
fo_model.fit(X, y)

pickle.dump(fo_model, open(os.path.join(model_path, f"Weather Model - fo {todaysdate}"), 'wb'))


X_copy = X.copy()

# Replace for predicting with average
X_copy['fo_b'] = X_copy['fo_b'].mean()
X_copy['fo_p'] = X_copy['fo_p'].mean()

# Step 5: Make predictions
predictions = fo_model.predict(X_copy)

# Step 6: Calculate deciles based on predicted 
game_df['predicted_fo'] = predictions
game_df['decile_fo'] = pd.qcut(game_df['predicted_fo'], 10, labels=False)

# %% [markdown]
# ##### GO

# %%
# Step 3: Define features and target variable
X = game_df[['go_b', 'go_p', 'x_vect', 'y_vect', 'temperature'] + year_inputs + interaction_terms] 
y = game_df['go']

# Step 4: Fit a linear regression model
go_model = LinearRegression()
go_model.fit(X, y)

pickle.dump(go_model, open(os.path.join(model_path, f"Weather Model - go {todaysdate}"), 'wb'))


X_copy = X.copy()

# Replace for predicting with average
X_copy['go_b'] = X_copy['go_b'].mean()
X_copy['go_p'] = X_copy['go_p'].mean()

# Step 5: Make predictions
predictions = go_model.predict(X_copy)

# Step 6: Calculate deciles based on predicted 
game_df['predicted_go'] = predictions
game_df['decile_go'] = pd.qcut(game_df['predicted_go'], 10, labels=False)

# %% [markdown]
# ##### LO

# %%
# Step 3: Define features and target variable
X = game_df[['lo_b', 'lo_p', 'x_vect', 'y_vect', 'temperature'] + year_inputs + interaction_terms] 
y = game_df['lo']

# Step 4: Fit a linear regression model
lo_model = LinearRegression()
lo_model.fit(X, y)

pickle.dump(lo_model, open(os.path.join(model_path, f"Weather Model - lo {todaysdate}"), 'wb'))


X_copy = X.copy()

# Replace for predicting with average
X_copy['lo_b'] = X_copy['lo_b'].mean()
X_copy['lo_p'] = X_copy['lo_p'].mean()

# Step 5: Make predictions
predictions = lo_model.predict(X_copy)

# Step 6: Calculate deciles based on predicted 
game_df['predicted_lo'] = predictions
game_df['decile_lo'] = pd.qcut(game_df['predicted_lo'], 10, labels=False)

# %% [markdown]
# ##### PO

# %%
# Step 3: Define features and target variable
X = game_df[['po_b', 'po_p', 'x_vect', 'y_vect', 'temperature'] + year_inputs + interaction_terms] 
y = game_df['po']

# Step 4: Fit a linear regression model
po_model = LinearRegression()
po_model.fit(X, y)

pickle.dump(po_model, open(os.path.join(model_path, f"Weather Model - po {todaysdate}"), 'wb'))


X_copy = X.copy()

# Replace for predicting with average
X_copy['po_b'] = X_copy['po_b'].mean()
X_copy['po_p'] = X_copy['po_p'].mean()

# Step 5: Make predictions
predictions = po_model.predict(X_copy)

# Step 6: Calculate deciles based on predicted 
game_df['predicted_po'] = predictions
game_df['decile_po'] = pd.qcut(game_df['predicted_po'], 10, labels=False)

# %% [markdown]
# ### Graph

# %%
# Choose an event to graph and view park/weather factors
event = 'b2'

# Step 7: Calculate average predicted and actual hr for each decile
decile_means = game_df.groupby(f'decile_{event}').agg({f'predicted_{event}': 'mean', f'{event}': 'mean'})
# decile_means = game_df.query('venue_id == "17"').groupby('decile').agg({'predicted_hr': 'mean', 'hr': 'mean'})

# Step 8: Plot actual hr vs predicted hr by decile
plt.figure(figsize=(10, 6))
plt.plot(decile_means.index, decile_means[f'predicted_{event}'], label=f'Predicted {event}', marker='o')
plt.plot(decile_means.index, decile_means[f'{event}'], label=f'Actual {event}', marker='o')
plt.xlabel('Decile')
plt.ylabel(f'{event}')
plt.title(f'Actual vs Predicted {event} by Decile')
plt.legend()
plt.show()

# %% [markdown]
# ### Display Park/Weather Factors

# %%
# Calculate park factors (=predicted rate/average rate)
game_df[f'{event}_factor'] = game_df[f'predicted_{event}'] / game_df[event].mean()

# Calculate averages by park
park_averages = game_df[game_df['venue_id'].isin(team_map['VENUE_ID'].astype(str))].groupby('venue_id')[[f'decile_{event}', f'{event}', f'predicted_{event}', f'{event}_b', f'{event}_p']].mean().sort_values(by=[f'decile_{event}'], ascending=False).reset_index()
# Calculate factor summary statistics for parks for given state
park_descriptions = game_df[game_df['venue_id'].isin(team_map['VENUE_ID'].astype(str))].groupby('venue_id')[f'{event}_factor'].describe().sort_values('mean', ascending=False)

# Merge on team information
merge_map = team_map[['BBREFTEAM', 'VENUE_ID']]
merge_map['VENUE_ID'] = merge_map['VENUE_ID'].astype(str)
park_descriptions = park_descriptions.merge(merge_map, left_on=['venue_id'], right_on=['VENUE_ID'], how='left')
# Merge on park averages
park_descriptions = park_descriptions.merge(park_averages, left_on=['VENUE_ID'], right_on=['venue_id'], how='left')

# Calculate park factors
park_descriptions[f'{event}_factor'] = park_descriptions[f'predicted_{event}'] / game_df[event].mean()
park_descriptions = park_descriptions[['BBREFTEAM', 'VENUE_ID', f'{event}_factor', f'{event}', f'predicted_{event}', f'{event}_b', f'{event}_p', f'decile_{event}', 'mean', 'count', 'std', 'min', '25%', '50%', '75%', 'max']]

park_descriptions
# Out:
#    BBREFTEAM VENUE_ID  b2_factor        b2  predicted_b2      b2_b      b2_p  \
# 0        BOS        3   1.245853  0.055883      0.055128  0.047664  0.043793
# 1        COL       19   1.209125  0.052714      0.053503  0.043683  0.043369
# 2        ARI       15   1.132169  0.049756      0.050098  0.044616  0.043647
# 3        PIT       31   1.092955  0.048973      0.048362  0.044006  0.046056
# 4        KCR        7   1.089316  0.046929      0.048201  0.043313  0.042623
# 5        MIN     3312   1.077177  0.046691      0.047664  0.044499  0.042413
# 6        CLE        5   1.061041  0.047467      0.046950  0.045493  0.044818
# 7        TOR       14   1.057680  0.047172      0.046801  0.045332  0.044627
# 8        WSN     3309   1.039394  0.045759      0.045992  0.045380  0.043336
# 9        SFG     2395   1.019775  0.045277      0.045124  0.045626  0.043968
# 10       ATL     4705   1.007998  0.044468      0.044603  0.047078  0.042350
# 11       CIN     2602   1.003723  0.044124      0.044414  0.043928  0.044237
# 12       OAK       10   0.997498  0.044601      0.044138  0.045856  0.044451
# 13       PHI     2681   0.990652  0.044186      0.043836  0.045335  0.044582
# 14       LAD       22   0.989575  0.042287      0.043788  0.045502  0.040613
# 15       DET     2394   0.989058  0.043452      0.043765  0.044263  0.043953
# 16       STL     2889   0.972022  0.042796      0.043011  0.044489  0.043999
# 17       MIA     4169   0.960008  0.042232      0.042480  0.043998  0.044275
# 18       TBR       12   0.958295  0.042016      0.042404  0.045796  0.042722
# 19       BAL        2   0.944914  0.043366      0.041812  0.045642  0.046872
# 20       HOU     2392   0.940543  0.042569      0.041618  0.047814  0.044095
# 21       LAA        1   0.930984  0.041050      0.041195  0.044028  0.044466
# 22       SDP     2680   0.930973  0.041455      0.041195  0.045397  0.044351
# 23       TEX     5325   0.928541  0.040262      0.041087  0.044340  0.042833
# 24       CHC       17   0.926861  0.041297      0.041013  0.045532  0.044307
# 25       CHW        4   0.917587  0.039775      0.040602  0.044435  0.042762
# 26       MIL       32   0.916299  0.040443      0.040545  0.045302  0.043663
# 27       SEA      680   0.890817  0.039828      0.039418  0.044783  0.045094
# 28       NYY     3313   0.863597  0.038343      0.038213  0.044259  0.044876
# 29       NYM     3289   0.853084  0.038876      0.037748  0.046532  0.045361
#
#     decile_b2      mean   count       std       min       25%       50%  \
# 0    8.612200  1.245853  1377.0  0.103768  0.865274  1.180096  1.258306
# 1    8.402520  1.209125  1349.0  0.102414  0.816917  1.144822  1.215637
# 2    7.284157  1.132169  1376.0  0.128795  0.562888  1.064706  1.119433
# 3    6.854275  1.092955  1345.0  0.101019  0.816038  1.018929  1.097969
# 4    6.891016  1.089316  1358.0  0.090375  0.855453  1.031555  1.080422
# 5    6.668394  1.077177  1351.0  0.093305  0.700502  1.022312  1.083384
# 6    6.275362  1.061041  1380.0  0.093727  0.784872  0.996970  1.066572
# 7    6.391947  1.057680  1217.0  0.072595  0.847168  1.012396  1.042448
# 8    5.876623  1.039394  1386.0  0.078916  0.701296  0.990975  1.039927
# 9    5.303584  1.019775  1367.0  0.085199  0.738665  0.955914  1.031434
# 10   5.065177  1.007998  1074.0  0.057708  0.814356  0.970318  1.004578
# 11   4.809098  1.003723  1341.0  0.085717  0.710089  0.947640  0.998868
# 12   4.713011  0.997498  1345.0  0.078240  0.797172  0.938295  0.996400
# 13   4.561594  0.990652  1380.0  0.061906  0.809259  0.954276  0.989784
# 14   4.436552  0.989575  1450.0  0.084811  0.735091  0.931322  0.990016
# 15   4.479881  0.989058  1342.0  0.051562  0.844735  0.953928  0.982121
# 16   4.122975  0.972022  1358.0  0.079410  0.655389  0.932840  0.978708
# 17   3.534328  0.960008  1340.0  0.125629  0.542504  0.876727  0.936078
# 18   3.579371  0.958295  1367.0  0.070703  0.003161  0.906065  0.970442
# 19   3.229276  0.944914  1339.0  0.091036  0.633059  0.882617  0.939054
# 20   3.157311  0.940543  1443.0  0.077596  0.590397  0.863738  0.975620
# 21   2.666667  0.930984  1350.0  0.067958  0.766782  0.881757  0.926287
# 22   2.765004  0.930973  1383.0  0.071692  0.735213  0.879890  0.930061
# 23   2.585284  0.928541   598.0  0.055258  0.669536  0.907732  0.930858
# 24   2.827810  0.926861  1388.0  0.090634  0.638705  0.870437  0.931558
# 25   2.288675  0.917587  1351.0  0.057194  0.718134  0.885419  0.912594
# 26   2.410350  0.916299  1372.0  0.069778  0.722091  0.885504  0.913760
# 27   1.798658  0.890817  1341.0  0.073917  0.662251  0.836539  0.904181
# 28   1.116968  0.863597  1385.0  0.066217  0.647397  0.818572  0.876403
# 29   1.270742  0.853084  1374.0  0.090752  0.549787  0.778034  0.839457
#
#          75%       max
# 0   1.321658  1.467921
# 1   1.280311  1.496870
# 2   1.216406  1.650732
# 3   1.168391  1.359686
# 4   1.136896  1.385495
# 5   1.140794  1.333165
# 6   1.129235  1.309944
# 7   1.102508  1.325409
# 8   1.089165  1.326568
# 9   1.085043  1.283510
# 10  1.049621  1.214997
# 11  1.049233  1.280757
# 12  1.060635  1.152822
# 13  1.035125  1.148101
# 14  1.045882  1.279602
# 15  1.015170  1.154349
# 16  1.026262  1.159243
# 17  1.018372  1.405910
# 18  0.993569  1.073720
# 19  1.000167  1.185530
# 20  1.004216  1.139081
# 21  0.977725  1.142601
# 22  0.980780  1.151227
# 23  0.943111  1.170193
# 24  0.987552  1.213578
# 25  0.954021  1.113514
# 26  0.958861  1.124235
# 27  0.940487  1.196112
# 28  0.910099  1.045213
# 29  0.910889  1.110651

# %% [markdown]
# Future Considerations:
# - Consider rolling park factors to avoid using year
# - Clean to remove certain anomalous games (wind at the Trop, for example)
