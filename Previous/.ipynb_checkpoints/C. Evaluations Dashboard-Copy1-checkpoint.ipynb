# %% [markdown]
# # C. Evaluations Dashboard
# This evaluates the following:
# - Game projections
# - DFS player projections
# - DFS lineups

# %% [markdown]
# ### Imports

# %%
# %run "C:\Users\james\Documents\MLB\Code\U1. Imports.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U2. Utilities.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U3. Classes.ipynb"


baseball_path = r'C:\Users\james\Documents\MLB\Database'

# %%
# Set option to display numbers without scientific notation
pd.set_option('display.float_format', '{:.6f}'.format)

# %% [markdown]
# ### C01. Scores

# %%
# %run "C:\Users\james\Documents\MLB\Code\C01. Gambling.ipynb"

# %% [markdown]
# ##### Read in game results

# %%
all_games_df = read_and_save_games(team_map, generate=False)

# %% [markdown]
# ##### Read in simulation scores

# %%
# %%time
start_date = "20220407"
end_date = "20220507"

sim_score_df = read_sim_scores(start_date, end_date)
# Out:
# CPU times: total: 29 s
# Wall time: 4min 3s

# %%
date_list = list(sim_score_df['date'].unique())

# %% [markdown]
# ##### Read in Odds

# %%
# %%time
df = pd.merge(sim_score_df, all_games_df, on='game_id', how='left', suffixes=("", "_act"))

gambling_files = []
for date in date_list:
    odds_df = read_odds(date)
    date_df = pd.merge(df, odds_df, on=['date', 'game_num', 'VisitorTeamShort'], how='inner')
    date_df = gambling_stats_games(date_df)
    date_df['date'] = date
    gambling_files.append(date_df)
    
    
gambling_df = pd.concat(gambling_files, axis=0).reset_index(drop=True)
gambling_df = vegas_runs(gambling_df)
gambling_df.reset_index(inplace=True, drop=True)
# Out:
# CPU times: total: 3.75 s
# Wall time: 4.32 s

# %%
print("Over/Under\n", gambling_df.query('date <= "20220507"')['OverUnderPick'].value_counts())
# Out:
# Over/Under
#  Under      182
# Over       131
# Neither    114
# Name: OverUnderPick, dtype: int64

# %% [markdown]
# ##### Vegas Runs

# %%
gambling_df.query('date <= "20220507"')[['VisitorModelRuns', 'HomeModelRuns', 'VisitorVegasRuns', 'HomeVegasRuns', 'away_score_act', 'home_score_act', 'VisitorModelSqError', 'HomeModelSqError', 'VisitorVegasSqError', 'HomeVegasSqError']].describe()
# Out:
#        VisitorModelRuns  HomeModelRuns  VisitorVegasRuns  HomeVegasRuns  \
# count        427.000000     427.000000        427.000000     427.000000
# mean           4.251400       4.316157          4.014988       4.344965
# std            0.619690       0.568552          0.689431       0.666567
# min            2.774000       2.817000          2.500000       2.600000
# 25%            3.813000       3.945000          3.500000       3.900000
# 50%            4.189000       4.319000          3.900000       4.300000
# 75%            4.595500       4.712000          4.400000       4.800000
# max            6.451000       5.992000          7.000000       6.200000
#
#        away_score_act  home_score_act  VisitorModelSqError  HomeModelSqError  \
# count      427.000000      427.000000           427.000000        427.000000
# mean         3.964871        4.081967             8.889648          9.242375
# std          2.988426        3.056637            13.915414         19.570547
# min          0.000000        0.000000             0.000009          0.000001
# 25%          2.000000        2.000000             1.216634          1.458068
# 50%          4.000000        3.000000             4.485924          3.952144
# 75%          6.000000        6.000000            11.182337         10.504117
# max         17.000000       21.000000           168.818049        267.878689
#
#        VisitorVegasSqError  HomeVegasSqError
# count           427.000000        427.000000
# mean              8.901124          8.909813
# std              14.644680         17.952646
# min               0.000000          0.000000
# 25%               1.105000          1.210000
# 50%               4.410000          4.000000
# 75%              10.240000         10.565000
# max             156.250000        222.010000

# %% [markdown]
# ##### Graph Payouts

# %%
# Create a single row with three subplots
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

# Call the function for each subplot
payout_plotter(gambling_df.query("date <= '20220507'"), 'Spread', ax=axes[0])
payout_plotter(gambling_df.query("date <= '20220507'"), 'OverUnder', ax=axes[1])
payout_plotter(gambling_df.query("date <= '20220507'"), 'ML', ax=axes[2])

# Adjust layout for better spacing
plt.tight_layout()

# Show the plots
plt.show()

# %%
significance_test(gambling_df.query('(date <= "20220507") and ((SpreadPick == "Away" and Spread > 0) or (SpreadPick == "Home" and Spread < 0))'), "Spread", 1, 0.05)
significance_test(gambling_df.query('(date <= "20220507") and (OverUnderPick == "Under")'), "OverUnder", 1.0, 0.05)
significance_test(gambling_df.query('(date <= "20220507")'), "ML", 1.4, 0.05)
# Out:
# Average: 1.28664, n: 69, p_value: 0.055, significant: No
# Average: 1.10964, n: 182, p_value: 0.118, significant: No
# Average: 0.96667, n: 3, p_value: 0.976, significant: No

# %%
gambling_df.query('(date <= "20220507") and ((SpreadPick == "Away" and Spread > 0))')[['VisitorModelRuns', 'HomeModelRuns', 'Spread', 'SpreadMoney1', 'SpreadMoney2', 'away_score_act', 'home_score_act', 'away_sp_proj', 'home_sp_proj', 'AwaySpreadPred', 'HomeSpreadPred', 'AwaySpreadAct', 'HomeSpreadAct', 'SpreadPick', 'SpreadPayout']].head(1)
# Out:
#    VisitorModelRuns  HomeModelRuns   Spread  SpreadMoney1  SpreadMoney2  \
# 8          5.435000       4.273000 1.500000      2.160000      1.787402
#
#    away_score_act  home_score_act  away_sp_proj  home_sp_proj  AwaySpreadPred  \
# 8        2.000000        4.000000      0.471000      0.529000        1.017360
#
#    HomeSpreadPred  AwaySpreadAct  HomeSpreadAct SpreadPick  SpreadPayout
# 8        0.945535       0.000000       1.787402       Away      0.000000

# %%
gambling_df.query('SpreadPick == "Home" and Spread > 0')['SpreadPayout'].mean()
# gambling_df['SpreadPayout'].mean()
# Out:
# 0.549941141744777

# %%
gambling_df['ModelDiff'] = (gambling_df['VisitorModelRuns'] - gambling_df['HomeModelRuns']).abs()
gambling_df['VegasDiff'] = (gambling_df['VisitorVegasRuns'] - gambling_df['HomeVegasRuns']).abs()
gambling_df.describe()
# Out:
#             game_id   game_num  VisitorModelRuns  HomeModelRuns    away_id  \
# count    427.000000 427.000000        427.000000     427.000000 427.000000
# mean  662290.248244   1.023419          4.251400       4.316157 128.482436
# std      687.207323   0.151408          0.619690       0.568552  14.235331
# min   661032.000000   1.000000          2.774000       2.817000 108.000000
# 25%   661736.000000   1.000000          3.813000       3.945000 115.000000
# 50%   662272.000000   1.000000          4.189000       4.319000 133.000000
# 75%   662907.500000   1.000000          4.595500       4.712000 141.000000
# max   663463.000000   2.000000          6.451000       5.992000 158.000000
#
#          home_id  game_num_act  away_score_act  home_score_act    venue_id  \
# count 427.000000    427.000000      427.000000      427.000000  427.000000
# mean  128.779859      1.049180        3.964871        4.081967 1543.922717
# std    14.351662      0.216498        2.988426        3.056637 1703.206009
# min   108.000000      1.000000        0.000000        0.000000    1.000000
# 25%   115.000000      1.000000        2.000000        2.000000   12.000000
# 50%   134.000000      1.000000        4.000000        3.000000   32.000000
# 75%   141.000000      1.000000        6.000000        6.000000 2889.000000
# max   158.000000      2.000000       17.000000       21.000000 5325.000000
#
#           Spread         OU  SpreadMoney1  SpreadMoney2   OuMoney1   OuMoney2  \
# count 427.000000 427.000000    427.000000    427.000000 427.000000 427.000000
# max       1.000000        1.306090        1.252800   1.356905   1.314810
#
#        AwayMLPred  HomeMLPred  AwaySpreadAct  HomeSpreadAct   UnderAct  \
# count  427.000000  427.000000     427.000000     427.000000 427.000000
# mean     0.986065    0.958372       0.948358       1.082285   1.064351
# std      0.118162    0.099889       1.016081       1.070781   0.935245
# min      0.704192    0.664304       0.000000       0.000000   0.000000
# 25%      0.901815    0.892750       0.000000       0.000000   0.000000
# 50%      0.971800    0.950300       0.000000       1.534759   1.826446
# 75%      1.053313    1.018096       1.900901       2.100000   1.913261
# max      1.557300    1.339960       2.800000       2.750000   2.050000
#
#          OverAct  AwayMLAct  HomeMLAct  SpreadPayout  OverUnderPayout  \
# count 427.000000 427.000000 427.000000    290.000000       313.000000
# mean    0.852558   0.974275   0.922471      0.775196         1.030771
# std     0.934066   1.054088   0.915583      0.979052         0.950756
# min     0.000000   0.000000   0.000000      0.000000         0.000000
# 25%     0.000000   0.000000   0.000000      0.000000         0.000000
# 50%     0.000000   0.000000   1.374532      0.000000         1.833333
# 75%     1.892857   1.913261   1.714286      1.698087         1.943396
# max     2.050000   3.950000   2.780000      2.800000         2.050000
#
#         MLPayout  SpreadPayoutPred  OverUnderPayoutPred  MLPayoutPred  \
# count 309.000000        290.000000           313.000000    309.000000
# mean    0.862233          1.065031             1.098481      1.087519
# std     1.092646          0.055737             0.074406      0.078551
# min     0.000000          1.000290             1.000909      1.000800
# 25%     0.000000          1.020600             1.035692      1.028038
# 50%     0.000000          1.051219             1.081544      1.071757
# 75%     2.000000          1.094993             1.149915      1.125090
# max     3.950000          1.306090             1.356905      1.557300
#
#        VisitorModelError  VisitorVegasError  VisitorModelSqError  \
# count         427.000000         427.000000           427.000000
# mean            0.286529           0.050117             8.889648
# std             2.971233           2.986553            13.915414
# min           -12.993000         -12.500000             0.000009
# 25%            -1.471000          -1.650000             1.216634
# 50%             0.826000           0.500000             4.485924
# 75%             2.545500           2.300000            11.182337
# max             5.451000           5.600000           168.818049
#
#        VisitorVegasSqError  HomeModelError  HomeVegasError  HomeModelSqError  \
# count           427.000000      427.000000      427.000000        427.000000
# mean              8.901124        0.234190        0.262998          9.242375
# std              14.644680        3.034649        2.976810         19.570547
# min               0.000000      -16.367000      -14.900000          0.000001
# 25%               1.105000       -1.415500       -1.200000          1.458068
# 50%               4.410000        1.150000        1.100000          3.952144
# 75%              10.240000        2.313500        2.300000         10.504117
# max             156.250000        4.916000        4.800000        267.878689
#
#        HomeVegasSqError  TotalVegasRuns  ModelDiff  VegasDiff
# count        427.000000      427.000000 427.000000 427.000000
# mean           8.909813        8.359953   0.628831   0.812881
# std           17.952646        1.005040   0.455290   0.525319
# min            0.000000        6.600000   0.003000   0.000000
# 25%            1.210000        7.700000   0.282500   0.400000
# 50%            4.000000        8.200000   0.541000   0.700000
# 75%           10.565000        8.700000   0.909000   1.100000
# max          222.010000       12.300000   2.307000   2.500000

# %%
gambling_df.query('Spread > 0')['SpreadPick'].value_counts()
# Out:
# Home       95
# Neither    51
# Away       35
# Name: SpreadPick, dtype: int64

# %%
# You're almost impossibly bad at spreads lol
# Might be good to know why
# Very good when predicting unders (Biased toward over)
# I think you're probably always taking the points in the Spreads
# Theory: You're always predicting close games. Because of this, your spread pick is always the points.

# %% [markdown]
# ##### Graph Runs

# %%
# Total: Choose Vegas or Actual to compare my runs to 
total = "TotalVegasRuns"

# You can convert the index to a list for the x-axis and get the values for the y-axis
x_values = gambling_df.index.tolist()
y_values = gambling_df['total_proj'].tolist()

# Calculate the rolling average
rolling_avg = gambling_df[f'{total}'].rolling(window=200, min_periods=100).mean()

# Create a scatter plot
plt.scatter(x_values, y_values, label='total_proj')

# Add the rolling average line
plt.plot(x_values, rolling_avg, color='red', label='Rolling Average (Window=200)')

# Set labels and title
plt.xlabel('Index')
plt.ylabel('total_proj')
plt.title('Scatter Plot with Rolling Average')
plt.legend()

# Show the plot
plt.show()

# %%
afadsfaf

# %% [markdown]
# ### C02. Projections

# %%
# %run "C:\Users\james\Documents\MLB\Code\C02. Projections.ipynb"

# %%
# Read in contest history
history = pd.read_csv(os.path.join(baseball_path, "Utilities", "draftkings-contest-entry-history.csv"))

# %%
# Read in cleaned contest history (this needs to be fixed long-term)
contests = pd.read_csv(os.path.join(baseball_path, "Utilities", "Contests.csv"))
contests = contests[::-1]

# %%
contests = contests[~contests['draftGroupId'].isna()].reset_index(drop=True)

# %%
comparable_dfs = []
for i in range(len(contests)):
    try:
        contestKey = contests['contestKey'][i].astype('int')
        draftGroupId = contests['draftGroupId'][i].astype('int')

        # print(draftGroupId)

        # Read in projection dataframes
        my_df = read_player_sims(draftGroupId)
        # print(my_df.head(10))
        dff_df = read_dff(contestKey, history)
        roto_df = read_roto(contestKey, history)

        # Merge them together
        projection_df = merge_projections(my_df, dff_df, roto_df, quietly=True)

        # Read in contest results
        score_df = read_results(contestKey)

        # Evaluate projections
        complete_df = evaluate_projections_post(projection_df, score_df)
        comparable_df = compare_projections(complete_df)
        
        # print("Me: ", len(my_df['TeamAbbrev'].unique()), "DFF: ", len(dff_df['TeamAbbrev'].unique()), "Roto: ", len(roto_df['TeamAbbrev'].unique()), "Merged:", len(comparable_df['TeamAbbrev'].unique()))
        # print("Me: ", len(my_df), "DFF: ", len(dff_df), "Roto:", len(roto_df), "Merged:", len(comparable_df))
        
        # Add to list of dataframes
        comparable_dfs.append(comparable_df)
        
    except:
        pass

# %%
all_projections = pd.concat(comparable_dfs, axis=0).head(360000)
len(all_projections)

# %%
batter_means = all_projections.query('`Roster Position` != "P" and Projection_Me > 0 and Projection_DFF > 0 and Projection_Roto > 0').agg('mean')
pitcher_means = all_projections.query('`Roster Position` == "P" and Projection_Me > 0 and Projection_DFF > 0 and Projection_Roto > 0').agg('mean')
all_means = all_projections.query('Projection_Me > 0 and Projection_DFF > 0 and Projection_Roto > 0').agg('mean')


batter_means_unimp = all_projections.query('imp == 0 and `Roster Position` != "P" and Projection_Me > 0 and Projection_DFF > 0 and Projection_Roto > 0').agg('mean')
pitcher_means_unimp = all_projections.query('imp == 0 and `Roster Position` == "P" and Projection_Me > 0 and Projection_DFF > 0 and Projection_Roto > 0').agg('mean')
all_means_unimp = all_projections.query('imp == 0 and Projection_Me > 0 and Projection_DFF > 0 and Projection_Roto > 0').agg('mean')

batter_means_imp = all_projections.query('imp == 1 and `Roster Position` != "P" and Projection_Me > 0 and Projection_DFF > 0 and Projection_Roto > 0').agg('mean')
pitcher_means_imp = all_projections.query('imp == 1 and `Roster Position` == "P" and Projection_Me > 0 and Projection_DFF > 0 and Projection_Roto > 0').agg('mean')
all_means_imp = all_projections.query('imp == 1 and Projection_Me > 0 and Projection_DFF > 0 and Projection_Roto > 0').agg('mean')



means_df = pd.concat([batter_means, pitcher_means, all_means, batter_means_unimp, pitcher_means_unimp, all_means_unimp, batter_means_imp, pitcher_means_imp, all_means_imp], axis=1).T
means_df.set_index(pd.Index(["Batters", "Pitchers", "All", "Batters Unimp", "Pitchers Unimp", "All Unimp", "Batters Imp", "Pitchers Imp", "All Imp"]), inplace=True)

means_df.drop(columns={'ownership'})
