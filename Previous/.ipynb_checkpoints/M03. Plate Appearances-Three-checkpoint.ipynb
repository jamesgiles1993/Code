# %% [markdown]
# # M03. Predict PAs
# - This predicts the outcome of plate appearances
# - Type: Model
# - Run Frequency: Irregular
# - Sources:
#     - MLB API
#     - Steamer
# - Created: 4/19/2024
# - Updated: 2/1/2025

# %% [markdown]
# ### Imports

# %%
# %run "U1. Imports.ipynb"
# %run "U2. Utilities.ipynb"
# %run "U3. Classes.ipynb"
# %run "U4. Datasets.ipynb"
# %run "U5. Models.ipynb"

# %%
# Set option to display numbers without scientific notation
pd.set_option('display.float_format', '{:.6f}'.format)

# %% [markdown]
# ### Data

# %% [markdown]
# ##### Park x Weather Factors

# %%
multiplier_df = pd.read_csv(os.path.join(baseball_path, "Multiplier Dataset.csv"))

# %% [markdown]
# ##### Plate Appearances

# %%
complete_dataset = create_pa_inputs(multiplier_df, start_year=2013, end_year=2024, short=50, long=300, adjust=True, generate=False, write=False)

# %% [markdown]
# ##### Steamer

# %%
steamer_hitters_df = pd.read_csv(os.path.join(baseball_path, "A03. Steamer", "steamer_hitters_weekly_log.csv"), encoding='iso-8859-1')

# %%
steamer_pitchers_df = pd.read_csv(os.path.join(baseball_path, "A03. Steamer", "steamer_pitchers_weekly_log.csv"), encoding='iso-8859-1')

# %% [markdown]
# ### Clean

# %% [markdown]
# ##### MLB Stats API

# %%
# %%time
complete_dataset[batter_inputs] = scale_batter_stats.transform(complete_dataset[batter_inputs])
complete_dataset[pitcher_inputs] = scale_pitcher_stats.transform(complete_dataset[pitcher_inputs])
# Out:
# CPU times: total: 1.77 s
# Wall time: 1.84 s

# %% [markdown]
# ##### Steamer

# %% [markdown]
# Clean

# %%
steamer_hitters_df2 = clean_steamer_hitters(steamer_hitters_df)
steamer_hitters_df2.dropna(subset=batter_stats_fg, inplace=True)

# %% [markdown]
# Scale

# %%
steamer_hitters_df2[batter_stats_fg] = scale_batter_stats_steamer.transform(steamer_hitters_df2[batter_stats_fg])

# %% [markdown]
# Read in pitchers

# %% [markdown]
# Clean

# %%
steamer_pitchers_df2 = clean_steamer_pitchers(steamer_pitchers_df)
steamer_pitchers_df2.dropna(subset=pitcher_stats_fg2, inplace=True)

# %% [markdown]
# Scale

# %%
steamer_pitchers_df2[pitcher_stats_fg] = scale_pitcher_stats_steamer.transform(steamer_pitchers_df2[pitcher_stats_fg])

# %% [markdown]
# ##### Merge

# %% [markdown]
# Format dates

# %%
complete_dataset['date_time'] = pd.to_datetime(complete_dataset['date'], format='%Y%m%d')
complete_dataset['date_time_copy'] = complete_dataset['date_time'].copy()
steamer_hitters_df2['date_time'] = pd.to_datetime(steamer_hitters_df2['date'], format='%Y%m%d')
steamer_pitchers_df2['date_time'] = pd.to_datetime(steamer_pitchers_df2['date'], format='%Y%m%d')

steamer_hitters_df2.rename(columns={'mlbamid': 'batter'}, inplace=True)
steamer_pitchers_df2.rename(columns={'mlbamid': 'pitcher'}, inplace=True)

# %% [markdown]
# Sort to prep for merge

# %%
complete_dataset.sort_values('date_time', inplace=True)
steamer_hitters_df2.sort_values('date_time', inplace=True)
steamer_pitchers_df2.sort_values('date_time', inplace=True)

# %% [markdown]
# Drop unnecessary columns

# %%
steamer_hitters_df2.drop(columns=['date', 'firstname', 'lastname', 'steamerid'], inplace=True)
steamer_pitchers_df2.drop(columns=['date', 'firstname', 'lastname', 'steamerid'], inplace=True)

# %% [markdown]
# Remove missing pitchers (occurs occassionally in 2014)

# %%
steamer_pitchers_df2 = steamer_pitchers_df2[~steamer_pitchers_df2['pitcher'].isna()].reset_index(drop=True)

# %% [markdown]
# Set data types

# %%
complete_dataset['batter'] = complete_dataset['batter'].astype(int).astype(str)
complete_dataset['pitcher'] = complete_dataset['pitcher'].astype(int).astype(str)
steamer_hitters_df2['batter'] = steamer_hitters_df2['batter'].astype(int).astype(str)
steamer_pitchers_df2['pitcher'] = steamer_pitchers_df2['pitcher'].astype(int).astype(str)

# %% [markdown]
# Merge asof most recent date in Steamer

# %%
complete_merged_df = pd.merge_asof(
    complete_dataset,
    steamer_hitters_df2,
    on='date_time',
    by='batter',  # Group by 'batter'
    direction='backward'  # Use 'backward', 'forward', or 'nearest' as appropriate
)
# Correct datetime (might be unnecessary, but I'm not sure which date_time it takes after the merge)
complete_merged_df['date_time'] = complete_merged_df['date_time_copy'].copy()

complete_merged_df = pd.merge_asof(
    complete_merged_df,
    steamer_pitchers_df2,
    on='date_time',
    by='pitcher',  # Group by 'batter'
    direction='backward'  # Use 'backward', 'forward', or 'nearest' as appropriate
)

# %% [markdown]
# ##### Impute

# %% [markdown]
# For players with insufficient sample sizes, stats are imputed

# %% [markdown]
# Option 1: Steamer

# %% [markdown]
# First, remove from dataset if ever missing FG/Steamer stats

# %%
complete_merged_df = complete_merged_df[~complete_merged_df['b1_rate'].isna()]
complete_merged_df = complete_merged_df[~complete_merged_df['H9'].isna()]

# %%
# Add hands to use in imputation
batter_stats_fg_imp = batter_stats_fg + ['b_L', 'p_L', 'imp_b']
pitcher_stats_fg_imp = pitcher_stats_fg + ['b_L', 'p_L', 'imp_p']

### Batters
# Use Steamer stats to predict API/Statcast stats for those with limited samples
batter_predictions = impute_batter_stats.predict(complete_merged_df.loc[complete_merged_df['pa_b'] < 40, batter_stats_fg_imp])

# Impute inputs with limited sample size with predicted values
complete_merged_df.loc[complete_merged_df['pa_b'] < 40, batter_inputs] = batter_predictions

### Pitchers
# Use Steamer stats to predict API/Statcast stats for those with limited samples
pitcher_predictions = impute_pitcher_stats.predict(complete_merged_df.loc[complete_merged_df['pa_p'] < 40, pitcher_stats_fg_imp])

# Impute inputs with limited sample size with predicted values
complete_merged_df.loc[complete_merged_df['pa_p'] < 40, pitcher_inputs] = pitcher_predictions

# %% [markdown]
# Option 2: 0s

# %%
# # Testing instead of imputing, just weighting with 0s
# complete_merged_df[batter_inputs].fillna(0, inplace=True)
# complete_merged_df[pitcher_inputs].fillna(0, inplace=True)

# # Calculate the weighted average for each column in pitcher_stats
# # Could be simplified, but I wanted to show the steps
# # Weighted average of provided value and 0. PAs and 50-PAs are weights. 
# for col in batter_inputs:
#     complete_merged_df[col] = (complete_merged_df[col] * complete_merged_df['pa_b'] + 0 * (50-complete_merged_df['pa_b']))/50

# # Calculate the weighted average for each column in pitcher_stats
# for col in pitcher_inputs:
#     complete_merged_df[col] = (complete_merged_df[col] * complete_merged_df['pa_p'] + 0 * (50-complete_merged_df['pa_p']))/50

# %% [markdown]
# ### Select Data

# %% [markdown]
# Drop early observations

# %%
complete_merged_df = complete_merged_df[complete_merged_df['game_date'] > '2015-07-01']

# %% [markdown]
# Drop atypical events

# %%
complete_merged_df = complete_merged_df.query('eventsModel != "Cut"')

# %% [markdown]
# Drop observations from inactive parks

# %%
active_parks = list(team_map['VENUE_ID'].astype(int))
complete_merged_df = complete_merged_df[complete_merged_df['venue_id'].astype(int).isin(active_parks)]

# %% [markdown]
# ### Select Variables

# %% [markdown]
# Batter Inputs

# %%
batter_input_list = batter_inputs

# %% [markdown]
# Pitcher Inputs

# %%
pitcher_input_list = pitcher_inputs

# %% [markdown]
# Hand Inputs

# %%
hand_input_list = ['p_L', 'b_L']

# %% [markdown]
# Imputation Inputs

# %%
imp_input_list = ['imp_b', 'imp_p']

# %% [markdown]
# Starter Input(s)

# %%
starter_input_list = ['starter']

# %% [markdown]
# Cumulative Inning Inputs

# %%
cumulative_inning_input_list = [col for col in complete_merged_df.columns if col.endswith("_inning")]

# %%
cumulative_inning_input_list.remove('rbi_inning')

# %% [markdown]
# Cumulative Game Inputs

# %%
cumulative_game_input_list = [col for col in complete_merged_df.columns if col.endswith("_game")]

# %%
cumulative_game_input_list.remove('rbi_game')

# %% [markdown]
# Game State Inputs

# %%
complete_merged_df['winning'] = (complete_merged_df['preBatterScore'] > complete_merged_df['prePitcherScore']).astype(int)
complete_merged_df['winning_big'] = (complete_merged_df['preBatterScore'] > complete_merged_df['prePitcherScore'] + 3).astype(int)

# %%
game_state_input_list = ['onFirst', 'onSecond', 'onThird', 'top', 'score_diff', 'prePitcherScore', 'preBatterScore', 'winning', 'winning_big', 'times_faced']

# %% [markdown]
# Inning Inputs

# %%
for inning in range(1, 12):
    complete_merged_df[f'inning_{inning}'] = (complete_merged_df['inning'] == inning).astype(int)
complete_merged_df['inning_11'] = (complete_merged_df['inning'] >= 11).astype(int)

# %%
inning_input_list = [col for col in complete_merged_df.columns if col.startswith("inning_")]

# %% [markdown]
# Out Inputs

# %%
for out in range(0, 3):
    complete_merged_df[f'outs_{out}'] = (complete_merged_df['outs_pre'] == out).astype(int)

# %%
out_input_list = ['outs_0', 'outs_1', 'outs_2']

# %% [markdown]
# Venue Inputs

# %%
complete_merged_df['venue_id2'] = complete_merged_df['venue_id'].copy()
complete_merged_df = pd.get_dummies(complete_merged_df, columns=['venue_id2'], prefix='venue')

# %%
venue_input_list = [col for col in complete_merged_df.columns if col.startswith("venue_") and col != "venue_id"]

# %% [markdown]
# Multiplier Inputs

# %%
for event in events_list:
    # Assign multiplier for their 
    complete_merged_df[f'{event}_wfx'] = np.where(complete_merged_df['batSide'] == "L", complete_merged_df[f'{event}_wfx_l'], complete_merged_df[f'{event}_wfx_r'])

# %%
multiplier_input_list = [f'{event}_wfx' for event in events_list]

# %% [markdown]
# Inputs

# %%
input_list = batter_input_list + pitcher_input_list + hand_input_list + imp_input_list + starter_input_list + cumulative_inning_input_list + cumulative_game_input_list + game_state_input_list + inning_input_list + out_input_list + venue_input_list + multiplier_input_list

# %% [markdown]
# Outputs

# %%
output_list = ['is_out', 'eventsModel']

# %% [markdown]
# Other variables

# %%
additional_list = ['pa_b', 'pa_p', 'year', 'date', 'gamePk', 'atBatIndex', 'venue_id', 'batterName', 'pitcherName']

# %% [markdown]
# Variables to keep

# %%
keep_list = input_list + output_list + additional_list

# %% [markdown]
# ### Shift

# %% [markdown]
# Many batter and pitcher stats are calculated at the end of the plate appearance. For prediction purposes, we need these stats coming into the plate appearance, so we need to shift.

# %% [markdown]
# ##### Batter Inputs

# %% [markdown]
# Sort

# %%
complete_merged_df.sort_values(['date', 'gamePk', 'atBatIndex'], ascending=True, inplace=True)

# %% [markdown]
# Shift

# %%
complete_merged_df[batter_inputs + ['ab_b', 'pa_b', 'imp_b']] = complete_merged_df.groupby(['batter', 'pitchHand'])[batter_inputs + ['ab_b', 'pa_b', 'imp_b']].shift(1)

# %% [markdown]
# ##### Pitcher Inputs

# %% [markdown]
# Sort

# %%
complete_merged_df.sort_values(['date', 'gamePk', 'atBatIndex'], ascending=True, inplace=True)

# %% [markdown]
# Shift

# %%
complete_merged_df[pitcher_inputs + ['ab_p', 'pa_p', 'imp_p']] = complete_merged_df.groupby(['pitcher', 'batSide'])[pitcher_inputs + ['ab_p', 'pa_p', 'imp_p']].shift(1)

# %% [markdown]
# ##### Inning Sums

# %% [markdown]
# Sort

# %%
complete_merged_df.sort_values(['date', 'gamePk', 'atBatIndex'], ascending=True, inplace=True)

# %% [markdown]
# Shift

# %%
complete_merged_df[cumulative_inning_input_list] = complete_merged_df.groupby(['gamePk', 'inning', 'pitcher'])[cumulative_inning_input_list].shift(1)
complete_merged_df[cumulative_inning_input_list] = complete_merged_df[cumulative_inning_input_list].fillna(0)

# %% [markdown]
# ##### Game Sums

# %% [markdown]
# Sort

# %%
complete_merged_df.sort_values(['date', 'gamePk', 'atBatIndex'], ascending=True, inplace=True)

# %% [markdown]
# Shift

# %%
complete_merged_df[cumulative_game_input_list + ['times_faced']] = complete_merged_df.groupby(['gamePk', 'pitcher'])[cumulative_game_input_list + ['times_faced']].shift(1)
complete_merged_df[cumulative_game_input_list + ['times_faced']] = complete_merged_df[cumulative_game_input_list + ['times_faced']].fillna(0)

# %% [markdown]
# ### Model Dataset

# %% [markdown]
# Create Model Dataset

# %%
model_dataset = complete_merged_df[keep_list]

model_dataset.dropna(subset=input_list, inplace=True)
model_dataset.reset_index(drop=True, inplace=True)

# %% [markdown]
# Free up memory

# %%
del complete_merged_df, complete_dataset, steamer_hitters_df, steamer_hitters_df2, steamer_pitchers_df, steamer_pitchers_df2, multiplier_df,  batter_predictions, pitcher_predictions

# %%
n1 = len(input_list) + 1

# %% [markdown]
# ### Train/Test Split

# %% [markdown]
# Split

# %%
np.random.seed(42)
model_dataset['split'] = np.random.choice([0, 0, 1], size=len(model_dataset))

# %% [markdown]
# Create masks to identify training and testing datasets

# %% [markdown]
# Note: to train on the entire dataset, you can simply set split = 0 for the entire dataset

# %%
training_mask = (model_dataset['split'] == 0)
# testing_mask = (model_dataset['split'] == 1)

# training_out_mask = (model_dataset['is_out'] == 1) & (model_dataset['split'] == 0)
# testing_out_mask = (model_dataset['is_out'] == 1) & (model_dataset['split'] == 1)

# training_safe_mask = (model_dataset['is_out'] == 0) & (model_dataset['split'] == 0)
# testing_safe_mask = (model_dataset['is_out'] == 0) & (model_dataset['split'] == 1)

out_mask = (model_dataset['is_out'] == 1)

# %%
model_dataset[training_mask].shape
# Out:
# (1030870, 206)

# %%
model_dataset[~training_mask].shape
# Out:
# (515817, 206)

# %% [markdown]
# ### Binary

# %%
# %%time
# Neural network layers
# layers = (196,196,)
layers = (10,)
# layers = (196,196,196,196,196,196)
layers_str = ''.join(str(x) for x in layers)
activation = 'relu'
iters = 1000
alpha = 0.0001
learning_rate = 0.00001
batch_size='auto'
random_state = random.randint(1,99999)
print(random_state)
num_models = 1
cv = 1 # Unused
n_jobs = 1

binary_filename = f"predict_binary_{layers_str}_{todaysdate}.sav"
print(binary_filename)


# Define the individual models in the ensemble
models = [
    MLPClassifier(hidden_layer_sizes=layers, activation=activation, verbose=True, alpha=alpha, learning_rate_init=learning_rate, early_stopping=True, 
                  random_state=random_state+i, max_iter=iters, batch_size=batch_size) for i in range(num_models)]

# Create the ensemble classifier using VotingClassifier
predict_binary = VotingClassifier(estimators=[('model'+str(i+1), model) for i, model in enumerate(models)], voting='soft', n_jobs=n_jobs).fit(model_dataset[training_mask][input_list], model_dataset[training_mask][['is_out']].values.ravel())

# Save model
pickle.dump(predict_binary, open(os.path.join(model_path, "M03. Plate Appearances", binary_filename), 'wb'))
# Out:
# 99204
# predict_binary_10_20250221.sav
# Iteration 1, loss = 0.69816752
# Validation score: 0.664381
# Iteration 2, loss = 0.65243122
# Validation score: 0.672054
# Iteration 3, loss = 0.64227844
# Validation score: 0.674479
# Iteration 4, loss = 0.63800961
# Validation score: 0.675449
# Iteration 5, loss = 0.63553486
# Validation score: 0.676584
# Iteration 6, loss = 0.63384477
# Validation score: 0.677496
# Iteration 7, loss = 0.63258485
# Validation score: 0.678165
# Iteration 8, loss = 0.63158739
# Validation score: 0.678543
# Iteration 9, loss = 0.63077417
# Validation score: 0.678863
# Iteration 10, loss = 0.63010997
# Validation score: 0.678834
# Iteration 11, loss = 0.62954086
# Validation score: 0.678766
# Iteration 12, loss = 0.62906072
# Validation score: 0.678902
# Iteration 13, loss = 0.62865916
# Validation score: 0.679193
# Iteration 14, loss = 0.62830691
# Validation score: 0.679106
# Iteration 15, loss = 0.62798696
# Validation score: 0.679349
# Iteration 16, loss = 0.62771083
# Validation score: 0.679164
# Iteration 17, loss = 0.62745579
# Validation score: 0.679358
# Iteration 18, loss = 0.62722776
# Validation score: 0.679319
# Iteration 19, loss = 0.62701683
# Validation score: 0.679339
# Iteration 20, loss = 0.62682990
# Validation score: 0.679494
# Iteration 21, loss = 0.62667637
# Validation score: 0.679475
# Iteration 22, loss = 0.62651913
# Validation score: 0.679339
# Iteration 23, loss = 0.62638733
# Validation score: 0.679552
# Iteration 24, loss = 0.62626708
# Validation score: 0.679416
# Iteration 25, loss = 0.62616461
# Validation score: 0.679552
# Iteration 26, loss = 0.62605853
# Validation score: 0.679533
# Iteration 27, loss = 0.62597478
# Validation score: 0.679581
# Iteration 28, loss = 0.62588104
# Validation score: 0.679543
# Iteration 29, loss = 0.62581025
# Validation score: 0.679669
# Iteration 30, loss = 0.62572234
# Validation score: 0.679533
# Iteration 31, loss = 0.62566106
# Validation score: 0.679640
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# CPU times: total: 6min 48s
# Wall time: 59.6 s

# %%
# Predict all types
all_outputs = list(predict_binary.classes_)
all_outputs_pred = ["is_safe_pred", "is_out_pred"]

model_dataset.loc[~training_mask, all_outputs_pred] = predict_binary.predict_proba(model_dataset[~training_mask][input_list])

# %%
# Set quantiles
quantiles = 10

# Create quantiles
for var in ['is_out']:    
    # Create actual outcome column
    model_dataset.loc[~training_mask, f'{var}_act'] = (model_dataset.loc[~training_mask, 'eventsModel'] == var).astype(int)

    # Create actual is_out value
    if var == "is_out":
        model_dataset.loc[~training_mask, f'{var}_act'] = model_dataset.loc[~training_mask, 'eventsModel'].isin(['so', 'lo', 'po', 'go', 'fo']).astype(int)
    
    # Create deciles
    model_dataset.loc[~training_mask, f'{var}_quantile'] = pd.qcut(model_dataset.loc[~training_mask, f'{var}_pred'], quantiles, labels=False)
    
    # Create aggregated dataframe
    globals()[f"{var}_df"] = model_dataset.loc[~training_mask].groupby(f'{var}_quantile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()
    # globals()[f"{var}_df"] = model_dataset.query('year >= 2024').loc[testing_mask].groupby(f'{var}_quantile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()
    # globals()[f"{var}_df"] = model_dataset.query('venue_id == 19').loc[testing_mask].groupby(f'{var}_quantile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()

# %%
# Create figure and single subplot
fig, ax = plt.subplots(1, 1, figsize=(4, 4))

var = "is_out"

# Plot the data on the single axis
ax.plot(globals()[f"{var}_df"][f'{var}_quantile'], globals()[f"{var}_df"][f'{var}_act'], color='black')
ax.plot(globals()[f"{var}_df"][f'{var}_quantile'], globals()[f"{var}_df"][f'{var}_pred'], color='red')
ax.set_title(var)

# Adjust layout
fig.tight_layout(pad=0.0)

# Show figure
plt.show()

# %%
model_dataset[training_mask][out_mask].shape, model_dataset[training_out_mask].shape
# Out:
# ((700914, 210), (700914, 210))

# %% [markdown]
# ### Outs

# %%
# %%time
# Neural network layers
# layers = (196,196,)
layers = (10,)
# layers = (196,196,196,196,196,196)
layers_str = ''.join(str(x) for x in layers)
activation = 'relu'
iters = 1000
alpha = 0.0001
learning_rate = 0.00001
batch_size='auto'
random_state = random.randint(1,99999)
print(random_state)
num_models = 1
cv = 1 # Unused
n_jobs = 1

outs_filename = f"predict_out_{layers_str}_{todaysdate}.sav"
print(outs_filename)


# Define the individual models in the ensemble
models = [MLPClassifier(hidden_layer_sizes=layers, activation=activation, verbose=True, alpha=alpha, learning_rate_init=learning_rate, early_stopping=True, 
          random_state=random_state+i, max_iter=iters, batch_size=batch_size) for i in range(num_models)]

# Create the ensemble classifier using VotingClassifier
predict_outs = VotingClassifier(estimators=[('model'+str(i+1), model) for i, model in enumerate(models)], voting='soft', n_jobs=n_jobs).fit(model_dataset[training_mask][out_mask][input_list], model_dataset[training_mask][out_mask][['eventsModel']].values.ravel())

# Save model
pickle.dump(predict_outs, open(os.path.join(model_path, "M03. Plate Appearances", outs_filename), 'wb'))
# Out:
# 20663
# predict_out_10_20250221.sav
# Iteration 1, loss = 2.09786386
# Validation score: 0.257647
# Iteration 2, loss = 1.75908311
# Validation score: 0.305242
# Iteration 3, loss = 1.62451865
# Validation score: 0.330209
# Iteration 4, loss = 1.55023210
# Validation score: 0.344262
# Iteration 5, loss = 1.51055289
# Validation score: 0.351010
# Iteration 6, loss = 1.48954919
# Validation score: 0.354620
# Iteration 7, loss = 1.47643320
# Validation score: 0.357373
# Iteration 8, loss = 1.46720375
# Validation score: 0.360426
# Iteration 9, loss = 1.46040791
# Validation score: 0.362723
# Iteration 10, loss = 1.45518848
# Validation score: 0.365505
# Iteration 11, loss = 1.45101782
# Validation score: 0.368188
# Iteration 12, loss = 1.44761999
# Validation score: 0.369557
# Iteration 13, loss = 1.44475485
# Validation score: 0.371911
# Iteration 14, loss = 1.44234399
# Validation score: 0.373252
# Iteration 15, loss = 1.44026695
# Validation score: 0.374294
# Iteration 16, loss = 1.43845294
# Validation score: 0.375407
# Iteration 17, loss = 1.43686480
# Validation score: 0.376263
# Iteration 18, loss = 1.43549578
# Validation score: 0.376919
# Iteration 19, loss = 1.43419535
# Validation score: 0.378231
# Iteration 20, loss = 1.43298778
# Validation score: 0.379601
# Iteration 21, loss = 1.43187300
# Validation score: 0.380771
# Iteration 22, loss = 1.43081818
# Validation score: 0.381384
# Iteration 23, loss = 1.42987902
# Validation score: 0.381784
# Iteration 24, loss = 1.42901211
# Validation score: 0.382026
# Iteration 25, loss = 1.42820090
# Validation score: 0.382925
# Iteration 26, loss = 1.42747727
# Validation score: 0.383425
# Iteration 27, loss = 1.42684042
# Validation score: 0.383097
# Iteration 28, loss = 1.42620871
# Validation score: 0.383311
# Iteration 29, loss = 1.42562115
# Validation score: 0.384138
# Iteration 30, loss = 1.42507409
# Validation score: 0.384366
# Iteration 31, loss = 1.42457655
# Validation score: 0.384452
# Iteration 32, loss = 1.42408060
# Validation score: 0.385122
# Iteration 33, loss = 1.42363627
# Validation score: 0.385351
# Iteration 34, loss = 1.42319788
# Validation score: 0.385779
# Iteration 35, loss = 1.42277948
# Validation score: 0.386121
# Iteration 36, loss = 1.42240831
# Validation score: 0.386506
# Iteration 37, loss = 1.42204123
# Validation score: 0.386435
# Iteration 38, loss = 1.42169048
# Validation score: 0.387020
# Iteration 39, loss = 1.42136719
# Validation score: 0.387191
# Iteration 40, loss = 1.42105376
# Validation score: 0.387262
# Iteration 41, loss = 1.42075147
# Validation score: 0.387733
# Iteration 42, loss = 1.42046792
# Validation score: 0.388004
# Iteration 43, loss = 1.42016991
# Validation score: 0.388290
# Iteration 44, loss = 1.41991615
# Validation score: 0.388318
# Iteration 45, loss = 1.41963146
# Validation score: 0.388076
# Iteration 46, loss = 1.41938540
# Validation score: 0.388218
# Iteration 47, loss = 1.41911906
# Validation score: 0.388760
# Iteration 48, loss = 1.41888703
# Validation score: 0.389288
# Iteration 49, loss = 1.41863895
# Validation score: 0.388447
# Iteration 50, loss = 1.41840068
# Validation score: 0.389074
# Iteration 51, loss = 1.41818365
# Validation score: 0.389331
# Iteration 52, loss = 1.41795086
# Validation score: 0.389260
# Iteration 53, loss = 1.41771126
# Validation score: 0.389674
# Iteration 54, loss = 1.41751059
# Validation score: 0.389802
# Iteration 55, loss = 1.41728805
# Validation score: 0.389773
# Iteration 56, loss = 1.41707239
# Validation score: 0.390059
# Iteration 57, loss = 1.41688082
# Validation score: 0.390230
# Iteration 58, loss = 1.41666745
# Validation score: 0.390501
# Iteration 59, loss = 1.41647951
# Validation score: 0.390658
# Iteration 60, loss = 1.41627269
# Validation score: 0.390958
# Iteration 61, loss = 1.41608662
# Validation score: 0.391243
# Iteration 62, loss = 1.41588424
# Validation score: 0.391400
# Iteration 63, loss = 1.41569086
# Validation score: 0.391771
# Iteration 64, loss = 1.41551003
# Validation score: 0.391799
# Iteration 65, loss = 1.41530417
# Validation score: 0.391799
# Iteration 66, loss = 1.41514307
# Validation score: 0.392042
# Iteration 67, loss = 1.41493910
# Validation score: 0.392042
# Iteration 68, loss = 1.41476484
# Validation score: 0.392127
# Iteration 69, loss = 1.41460841
# Validation score: 0.392270
# Iteration 70, loss = 1.41444185
# Validation score: 0.392584
# Iteration 71, loss = 1.41425442
# Validation score: 0.392670
# Iteration 72, loss = 1.41410695
# Validation score: 0.392498
# Iteration 73, loss = 1.41396641
# Validation score: 0.392627
# Iteration 74, loss = 1.41378295
# Validation score: 0.392513
# Iteration 75, loss = 1.41367236
# Validation score: 0.392855
# Iteration 76, loss = 1.41350577
# Validation score: 0.392969
# Iteration 77, loss = 1.41335376
# Validation score: 0.393183
# Iteration 78, loss = 1.41320476
# Validation score: 0.393526
# Iteration 79, loss = 1.41307568
# Validation score: 0.393440
# Iteration 80, loss = 1.41292846
# Validation score: 0.393383
# Iteration 81, loss = 1.41277118
# Validation score: 0.393497
# Iteration 82, loss = 1.41263622
# Validation score: 0.393568
# Iteration 83, loss = 1.41248764
# Validation score: 0.393554
# Iteration 84, loss = 1.41235709
# Validation score: 0.394182
# Iteration 85, loss = 1.41222573
# Validation score: 0.394596
# Iteration 86, loss = 1.41210806
# Validation score: 0.394139
# Iteration 87, loss = 1.41198640
# Validation score: 0.394667
# Iteration 88, loss = 1.41184443
# Validation score: 0.394610
# Iteration 89, loss = 1.41171860
# Validation score: 0.394453
# Iteration 90, loss = 1.41157757
# Validation score: 0.394325
# Iteration 91, loss = 1.41147093
# Validation score: 0.394596
# Iteration 92, loss = 1.41133748
# Validation score: 0.394838
# Iteration 93, loss = 1.41121934
# Validation score: 0.394738
# Iteration 94, loss = 1.41111485
# Validation score: 0.394867
# Iteration 95, loss = 1.41100096
# Validation score: 0.394838
# Iteration 96, loss = 1.41090369
# Validation score: 0.394681
# Iteration 97, loss = 1.41080506
# Validation score: 0.395009
# Iteration 98, loss = 1.41069639
# Validation score: 0.394952
# Iteration 99, loss = 1.41059734
# Validation score: 0.395480
# Iteration 100, loss = 1.41049543
# Validation score: 0.395452
# Iteration 101, loss = 1.41040209
# Validation score: 0.395494
# Iteration 102, loss = 1.41032127
# Validation score: 0.395766
# Iteration 103, loss = 1.41023746
# Validation score: 0.395523
# Iteration 104, loss = 1.41015212
# Validation score: 0.395537
# Iteration 105, loss = 1.41007063
# Validation score: 0.395152
# Iteration 106, loss = 1.40996373
# Validation score: 0.395523
# Iteration 107, loss = 1.40989099
# Validation score: 0.395666
# Iteration 108, loss = 1.40982868
# Validation score: 0.395951
# Iteration 109, loss = 1.40977305
# Validation score: 0.395865
# Iteration 110, loss = 1.40965232
# Validation score: 0.395708
# Iteration 111, loss = 1.40960597
# Validation score: 0.395766
# Iteration 112, loss = 1.40952197
# Validation score: 0.395865
# Iteration 113, loss = 1.40947169
# Validation score: 0.396236
# Iteration 114, loss = 1.40938677
# Validation score: 0.396279
# Iteration 115, loss = 1.40931009
# Validation score: 0.396022
# Iteration 116, loss = 1.40924667
# Validation score: 0.396351
# Iteration 117, loss = 1.40919776
# Validation score: 0.396393
# Iteration 118, loss = 1.40912370
# Validation score: 0.396222
# Iteration 119, loss = 1.40904931
# Validation score: 0.396736
# Iteration 120, loss = 1.40898356
# Validation score: 0.396322
# Iteration 121, loss = 1.40891435
# Validation score: 0.396037
# Iteration 122, loss = 1.40884900
# Validation score: 0.396165
# Iteration 123, loss = 1.40878988
# Validation score: 0.396265
# Iteration 124, loss = 1.40874127
# Validation score: 0.396393
# Iteration 125, loss = 1.40867298
# Validation score: 0.396408
# Iteration 126, loss = 1.40861803
# Validation score: 0.396507
# Iteration 127, loss = 1.40853471
# Validation score: 0.396408
# Iteration 128, loss = 1.40848443
# Validation score: 0.396194
# Iteration 129, loss = 1.40845892
# Validation score: 0.396750
# Iteration 130, loss = 1.40839182
# Validation score: 0.397092
# Iteration 131, loss = 1.40832325
# Validation score: 0.396907
# Iteration 132, loss = 1.40828714
# Validation score: 0.397021
# Iteration 133, loss = 1.40823264
# Validation score: 0.397207
# Iteration 134, loss = 1.40818278
# Validation score: 0.397078
# Iteration 135, loss = 1.40813614
# Validation score: 0.397207
# Iteration 136, loss = 1.40807505
# Validation score: 0.397178
# Iteration 137, loss = 1.40802461
# Validation score: 0.397164
# Iteration 138, loss = 1.40799632
# Validation score: 0.396793
# Iteration 139, loss = 1.40794138
# Validation score: 0.396636
# Iteration 140, loss = 1.40789582
# Validation score: 0.397463
# Iteration 141, loss = 1.40783878
# Validation score: 0.396650
# Iteration 142, loss = 1.40780455
# Validation score: 0.396793
# Iteration 143, loss = 1.40774587
# Validation score: 0.397791
# Iteration 144, loss = 1.40770926
# Validation score: 0.397649
# Iteration 145, loss = 1.40766111
# Validation score: 0.396921
# Iteration 146, loss = 1.40762716
# Validation score: 0.397335
# Iteration 147, loss = 1.40757108
# Validation score: 0.397149
# Iteration 148, loss = 1.40753260
# Validation score: 0.397849
# Iteration 149, loss = 1.40748077
# Validation score: 0.397292
# Iteration 150, loss = 1.40743665
# Validation score: 0.397506
# Iteration 151, loss = 1.40739026
# Validation score: 0.397549
# Iteration 152, loss = 1.40733580
# Validation score: 0.397392
# Iteration 153, loss = 1.40728830
# Validation score: 0.397592
# Iteration 154, loss = 1.40722964
# Validation score: 0.397806
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# CPU times: total: 25min 35s
# Wall time: 3min 17s

# %%
# Predict out types
outs_outputs = list(predict_outs.classes_)
outs_outputs_pred = [x + "_pred" for x in outs_outputs]

model_dataset.loc[~training_mask & out_mask, outs_outputs_pred] = predict_outs.predict_proba(model_dataset[~training_mask][out_mask][input_list])

# %%
outs_outputs_pred
# Out:
# ['fo_pred', 'go_pred', 'lo_pred', 'po_pred', 'so_pred']

# %%
# Create deciles
for var in outs_outputs:
    # Create actual outcome column
    model_dataset.loc[~training_mask & out_mask, f'{var}_act'] = (model_dataset.loc[~training_mask & out_mask, 'eventsModel'] == var).astype(int)
    
    # Create deciles
    model_dataset.loc[~training_mask & out_mask, f'{var}_decile'] = pd.qcut(model_dataset.loc[~training_mask & out_mask, f'{var}_pred'], 10, labels=False)
    
    # Create aggregated dataframe
    globals()[f"{var}_df"] = model_dataset.loc[~training_mask & out_mask].groupby(f'{var}_decile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()
    # globals()[f"{var}_df"] = testing_dataset.query('year >= 2022').loc[mask].groupby(f'{var}_decile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()
    # globals()[f"{var}_df"] = testing_dataset.query('venue_id == 19').loc[mask].groupby(f'{var}_decile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()

# %%
# Create figures
fig, axs = plt.subplots(2, 3, figsize=(12, 8))

for i, var in enumerate(outs_outputs):
    row = i // 3  # Calculate the row index based on the iteration
    col = i % 3   # Calculate the column index based on the iteration
    axs[row, col].plot(globals()[f"{var}_df"][f'{var}_decile'], globals()[f"{var}_df"][f'{var}_pred'], color='red')
    axs[row, col].plot(globals()[f"{var}_df"][f'{var}_decile'], globals()[f"{var}_df"][f'{var}_act'], color='black')
    axs[row, col].set_title(var)
    # axs[row, col].set_ylim(0,0.35)


# Add some space between subplots to prevent overlapping
fig.tight_layout(pad=.0)

# Show the figure
plt.show()

# %% [markdown]
# ### Safe

# %%
# %%time
# Neural network layers
# layers = (174,174,174,174)
layers = (10,)
# layers = (198,198,198,198,198,198)
# layers = (196,196,196,196,196)
# To string
layers_str = ''.join(str(x) for x in layers)
# Activation method
activation = 'relu'
# Iterations
iters = 100
# Alpha
alpha = 0.0001
# Learning Rate
learning_rate = 0.00001
# Batch Size
batch_size='auto'
# batch_size=32
# Random state
random_state = 10
# Number of models
num_models = 3

safe_filename = f"predict_safe_{layers_str}_{todaysdate}.sav"
print(safe_filename)



# Define the individual models in the ensemble
models = [
    MLPClassifier(hidden_layer_sizes=layers, activation=activation, verbose=True, alpha=alpha, learning_rate_init=learning_rate, early_stopping=True, random_state=random_state+i, max_iter=iters, batch_size=batch_size)
    for i in range(num_models)
]

# Create the ensemble classifier using VotingClassifier
predict_safe = VotingClassifier(estimators=[('model'+str(i+1), model) for i, model in enumerate(models)], voting='soft', n_jobs=-2).fit(model_dataset[training_safe_mask][input_list], model_dataset[training_safe_mask][['eventsModel']].values.ravel())

# Save model
pickle.dump(predict_safe, open(os.path.join(model_path, "M03. Plate Appearances", safe_filename), 'wb'))
# Out:
# predict_safe_10_20250221.sav
# CPU times: total: 2.08 s
# Wall time: 1min 25s

# %%
# Predict safe types
safe_outputs = list(predict_safe.classes_)
safe_outputs_pred = [x + "_pred" for x in safe_outputs]

model_dataset.loc[testing_safe_mask, safe_outputs_pred] = predict_safe.predict_proba(model_dataset[testing_safe_mask][input_list])

# %%
# Create deciles
for var in safe_outputs:    
    # Create actual outcome column
    model_dataset.loc[testing_safe_mask, f'{var}_act'] = (model_dataset.loc[testing_safe_mask, 'eventsModel'] == var).astype(int)
    
    # Create deciles
    model_dataset.loc[testing_safe_mask, f'{var}_decile'] = pd.qcut(model_dataset.loc[testing_safe_mask, f'{var}_pred'], 10, labels=False)
    
    # Create aggregated dataframe
    globals()[f"{var}_df"] = model_dataset.loc[testing_safe_mask].groupby(f'{var}_decile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()
    globals()[f"{var}_df"] = model_dataset.query('year >= 2022').loc[testing_safe_mask].groupby(f'{var}_decile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()
    # globals()[f"{var}_df"] = model_dataset.query('venue_id == 19').loc[testing_safe_mask].groupby(f'{var}_decile')[[f'{var}_act', f'{var}_pred']].mean().reset_index()

# %%
# Create figures
fig, axs = plt.subplots(2, 3, figsize=(12, 8))

for i, var in enumerate(safe_outputs):
    row = i // 3  # Calculate the row index based on the iteration
    col = i % 3   # Calculate the column index based on the iteration
    axs[row, col].plot(globals()[f"{var}_df"][f'{var}_decile'], globals()[f"{var}_df"][f'{var}_act'], color='black')
    axs[row, col].plot(globals()[f"{var}_df"][f'{var}_decile'], globals()[f"{var}_df"][f'{var}_pred'], color='red')
    axs[row, col].set_title(var)
    # axs[row, col].set_ylim(globals()[df_name][f'{var}_act'].min(),globals()[df_name][f'{var}_act'].max())
    

# Add some space between subplots to prevent overlapping
fig.tight_layout(pad=.0)

# Show the figure
plt.show()
