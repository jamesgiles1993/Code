# %% [markdown]
# # A. Morning Dashboard
# - Date: 3/23/2024
# - Description: This runs every morning to gather time-insensitive data:
#     - DraftKings upcoming contests, salaries, and previous results
#     - Stats API and Statcast
#     - Steamer

# %% [markdown]
# ### Imports

# %%
# %run "C:\Users\james\Documents\MLB\Code\U1. Imports.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U2. Utilities.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U3. Classes.ipynb"

# %% [markdown]
# ### A01. DraftKings

# %%
# %run "C:\Users\james\Documents\MLB\Code\A01. DraftKings.ipynb"

# %% [markdown]
# ##### 1. Contests

# %%
# Scrape contests
contest_df = contests(todaysdate)
# To csv
contest_df.to_csv(os.path.join(baseball_path, 'A01. DraftKings', '1. Contests', f'Contests {todaysdate}.csv'), index=False)

# %% [markdown]
# ##### 7. Subsets

# %%
# Select subset
subset_df = create_subset(contest_df, contests_per_draftGroupId=5, entry_fee_max=100, added_contestKeys=[], date_dash=todaysdate_dash)
subset_df.reset_index(drop=True, inplace=True)

# Save subset
subset_df.to_csv(os.path.join(baseball_path, "A01. DraftKings", "7. Subsets", f'Subset {todaysdate}.csv'), index=False)

# %% [markdown]
# ##### 2. Draftables

# %%
# %%time
# Loop over contests of interest
for draftGroupId in list(subset_df['draftGroupId'].unique()):
    print(draftGroupId)
    try:
        # Scrape draftables (DK Salaries)
        draftable_df = draftables(draftGroupId)
        # To csv
        draftable_df.to_csv(os.path.join(baseball_path, "A01. DraftKings", "2. Draftables", f"Draftables {draftGroupId}.csv"), index=False, encoding='iso-8859-1')
        print(f"Saved {draftGroupId}")
    except:
        print(f"Didn't save {draftGroupId}")
# Out:
# 107744
# Saved 107744
# 107737
# Didn't save 107737
# 107736
# Saved 107736
# 107734
# Didn't save 107734
# 107733
# Didn't save 107733
# 107730
# Didn't save 107730
# 107729
# Didn't save 107729
# 107728
# Saved 107728
# 107727
# Didn't save 107727
# 107411
# Saved 107411
# CPU times: total: 2.58 s
# Wall time: 4.84 s

# %% [markdown]
# ##### 3. Payouts

# %%
# %%time
# Loop over contests of interest
for i in range(len(subset_df)):
    # Extract contestKey
    contestKey = subset_df['contestKey'][i]
    try:
        # Scrape payouts
        payout_df = payouts(contestKey)
        # To csv
        payout_df.to_csv(os.path.join(baseball_path, "A01. DraftKings", "3. Payouts", f"Payouts {contestKey}.csv"), index=False, encoding='iso-8859-1')
    except:
        print(f"Didn't save {contestKey}.")
# Out:
# CPU times: total: 9.36 s
# Wall time: 17.1 s

# %% [markdown]
# ##### 4. Results, 5. Entry Results, and 6. Player Results

# %% [markdown]
# Note: This will break if there were no games yesterday.

# %%
# Read in yesterdays subset
yesterdays_subset_df = pd.read_csv(os.path.join(baseball_path, 'A01. DraftKings', '7. Subsets', f'Subset {yesterdaysdate}.csv'))

# %%
# Loop over yesterday's contests
for i in range(len(yesterdays_subset_df)):
    # Extract contestKey
    contestKey = yesterdays_subset_df['contestKey'][i]
    print(contestKey)
    # Scrape results
    results(contestKey, sleep_time=5)

    try:        
        # Read into pandas
        results_df = pd.read_csv(os.path.join(baseball_path, "A01. DraftKings", "4. Results", f"contest-standings-{contestKey}.csv"))
        
        # Entry results
        entry_results_df = entry_results(results_df)
        entry_results_df.to_csv(os.path.join(baseball_path, "A01. DraftKings", "5. Entry Results", f"Entry Results {contestKey}.csv"), index=False, encoding='iso-8859-1')
    
        # Player results
        player_results_df = player_results(results_df)
        player_results_df.to_csv(os.path.join(baseball_path, "A01. DraftKings", "6. Player Results", f"Player Results {contestKey}.csv"), index=False, encoding='iso-8859-1')
    except IndexError as e:
        print(f"Downloaded contest-standings-{contestKey}. Non-traditional format.")
    except pd.errors.EmptyDataError as e:
        print(f"Downloaded contest-standings-{contestKey}. Empty file.")
    except FileNotFoundError as e:
        print(f"Couldn't find {contestKey}.")
# Out:
# 162173693
# contest-standings-162173693
# ['contest-standings-162173693.zip']
# C:\Users\james\Downloads\contest-standings-162173693.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162173693. Non-traditional format.
# 162172896
# contest-standings-162172896
# ['contest-standings-162172896.zip']
# C:\Users\james\Downloads\contest-standings-162172896.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162172896. Non-traditional format.
# 162178381
# contest-standings-162178381
# ['contest-standings-162178381.zip']
# C:\Users\james\Downloads\contest-standings-162178381.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162178381. Non-traditional format.
# 162172802
# contest-standings-162172802
# ['contest-standings-162172802.csv']
# C:\Users\james\Downloads\contest-standings-162172802.csv
# File copied successfully!
# Downloaded contest-standings-162172802. Empty file.
# 162172801
# contest-standings-162172801
# ['contest-standings-162172801.csv']
# C:\Users\james\Downloads\contest-standings-162172801.csv
# File copied successfully!
# Downloaded contest-standings-162172801. Non-traditional format.
# 162172800
# contest-standings-162172800
# ['contest-standings-162172800.csv']
# C:\Users\james\Downloads\contest-standings-162172800.csv
# File copied successfully!
# Downloaded contest-standings-162172800. Empty file.
# 162172797
# contest-standings-162172797
# ['contest-standings-162172797.csv']
# C:\Users\james\Downloads\contest-standings-162172797.csv
# File copied successfully!
# Downloaded contest-standings-162172797. Non-traditional format.
# 162172799
# contest-standings-162172799
# ['contest-standings-162172799.csv']
# C:\Users\james\Downloads\contest-standings-162172799.csv
# File copied successfully!
# Downloaded contest-standings-162172799. Non-traditional format.
# 162173680
# contest-standings-162173680
# ['contest-standings-162173680.zip']
# C:\Users\james\Downloads\contest-standings-162173680.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162173680. Non-traditional format.
# 162173681
# contest-standings-162173681
# ['contest-standings-162173681.zip']
# C:\Users\james\Downloads\contest-standings-162173681.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162173681. Non-traditional format.
# 162172527
# contest-standings-162172527
# ['contest-standings-162172527.csv']
# C:\Users\james\Downloads\contest-standings-162172527.csv
# File copied successfully!
# Downloaded contest-standings-162172527. Empty file.
# 162171939
# contest-standings-162171939
# ['contest-standings-162171939.csv']
# C:\Users\james\Downloads\contest-standings-162171939.csv
# File copied successfully!
# Downloaded contest-standings-162171939. Non-traditional format.
# 162171945
# contest-standings-162171945
# ['contest-standings-162171945.csv']
# C:\Users\james\Downloads\contest-standings-162171945.csv
# File copied successfully!
# Downloaded contest-standings-162171945. Non-traditional format.
# 162173672
# contest-standings-162173672
# ['contest-standings-162173672.zip']
# C:\Users\james\Downloads\contest-standings-162173672.zip
# Zip file unpacked successfully!
# 162173663
# contest-standings-162173663
# ['contest-standings-162173663.zip']
# C:\Users\james\Downloads\contest-standings-162173663.zip
# Zip file unpacked successfully!
# 162173673
# contest-standings-162173673
# ['contest-standings-162173673.zip']
# C:\Users\james\Downloads\contest-standings-162173673.zip
# Zip file unpacked successfully!
# 162173671
# contest-standings-162173671
# ['contest-standings-162173671.zip']
# C:\Users\james\Downloads\contest-standings-162173671.zip
# Zip file unpacked successfully!
# 162173661
# contest-standings-162173661
# ['contest-standings-162173661.csv']
# C:\Users\james\Downloads\contest-standings-162173661.csv
# File copied successfully!
# 162173656
# contest-standings-162173656
# ['contest-standings-162173656.zip']
# C:\Users\james\Downloads\contest-standings-162173656.zip
# Zip file unpacked successfully!
# 162173660
# contest-standings-162173660
# ['contest-standings-162173660.zip']
# C:\Users\james\Downloads\contest-standings-162173660.zip
# Zip file unpacked successfully!
# 162171916
# contest-standings-162171916
# ['contest-standings-162171916.csv']
# C:\Users\james\Downloads\contest-standings-162171916.csv
# File copied successfully!
# 162172437
# contest-standings-162172437
# ['contest-standings-162172437.csv']
# C:\Users\james\Downloads\contest-standings-162172437.csv
# File copied successfully!
# Downloaded contest-standings-162172437. Empty file.
# 162173652
# contest-standings-162173652
# ['contest-standings-162173652.zip']
# C:\Users\james\Downloads\contest-standings-162173652.zip
# Zip file unpacked successfully!
# 162172776
# contest-standings-162172776
# ['contest-standings-162172776.csv']
# C:\Users\james\Downloads\contest-standings-162172776.csv
# File copied successfully!
# Downloaded contest-standings-162172776. Empty file.
# 162172775
# contest-standings-162172775
# ['contest-standings-162172775.csv']
# C:\Users\james\Downloads\contest-standings-162172775.csv
# File copied successfully!
# Downloaded contest-standings-162172775. Non-traditional format.
# 162172772
# contest-standings-162172772
# ['contest-standings-162172772.csv']
# C:\Users\james\Downloads\contest-standings-162172772.csv
# File copied successfully!
# Downloaded contest-standings-162172772. Non-traditional format.
# 162172774
# contest-standings-162172774
# ['contest-standings-162172774.csv']
# C:\Users\james\Downloads\contest-standings-162172774.csv
# File copied successfully!
# Downloaded contest-standings-162172774. Non-traditional format.
# 162172773
# contest-standings-162172773
# ['contest-standings-162172773.csv']
# C:\Users\james\Downloads\contest-standings-162172773.csv
# File copied successfully!
# Downloaded contest-standings-162172773. Non-traditional format.
# 162173640
# contest-standings-162173640
# ['contest-standings-162173640.zip']
# C:\Users\james\Downloads\contest-standings-162173640.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162173640. Non-traditional format.
# 162173642
# contest-standings-162173642
# ['contest-standings-162173642.zip']
# C:\Users\james\Downloads\contest-standings-162173642.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162173642. Non-traditional format.
# 162173643
# contest-standings-162173643
# ['contest-standings-162173643.zip']
# C:\Users\james\Downloads\contest-standings-162173643.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162173643. Non-traditional format.
# 162173636
# contest-standings-162173636
# ['contest-standings-162173636.csv']
# C:\Users\james\Downloads\contest-standings-162173636.csv
# File copied successfully!
# Downloaded contest-standings-162173636. Non-traditional format.
# 162172257
# contest-standings-162172257
# ['contest-standings-162172257.csv']
# C:\Users\james\Downloads\contest-standings-162172257.csv
# File copied successfully!
# Downloaded contest-standings-162172257. Empty file.
# 162173598
# contest-standings-162173598
# ['contest-standings-162173598.zip']
# C:\Users\james\Downloads\contest-standings-162173598.zip
# Zip file unpacked successfully!
# 162173601
# contest-standings-162173601
# ['contest-standings-162173601.zip']
# C:\Users\james\Downloads\contest-standings-162173601.zip
# Zip file unpacked successfully!
# 162173596
# contest-standings-162173596
# ['contest-standings-162173596.zip']
# C:\Users\james\Downloads\contest-standings-162173596.zip
# Zip file unpacked successfully!
# 162173597
# contest-standings-162173597
# ['contest-standings-162173597.zip']
# C:\Users\james\Downloads\contest-standings-162173597.zip
# Zip file unpacked successfully!
# 162173604
# contest-standings-162173604
# ['contest-standings-162173604.zip']
# C:\Users\james\Downloads\contest-standings-162173604.zip
# Zip file unpacked successfully!
# 162173600
# contest-standings-162173600
# ['contest-standings-162173600.zip']
# C:\Users\james\Downloads\contest-standings-162173600.zip
# Zip file unpacked successfully!

# %% [markdown]
# ### A02. MLB API

# %%
# %run "C:\Users\james\Documents\MLB\Code\A02. MLB API.ipynb"

# %% [markdown]
# ##### 1. Stats API

# %%
statsapi_df = plays_statsapi("03/20/2024", "11/15/2024")
statsapi_df.to_csv(os.path.join(baseball_path, "A02. MLB API", "1. Stats API", "Stats API 2024.csv"), index=False, encoding='iso-8859-1')

del statsapi_df

# %% [markdown]
# ##### 2. Statcast

# %%
statcast_df = plays_statcast("2024-03-20", "2024-11-15")
statcast_df.to_csv(os.path.join(baseball_path, "A02. MLB API", "2. Statcast", "Statcast 2024.csv"), index=False, encoding='iso-8859-1')

del statcast_df
# Out:
# This is a large query, it may take a moment to complete
# 100%|██████████| 241/241 [03:49<00:00,  1.05it/s]

# %% [markdown]
# ### A03. Steamer

# %%
# %run "C:\Users\james\Documents\MLB\Code\A03. Steamer.ipynb"

# %%
download_steamer()

# %%
move_steamer()
# Out:
# Moved 'C:\Users\james\Downloads\steamer_pitchers_weekly_log.csv' to 'C:\Users\james\Documents\MLB\Database\A03. Steamer'.
# Moved 'C:\Users\james\Downloads\steamer_hitters_weekly_log.csv' to 'C:\Users\james\Documents\MLB\Database\A03. Steamer'.
# Moved 'C:\Users\james\Downloads\steamer_pitchers.csv' to 'C:\Users\james\Documents\MLB\Database\A03. Steamer'.
# Moved 'C:\Users\james\Downloads\steamer_hitters.csv' to 'C:\Users\james\Documents\MLB\Database\A03. Steamer'.

# %% [markdown]
# ### A07. Projections

# %%
# %run "C:\Users\james\Documents\MLB\Code\A07. Projections.ipynb"

# %%
# Scrape slates
dff_slates_df = dff_slates(todaysdate)
# To csv
dff_slates_df.to_csv(os.path.join(baseball_path, "A07. Projections", "1. DFF", "1. Slates", f"DFF Slates {todaysdate}.csv"), index=False)

# %%
# Scrape slates
roto_slates_df = roto_slates(todaysdate)
# To csv
roto_slates_df.to_csv(os.path.join(baseball_path, "A07. Projections", "2. RotoWire", "1. Slates", f"RotoWire Slates {todaysdate}.csv"), index=False)
