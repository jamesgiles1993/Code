# %% [markdown]
# # B. Sim Dashboard

# %% [markdown]
# ### Imports

# %%
# %run "C:\Users\james\Documents\MLB\Code\U1. Imports.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U2. Utilities.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U3. Classes.ipynb"

# %%
# # Schedule
# pause_code(start_time='2024-04-04T15:00:00', timezone='EST')

# %%
# %run "A. Night Dashboard.ipynb"
# Out:
# Running Night Dashboard
# CPU times: total: 0 ns
# Wall time: 2min 54s
# CPU times: total: 203 ms
# Wall time: 1min 4s
# CPU times: total: 31.2 ms
# Wall time: 3.9 s
# 19A01
# 19A04
# 19A05
# 19A07
# 19A06
# 19A09
# 19AFE
# 19A0E
# 19A0F
# 19A10
# No data found in API response.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_18564\33358245.py:6
#       4 roto_projections_df = roto_projections(todaysdate, code)
#       5 # To csv
# ----> 6 roto_projections_df.to_csv(os.path.join(baseball_path, "A07. Projections", "2. RotoWire", "2. Projections", f"RotoWire Projections {code}.csv"), index=False)
#
# AttributeError: 'NoneType' object has no attribute 'to_csv'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 get_ipython().run_line_magic('run', '"A. Night Dashboard.ipynb"')
#
# File ~\anaconda3\envs\MLB\lib\site-packages\IPython\core\interactiveshell.py:2432, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2430     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2431 with self.builtin_trap:
# -> 2432     result = fn(*args, **kwargs)
#    2434 # The code below prevents the output from being displayed
#    2435 # when using magics with decorator @output_can_be_silenced
#    2436 # when the last Python token in the expression is a ';'.
#    2437 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\envs\MLB\lib\site-packages\IPython\core\magics\execution.py:737, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     735     with preserve_keys(self.shell.user_ns, '__file__'):
#     736         self.shell.user_ns['__file__'] = filename
# --> 737         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     738     return
#     740 # Control the response to exit() calls made by the script being run
#
# File ~\anaconda3\envs\MLB\lib\site-packages\IPython\core\interactiveshell.py:2954, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2952 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2953 if raise_exceptions:
# -> 2954     result.raise_error()
#    2955 elif not result.success:
#    2956     break
#
# File ~\anaconda3\envs\MLB\lib\site-packages\IPython\core\interactiveshell.py:270, in ExecutionResult.raise_error(self)
#     268     raise self.error_before_exec
#     269 if self.error_in_exec is not None:
# --> 270     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Temp\ipykernel_18564\33358245.py:6
#       4 roto_projections_df = roto_projections(todaysdate, code)
#       5 # To csv
# ----> 6 roto_projections_df.to_csv(os.path.join(baseball_path, "A07. Projections", "2. RotoWire", "2. Projections", f"RotoWire Projections {code}.csv"), index=False)
#
# AttributeError: 'NoneType' object has no attribute 'to_csv'

# %% [markdown]
# ### Directory

# %%
baseball_path = r'C:\Users\james\Documents\MLB\Database'

# %% [markdown]
# ### Contest

# %%
# Read in subset of contests for which we'll create guides
subset_df = pd.read_csv(os.path.join(baseball_path, 'A01. DraftKings', '7. Subsets', f'Subset {todaysdate}.csv'))
four_seamer_df = subset_df[subset_df['Name'].str.contains('eamer')].sort_values('contestTime').reset_index(drop=True)
four_seamer_df
# Out:
#                                           Name  Cash Prize  Entry Fee  \
# 0  MLB $20K Four-Seamer [20 Entry Max] (Early)     20000.0        4.0
# 1              MLB $2K Four-Seamer (Afternoon)      2000.0        4.0
# 2                 MLB $500 Four-Seamer (Turbo)       500.0        4.0
# 3          MLB $10K Four-Seamer [20 Entry Max]     10000.0        4.0
# 4                  MLB $1K Four-Seamer (Night)      1000.0        4.0
#
#    contestKey  draftGroupId          contestDate contestTime      date  \
# 0   160731260        104961  2024-04-20 13:05:00  Sat 1:05PM  20240420
# 1   160731308        104966  2024-04-20 16:05:00  Sat 4:05PM  20240420
# 2   160731330        104969  2024-04-20 18:05:00  Sat 6:05PM  20240420
# 3   160734587        105214  2024-04-20 19:10:00  Sat 7:10PM  20240420
# 4   160731360        104975  2024-04-20 20:10:00  Sat 8:10PM  20240420
#
#     date_dash
# 0  2024-04-20
# 1  2024-04-20
# 2  2024-04-20
# 3  2024-04-20
# 4  2024-04-20

# %%
# Set contestKey
contestKey = four_seamer_df['contestKey'][0]

# Read in Contest Guide
guide = pd.read_csv(os.path.join(baseball_path, "A09. Contest Guides", f"Contest Guide {contestKey}.csv"))

# Identify draftGroupId
draftGroupId = guide['draftGroupId'][0]

# Identify RotoWire slate
roto_slate = guide['roto_slate'][0]

# Print out name
print(f"Date: {guide['date'][0]}. Slate: {guide['slate'][0]}. {guide['name'][0]}. {roto_slate}.")
# Out:
# Date: 20240419. Slate: All. MLB $20K Four-Seamer [20 Entry Max]. 14849.

# %% [markdown]
# ### Settings

# %%
# Recreate game_df
generate = True

# Run historic matchups
historic = False
# Run matchups necessary for slate
slate_only = True

# Run:
Matchups = True
Simulations = True
Optimizer = True

# %% [markdown]
# # Games

# %% [markdown]
# Select start and end date (should be todaysdate for both if running day-of)

# %%
# start_date = "20220924"
start_date = todaysdate
end_date = todaysdate

# %% [markdown]
# Read in games

# %%
game_df = read_and_save_games(team_map, generate)
game_df = game_df[(game_df['date'] >= start_date) & (game_df['date'] <= end_date)].reset_index(drop=True)

# %%
slate_df = game_df[game_df['game_id'].isin(guide['game_id'].unique())].reset_index(drop=True)

# %% [markdown]
# ### Weather

# %%
rotogrinders_df = pd.read_csv(os.path.join(baseball_path, "A06. Weather", "2. RotoGrinders", f"RotoGrinders {todaysdate}.csv"))
red_list = list(rotogrinders_df.query('Tag == "red" or Tag2 == "red"')['Away']) + list(rotogrinders_df.query('Tag == "red" or Tag2 == "red"')['Home'])
orange_list = list(rotogrinders_df.query('Tag == "orange" or Tag2 == "orange"')['Away']) + list(rotogrinders_df.query('Tag == "orange" or Tag2 == "orange"')['Home'])
rotogrinders_df[['Tag', 'Tag2', 'Away', 'Home', 'date', 'Description']]
# Out:
#      Tag  Tag2 Away Home      date  \
# 0  green   NaN  HOU  WSH  20240419
# 1  green   NaN  DET  MIN  20240419
# 2  green   NaN   TB  NYY  20240419
# 3    red   NaN  SEA  COL  20240419
#
#                                                                                                       Description
# 0                                            Could be a quick shower, but nothing which should cause a big issue.
# 1  Looks like the winds are blowing out with gusts to around 30 mph. That said, temps will likely be in the 40's.
# 2                                                          Models are hinting at a quick shower, but no big deal.
# 3                                                                                           Officially postponed.

# %% [markdown]
# ### B01. Matchups

# %%
# %run "C:\Users\james\Documents\MLB\Code\B01. Matchups.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\A02. MLB API.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\A03. Steamer.ipynb"

# %% [markdown]
# ##### Load
# This loads in datasets needed to create matchup files

# %%
# %%time
complete_dataset = pd.read_csv(os.path.join(baseball_path, "Stat Dataset.csv"))
steamer_hitters_df = pd.read_csv(os.path.join(baseball_path, "Steamer Hitters.csv"))
steamer_pitchers_df = pd.read_csv(os.path.join(baseball_path, "Steamer Pitchers.csv"))
# Out:
# CPU times: total: 12.4 s
# Wall time: 12.6 s

# %% [markdown]
# Create matchups <br>
# Why does this sometimes have pickling errors? Fixed by rerunning.

# %%
# %%time
try:
    print(len(game_df))
    empty_list = Parallel(n_jobs=-1, verbose=True)(delayed(create_matchup_files)(game_df, row, complete_dataset, steamer_hitters_df, steamer_pitchers_df, team_map) for row in range(len(game_df)))
except:
    print("Trying Again")
    empty_list = Parallel(n_jobs=-1, verbose=True)(delayed(create_matchup_files)(game_df, row, complete_dataset, steamer_hitters_df, steamer_pitchers_df, team_map) for row in range(len(game_df)))
# Out:
# 14
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  14 | elapsed:   41.1s finished
# CPU times: total: 28.7 s
# Wall time: 41.6 s

# %% [markdown]
# ### B02. Simulations

# %%
# %run "C:\Users\james\Documents\MLB\Code\B02. Simulations.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U1. Imports.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U3. Classes.ipynb"

# %%
historic, slate_only
# Out:
# (False, True)

# %%
num_batches = int(os.cpu_count() / 1)
batch_size = int(63 * 1)

# %%
if historic == False:
    # Openers
    draftables = pd.read_csv(os.path.join(baseball_path, "A01. DraftKings", "2. Draftables", f"Draftables {draftGroupId}.csv"), encoding='iso-8859-1')
    opener_list = list(draftables.query('Salary < 5000 and `Roster Position` == "P"')['Name'])
    print(f"Openers: {opener_list[:10]}")

    # Teams with Projected Lineups
    projected_lineups = pd.read_csv(os.path.join(baseball_path, "A05. Rosters", "3. Batting Orders Projected", f"Batting Orders Projected {todaysdate}.csv"))
    projected_teams = projected_lineups.merge(team_map[['SFBBTEAM', 'DKTEAM']], left_on=['team code'], right_on=['SFBBTEAM'], how='inner')
    projected_team_list = list(projected_teams.query('` confirmed` == "N"')['DKTEAM'].unique())
    print(f"Projected teams: {projected_team_list}")
else:
    opener_list = []
    projected_lineups = None
    projected_team_list = []
# Out:
# Openers: ['Brooks Wilson', 'Jose Corniell', 'Marc Church', 'Ken Giles', 'Carson Coleman', 'Scott Blewett', 'Jesús Tinoco', 'Anthony Vizcaya', 'Blake Taylor', 'Steven Jennings']
# Projected teams: ['SEA', 'TOR', 'SD', 'NYM', 'SF']

# %%
# Choose which games to run simulations for
if slate_only == True:
    # Just the slate
    run_df = slate_df.copy()
else:
    # All games
    run_df = game_df.copy()

# %%
# %%time
# Print out games to simulate
_ = [print(f"{row['away_team']}@{row['home_team']} {pd.to_datetime(row['game_datetime']).tz_convert('US/Eastern').strftime('%Y-%m-%d %H:%M:%S')}") for index, row in run_df.head(15).iterrows()]

# Loop over dates of interest
for date in list(run_df['date'].unique()):
    print(date)
    # Extract year
    year = date[:4]
    # Extract matchups
    matchup_list = [os.path.splitext(f)[0] for f in os.listdir(os.path.join(baseball_path, "B01. Matchups", f"Matchups {date}"))]
    
    # Loop over games
    daily_df = run_df.query(f'date == "{date}"').reset_index()
    print(daily_df.shape)
    for i in range(len(daily_df)):            
        # Extract info from run_df to look up proper file in matchups path
        away_team = daily_df['away_team'][i]
        home_team = daily_df['home_team'][i]
        game_id = daily_df['game_id'][i]
        # Beginning of filename in matchup folder
        lookup = f"{away_team}@{home_team} {game_id}"
        
        # Find the matchup file
        matchup = next((matchup for matchup in matchup_list if matchup.startswith(lookup)), None)
        print(matchup)
        
        # Create matchups
        matchup_path = os.path.join(baseball_path, "B01. Matchups", f"Matchups {date}", f"{matchup}.xlsx")
        AwayBatters, HomeBatters, AwayPitchers, HomePitchers = create_matchup(matchup_path, batter_stats_scaler, batter_stats_fg_scaler, batter_imputations_model, pitcher_stats_scaler, pitcher_stats_fg_scaler, pitcher_imputations_model, projected_lineups)
        
        # Create Scoreboard object
        game_template = Scoreboard(AwayBatters, HomeBatters, AwayPitchers, HomePitchers, 9)       
        
        ### Sim games
        # With batching (fast!)
        start = time.time()
        game_list = Parallel(n_jobs=num_batches, verbose=1)(delayed(sim_game_batch)(game_template, model_pulls, model_binary, model_outs, model_safe, opener_list, year, innings=9, debug=False, batch_size=batch_size) for batches in range(num_batches))
        game_list = [game for sublist in game_list for game in sublist]
        print(f"Simming {batch_size*num_batches} games took {time.time() - start} seconds.")
        
        # Without batching (slow!)
        # game_list = Parallel(n_jobs=16, verbose=0)(delayed(sim_game)(game_template, model_pulls, model_binary, model_outs, model_safe, opener_list, year, innings=9, debug=False) for sims in range(num_sims))
        
        # # Without joblib (slower!)
        # start = time.time()
        # game_list = []
        # for i in range(10):
        #     game = sim_game(game_template, model_pulls, model_binary, model_outs, model_safe, opener_list, year, innings=9, debug=True)
        #     game_list.append(game)
        # print(f"Simming {num_sims} games took {time.time() - start} seconds.")
        
        # Create object path
        game_path = os.path.join(baseball_path, "B02. Simulations", "1. Game Sims", f"Matchups {date}", f"{matchup}") 
        player_path = os.path.join(baseball_path, "B02. Simulations", "2. Player Sims", f"Matchups {date}", f"{matchup}") 
        # Clear folders
        if os.path.exists(game_path):
            shutil.rmtree(game_path)
        if os.path.exists(player_path):
            shutil.rmtree(player_path)
        # Make folders
        os.makedirs(game_path, exist_ok=True)
        os.makedirs(player_path, exist_ok=True)
        
        # Save each object in the list to a separate file
        for i, game_object in enumerate(game_list):
            # Delete unnecessary attributes from batter objects
            for batter in game_object.away_batters + game_object.home_batters:
                batter = batter.keep_selected_attributes()
            # Delete unnecessary attributes from pitcher objects
            for pitcher in game_object.away_pitchers + game_object.home_pitchers:
                pitcher = pitcher.keep_selected_attributes()
            # Delete unnecessary attributes from game objects
            game_object.keep_selected_attributes()

            # Constructing DataFrames for game, batters, and pitchers
            game_score_df = pd.DataFrame({
                "away_score": [game_object.away_score],
                "home_score": [game_object.home_score]
            })

            away_batters_df = pd.DataFrame([vars(batter) for batter in game_object.away_batters])
            away_batters_df['team'] = "away"
            home_batters_df = pd.DataFrame([vars(batter) for batter in game_object.home_batters])
            home_batters_df['team'] = "home"
            batters_df = pd.concat([away_batters_df, home_batters_df], axis=0)
            
            away_pitchers_df = pd.DataFrame([vars(pitcher) for pitcher in game_object.away_pitchers])
            away_pitchers_df['team'] = "away"
            home_pitchers_df = pd.DataFrame([vars(pitcher) for pitcher in game_object.home_pitchers])
            home_pitchers_df['team'] = "home"
            pitchers_df = pd.concat([away_pitchers_df, home_pitchers_df], axis=0)
            
            # Specify the file paths where you want to save the CSV files
            game_file_path = os.path.join(game_path, "game_{}.csv").format(i)
            batters_file_path = os.path.join(player_path, "batters_{}.csv").format(i)
            pitchers_file_path = os.path.join(player_path, "pitchers_{}.csv").format(i)

            # Saving DataFrames to CSV files
            game_score_df.to_csv(game_file_path, index=False)
            batters_df.to_csv(batters_file_path, index=False)
            pitchers_df.to_csv(pitchers_file_path, index=False)

        print(f'Saved to {game_path}')
# Out:
# TBR@NYY 2024-04-19 19:05:00
# OAK@CLE 2024-04-19 19:10:00
# TEX@ATL 2024-04-19 19:20:00
# BAL@KCR 2024-04-19 19:40:00
# DET@MIN 2024-04-19 20:10:00
# MIL@STL 2024-04-19 20:15:00
# TOR@SDP 2024-04-19 21:40:00
# NYM@LAD 2024-04-19 22:10:00
# ARI@SFG 2024-04-19 22:15:00
# 20240419
# (9, 33)
# TBR@NYY 745758 1905
# 45.0
# No pitcher imputations vs RHB
# No pitcher imputations vs LHB
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:   57.9s remaining:  6.8min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  1.1min finished
# Simming 1008 games took 65.861572265625 seconds.
# Saved to C:\Users\james\Documents\MLB\Database\B02. Simulations\1. Game Sims\Matchups 20240419\TBR@NYY 745758 1905
# OAK@CLE 746650 1910
# 45.0
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:  1.0min remaining:  7.1min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  1.1min finished
# Simming 1008 games took 68.58874130249023 seconds.
# Saved to C:\Users\james\Documents\MLB\Database\B02. Simulations\1. Game Sims\Matchups 20240419\OAK@CLE 746650 1910
# TEX@ATL 747136 1920
# 45.0
# No pitcher imputations vs LHB
# No pitcher imputations vs RHB
# No pitcher imputations vs LHB
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:  1.0min remaining:  7.1min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  1.1min finished
# Simming 1008 games took 68.59214162826538 seconds.
# Saved to C:\Users\james\Documents\MLB\Database\B02. Simulations\1. Game Sims\Matchups 20240419\TEX@ATL 747136 1920
# BAL@KCR 746325 1940
# 45.0
# No pitcher imputations vs RHB
# No pitcher imputations vs LHB
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:  1.0min remaining:  7.2min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  1.2min finished
# Simming 1008 games took 69.84857821464539 seconds.
# Saved to C:\Users\james\Documents\MLB\Database\B02. Simulations\1. Game Sims\Matchups 20240419\BAL@KCR 746325 1940
# DET@MIN 745922 2010
# 45.0
# No pitcher imputations vs RHB
# No pitcher imputations vs LHB
# No pitcher imputations vs RHB
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:   53.9s remaining:  6.3min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  1.0min finished
# Simming 1008 games took 61.11270189285278 seconds.
# Saved to C:\Users\james\Documents\MLB\Database\B02. Simulations\1. Game Sims\Matchups 20240419\DET@MIN 745922 2010
# MIL@STL 745189 2015
# 45.0
# No pitcher imputations vs RHB
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:   60.0s remaining:  7.0min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  1.1min finished
# Simming 1008 games took 67.64522767066956 seconds.
# Saved to C:\Users\james\Documents\MLB\Database\B02. Simulations\1. Game Sims\Matchups 20240419\MIL@STL 745189 2015
# TOR@SDP 745430 2140
# Away batters use Baseball Monster projected lineups
# Home batters use Baseball Monster projected lineups
# 45.0
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:  1.0min remaining:  7.2min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  1.2min finished
# Simming 1008 games took 70.78488087654114 seconds.
# Saved to C:\Users\james\Documents\MLB\Database\B02. Simulations\1. Game Sims\Matchups 20240419\TOR@SDP 745430 2140
# NYM@LAD 746160 2210
# Away batters use Baseball Monster projected lineups
# 45.0
# No pitcher imputations vs RHB
# No pitcher imputations vs LHB
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:  1.0min remaining:  7.0min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  1.1min finished
# Simming 1008 games took 68.6733295917511 seconds.
# Saved to C:\Users\james\Documents\MLB\Database\B02. Simulations\1. Game Sims\Matchups 20240419\NYM@LAD 746160 2210
# ARI@SFG 745352 2215
# Home batters use Baseball Monster projected lineups
# 45.0
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:  1.0min remaining:  7.3min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  1.2min finished
# Simming 1008 games took 69.91317462921143 seconds.
# Saved to C:\Users\james\Documents\MLB\Database\B02. Simulations\1. Game Sims\Matchups 20240419\ARI@SFG 745352 2215
# CPU times: total: 2min 32s
# Wall time: 11min 28s

# %%
# Optionally, read in C02, vegas scores, my scores

# %%
# 20220924
# SHOULD DELETE EXISTING FOLDERS

# %% [markdown]
# ### B03. Lineups

# %%
# %run "U1. Imports.ipynb"
# %run "U2. Utilities.ipynb"
# %run "C02. Projections.ipynb"
# %run "B03. Optimizer.ipynb"

# %%
sort_by = 'Plus3'
min_salary = 49000
min_projection = (5, 5, 4)
major_stack = (5, 5, 5)
minor_stack = (2, 2, 2)
max_exposure_batters = 0.5
max_exposure_pitchers = 0.7
excluded_teams = ([team for var in ['red_list', 'orange_list', 'projected_team_list'] if globals().get(var) is not None for team in globals()[var]], [team for var in ['red_list'] if globals().get(var) is not None for team in globals()[var]], [team for var in ['red_list'] if globals().get(var) is not None for team in globals()[var]])
min_starters = (10, 10, 0)
lineups = 200
historic= False

# %%
excluded_teams
# Out:
# (['SEA', 'COL', 'SEA', 'TOR', 'SD', 'NYM', 'SF'],
#  ['SEA', 'COL'],
#  ['SEA', 'COL'])

# %% [markdown]
# ### Run One

# %% [markdown]
# ##### 1. Players

# %%
draftables_with_sims = create_player_file(contestKey, guide, draftGroupId, roto_slate, max_exposure_pitchers, max_exposure_batters)
draftables_with_sims.to_csv(os.path.join(baseball_path, "B03. Lineups", "1. Players", f"Players {contestKey}.csv"), index=False, encoding='iso-8859-1')

# %%
webbrowser.open(os.path.join(baseball_path, "B03. Lineups", "1. Players", f"Players {contestKey}.csv"))
# Out:
# True

# %% [markdown]
# ##### 2. Lineups

# %%
# %%time
attempts = [
    ("Maximum Constraints", min_projection[0], major_stack[0], minor_stack[0], excluded_teams[0], min_starters[0]),
    ("Some Constraints", min_projection[1], major_stack[1], minor_stack[1], excluded_teams[1], min_starters[1]),
    ("Minimum Constraints", min_projection[2], major_stack[2], minor_stack[2], excluded_teams[2], min_starters[2])
]

for attempt_name, projection, major, minor, excluded, starters in attempts:
    print(f"Attempting: {attempt_name}")
    try:
        create_lineups(contestKey, min_salary, projection, major, minor, excluded, starters, lineups)
        break  # Exit loop if successful
    except Exception as e:
        print(f"Attempt failed: {e}\n")
# Out:
# Attempting: Maximum Constraints
# 1
# 25
# 50
# 75
# 99
# 100
# 125
# 150
# 175
# CPU times: total: 3.2 s
# Wall time: 8min 50s

# %% [markdown]
# ##### 3. Lineups Ranked

# %%
sort_by_list = ['P50', 'P75', 'P90', 'P95', 'P99', 'P100', 'Tail', 'Sim STD', 'Plus2', 'Plus3', 'rostership', 'pitcher rostership', 'batter_rostership']
lineups_ranked = choose_lineups(contestKey, roto_slate, sort_by)
lineups_ranked.to_csv(os.path.join(baseball_path, "B03. Lineups", "3. Lineups Ranked", f"Lineups Ranked {contestKey}.csv"), index=False)
# Out:
# (200, 1100)

# %%
lineups_ranked.query('pareto == 1')
# Out:
#                            P                           P.1  \
# 0    Jack Flaherty(33699694)            Joe Ryan(33699690)
# 1    Jack Flaherty(33699694)            Joe Ryan(33699690)
# 2    Jack Flaherty(33699694)            Joe Ryan(33699690)
# 3    Jack Flaherty(33699694)            Joe Ryan(33699690)
# 4    Jack Flaherty(33699694)            Joe Ryan(33699690)
# 5    Jack Flaherty(33699694)            Joe Ryan(33699690)
# 6    Jack Flaherty(33699694)            Joe Ryan(33699690)
# 7    Jack Flaherty(33699694)            Joe Ryan(33699690)
# 8    Jack Flaherty(33699694)            Joe Ryan(33699690)
# 9    Jack Flaherty(33699694)            Joe Ryan(33699690)
# 10  Freddy Peralta(33699685)  Yoshinobu Yamamoto(33699684)
# 11   Jack Flaherty(33699694)            Joe Ryan(33699690)
# 12      Chris Sale(33699686)      Freddy Peralta(33699685)
# 13      Chris Sale(33699686)      Freddy Peralta(33699685)
# 14      Chris Sale(33699686)      Freddy Peralta(33699685)
# 15      Chris Sale(33699686)      Freddy Peralta(33699685)
#
#                             C                       1B  \
# 0   Shea Langeliers(33699860)  Anthony Rizzo(33699823)
# 1   Shea Langeliers(33699860)  Anthony Rizzo(33699823)
# 2    Salvador Perez(33699742)  Anthony Rizzo(33699823)
# 3      Ben Rortvedt(33699886)  Anthony Rizzo(33699823)
# 4   Adley Rutschman(33699737)  Anthony Rizzo(33699823)
# 5        Will Smith(33699749)  Anthony Rizzo(33699823)
# 6   Shea Langeliers(33699860)  Anthony Rizzo(33699823)
# 7         Bo Naylor(33699819)  Anthony Rizzo(33699823)
# 8    Salvador Perez(33699742)  Anthony Rizzo(33699823)
# 9      Ben Rortvedt(33699886)  Anthony Rizzo(33699823)
# 10  Shea Langeliers(33699860)  Anthony Rizzo(33699823)
# 11  Shea Langeliers(33699860)      Ryan Noda(33699902)
# 12     Jose Trevino(33699919)     Yandy Diaz(33699734)
# 13     Jose Trevino(33699919)    Tyler Nevin(33699944)
# 14     Jose Trevino(33699919)    Tyler Nevin(33699944)
# 15     Jose Trevino(33699919)    Tyler Nevin(33699944)
#
#                           2B                         3B  \
# 0   Gleyber Torres(33699771)     Abraham Toro(33699913)
# 1   Gleyber Torres(33699771)    Isaac Paredes(33699760)
# 2   Gleyber Torres(33699771)     Abraham Toro(33699913)
# 3   Gleyber Torres(33699771)     Abraham Toro(33699913)
# 4   Gleyber Torres(33699771)     Abraham Toro(33699913)
# 5   Gleyber Torres(33699771)     Abraham Toro(33699913)
# 6   Gleyber Torres(33699771)    Isaac Paredes(33699760)
# 7   Gleyber Torres(33699771)     Abraham Toro(33699913)
# 8   Gleyber Torres(33699771)     Abraham Toro(33699913)
# 9   Gleyber Torres(33699771)    Isaac Paredes(33699760)
# 10  Gleyber Torres(33699771)    Davis Wendzel(33699993)
# 11      Zack Gelof(33699763)     Abraham Toro(33699913)
# 12  Gleyber Torres(33699771)  Oswaldo Cabrera(33699849)
# 13      Zack Gelof(33699763)     Abraham Toro(33699913)
# 14      Zack Gelof(33699763)     Abraham Toro(33699913)
# 15      Zack Gelof(33699763)     Abraham Toro(33699913)
#
#                           SS                           OF  \
# 0    Anthony Volpe(33699755)        Aaron Judge(33699710)
# 1    Anthony Volpe(33699755)        Aaron Judge(33699710)
# 2    Anthony Volpe(33699755)        Aaron Judge(33699710)
# 3    Anthony Volpe(33699755)        Aaron Judge(33699710)
# 4    Anthony Volpe(33699755)        Aaron Judge(33699710)
# 5    Anthony Volpe(33699755)        Aaron Judge(33699710)
# 6    Anthony Volpe(33699755)  Giancarlo Stanton(33699759)
# 7    Anthony Volpe(33699755)  Giancarlo Stanton(33699759)
# 8    Anthony Volpe(33699755)  Giancarlo Stanton(33699759)
# 9    Anthony Volpe(33699755)  Giancarlo Stanton(33699759)
# 10   Anthony Volpe(33699755)        Aaron Judge(33699710)
# 11   Anthony Volpe(33699755)          Juan Soto(33699711)
# 12   Anthony Volpe(33699755)          Juan Soto(33699711)
# 13    Mookie Betts(33699704)        Aaron Judge(33699710)
# 14    Mookie Betts(33699704)        Aaron Judge(33699710)
# 15  Bobby Witt Jr.(33699707)        Aaron Judge(33699710)
#
#                            OF.1                        OF.2   Budget  \
# 0           Juan Soto(33699711)   Lawrence Butler(33699983)  49700.0
# 1   Giancarlo Stanton(33699759)   Lawrence Butler(33699983)  49900.0
# 2   Giancarlo Stanton(33699759)   Lawrence Butler(33699983)  49800.0
# 3           Juan Soto(33699711)   Lawrence Butler(33699983)  49400.0
# 4   Giancarlo Stanton(33699759)   Lawrence Butler(33699983)  49700.0
# 5   Giancarlo Stanton(33699759)   Lawrence Butler(33699983)  49600.0
# 6           Juan Soto(33699711)   Lawrence Butler(33699983)  49800.0
# 7           Juan Soto(33699711)        Seth Brown(33699891)  49700.0
# 8           Juan Soto(33699711)   Lawrence Butler(33699983)  49700.0
# 9           Juan Soto(33699711)   Lawrence Butler(33699983)  49500.0
# 10  Giancarlo Stanton(33699759)   Lawrence Butler(33699983)  49900.0
# 11    Lawrence Butler(33699983)  Ronald Acuna Jr.(33699706)  49800.0
# 12    Lawrence Butler(33699983)        Seth Brown(33699891)  50000.0
# 13    Lawrence Butler(33699983)        Seth Brown(33699891)  49800.0
# 14          JJ Bleday(33699868)   Lawrence Butler(33699983)  50000.0
# 15    Lawrence Butler(33699983)        Seth Brown(33699891)  49600.0
#
#     AvgPointsPerGame  confirmed   PCT50    PCT75   PCT90    PCT95    PCT99  \
# 0            118.035          1  20.150  26.5000  31.350  34.5325  39.9545
# 1            118.125          1  20.150  26.5000  31.350  34.5325  39.9545
# 2            118.086          1  20.150  26.5000  31.350  34.5325  39.9545
# 3            117.650          1  20.150  26.5000  31.350  34.5325  39.9545
# 4            118.850          1  20.150  26.5000  31.350  34.5325  39.9545
# 5            118.462          1  20.150  26.5000  31.350  34.5325  39.9545
# 6            116.974          1  20.150  26.5000  31.350  34.5325  39.9545
# 7            116.585          1  20.150  26.5000  31.350  34.5325  39.9545
# 8            116.935          1  20.150  26.5000  31.350  34.5325  39.9545
# 9            116.589          1  20.150  26.5000  31.350  34.5325  39.9545
# 10           107.116          1  20.200  26.7125  31.965  35.3500  40.0185
# 11           114.022          1  20.150  26.5000  31.350  34.5325  39.9545
# 12           107.172          1  18.375  25.3000  30.515  32.9975  40.0940
# 13           103.896          1  18.375  25.3000  30.515  32.9975  40.0940
# 14           103.737          1  18.375  25.3000  30.515  32.9975  40.0940
# 15           103.172          1  18.375  25.3000  30.515  32.9975  40.0940
#
#     PCT100  Confirmed Starter  confirmed_P.1  PCT50_P.1  PCT75_P.1  PCT90_P.1  \
# 0    50.05                  1              1     25.250    31.3500     36.715
# 1    50.05                  1              1     25.250    31.3500     36.715
# 2    50.05                  1              1     25.250    31.3500     36.715
# 3    50.05                  1              1     25.250    31.3500     36.715
# 4    50.05                  1              1     25.250    31.3500     36.715
# 5    50.05                  1              1     25.250    31.3500     36.715
# 6    50.05                  1              1     25.250    31.3500     36.715
# 7    50.05                  1              1     25.250    31.3500     36.715
# 8    50.05                  1              1     25.250    31.3500     36.715
# 9    50.05                  1              1     25.250    31.3500     36.715
# 10   44.75                  1              1     17.075    23.6625     29.880
# 11   50.05                  1              1     25.250    31.3500     36.715
# 12   46.20                  1              1     20.200    26.7125     31.965
# 13   46.20                  1              1     20.200    26.7125     31.965
# 14   46.20                  1              1     20.200    26.7125     31.965
# 15   46.20                  1              1     20.200    26.7125     31.965
#
#     PCT95_P.1  PCT99_P.1  PCT100_P.1  Confirmed Starter_P.1  confirmed_C  \
# 0     39.8975    46.7940       55.65                      1            1
# 1     39.8975    46.7940       55.65                      1            1
# 2     39.8975    46.7940       55.65                      1            1
# 3     39.8975    46.7940       55.65                      1            1
# 4     39.8975    46.7940       55.65                      1            1
# 5     39.8975    46.7940       55.65                      1            1
# 6     39.8975    46.7940       55.65                      1            1
# 7     39.8975    46.7940       55.65                      1            1
# 8     39.8975    46.7940       55.65                      1            1
# 9     39.8975    46.7940       55.65                      1            1
# 10    32.2650    38.6185       43.60                      1            1
# 11    39.8975    46.7940       55.65                      1            1
# 12    35.3500    40.0185       44.75                      1            1
# 13    35.3500    40.0185       44.75                      1            1
# 14    35.3500    40.0185       44.75                      1            1
# 15    35.3500    40.0185       44.75                      1            1
#
#     PCT50_C  PCT75_C  PCT90_C  PCT95_C  PCT99_C  PCT100_C  \
# 0       4.0     11.0     18.0    21.00    32.00      46.0
# 1       4.0     11.0     18.0    21.00    32.00      46.0
# 2       5.0     11.0     17.0    21.00    28.93      40.0
# 3       5.0      9.0     17.0    21.00    31.86      44.0
# 4       7.0     11.0     18.0    22.00    30.00      41.0
# 5       5.0     11.0     17.0    21.65    32.86      43.0
# 6       4.0     11.0     18.0    21.00    32.00      46.0
# 7       5.0     11.0     18.0    21.00    28.93      42.0
# 8       5.0     11.0     17.0    21.00    28.93      40.0
# 9       5.0      9.0     17.0    21.00    31.86      44.0
# 10      4.0     11.0     18.0    21.00    32.00      46.0
# 11      4.0     11.0     18.0    21.00    32.00      46.0
# 12      5.0     10.0     17.0    21.00    30.00      40.0
# 13      5.0     10.0     17.0    21.00    30.00      40.0
# 14      5.0     10.0     17.0    21.00    30.00      40.0
# 15      5.0     10.0     17.0    21.00    30.00      40.0
#
#     Confirmed Starter_C  confirmed_1B  PCT50_1B  PCT75_1B  PCT90_1B  PCT95_1B  \
# 0                     1             1       6.0      12.0      19.0      23.0
# 1                     1             1       6.0      12.0      19.0      23.0
# 2                     1             1       6.0      12.0      19.0      23.0
# 3                     1             1       6.0      12.0      19.0      23.0
# 4                     1             1       6.0      12.0      19.0      23.0
# 5                     1             1       6.0      12.0      19.0      23.0
# 6                     1             1       6.0      12.0      19.0      23.0
# 7                     1             1       6.0      12.0      19.0      23.0
# 8                     1             1       6.0      12.0      19.0      23.0
# 9                     1             1       6.0      12.0      19.0      23.0
# 10                    1             1       6.0      12.0      19.0      23.0
# 11                    1             1       4.0       9.0      16.0      20.0
# 12                    1             1       7.0      13.0      20.3      25.0
# 13                    1             1       5.0       9.0      14.0      18.0
# 14                    1             1       5.0       9.0      14.0      18.0
# 15                    1             1       5.0       9.0      14.0      18.0
#
#     PCT99_1B  PCT100_1B  Confirmed Starter_1B  confirmed_2B  PCT50_2B  \
# 0      30.93       45.0                     1             1       7.0
# 1      30.93       45.0                     1             1       7.0
# 2      30.93       45.0                     1             1       7.0
# 3      30.93       45.0                     1             1       7.0
# 4      30.93       45.0                     1             1       7.0
# 5      30.93       45.0                     1             1       7.0
# 6      30.93       45.0                     1             1       7.0
# 7      30.93       45.0                     1             1       7.0
# 8      30.93       45.0                     1             1       7.0
# 9      30.93       45.0                     1             1       7.0
# 10     30.93       45.0                     1             1       7.0
# 11     28.00       46.0                     1             1       6.0
# 12     34.93       52.0                     1             1       7.0
# 13     25.93       37.0                     1             1       6.0
# 14     25.93       37.0                     1             1       6.0
# 15     25.93       37.0                     1             1       6.0
#
#     PCT75_2B  PCT90_2B  PCT95_2B  PCT99_2B  PCT100_2B  Confirmed Starter_2B  \
# 0       14.0      22.0     26.65      33.0       44.0                     1
# 1       14.0      22.0     26.65      33.0       44.0                     1
# 2       14.0      22.0     26.65      33.0       44.0                     1
# 3       14.0      22.0     26.65      33.0       44.0                     1
# 4       14.0      22.0     26.65      33.0       44.0                     1
# 5       14.0      22.0     26.65      33.0       44.0                     1
# 6       14.0      22.0     26.65      33.0       44.0                     1
# 7       14.0      22.0     26.65      33.0       44.0                     1
# 8       14.0      22.0     26.65      33.0       44.0                     1
# 9       14.0      22.0     26.65      33.0       44.0                     1
# 10      14.0      22.0     26.65      33.0       44.0                     1
# 11      12.0      18.0     23.00      32.0       41.0                     1
# 12      14.0      22.0     26.65      33.0       44.0                     1
# 13      12.0      18.0     23.00      32.0       41.0                     1
# 14      12.0      18.0     23.00      32.0       41.0                     1
# 15      12.0      18.0     23.00      32.0       41.0                     1
#
#     confirmed_3B  PCT50_3B  PCT75_3B  PCT90_3B  PCT95_3B  PCT99_3B  PCT100_3B  \
# 0              1       5.0      11.0      18.0     21.65      28.0       48.0
# 1              1       5.0      12.0      19.0     23.00      31.0       44.0
# 2              1       5.0      11.0      18.0     21.65      28.0       48.0
# 3              1       5.0      11.0      18.0     21.65      28.0       48.0
# 4              1       5.0      11.0      18.0     21.65      28.0       48.0
# 5              1       5.0      11.0      18.0     21.65      28.0       48.0
# 6              1       5.0      12.0      19.0     23.00      31.0       44.0
# 7              1       5.0      11.0      18.0     21.65      28.0       48.0
# 8              1       5.0      11.0      18.0     21.65      28.0       48.0
# 9              1       5.0      12.0      19.0     23.00      31.0       44.0
# 10             1       4.0       8.0      16.3     20.00      28.0       39.0
# 11             1       5.0      11.0      18.0     21.65      28.0       48.0
# 12             1       5.0      11.0      18.0     21.00      31.0       40.0
# 13             1       5.0      11.0      18.0     21.65      28.0       48.0
# 14             1       5.0      11.0      18.0     21.65      28.0       48.0
# 15             1       5.0      11.0      18.0     21.65      28.0       48.0
#
#     Confirmed Starter_3B  confirmed_SS  PCT50_SS  PCT75_SS  PCT90_SS  \
# 0                      1             1       8.0     15.00      21.0
# 1                      1             1       8.0     15.00      21.0
# 2                      1             1       8.0     15.00      21.0
# 3                      1             1       8.0     15.00      21.0
# 4                      1             1       8.0     15.00      21.0
# 5                      1             1       8.0     15.00      21.0
# 6                      1             1       8.0     15.00      21.0
# 7                      1             1       8.0     15.00      21.0
# 8                      1             1       8.0     15.00      21.0
# 9                      1             1       8.0     15.00      21.0
# 10                     1             1       8.0     15.00      21.0
# 11                     1             1       8.0     15.00      21.0
# 12                     1             1       8.0     15.00      21.0
# 13                     1             1       8.0     14.25      21.0
# 14                     1             1       8.0     14.25      21.0
# 15                     1             1       7.0     14.00      20.0
#
#     PCT95_SS  PCT99_SS  PCT100_SS  Confirmed Starter_SS  confirmed_OF  \
# 0       26.0     37.00       65.0                     1             1
# 1       26.0     37.00       65.0                     1             1
# 2       26.0     37.00       65.0                     1             1
# 3       26.0     37.00       65.0                     1             1
# 4       26.0     37.00       65.0                     1             1
# 5       26.0     37.00       65.0                     1             1
# 6       26.0     37.00       65.0                     1             1
# 7       26.0     37.00       65.0                     1             1
# 8       26.0     37.00       65.0                     1             1
# 9       26.0     37.00       65.0                     1             1
# 10      26.0     37.00       65.0                     1             1
# 11      26.0     37.00       65.0                     1             1
# 12      26.0     37.00       65.0                     1             1
# 13      25.0     35.86       51.0                     1             1
# 14      25.0     35.86       51.0                     1             1
# 15      24.0     34.93       44.0                     1             1
#
#     PCT50_OF  PCT75_OF  PCT90_OF  PCT95_OF  PCT99_OF  PCT100_OF  \
# 0        9.0      18.0      25.3      33.0     44.00       60.0
# 1        9.0      18.0      25.3      33.0     44.00       60.0
# 2        9.0      18.0      25.3      33.0     44.00       60.0
# 3        9.0      18.0      25.3      33.0     44.00       60.0
# 4        9.0      18.0      25.3      33.0     44.00       60.0
# 5        9.0      18.0      25.3      33.0     44.00       60.0
# 6        7.0      16.0      23.0      28.0     37.00       44.0
# 7        7.0      16.0      23.0      28.0     37.00       44.0
# 8        7.0      16.0      23.0      28.0     37.00       44.0
# 9        7.0      16.0      23.0      28.0     37.00       44.0
# 10       9.0      18.0      25.3      33.0     44.00       60.0
# 11       8.0      16.0      23.0      27.0     36.86       53.0
# 12       8.0      16.0      23.0      27.0     36.86       53.0
# 13       9.0      18.0      25.3      33.0     44.00       60.0
# 14       9.0      18.0      25.3      33.0     44.00       60.0
# 15       9.0      18.0      25.3      33.0     44.00       60.0
#
#     Confirmed Starter_OF  confirmed_OF.1  PCT50_OF.1  PCT75_OF.1  PCT90_OF.1  \
# 0                      1               1         8.0        16.0        23.0
# 1                      1               1         7.0        16.0        23.0
# 2                      1               1         7.0        16.0        23.0
# 3                      1               1         8.0        16.0        23.0
# 4                      1               1         7.0        16.0        23.0
# 5                      1               1         7.0        16.0        23.0
# 6                      1               1         8.0        16.0        23.0
# 7                      1               1         8.0        16.0        23.0
# 8                      1               1         8.0        16.0        23.0
# 9                      1               1         8.0        16.0        23.0
# 10                     1               1         7.0        16.0        23.0
# 11                     1               1         6.0        14.0        18.0
# 12                     1               1         6.0        14.0        18.0
# 13                     1               1         6.0        14.0        18.0
# 14                     1               1         6.0        11.0        18.0
# 15                     1               1         6.0        14.0        18.0
#
#     PCT95_OF.1  PCT99_OF.1  PCT100_OF.1  Confirmed Starter_OF.1  \
# 0         27.0       36.86         53.0                       1
# 1         28.0       37.00         44.0                       1
# 2         28.0       37.00         44.0                       1
# 3         27.0       36.86         53.0                       1
# 4         28.0       37.00         44.0                       1
# 5         28.0       37.00         44.0                       1
# 6         27.0       36.86         53.0                       1
# 7         27.0       36.86         53.0                       1
# 8         27.0       36.86         53.0                       1
# 9         27.0       36.86         53.0                       1
# 10        28.0       37.00         44.0                       1
# 11        23.0       35.93         53.0                       1
# 12        23.0       35.93         53.0                       1
# 13        23.0       35.93         53.0                       1
# 14        22.0       29.93         46.0                       1
# 15        23.0       35.93         53.0                       1
#
#     confirmed_OF.2  PCT50_OF.2  PCT75_OF.2  PCT90_OF.2  PCT95_OF.2  \
# 0                1         6.0        14.0        18.0        23.0
# 1                1         6.0        14.0        18.0        23.0
# 2                1         6.0        14.0        18.0        23.0
# 3                1         6.0        14.0        18.0        23.0
# 4                1         6.0        14.0        18.0        23.0
# 5                1         6.0        14.0        18.0        23.0
# 6                1         6.0        14.0        18.0        23.0
# 7                1         6.0        12.0        19.0        23.0
# 8                1         6.0        14.0        18.0        23.0
# 9                1         6.0        14.0        18.0        23.0
# 10               1         6.0        14.0        18.0        23.0
# 11               1         9.0        16.0        23.0        27.0
# 12               1         6.0        12.0        19.0        23.0
# 13               1         6.0        12.0        19.0        23.0
# 14               1         6.0        14.0        18.0        23.0
# 15               1         6.0        12.0        19.0        23.0
#
#     PCT99_OF.2  PCT100_OF.2  Confirmed Starter_OF.2   Sim 0   Sim 1   Sim 2  \
# 0        35.93         53.0                       1  142.75   96.75  144.05
# 1        35.93         53.0                       1  164.75   94.75  134.05
# 2        35.93         53.0                       1  141.75  103.75  147.05
# 3        35.93         53.0                       1  135.75   88.75  134.05
# 4        35.93         53.0                       1  151.75  118.75  154.05
# 5        35.93         53.0                       1  137.75  100.75  125.05
# 6        35.93         53.0                       1  163.75   91.75  137.05
# 7        31.93         40.0                       1  119.75   99.75   95.05
# 8        35.93         53.0                       1  140.75  100.75  150.05
# 9        35.93         53.0                       1  156.75   83.75  127.05
# 10       35.93         53.0                       1  137.25   86.35  112.95
# 11       38.93         49.0                       1  132.75  124.75  151.05
# 12       31.93         40.0                       1  144.15   48.30   86.50
# 13       31.93         40.0                       1  115.15   84.30  104.50
# 14       35.93         53.0                       1  107.15   80.30  120.50
# 15       31.93         40.0                       1  113.15   75.30  109.50
#
#      Sim 3   Sim 4   Sim 5   Sim 6   Sim 7  Sim 8   Sim 9  Sim 10  Sim 11  \
# 0   109.45  145.20  120.55  120.50  141.85  158.9   78.70  167.40  127.30
# 1    98.45  133.20  100.55  129.50  184.85  151.9   80.70  162.40  108.30
# 2    86.45  142.20   98.55   99.50  177.85  153.9   84.70  147.40  130.30
# 3   113.45  125.20  118.55  123.50  141.85  164.9   75.70  154.40  116.30
# 4    80.45  132.20  101.55  120.50  176.85  161.9   84.70  147.40  135.30
# 5    89.45  137.20  101.55   97.50  177.85  159.9   81.70  149.40  151.30
# 6    82.45  134.20  128.55  128.50  166.85  149.9   82.70  142.40  106.30
# 7    85.45  145.20  132.55  107.50  151.85  130.9  113.70  125.40  130.30
# 8    70.45  143.20  126.55   98.50  159.85  151.9   86.70  127.40  128.30
# 9    86.45  114.20  126.55  131.50  166.85  155.9   79.70  129.40   95.30
# 10   79.45  116.70   70.35   71.65  194.05  116.8   82.40  136.85  110.50
# 11  165.45  168.20  104.55  117.50   97.85  198.9   69.70  128.40  116.30
# 12   82.85  153.05  147.25   92.25  138.45  125.3  114.75   92.15   93.55
# 13  177.85  147.05   76.25  101.25  120.45  162.3   87.75  133.15  122.55
# 14  178.85  136.05   71.25  103.25  123.45  147.3   62.75  143.15  123.55
# 15  149.85  154.05   77.25  102.25  116.45  174.3  101.75  108.15  126.55
#
#     Sim 12  Sim 13  Sim 14  Sim 15  Sim 16  Sim 17  Sim 18  Sim 19  Sim 20  \
# 0   127.55  104.65  176.10  137.05  143.65   74.75   90.10  130.45  132.10
# 1   133.55   83.65  149.10  112.05  151.65  101.75   90.10  107.45  111.10
# 2   115.55   97.65  144.10  116.05  149.65   76.75  108.10  109.45  103.10
# 3   120.55  104.65  157.10  137.05  129.65   75.75   88.10  126.45  121.10
# 4   117.55   90.65  148.10  126.05  141.65   79.75  116.10  124.45  106.10
# 5   112.55   95.65  141.10  126.05  156.65   76.75  110.10  112.45  108.10
# 6   138.55  103.65  197.10  115.05  156.65  105.75   92.10  133.45  129.10
# 7   109.55  110.65  197.10  138.05  151.65   92.75  108.10  167.45  108.10
# 8   120.55  117.65  192.10  119.05  154.65   80.75  110.10  135.45  121.10
# 9   131.55  103.65  178.10  115.05  142.65  106.75   90.10  129.45  118.10
# 10   71.05   75.10  147.10   80.00  127.60   85.85   62.80  104.40  109.85
# 11  123.55  122.65  178.10  149.05  154.65   69.75  125.10  150.45  123.10
# 12   88.20  125.20  190.55  118.05   97.70   86.80   72.15  197.35   98.60
# 13   71.20  117.20   91.55  116.05   87.70   75.80   90.15  130.35   93.60
# 14   70.20  118.20   82.55  114.05   87.70   77.80  103.15  114.35   86.60
# 15   75.20  121.20   84.55  116.05   75.70   76.80   90.15  134.35   92.60
#
#     Sim 21  Sim 22  Sim 23  Sim 24  Sim 25  Sim 26  Sim 27  Sim 28  Sim 29  \
# 0    114.7  144.00  118.85  157.00  143.70   52.90  162.35  120.60   75.45
# 1    119.7  179.00  124.85  169.00  118.70   71.90  164.35  106.60   85.45
# 2    100.7  149.00  133.85  170.00  125.70   84.90  171.35  120.60   84.45
# 3    108.7  142.00  118.85  149.00  153.70   55.90  172.35  122.60   82.45
# 4     93.7  155.00  126.85  181.00  130.70   71.90  164.35  112.60   84.45
# 5     93.7  149.00  124.85  167.00  128.70   77.90  170.35  122.60   79.45
# 6    100.7  156.00  137.85  166.00  139.70   67.90  123.35   92.60   74.45
# 7     48.7  103.00  130.85  123.00  122.70   63.90  129.35  129.60   80.45
# 8     81.7  126.00  146.85  167.00  146.70   80.90  130.35  106.60   73.45
# 9     94.7  154.00  137.85  158.00  149.70   70.90  133.35   94.60   81.45
# 10   115.1  150.85  107.45  164.85   80.45   68.40  193.05   78.95   57.50
# 11   100.7  119.00  117.85  165.00  139.70   81.90  108.35  126.60   65.45
# 12    69.8   90.85  116.45  162.70  132.65   81.05  131.85  101.05   76.60
# 13    79.8  114.85   89.45  170.70  123.65   92.05  165.85  111.05   94.60
# 14    86.8  120.85   86.45  174.70  146.65   92.05  189.85  122.05   97.60
# 15    86.8  101.85   88.45  170.70  110.65   93.05  159.85  116.05  105.60
#
#     Sim 30  Sim 31  Sim 32  Sim 33  Sim 34  Sim 35  Sim 36  Sim 37  Sim 38  \
# 0   137.20  119.35   80.85  170.15  157.80  117.50  142.50  168.75  112.65
# 1   142.20  103.35  113.85  160.15  131.80  117.50  132.50  136.75   86.65
# 2   141.20  124.35   74.85  168.15  151.80  125.50  133.50  143.75   95.65
# 3   125.20  119.35   66.85  172.15  151.80  118.50  140.50  158.75  120.65
# 4   131.20  111.35   79.85  147.15  149.80  136.50  140.50  146.75  113.65
# 5   144.20  116.35   74.85  152.15  164.80  121.50  141.50  141.75   92.65
# 6   128.20  131.35  117.85  157.15  116.80  124.50  118.50  162.75  105.65
# 7   107.20  139.35   76.85  133.15  135.80  127.50  130.50  154.75  121.65
# 8   127.20  152.35   78.85  165.15  136.80  132.50  119.50  169.75  114.65
# 9   116.20  131.35  103.85  159.15  110.80  125.50  116.50  152.75  113.65
# 10  112.10   71.20  128.60  157.05  147.65   77.00   99.85  106.30   86.90
# 11  107.20  141.35   90.85  161.15  121.80  132.50  128.50  174.75  110.65
# 12   85.95   95.35   80.95  128.50  110.50   85.85  117.15  155.90  155.85
# 13   90.95   66.35   70.95  126.50  122.50   95.85  133.15  123.90  131.85
# 14   93.95   73.35   70.95  123.50  127.50  102.85  119.15  120.90  112.85
# 15   94.95   52.35   70.95  141.50  126.50  116.85  126.15  110.90  134.85
#
#     Sim 39  Sim 40  Sim 41  Sim 42  Sim 43  Sim 44  Sim 45  Sim 46  Sim 47  \
# 0   100.80  105.90   95.80   86.15  127.15  123.05  103.95  124.55  146.95
# 1    82.80  119.90  100.80   95.15  146.15  109.05  116.95  133.55  160.95
# 2    83.80   98.90   72.80   98.15  128.15   83.05  102.95  113.55  134.95
# 3    96.80   90.90   80.80   93.15  120.15  103.05  103.95  104.55  142.95
# 4    81.80  110.90   77.80   93.15  136.15   90.05   96.95  107.55  139.95
# 5    82.80  103.90   63.80  105.15  131.15   86.05   90.95  119.55  134.95
# 6    97.80  112.90  107.80   89.15  135.15  112.05  112.95  121.55  121.95
# 7    87.80  114.90   86.80  107.15  111.15  102.05  101.95  105.55   98.95
# 8    98.80   91.90   79.80   92.15  117.15   86.05   98.95  101.55   95.95
# 9    93.80   97.90   92.80   96.15  128.15   92.05  112.95  101.55  117.95
# 10   86.55   68.15   91.25  110.70  117.80  102.35   94.65  134.55  146.70
# 11  129.80  104.90  106.80   74.15   94.15  120.05   98.95  104.55  104.95
# 12  131.10   59.45  120.05  141.75   92.55   96.05   88.35   97.55  134.20
# 13  140.10   70.45  115.05  136.75   82.55  109.05   87.35  123.55  138.20
# 14  143.10   58.45  109.05  131.75   80.55   95.05  104.35  110.55  145.20
# 15  142.10   68.45  115.05  141.75   65.55   96.05   80.35  124.55  136.20
#
#     Sim 48  Sim 49  Sim 50  Sim 51  Sim 52  Sim 53  Sim 54  Sim 55  Sim 56  \
# 0   127.25  106.75  150.45  174.55  107.25  162.30  138.65  151.55  153.70
# 1   110.25   96.75  156.45  174.55  107.25  196.30  138.65  164.55  154.70
# 2   111.25   86.75  135.45  173.55  107.25  174.30  137.65  148.55  161.70
# 3   120.25  115.75  157.45  188.55  107.25  163.30  131.65  127.55  148.70
# 4   129.25   89.75  132.45  171.55  107.25  187.30  157.65  151.55  151.70
# 5   123.25   88.75  148.45  175.55  128.25  172.30  149.65  150.55  145.70
# 6   101.25   88.75  154.45  160.55   95.25  197.30  143.65  154.55  157.70
# 7   124.25   72.75  132.45  154.55  100.25  141.30  145.65  162.55  139.70
# 8   102.25   78.75  133.45  159.55   95.25  175.30  142.65  138.55  164.70
# 9    94.25   97.75  161.45  174.55   95.25  198.30  136.65  130.55  152.70
# 10  130.80   81.95  145.70  155.70  116.05  160.55  109.65  180.30  144.55
# 11  120.25   88.75  133.45  140.55   77.25  156.30  154.65  113.55  147.70
# 12  129.60  124.40  117.25  134.40  151.65  155.30  116.60  147.55  125.60
# 13  139.60  116.40  132.25   88.40  160.65  139.30  107.60  163.55   97.60
# 14  130.60  119.40  149.25   96.40  159.65  159.30  119.60  165.55   92.60
# 15  114.60  105.40  115.25  107.40  123.65  133.30  102.60  149.55   92.60
#
#     Sim 57  Sim 58  Sim 59  Sim 60  Sim 61  Sim 62  Sim 63  Sim 64  Sim 65  \
# 0    81.20  134.70  122.15  105.45   77.45   134.2   49.75  109.50    59.9
# 1    76.20  129.70  129.15  110.45   79.45   151.2   61.75   91.50    58.9
# 2    63.20  136.70  156.15  114.45   71.45   167.2   49.75  108.50    68.9
# 3    74.20  140.70  130.15  123.45   82.45   134.2   54.75  113.50    62.9
# 4    61.20  141.70  136.15  112.45   67.45   148.2   63.75  101.50    76.9
# 5    72.20  152.70  142.15  107.45   69.45   153.2   56.75  108.50    66.9
# 6    94.20  155.70  143.15  105.45   90.45   135.2   61.75  105.50    44.9
# 7    72.20  194.70  170.15  103.45   97.45   132.2   61.75  110.50    52.9
# 8    81.20  162.70  170.15  109.45   82.45   151.2   49.75  122.50    54.9
# 9    87.20  161.70  151.15  123.45   95.45   135.2   66.75  109.50    47.9
# 10   50.30  130.80  103.50   90.75   51.20   110.9   69.40  102.70    57.1
# 11   97.20  110.70  118.15  107.45   84.45   139.2   58.75   98.50    62.9
# 12   73.45  119.45  107.05  126.90   53.45   108.4  109.20  110.45    46.9
# 13   66.45   91.45   78.05  148.90   47.45    69.4   71.20   89.45    83.9
# 14   66.45  104.45   76.05  139.90   33.45    87.4   71.20   91.45    81.9
# 15   66.45   72.45   80.05  131.90   54.45    67.4   85.20   86.45    94.9
#
#     Sim 66  Sim 67  Sim 68  Sim 69  Sim 70  Sim 71  Sim 72  Sim 73  Sim 74  \
# 0    57.95  121.05  125.85    90.6  130.05  131.55   87.95  110.90  148.75
# 1    63.95  119.05  109.85    76.6  147.05  138.55   83.95  123.90  194.75
# 2    60.95  138.05  117.85    81.6  148.05  154.55  101.95  125.90  172.75
# 3    71.95  119.05  115.85    92.6  135.05  149.55   87.95  108.90  154.75
# 4    63.95  121.05  114.85    80.6  150.05  147.55   92.95  122.90  185.75
# 5    65.95  134.05  110.85    88.6  148.05  149.55   94.95  120.90  175.75
# 6    63.95  105.05  107.85    79.6  155.05  126.55   69.95  125.90  169.75
# 7    84.95  107.05  125.85    83.6  165.05  142.55   85.95  113.90  130.75
# 8    60.95  124.05  115.85    84.6  156.05  142.55   87.95  127.90  147.75
# 9    77.95  103.05   97.85    81.6  160.05  144.55   69.95  123.90  175.75
# 10   68.85   75.25   96.55    90.4  103.40  118.10   65.20   96.05  137.35
# 11   85.95  106.05  100.85   100.6   86.05  100.55   97.95  110.90  137.75
# 12   91.65   68.25  104.05    85.2  110.35  138.05   82.55   76.60   98.85
# 13   90.65   77.25   87.05    77.2   85.35  114.05  123.55   96.60  108.85
# 14   83.65   70.25   85.05    77.2   86.35  112.05  124.55   96.60  102.85
# 15   82.65   75.25   84.05    77.2   74.35  125.05  137.55   96.60  113.85
#
#     Sim 75  Sim 76  Sim 77  Sim 78  Sim 79  Sim 80  Sim 81  Sim 82  Sim 83  \
# 0    98.65  146.95  109.35  181.15  120.00  144.25  120.10  100.25  173.60
# 1    81.65  125.95  102.35  195.15   97.00  133.25  118.10  109.25  180.60
# 2    82.65  135.95  126.35  191.15   84.00  135.25  139.10   99.25  169.60
# 3    98.65  176.95  104.35  181.15  107.00  139.25  129.10   89.25  148.60
# 4    84.65  140.95  108.35  185.15  122.00  144.25  120.10   94.25  162.60
# 5    99.65  150.95  105.35  185.15   86.00  133.25  120.10  103.25  159.60
# 6    89.65  142.95   88.35  182.15  110.00  136.25  111.10  106.25  157.60
# 7   102.65  156.95   72.35  182.15   95.00  125.25  116.10  110.25  131.60
# 8    90.65  152.95  112.35  178.15   97.00  138.25  132.10   96.25  146.60
# 9    89.65  172.95   83.35  182.15   97.00  131.25  120.10   95.25  132.60
# 10   78.25  138.75   93.35  177.10   86.95  113.90  112.55   96.40  163.75
# 11  109.65   83.95  115.35  139.15  122.00  134.25  111.10  103.25  150.60
# 12   69.45  108.75   82.40  161.35  127.15   84.15   90.15   71.65  120.65
# 13   83.45   61.75  113.40  138.35  106.15  111.15   85.15   85.65  113.65
# 14   83.45   61.75  120.40  147.35  109.15  111.15   87.15   75.65  108.65
# 15   73.45   77.75  127.40  140.35  113.15   97.15  102.15   69.65  125.65
#
#     Sim 84  Sim 85  Sim 86  Sim 87  Sim 88  Sim 89  Sim 90  Sim 91  Sim 92  \
# 0   174.05  116.45   98.35  150.00  239.55   98.75  180.40   99.50  114.55
# 1   141.05  111.45  118.35  141.00  207.55  129.75  168.40  113.50   87.55
# 2   145.05  107.45   95.35  125.00  199.55  101.75  167.40   92.50  106.55
# 3   177.05  112.45   87.35  127.00  221.55   87.75  172.40  104.50  114.55
# 4   150.05  102.45   95.35  125.00  213.55  101.75  165.40  103.50  106.55
# 5   163.05  104.45  103.35  130.00  209.55  101.75  203.40   97.50  118.55
# 6   141.05   93.45  107.35  153.00  208.55  131.75  153.40  127.50   86.55
# 7   135.05  110.45   87.35  117.00  206.55   90.75  167.40  115.50  114.55
# 8   145.05   89.45   84.35  137.00  200.55  103.75  152.40  106.50  105.55
# 9   144.05   89.45   96.35  130.00  190.55  120.75  145.40  132.50   86.55
# 10  113.95  101.80   77.65  103.40  180.25  118.80  173.15   93.35   74.25
# 11  172.05   86.45   94.35  154.00  223.55  110.75  135.40  107.50  128.55
# 12  149.10   97.05   79.20   81.55  162.55   71.70  124.80   92.05  111.40
# 13  182.10   82.05   92.20   82.55  111.55   61.70  112.80   67.05  101.40
# 14  191.10   79.05  107.20   88.55  114.55   61.70  119.80   67.05  101.40
# 15  182.10   80.05   82.20   55.55  103.55   65.70  107.80   72.05  105.40
#
#     Sim 93  Sim 94  Sim 95  Sim 96  Sim 97  Sim 98  Sim 99  Sim 100  Sim 101  \
# 0   151.95  120.85  171.25   93.75   158.7   88.85  106.70   164.70   131.40
# 1   134.95  109.85  168.25  116.75   137.7   91.85   85.70   164.70   150.40
# 2   143.95  121.85  164.25  129.75   163.7   93.85   82.70   154.70   127.40
# 3   140.95  119.85  152.25   89.75   163.7   83.85  102.70   162.70   122.40
# 4   159.95  122.85  155.25  100.75   151.7  113.85   89.70   155.70   122.40
# 5   139.95  127.85  154.25   92.75   186.7   88.85   83.70   153.70   131.40
# 6   125.95   97.85  146.25  104.75   124.7   84.85  101.70   125.70   118.40
# 7   134.95  118.85  140.25   99.75   128.7   75.85  111.70    95.70   108.40
# 8   134.95  109.85  142.25  117.75   150.7   86.85   98.70   115.70    95.40
# 9   114.95   96.85  127.25  100.75   129.7   79.85   97.70   123.70   109.40
# 10  129.05  105.40  120.70   98.55   137.3   55.00   67.55   147.35   143.30
# 11  185.95  105.85  149.25  102.75   128.7   91.85  136.70   102.70    77.40
# 12  100.50  101.10  117.25   79.05   121.1   86.05   94.35   114.75    66.15
# 13  146.50  107.10   97.25   80.05   129.1   79.05  112.35   106.75    81.15
# 14  163.50  100.10   97.25   90.05   129.1   81.05  106.35   106.75    85.15
# 15  149.50  113.10  109.25   81.05   114.1   86.05  103.35    90.75    74.15
#
#     Sim 102  Sim 103  Sim 104  Sim 105  Sim 106  Sim 107  Sim 108  Sim 109  \
# 0    250.95    78.65    94.15   170.90    125.0   135.90   121.00   140.45
# 1    251.95    73.65    87.15   154.90    155.0   129.90   144.00   149.45
# 2    225.95    91.65    73.15   163.90    130.0   128.90   142.00   147.45
# 3    214.95    78.65    81.15   159.90    150.0   135.90   114.00   144.45
# 4    241.95    77.65    78.15   168.90    138.0   125.90   145.00   149.45
# 5    247.95    77.65    80.15   154.90    133.0   125.90   142.00   157.45
# 6    236.95    81.65    90.15   133.90    145.0   147.90   148.00   159.45
# 7    208.95    81.65    79.15   145.90    115.0   155.90   141.00   129.45
# 8    210.95    99.65    76.15   142.90    120.0   146.90   146.00   157.45
# 9    200.95    81.65    77.15   122.90    170.0   147.90   141.00   163.45
# 10   240.65    82.80   108.85   104.75    130.3   125.95   156.30   133.15
# 11   199.95    87.65   107.15   141.90    110.0   161.90   169.00   134.45
# 12   190.70    94.60    66.20   107.45    108.6   129.95   161.05   141.90
# 13   182.70    58.60    67.20   103.45     86.6    93.95   152.05   101.90
# 14   162.70    61.60    66.20    87.45     84.6    83.95   126.05   103.90
# 15   190.70    52.60    56.20   104.45     95.6   109.95   145.05    97.90
#
#     Sim 110  Sim 111  Sim 112  Sim 113  Sim 114  Sim 115  Sim 116  Sim 117  \
# 0     77.40   134.15    122.6    95.15   105.15   103.30    79.00   138.75
# 1     70.40   133.15    108.6    86.15    87.15    88.30    77.00   138.75
# 2     81.40   147.15    109.6    82.15    96.15    81.30    66.00   130.75
# 3     96.40   149.15    118.6   110.15   105.15   100.30    68.00   135.75
# 4     77.40   143.15    119.6   109.15    93.15    87.30    84.00   137.75
# 5     85.40   135.15    123.6    83.15    99.15    81.30    74.00   142.75
# 6     56.40   113.15    123.6   103.15    94.15    89.30    61.00   131.75
# 7    100.40   129.15    122.6    84.15   101.15    91.30    87.00   126.75
# 8     67.40   127.15    124.6    99.15   103.15    82.30    50.00   123.75
# 9     75.40   128.15    119.6   118.15    94.15    86.30    50.00   128.75
# 10    90.30   113.40    137.0    73.15    95.40    95.45    73.65   127.90
# 11    88.40    91.15    127.6    96.15   113.15   117.30    67.00   118.75
# 12   104.85    89.50    165.2   132.30   104.85   140.65    85.60   162.75
# 13   131.85    94.50    122.2    85.30    92.85   133.65   106.60   116.75
# 14   115.85    90.50    124.2    87.30    90.85   139.65    94.60   102.75
# 15   134.85    80.50    120.2    92.30    87.85   146.65    97.60   117.75
#
#     Sim 118  Sim 119  Sim 120  Sim 121  Sim 122  Sim 123  Sim 124  Sim 125  \
# 0    118.65   147.25   152.25     80.1   122.00   155.25   114.30    103.6
# 1    124.65   135.25   140.25     82.1   133.00   150.25   126.30    114.6
# 2    115.65   134.25   147.25     92.1   136.00   151.25    94.30    117.6
# 3    129.65   142.25   149.25     90.1   120.00   144.25    98.30     96.6
# 4    117.65   141.25   145.25     89.1   140.00   143.25   107.30    102.6
# 5    118.65   138.25   139.25     82.1   119.00   154.25    99.30    109.6
# 6    109.65   125.25   140.25     71.1   151.00   111.25   116.30    109.6
# 7    103.65   151.25   139.25     63.1   141.00   145.25   106.30     97.6
# 8    100.65   124.25   147.25     81.1   154.00   112.25    84.30    112.6
# 9    120.65   120.25   137.25     81.1   149.00   100.25   100.30    102.6
# 10   115.35   100.40   104.55     95.8   126.35   146.25    92.30     79.7
# 11    90.65   154.25   112.25     76.1   124.00   105.25   112.30    113.6
# 12   116.85   116.65   137.10     66.4   150.40    82.40   119.85     85.1
# 13   122.85   144.65    94.10     66.4   114.40   130.40   132.85     68.1
# 14   111.85   115.65    89.10     66.4   121.40   118.40   126.85     58.1
# 15   129.85   133.65    98.10     80.4   104.40   118.40   131.85     81.1
#
#     Sim 126  Sim 127  Sim 128  Sim 129  Sim 130  Sim 131  Sim 132  Sim 133  \
# 0     81.65    87.45    95.60    93.35   101.30    63.75    68.35   130.00
# 1     98.65    78.45    93.60    78.35   108.30    59.75    61.35   128.00
# 2     90.65    88.45    94.60   103.35   114.30    58.75    63.35   132.00
# 3     83.65   105.45    96.60    87.35    99.30    60.75    63.35   116.00
# 4    100.65    99.45    95.60    94.35   102.30    63.75    65.35   137.00
# 5     94.65    83.45    94.60    90.35   106.30    63.75    65.35   121.00
# 6     91.65    75.45    96.60    65.35   105.30    61.75    61.35   113.00
# 7    107.65   102.45    85.60    81.35   100.30    62.75    58.35   111.00
# 8     83.65    85.45    97.60    90.35   111.30    60.75    63.35   117.00
# 9     93.65    93.45    97.60    59.35   103.30    58.75    56.35    99.00
# 10    64.70    85.45    79.55    89.55    96.10    34.35    37.85   120.05
# 11    89.65    98.45    99.60    70.35   109.30    69.75    87.35   157.00
# 12    65.70   103.05    96.25    76.40    95.95    75.55    35.25    84.00
# 13    87.70   130.05    93.25   115.40    79.95    60.55    57.25   122.00
# 14    73.70   109.05    96.25   114.40    82.95    58.55    64.25   123.00
# 15    79.70   125.05    90.25    99.40   105.95    60.55    62.25   123.00
#
#     Sim 134  Sim 135  Sim 136  Sim 137  Sim 138  Sim 139  Sim 140  Sim 141  \
# 0     142.5    82.85   135.50     86.3   149.75   100.10    79.90    69.55
# 1     120.5   100.85   108.50     88.3   144.75   106.10   112.90    74.55
# 2     137.5    81.85   127.50     88.3   154.75    84.10   102.90    77.55
# 3     148.5    62.85   127.50     86.3   151.75    94.10    96.90    66.55
# 4     135.5   103.85   137.50    106.3   152.75    84.10   100.90   105.55
# 5     128.5    87.85   128.50     86.3   144.75    92.10   113.90    82.55
# 6     120.5    97.85   109.50     88.3   148.75   105.10   109.90    77.55
# 7     154.5    90.85   131.50     92.3   132.75    73.10   125.90   121.55
# 8     137.5    78.85   128.50     88.3   158.75    83.10    99.90    80.55
# 9     126.5    77.85   101.50     88.3   150.75    99.10   126.90    74.55
# 10    107.7    79.45   124.15     79.7    83.60   136.55    90.75    62.60
# 11    127.5    98.85   117.50     98.3   125.75    93.10    70.90    70.55
# 12    155.9    98.30    87.45    117.2   137.05   126.90   123.10    75.85
# 13    151.9   109.30   145.45    125.2   132.05    98.90   103.10    80.85
# 14    133.9   105.30   155.45    126.2   139.05   101.90    87.10    69.85
# 15    135.9   109.30   122.45    117.2   131.05    88.90   118.10    85.85
#
#     Sim 142  Sim 143  Sim 144  Sim 145  Sim 146  Sim 147  Sim 148  Sim 149  \
# 0     81.35   116.80    70.15    96.55   109.20   103.35    93.05   150.95
# 1    101.35   116.80    82.15    79.55   130.20   105.35   102.05   144.95
# 2    102.35    96.80    89.15    58.55   119.20   111.35   104.05   144.95
# 3     81.35    98.80    70.15    91.55   114.20   103.35    96.05   137.95
# 4    107.35   111.80    83.15    67.55   126.20   110.35   114.05   164.95
# 5     98.35   105.80    92.15    66.55   131.20   107.35   113.05   136.95
# 6     95.35   126.80    80.15    87.55   124.20    96.35   112.05   131.95
# 7    107.35   110.80    93.15    72.55   115.20   104.35   101.05   130.95
# 8     96.35   106.80    87.15    66.55   113.20   102.35   114.05   131.95
# 9     95.35   108.80    80.15    82.55   129.20    96.35   115.05   118.95
# 10   124.45    73.80   116.70   105.35   124.50    75.70   102.85   165.30
# 11    86.35   124.80    78.15   126.55    93.20    78.35   109.05   138.95
# 12   122.00    69.65   101.05   121.95   117.75    88.45    91.15   117.70
# 13    88.00    70.65    86.05    82.95   118.75    78.45    76.15   120.70
# 14    91.00    70.65    99.05    97.95   129.75    79.45    75.15   129.70
# 15    88.00    66.65    88.05    88.95   103.75    92.45   101.15   106.70
#
#     Sim 150  Sim 151  Sim 152  Sim 153  Sim 154  Sim 155  Sim 156  Sim 157  \
# 0    105.75   106.25   150.45    81.45   154.55    191.6    80.70   178.60
# 1    121.75    86.25   148.45    85.45   167.55    151.6    62.70   171.60
# 2    114.75   111.25   129.45    83.45   125.55    164.6    65.70   136.60
# 3     87.75   112.25   144.45    86.45   138.55    191.6    80.70   166.60
# 4    123.75   105.25   127.45    83.45   135.55    166.6    67.70   133.60
# 5    113.75   111.25   129.45    80.45   135.55    164.6    62.70   137.60
# 6    117.75    92.25   148.45    86.45   180.55    151.6    65.70   190.60
# 7    137.75   136.25   139.45    66.45   123.55    160.6    79.70   174.60
# 8    110.75   117.25   129.45    84.45   138.55    164.6    68.70   155.60
# 9     99.75    98.25   142.45    91.45   164.55    151.6    65.70   178.60
# 10   109.40    61.50   146.05    98.85   127.85    138.9    87.65   118.70
# 11    94.75   112.25   127.45    77.45   164.55    128.6    64.70   174.60
# 12    77.10   102.70   160.30    87.85   135.15    137.5    88.90   122.15
# ...
# 1    121.70   143.40   118.65    86.45   118.20     93.8   121.40    97.55
# 2    133.70   127.40    98.65   106.45   128.20     92.8   137.40   112.55
# 3    148.70   134.40    83.65   104.45   148.20     94.8   144.40    90.55
# 4    128.70   127.40    94.65   110.45   124.20    102.8   143.40   100.55
# 5    133.70   133.40    95.65   111.45   133.20     97.8   147.40    93.55
# 6    104.70   130.40   121.65    82.45   123.20    100.8   112.40    96.55
# 7    109.70   109.40   120.65   101.45   138.20    125.8   136.40   112.55
# 8    116.70   114.40   101.65   102.45   133.20     99.8   128.40   111.55
# 9    111.70   126.40   126.65   103.45   138.20     97.8   112.40    91.55
# 10   127.80   131.65    88.65   137.15   125.45     97.1   145.45    84.75
# 11   101.70    87.40    93.65    83.45   122.20    107.8   167.40    82.55
# 12    85.65    92.50   141.10   129.10   117.05    109.1   128.00    97.65
# 13   104.65   122.50   100.10   142.10    85.05     99.1   131.00    80.65
# 14   122.65   112.50    88.10   137.10    83.05    105.1   133.00    80.65
# 15   107.65    91.50   102.10   153.10    85.05     94.1   123.00    93.65
#
#     Sim 958  Sim 959  Sim 960  Sim 961  Sim 962  Sim 963  Sim 964  Sim 965  \
# 0    132.35    88.60   101.90    99.15   113.65   105.05    87.65   136.15
# 1    131.35    89.60    96.90    94.15    98.65   103.05    95.65   108.15
# 2    128.35    98.60   111.90    97.15   118.65    94.05    92.65   104.15
# 3    126.35    92.60    99.90   117.15   116.65   103.05    87.65   137.15
# 4    133.35   106.60   116.90   108.15   109.65    99.05    98.65   117.15
# 5    133.35   101.60   104.90    95.15   111.65    91.05    99.65   108.15
# 6    128.35    72.60   100.90   107.15    99.65   112.05    91.65   140.15
# 7    134.35    62.60   113.90   126.15   110.65   109.05   123.65   126.15
# 8    125.35    81.60   115.90   110.15   119.65   103.05    88.65   136.15
# 9    122.35    76.60    98.90   125.15   102.65   110.05    91.65   141.15
# 10    97.60   112.45    94.65    74.05   113.15    91.00    73.35   130.80
# 11   146.35    97.60   111.90   136.15   111.65    79.05   101.65   130.15
# 12    78.70    62.20   114.80   152.15   108.90   111.25    81.05   141.65
# 13    85.70   112.20   119.80   102.15   117.90    59.25    67.05    75.65
# 14    93.70   124.20   118.80   100.15   122.90    64.25    63.05    76.65
# 15    93.70   107.20   139.80   117.15   139.90    56.25    70.05    88.65
#
#     Sim 966  Sim 967  Sim 968  Sim 969  Sim 970  Sim 971  Sim 972  Sim 973  \
# 0    151.05   142.85    122.8   111.55    39.40   137.25   172.10    93.95
# 1    137.05   136.85    106.8    96.55    58.40   131.25   157.10    84.95
# 2    165.05   123.85    104.8   102.55    41.40   154.25   150.10    90.95
# 3    151.05   132.85    122.8   130.55    34.40   135.25   166.10    93.95
# 4    166.05   120.85    108.8    95.55    46.40   162.25   152.10    90.95
# 5    167.05   127.85    111.8   109.55    42.40   153.25   154.10    90.95
# 6    124.05   152.85    130.8    82.55    56.40   138.25   166.10    89.95
# 7    166.05   154.85    141.8    88.55    42.40   149.25   153.10    91.95
# 8    152.05   139.85    128.8    88.55    39.40   161.25   159.10    95.95
# 9    124.05   142.85    130.8   101.55    51.40   136.25   160.10    89.95
# 10   125.65   100.35     80.1    69.00    57.70   111.40   126.65    79.40
# 11   111.05   144.85     83.8    99.55    48.40   122.25   180.10   114.95
# 12   111.75   114.00    109.1    81.20    55.85   107.50   152.75   102.90
# 13   124.75    93.00     51.1    96.20    59.85    93.50   125.75   118.90
# 14   123.75    88.00     66.1    98.20    67.85   105.50   118.75   107.90
# 15   106.75    85.00     43.1   118.20    55.85    99.50   121.75   112.90
#
#     Sim 974  Sim 975  Sim 976  Sim 977  Sim 978  Sim 979  Sim 980  Sim 981  \
# 0    108.75   116.35   132.05   141.85   142.25   155.60   176.95   143.00
# 1     87.75   113.35   126.05   121.85   142.25   161.60   147.95   144.00
# 2     84.75   127.35   136.05   144.85   178.25   146.60   177.95   117.00
# 3    121.75   116.35   132.05   145.85   142.25   162.60   184.95   110.00
# 4     84.75   115.35   127.05   141.85   167.25   151.60   175.95   108.00
# 5    105.75   116.35   134.05   153.85   172.25   149.60   178.95   107.00
# 6    115.75   110.35    99.05    77.85   144.25   146.60   150.95   138.00
# 7    124.75   126.35   112.05   136.85   175.25   137.60   197.95   114.00
# 8    112.75   124.35   109.05   100.85   180.25   131.60   180.95   111.00
# 9    128.75   110.35    99.05    81.85   144.25   153.60   158.95   105.00
# 10    78.20   102.50   124.80   140.25    80.80   132.25   161.05   111.95
# 11   120.75   131.35   101.05   114.85   120.25   180.60   170.95   137.00
# 12   145.45   117.15    82.05    71.40   116.35   145.60   175.30   179.60
# 13   124.45   119.15   101.05   152.40   102.35   124.60   132.30   120.60
# 14   109.45   130.15    88.05   166.40   116.35   117.60   118.30   103.60
# 15   113.45   117.15   113.05   148.40   103.35   127.60   156.30   129.60
#
#     Sim 982  Sim 983  Sim 984  Sim 985  Sim 986  Sim 987  Sim 988  Sim 989  \
# 0    112.60   186.05   138.30    160.5    103.5   135.35    92.80    94.85
# 1    108.60   195.05   136.30    144.5    101.5   170.35    84.80   103.85
# 2    100.60   165.05   160.30    148.5     91.5   164.35    86.80   110.85
# 3    126.60   172.05   145.30    144.5     94.5   136.35    97.80   121.85
# 4    122.60   170.05   159.30    148.5    100.5   166.35    88.80   109.85
# 5    102.60   163.05   145.30    150.5     93.5   157.35    89.80   108.85
# 6    132.60   169.05   128.30    146.5    107.5   170.35    87.80    81.85
# 7    119.60   148.05   137.30    152.5    120.5   154.35   103.80    94.85
# 8    124.60   139.05   152.30    150.5     97.5   164.35    89.80    88.85
# 9    146.60   155.05   135.30    130.5     98.5   171.35    92.80   108.85
# 10   118.45   148.60   151.20    148.7     75.0   147.40   101.05    62.60
# 11   107.60   120.05   107.30    206.5     97.5   116.35    95.80    71.85
# 12   127.80   115.75   120.95    139.7     92.0   140.40    82.80    66.70
# 13    90.80    93.75   104.95    144.7     75.0   111.40    75.80    57.70
# 14    97.80    94.75    93.95    162.7     84.0   113.40    56.80    51.70
# 15    70.80    80.75   103.95    129.7     77.0   107.40    83.80    50.70
#
#     Sim 990  Sim 991  Sim 992  Sim 993  Sim 994  Sim 995  Sim 996  Sim 997  \
# 0     94.85   106.25   100.35    104.2   138.50   109.95    120.2    85.95
# 1     99.85   103.25    91.35     82.2   127.50   112.95    114.2    98.95
# 2     80.85   110.25    92.35    101.2   157.50   112.95    115.2    83.95
# 3     73.85   103.25    98.35    139.2   138.50   111.95    136.2    99.95
# 4     88.85   116.25    92.35     91.2   141.50   132.95    123.2    89.95
# 5    105.85   113.25    90.35     91.2   144.50   117.95    115.2    81.95
# 6    100.85   107.25   103.35    102.2   109.50    90.95     96.2    96.95
# 7    105.85   116.25   116.35    148.2   129.50   120.95    106.2    83.95
# 8     81.85   114.25   104.35    121.2   139.50    90.95     97.2    81.95
# 9     79.85   104.25   101.35    137.2   109.50    92.95    112.2   110.95
# 10    93.25   125.10    62.70     80.0    95.40   114.50     81.8    71.50
# 11    93.85   131.25   105.35     87.2   141.50    85.95    105.2    80.95
# 12    86.35   164.15   111.95    132.7   118.85   108.45     91.0    82.10
# 13    76.35   170.15   108.95     91.7   152.85   137.45    103.0    69.10
# 14    68.35   171.15    94.95     76.7   171.85   128.45    106.0    67.10
# 15    89.35   169.15   101.95    114.7   134.85   137.45    108.0    87.10
#
#     Sim 998  Sim 999  Sim 1000  Sim 1001  Sim 1002  Sim 1003  Sim 1004  \
# 0    125.00   124.75     87.05    207.55     85.25     91.75     80.55
# 1    142.00   110.75     97.05    213.55    110.25     80.75     74.55
# 2    137.00   102.75    116.05    186.55    106.25     76.75     90.55
# 3    126.00   133.75     80.05    188.55     68.25    100.75     99.55
# 4    142.00   100.75    103.05    198.55    107.25     82.75     81.55
# 5    132.00   116.75     94.05    189.55    109.25     80.75     95.55
# 6    125.00   128.75     97.05    199.55    104.25     86.75     71.55
# 7    139.00   108.75     88.05    187.55    101.25     95.75     77.55
# 8    120.00   120.75    116.05    172.55    100.25     82.75     87.55
# 9    126.00   137.75     90.05    180.55     87.25     95.75     90.55
# 10   136.05    77.55     91.10    165.00    118.70    124.70    126.60
# 11   112.00   141.75     82.05    148.55     81.25     97.75     71.55
# 12   116.40   118.35     92.50    167.60     88.55    128.50     87.60
# 13   101.40    79.35     93.50    124.60     64.55    134.50     89.60
# 14    97.40    75.35     99.50    133.60     74.55    134.50     95.60
# 15   104.40    77.35     83.50    121.60     87.55    116.50    102.60
#
#     Sim 1005  Sim 1006  Sim 1007              Name  P_rostership  \
# 0     113.25    108.40    186.10   Lawrence Butler         14.70
# 1     112.25    118.40    188.10   Lawrence Butler         14.70
# 2     115.25     98.40    180.10   Lawrence Butler         14.70
# 3     105.25     98.40    186.10   Lawrence Butler         14.70
# 4     113.25     98.40    190.10   Lawrence Butler         14.70
# 5     119.25    122.40    175.10   Lawrence Butler         14.70
# 6     129.25    109.40    178.10   Lawrence Butler         14.70
# 7     101.25    115.40    171.10        Seth Brown         14.70
# 8     132.25     89.40    170.10   Lawrence Butler         14.70
# 9     121.25     99.40    178.10   Lawrence Butler         14.70
# 10    113.90    119.95    149.55   Lawrence Butler         24.90
# 11    129.25     83.40    172.10  Ronald Acuna Jr.         14.70
# 12    121.60    116.35    191.45        Seth Brown         20.08
# 13     97.60    101.35    150.45        Seth Brown         20.08
# 14    114.60     87.35    154.45   Lawrence Butler         20.08
# 15    108.60     85.35    149.45        Seth Brown         20.08
#
#     P.1_rostership  C_rostership  1B_rostership  2B_rostership  3B_rostership  \
# 0             28.4          1.16           7.11           7.17           1.93
# 1             28.4          1.16           7.11           7.17           2.89
# 2             28.4          2.03           7.11           7.17           1.93
# 3             28.4          0.46           7.11           7.17           1.93
# 4             28.4         10.80           7.11           7.17           1.93
# 5             28.4          7.73           7.11           7.17           1.93
# 6             28.4          1.16           7.11           7.17           2.89
# 7             28.4          0.04           7.11           7.17           1.93
# 8             28.4          2.03           7.11           7.17           1.93
# 9             28.4          0.46           7.11           7.17           2.89
# 10            15.8          1.16           7.11           7.17           8.70
# 11            28.4          1.16           0.76           0.84           1.93
# 12            24.9          6.07           2.86           7.17           6.45
# 13            24.9          6.07           0.88           0.84           1.93
# 14            24.9          6.07           0.88           0.84           1.93
# 15            24.9          6.07           0.88           0.84           1.93
#
#     SS_rostership  OF_rostership  OF.1_rostership  OF.2_rostership  \
# 0            7.20          10.00             6.50             1.12
# 1            7.20          10.00             7.94             1.12
# 2            7.20          10.00             7.94             1.12
# 3            7.20          10.00             6.50             1.12
# 4            7.20          10.00             7.94             1.12
# 5            7.20          10.00             7.94             1.12
# 6            7.20           7.94             6.50             1.12
# 7            7.20           7.94             6.50             2.97
# 8            7.20           7.94             6.50             1.12
# 9            7.20           7.94             6.50             1.12
# 10           7.20          10.00             7.94             1.12
# 11           7.20           6.50             1.12             5.00
# 12           7.20           6.50             1.12             2.97
# 13           9.85          10.00             1.12             2.97
# 14           9.85          10.00             1.89             1.12
# 15           5.00          10.00             1.12             2.97
#
#            AVG      P50       P75      P90       P95       P99    P100  \
# 0   118.034573  116.175  137.2750  156.340  169.8000  203.3850  253.10
# 1   118.124851  115.975  137.3750  157.195  169.4875  203.3395  252.10
# 2   118.086161  116.400  136.4875  156.180  170.6175  195.7790  248.30
# 3   117.649653  115.950  136.6125  157.030  168.9975  191.5720  236.10
# 4   118.850050  116.300  138.0375  156.395  167.0225  200.3635  241.95
# 5   118.462153  116.450  137.1125  156.205  168.4350  203.1620  257.30
# 6   116.974058  114.875  135.1625  154.595  166.0325  197.0475  271.10
# 7   116.585169  114.275  134.5750  154.975  166.5450  194.6720  253.10
# 8   116.935367  114.900  136.4750  154.865  166.6850  192.0230  264.10
# 9   116.589137  114.475  136.6625  154.395  165.9150  193.8050  254.10
# 10  107.116220  105.125  126.5250  147.175  160.5500  188.6265  240.65
# 11  114.021677  112.275  131.5750  150.615  163.8625  185.9150  236.50
# 12  107.171627  106.325  126.7000  144.595  157.5275  179.8395  216.95
# 13  103.895833  101.750  123.0625  142.780  152.6925  180.7290  190.80
# 14  103.737103  101.000  121.4250  141.650  154.9625  182.5235  195.85
# 15  103.171627  102.800  121.5625  140.480  153.0300  178.4400  208.25
#
#        Tail    Sim STD       Plus2       Plus3  rostership  \
# 0   9857.05  31.015347  180.065695  211.081042       85.29
# 1   9667.80  30.483703  179.092406  209.576108       87.69
# 2   9582.70  30.207136  178.500272  208.707408       87.60
# 3   9540.50  30.275962  178.201924  208.477886       84.59
# 4   9659.15  29.789664  178.429329  208.218993       96.37
# 5   9664.15  29.833802  178.129605  207.963407       93.30
# 6   9387.80  29.532351  176.038702  205.571053       84.19
# 7   9399.75  29.645237  175.875475  205.520712       83.96
# 8   9414.75  29.527536  175.990073  205.517609       84.10
# 9   9223.70  29.020398  174.629796  203.650194       83.49
# 10  9260.10  31.055136  169.226273  200.281409       91.10
# 11  9166.60  28.496943  171.015885  199.512828       67.61
# 12  8779.90  29.243399  165.658797  194.902196       85.32
# 13  8638.45  28.820078  161.536155  190.356233       78.64
# 14  8604.90  28.840358  161.417716  190.258075       77.56
# 15  8533.20  28.860819  160.893638  189.754457       73.79
#
#     pitcher rostership  batter rostership  pareto
# 0                43.10              42.19       1
# 1                43.10              44.59       1
# 2                43.10              44.50       1
# 3                43.10              41.49       1
# 4                43.10              53.27       1
# 5                43.10              50.20       1
# 6                43.10              41.09       1
# 7                43.10              40.86       1
# 8                43.10              41.00       1
# 9                43.10              40.39       1
# 10               40.70              50.40       1
# 11               43.10              24.51       1
# 12               44.98              40.34       1
# 13               44.98              33.66       1
# 14               44.98              32.58       1
# 15               44.98              28.81       1

# %% [markdown]
# ##### 4. Uploads

# %%
upload = create_upload_file(contestKey, sort_by)
upload.to_csv(os.path.join(baseball_path, "B03. Lineups", "4. Uploads", f"Upload {contestKey}.csv"), index=False)

# %% [markdown]
# ##### 5. Entries

# %%
entry = create_entry_file(draftGroupId, contestKey)
entry.to_csv(os.path.join(baseball_path, "B03. Lineups", "5. Entries", f"Entries {draftGroupId}.csv"), index=False, encoding='iso-8859-1')

# %% [markdown]
# ##### Email

# %%
email_upload_file(draftGroupId, contestKey)

# %% [markdown]
# ##### Upload

# %%
upload_entries()

# %% [markdown]
# ### Run All

# %%
# Create list of contestKeys with available guides
contestKey_list = os.listdir(os.path.join(baseball_path, "A09. Contest Guides"))
contestKey_list = [int(key.replace(".csv", "").split(" ")[2]) for key in contestKey_list]


# Create list of contestKeys with available results
result_contestKey_list = os.listdir(os.path.join(baseball_path, "A01. DraftKings", "6. Player Results"))
result_contestKey_list = [int(key.replace(".csv", "").split(" ")[2]) for key in result_contestKey_list]

# Find the overlap 
available_contestKey_list = list(set(result_contestKey_list) & set(contestKey_list))

# %%
# %%time
# fail_list = Parallel(n_jobs=-1, verbose=1)(delayed(create_contest_lineups2)(contestKey, sort_by, min_salary, min_projection[0], major_stack[0], minor_stack[0], excluded_teams=[], lineups, historic=True) for contestKey in available_contestKey_list)

# %%
# %%time
# fail_list2 = Parallel(n_jobs=-1, verbose=1)(delayed(create_contest_lineups2)(contestKey, sort_by='Plus3', min_salary=49000, min_projection=4, major_stack=5, minor_stack=2, max_exposure_batters=0.5, max_exposure_pitchers=0.75, excluded_teams=[], lineups=lineups, historic=True) for contestKey in [contestKey for contestKey in fail_list if contestKey is not None])

# %%
# %%time
# fail_list3 = Parallel(n_jobs=-1, verbose=1)(delayed(create_contest_lineups2)(contestKey, sort_by='Plus3', min_salary=49000, min_projection=4, major_stack=4, minor_stack=2, max_exposure_batters=0.5, max_exposure_pitchers=0.75, excluded_teams=[], lineups=lineups, historic=True) for contestKey in [contestKey for contestKey in fail_list2 if contestKey is not None])
