# %% [markdown]
# # M01. Batted Balls

# %% [markdown]
# ### Imports

# %%
# %run "C:\Users\james\Documents\MLB\Code\U1. Imports.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U2. Functions.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U3. Classes.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U4. Datasets.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U5. Models.ipynb"

# %% [markdown]
# ### Data

# %% [markdown]
# ##### MLB Stats API

# %%
start_year, end_year = 2015, 2025

# %% [markdown]
# Merge MLB Stats API and Statcast data

# %%
# %%time
df = merge_datasets(start_year, end_year)
df = clean_weather(df)
df = create_events(df)
df = create_variables(df)
df = start_data(df)
# Out:
# CPU times: total: 1min 48s
# Wall time: 51.7 s

# %% [markdown]
# Note:
# - if y > 198.27 and x < 125.42), it's actually to left
# - if y > 198.27 and x > 125.42), it's actually to right

# %% [markdown]
# Convert data types

# %%
df['proj_date'] = pd.to_datetime(df['date'], format='%Y%m%d')

# %%
df['mlbamid'] = df['batter'].astype(str)

# %% [markdown]
# ##### Baserunning

# %%
steamer_hitters_df = pd.read_csv(os.path.join(baseball_path, "A03. Steamer", "steamer_hitters_weekly_log.csv"), encoding='iso-8859-1', usecols=['proj_date', 'mlbamid', 'PA', 'UBR'], dtype='str')

# %% [markdown]
# Convert data types

# %%
steamer_hitters_df[['PA', 'UBR']] = steamer_hitters_df[['PA', 'UBR']].astype(float)

# %%
steamer_hitters_df['proj_date'] = pd.to_datetime(steamer_hitters_df['proj_date'])

# %% [markdown]
# Calculate UBR per 600 Plate Appearances

# %%
steamer_hitters_df['UBR600'] = steamer_hitters_df['UBR'] / steamer_hitters_df['PA'] * 600

# %% [markdown]
# ##### Merge

# %% [markdown]
# Baserunning Data

# %%
complete_dataset = pd.merge_asof(
    df.sort_values('proj_date'),
    steamer_hitters_df.sort_values('proj_date'),
    by='mlbamid',
    on='proj_date',
    direction='backward'
)

# %%
complete_dataset.shape
# Out:
# (1909345, 159)

# %% [markdown]
# ##### Sample

# %% [markdown]
# Sent launch data to 0 if not batted

# %%
complete_dataset[['launch_angle', 'launch_speed']] = complete_dataset[['launch_angle', 'launch_speed']].fillna(0)

# %% [markdown]
# Remove atypical events

# %%
complete_dataset = complete_dataset[~complete_dataset['eventsModel'].isin(["Cut"])].copy()

# %% [markdown]
# Select inputs

# %%
batted_ball_inputs = ['launch_angle', 'launch_speed', 'to_l', 'to_lc', 'to_c', 'to_rc', 'to_r', 'b_L', 'UBR600'] + ['bb', 'hbp', 'so']

# %%
complete_dataset = complete_dataset.dropna(subset=batted_ball_inputs)

# %% [markdown]
# ### Model #1. Expected Outcome

# %% [markdown]
# Probability of events given how the baseball was launched, where it was launched to, and some information about the batter, including handedness and base running. Notably excluded park and weather.

# %% [markdown]
# $ \hat{\text{eventsModel}} = launch\_angle + launch\_speed + to\_l + to\_lc + to\_c + to\_rc + to\_r + b\_L + UBR600 $

# %% [markdown]
# Define model input and outputs

# %%
X = complete_dataset[batted_ball_inputs].values
y = complete_dataset[['eventsModel']].values

# %% [markdown]
# ##### Encode

# %%
# Create one-hot encoder
encode_outcome = OneHotEncoder(sparse_output=False)
# Fit and transform
y_encoded = encode_outcome.fit_transform(y)
# Create folder
os.makedirs(os.path.join(model_path, "M01. Batted Balls", todaysdate), exist_ok=True)   
# Save
pickle.dump(encode_outcome, open(os.path.join(model_path, "M01. Batted Balls", todaysdate, "encode_output.pkl"), 'wb'))

# %% [markdown]
# ##### Scale

# %%
# Create scaler
scale_inputs = StandardScaler()
# Fit and transform
X_scaled = scale_inputs.fit_transform(X)
# Save
pickle.dump(scale_inputs, open(os.path.join(model_path, "M01. Batted Balls", todaysdate, "scale_inputs.pkl"), 'wb'))

# %% [markdown]
# ##### Train

# %%
# %%time
# Create neural network
predict_batted_balls = Sequential([
    Dense(32, input_shape=(X_scaled.shape[1],), activation='relu'),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(y_encoded.shape[1], activation='softmax')  # softmax for multi-class classification
])
# Compile
predict_batted_balls.compile(optimizer=Adam(learning_rate=0.00001), loss='categorical_crossentropy', metrics=['accuracy'])
# Use early stopping
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
# Fit
predict_batted_balls.fit(
    X_scaled, y_encoded,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stop])
# Save
predict_batted_balls.save(os.path.join(model_path, "M01. Batted Balls", todaysdate, 'predict_batted_balls.keras'))
# Out:
# Epoch 1/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 72s 1ms/step - accuracy: 0.7125 - loss: 0.9091 - val_accuracy: 0.8265 - val_loss: 0.4817
# Epoch 2/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 69s 1ms/step - accuracy: 0.8196 - loss: 0.4952 - val_accuracy: 0.8334 - val_loss: 0.4492
# Epoch 3/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 66s 1ms/step - accuracy: 0.8270 - loss: 0.4679 - val_accuracy: 0.8357 - val_loss: 0.4384
# Epoch 4/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 67s 1ms/step - accuracy: 0.8303 - loss: 0.4542 - val_accuracy: 0.8378 - val_loss: 0.4305
# Epoch 5/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 69s 1ms/step - accuracy: 0.8313 - loss: 0.4487 - val_accuracy: 0.8380 - val_loss: 0.4258
# Epoch 6/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 70s 1ms/step - accuracy: 0.8324 - loss: 0.4440 - val_accuracy: 0.8407 - val_loss: 0.4204
# Epoch 7/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 71s 2ms/step - accuracy: 0.8322 - loss: 0.4410 - val_accuracy: 0.8401 - val_loss: 0.4185
# Epoch 8/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 68s 1ms/step - accuracy: 0.8322 - loss: 0.4388 - val_accuracy: 0.8389 - val_loss: 0.4194
# Epoch 9/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 68s 1ms/step - accuracy: 0.8330 - loss: 0.4357 - val_accuracy: 0.8404 - val_loss: 0.4143
# Epoch 10/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 69s 1ms/step - accuracy: 0.8339 - loss: 0.4334 - val_accuracy: 0.8394 - val_loss: 0.4144
# Epoch 11/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 81s 2ms/step - accuracy: 0.8335 - loss: 0.4323 - val_accuracy: 0.8407 - val_loss: 0.4128
# Epoch 12/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 84s 2ms/step - accuracy: 0.8338 - loss: 0.4308 - val_accuracy: 0.8393 - val_loss: 0.4141
# Epoch 13/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 69s 1ms/step - accuracy: 0.8343 - loss: 0.4290 - val_accuracy: 0.8416 - val_loss: 0.4098
# Epoch 14/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 69s 1ms/step - accuracy: 0.8340 - loss: 0.4290 - val_accuracy: 0.8410 - val_loss: 0.4114
# Epoch 15/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 70s 2ms/step - accuracy: 0.8349 - loss: 0.4276 - val_accuracy: 0.8416 - val_loss: 0.4089
# Epoch 16/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 70s 1ms/step - accuracy: 0.8343 - loss: 0.4279 - val_accuracy: 0.8424 - val_loss: 0.4084
# Epoch 17/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 71s 2ms/step - accuracy: 0.8344 - loss: 0.4274 - val_accuracy: 0.8423 - val_loss: 0.4080
# Epoch 18/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 80s 2ms/step - accuracy: 0.8340 - loss: 0.4274 - val_accuracy: 0.8413 - val_loss: 0.4092
# Epoch 19/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 79s 2ms/step - accuracy: 0.8353 - loss: 0.4252 - val_accuracy: 0.8401 - val_loss: 0.4097
# Epoch 20/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 79s 2ms/step - accuracy: 0.8349 - loss: 0.4258 - val_accuracy: 0.8426 - val_loss: 0.4045
# Epoch 21/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 76s 2ms/step - accuracy: 0.8358 - loss: 0.4239 - val_accuracy: 0.8424 - val_loss: 0.4065
# Epoch 22/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 73s 2ms/step - accuracy: 0.8357 - loss: 0.4235 - val_accuracy: 0.8432 - val_loss: 0.4048
# Epoch 23/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 78s 2ms/step - accuracy: 0.8346 - loss: 0.4256 - val_accuracy: 0.8433 - val_loss: 0.4046
# Epoch 24/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 92s 2ms/step - accuracy: 0.8354 - loss: 0.4234 - val_accuracy: 0.8436 - val_loss: 0.4041
# Epoch 25/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 76s 2ms/step - accuracy: 0.8353 - loss: 0.4226 - val_accuracy: 0.8404 - val_loss: 0.4112
# Epoch 26/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 83s 2ms/step - accuracy: 0.8357 - loss: 0.4231 - val_accuracy: 0.8440 - val_loss: 0.4033
# Epoch 27/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 84s 2ms/step - accuracy: 0.8351 - loss: 0.4244 - val_accuracy: 0.8439 - val_loss: 0.4035
# Epoch 28/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 90s 2ms/step - accuracy: 0.8355 - loss: 0.4231 - val_accuracy: 0.8431 - val_loss: 0.4042
# Epoch 29/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 77s 2ms/step - accuracy: 0.8359 - loss: 0.4226 - val_accuracy: 0.8421 - val_loss: 0.4068
# Epoch 30/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 76s 2ms/step - accuracy: 0.8356 - loss: 0.4224 - val_accuracy: 0.8424 - val_loss: 0.4044
# Epoch 31/100
# 46817/46817 ━━━━━━━━━━━━━━━━━━━━ 77s 2ms/step - accuracy: 0.8364 - loss: 0.4210 - val_accuracy: 0.8432 - val_loss: 0.4036

# %% [markdown]
# ##### Predict

# %% [markdown]
# Predicted rates of events based on batted-ball data

# %%
predictions = predict_batted_balls.predict(X_scaled)

prediction_df = pd.DataFrame(predictions, columns=encode_outcome.categories_[0])
prediction_df = prediction_df.add_suffix('_pred_batted')

prediction_df = pd.concat([complete_dataset.reset_index(drop=True), prediction_df], axis=1)
# Out:
# 58521/58521 ━━━━━━━━━━━━━━━━━━━━ 44s 758us/step

# %% [markdown]
# ##### Evaluate

# %%
# Adjust the number of rows and columns
n_events = len(events_list)
n_cols = 3
n_rows = (n_events + n_cols - 1) // n_cols  # Ceiling division

# Set square plots: each subplot is 5x5 inches
fig, axes = plt.subplots(n_rows, n_cols, figsize=(5 * n_cols, 5 * n_rows))
axes = axes.flatten()

for i, event in enumerate(events_list):
    ax = axes[i]
    pred_col = f"{event}_pred_batted"
    
    if pred_col not in prediction_df.columns:
        continue

    # Bucket the predicted values into quantiles
    prediction_df['bucket'] = pd.qcut(prediction_df[pred_col], q=20, duplicates='drop')

    # Compute averages
    bucket_avg = prediction_df.groupby('bucket').agg(
        avg_pred=(pred_col, 'mean'),
        avg_actual=(event, 'mean')
    ).reset_index()

    # Plot
    ax.plot(bucket_avg['avg_pred'], label='Predicted')
    ax.plot(bucket_avg['avg_actual'], label='Actual')
    ax.set_title(f"{event.upper()} Prediction vs Actual")
    ax.set_xlabel("Quantile Bucket")
    ax.set_ylabel("Rate")
    ax.legend()
    ax.grid(True)

# Remove extra axes if any
for j in range(n_events, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
