# %% [markdown]
# # Contest Key Master List

# %% [markdown]
# ## 1. Results

# %% [markdown]
# ### Contest Results

# %%
folder_path = r"C:\Users\james\Documents\MLB\Data2\1. Results\A. Contest Results"

# Get a list of all files in the folder
files = os.listdir(folder_path)

# Regular expression pattern to match the numbers
pattern = r"contest-standings-(\d+)"

# List to store the extracted numbers
resultKeys = []

# Iterate over the files and extract the numbers
for file in files:
    match = re.search(pattern, file)
    if match:
        contestKey = match.group(1)
        resultKeys.append(contestKey)
        
len(resultKeys)
# Out:
# 255

# %% [markdown]
# ### Leaderboards

# %%
folder_path = r"C:\Users\james\Documents\MLB\Data2\1. Results\B. Leaderboards"

# Get a list of all files in the folder
files = os.listdir(folder_path)

# Regular expression pattern to match the numbers
pattern = r"Leaderboard (\d+)"

# List to store the extracted numbers
leaderboardKeys = []

# Iterate over the files and extract the numbers
for file in files:
    match = re.search(pattern, file)
    if match:
        contestKey = match.group(1)
        leaderboardKeys.append(contestKey)
        
len(leaderboardKeys)
# Out:
# 108

# %% [markdown]
# ## 2. Contests

# %% [markdown]
# ### Payouts

# %%
folder_path = r"C:\Users\james\Documents\MLB\Data2\2. Contests\B. Payouts"

# Get a list of all files in the folder
files = os.listdir(folder_path)

# Regular expression pattern to match the numbers
pattern = r"Payouts (\d+)"

# List to store the extracted numbers
payoutKeys = []

# Iterate over the files and extract the numbers
for file in files:
    match = re.search(pattern, file)
    if match:
        contestKey = match.group(1)
        payoutKeys.append(contestKey)
        
len(payoutKeys)
# Out:
# 340

# %% [markdown]
# ### Salaries

# %%
folder_path = r"C:\Users\james\Documents\MLB\Data2\2. Contests\C. Salaries"

# Get a list of all files in the folder
files = os.listdir(folder_path)

# Regular expression pattern to match the numbers
pattern = r"Salaries (\d+)"

# List to store the extracted numbers
salaryKeys = []

# Iterate over the files and extract the numbers
for file in files:
    match = re.search(pattern, file)
    if match:
        contestKey = match.group(1)
        salaryKeys.append(contestKey)
        
len(salaryKeys)
# Out:
# 339

# %% [markdown]
# ## 11. Projections

# %% [markdown]
# ### DFF

# %%
folder_path = r"C:\Users\james\Documents\MLB\Data2\11. Projections\A. DFF"

# Get a list of all files in the folder
files = os.listdir(folder_path)

# Regular expression pattern to match the numbers
pattern = r"DFF_MLB_cheatsheet_(\d+\-\d+\-\d+)"

# List to store the extracted numbers
dffDates = []

# Iterate over the files and extract the numbers
for file in files:
    match = re.search(pattern, file)
    if match:
        date = match.group(1)
        date = date.replace("-", "")
        dffDates.append(date)

len(dffDates)
# Out:
# 193

# %% [markdown]
# ### RotoWire

# %%
folder_path = r"C:\Users\james\Documents\MLB\Data2\11. Projections\B. RotoWire"

# Get a list of all files in the folder
files = os.listdir(folder_path)

# Regular expression pattern to match the numbers
pattern = r"Ownership_(\d+)"

# List to store the extracted numbers
rotoDates = []

# Iterate over the files and extract the numbers
for file in files:
    match = re.search(pattern, file)
    if match:
        date = match.group(1)
        rotoDates.append(date)
        
len(rotoDates)
# Out:
# 252

# %%
# Create a set of all unique contest keys
contestKeys = set(resultKeys + leaderboardKeys + payoutKeys + salaryKeys)

# Create a dataframe with contestKey column
df = pd.DataFrame({'contestKey': list(contestKeys)})

# Add columns indicating the presence of contestKey in each list
df['result'] = df['contestKey'].isin(resultKeys).astype(int)
df['leaderboard'] = df['contestKey'].isin(leaderboardKeys).astype(int)
df['payout'] = df['contestKey'].isin(payoutKeys).astype(int)
df['salary'] = df['contestKey'].isin(salaryKeys).astype(int)
# Out:
#     contestKey  result  leaderboard  payout  salary
# 0    146153490       1            1       1       1
# 1    125294388       1            0       1       1
# 2    143828084       1            0       1       1
# 3    143650745       0            0       1       1
# 4    129464514       0            0       1       1
# ..         ...     ...          ...     ...     ...
# 348  146395128       1            1       1       1
# 349  126016178       0            0       1       1
# 350  146047302       1            1       1       1
# 351  125939897       0            0       1       1
# 352  146900195       1            1       1       1
#
# [353 rows x 5 columns]

# %%
import os
import pandas as pd
from dateutil import parser

salaries_folder_path = r"C:\Users\james\Documents\MLB\Data2\2. Contests\C. Salaries"
payouts_folder_path = r"C:\Users\james\Documents\MLB\Data2\2. Contests\B. Payouts"

# Create new columns in the existing dataframe
df['date'] = None
df['entryFee'] = None
df['entries'] = None
df['draftGroupId'] = None
df['name'] = None

# Loop over values in "contestKey" column
for index, row in df.iterrows():
    contestKey = row['contestKey']
    
    # Read Salaries CSV file
    salaries_file_path = os.path.join(salaries_folder_path, f"Salaries {contestKey}.csv")
    if os.path.isfile(salaries_file_path):
        df_salaries = pd.read_csv(salaries_file_path, encoding='iso-8859-1')
        
        # Extract the date from the first row of "Game Info" column
        first_row_game_info = df_salaries.loc[0, 'Game Info']
        date_match = re.search(r'\d{2}/\d{2}/\d{4}', first_row_game_info)
        if date_match:
            date_str = date_match.group()
            date = parser.parse(date_str).strftime('%Y%m%d')
            df.at[index, 'date'] = date
    
    # Read Payouts CSV file
    payouts_file_path = os.path.join(payouts_folder_path, f"Payouts {contestKey}.csv")
    if os.path.isfile(payouts_file_path):
        df_payouts = pd.read_csv(payouts_file_path, encoding='iso-8859-1')
        
        # Extract desired columns from the first observation
        if not df_payouts.empty:
            df.at[index, 'entryFee'] = df_payouts.loc[0, 'entryFee']
            df.at[index, 'entries'] = df_payouts.loc[0, 'entries']
            df.at[index, 'draftGroupId'] = df_payouts.loc[0, 'draftGroupId']
            df.at[index, 'name'] = df_payouts.loc[0, 'name']
# Out:
#     contestKey  result  leaderboard  payout  salary      date entryFee  \
# 0    146153490       1            1       1       1  20230630        4
# 1    125294388       1            0       1       1  20220407       15
# 2    143828084       1            0       1       1  20230424        4
# 3    143650745       0            0       1       1  20230419        4
# 4    129464514       0            0       1       1  20220731        5
# ..         ...     ...          ...     ...     ...       ...      ...
# 348  146395128       1            1       1       1  20230707        4
# 349  126016178       0            0       1       1  20220421        5
# 350  146047302       1            1       1       1  20230627        4
# 351  125939897       0            0       1       1  20220419        1
# 352  146900195       1            1       1       1  20230719        4
#
#     entries draftGroupId                                          name
# 0        98        89147                   MLB $3K Four-Seamer (Night)
# 1     30205        66314  MLB $400K Opening Day Special [$100K to 1st]
# 2     14799        86162           MLB $50K Four-Seamer [20 Entry Max]
# 3      2972        85903   MLB $10K Four-Seamer [20 Entry Max] (Night)
# 4      2378        72239            MLB $10K Chin Music [Single Entry]
# ..      ...          ...                                           ...
# 348      45        89386                   MLB $1K Four-Seamer (Turbo)
# 349     297        67529  MLB $1.25K Chin Music [Single Entry] (Night)
# 350      43        89015                   MLB $1K Four-Seamer (Turbo)
# 351      39        67305                              MLB $1 Double Up
# 352    1207        89732           MLB $30K Four-Seamer [20 Entry Max]
#
# [353 rows x 10 columns]

# %%
df.sort_values('contestKey', inplace=True, ascending=False)
df.to_csv(r"C:\Users\james\Documents\MLB\Data2\Utilities\Contests.csv")
