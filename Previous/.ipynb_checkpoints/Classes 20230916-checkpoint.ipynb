# %%
# This creates a class called Batter with all the necessary stats - rates and totals
class Batter:
    def __init__(self, Name, ID, bats,
                 
                 b1_l, b2_l, b3_l, hr_l, bb_l, hbp_l, 
                 so_l, lo_l, po_l, go_l, fo_l, 
                 woba_l, estimated_woba_using_speedangle_l, slg_l, obp_l, iso_l,
                 to_left_l, to_middle_l, to_right_l,
                 hard_hit_l, barrel_l, totalDistance_l, launchSpeed_l,
                 pa_l, ab_l,
                 
                 b1_r, b2_r, b3_r, hr_r, bb_r, hbp_r, 
                 so_r, lo_r, po_r, go_r, fo_r, 
                 woba_r, estimated_woba_using_speedangle_r, slg_r, obp_r, iso_r,
                 to_left_r, to_middle_r, to_right_r,
                 hard_hit_r, barrel_r, totalDistance_r, launchSpeed_r,
                 pa_r, ab_r,
                 
                 b1_long_l, b2_long_l, b3_long_l, hr_long_l, bb_long_l, hbp_long_l, 
                 so_long_l, lo_long_l, po_long_l, go_long_l, fo_long_l, 
                 woba_long_l, estimated_woba_using_speedangle_long_l, slg_long_l, obp_long_l, iso_long_l,
                 to_left_long_l, to_middle_long_l, to_right_long_l,
                 hard_hit_long_l, barrel_long_l, totalDistance_long_l, launchSpeed_long_l,
                 pa_long_l, ab_long_l,
                 
                 b1_long_r, b2_long_r, b3_long_r, hr_long_r, bb_long_r, hbp_long_r, 
                 so_long_r, lo_long_r, po_long_r, go_long_r, fo_long_r, 
                 woba_long_r, estimated_woba_using_speedangle_long_r, slg_long_r, obp_long_r, iso_long_r,
                 to_left_long_r, to_middle_long_r, to_right_long_r,
                 hard_hit_long_r, barrel_long_r, totalDistance_long_r, launchSpeed_long_r,
                 pa_long_r, ab_long_r,
                 imp_l, imp_r,
                 
                b1_rate, b2_rate, b3_rate, hr_rate, bb_rate, hbp_rate, so_rate, fgobp, fgslg, fgwoba, 
                sba_2b, sba_3b, sb_2b, sb_3b, order, imputed
                ):
        
        
        
        
        self.Name = Name
        self.ID = ID
        self.bats = bats
        self.bats_copy = bats
        
        ### Proclivities against pitcher's hand
        # Short
        self.b1 = 0
        self.b2 = 0
        self.b3 = 0
        self.hr = 0
        self.bb = 0
        self.hbp = 0
        
        self.so = 0       
        self.lo = 0
        self.po = 0
        self.go = 0
        self.fo = 0
        
        self.woba = 0
        self.estimated_woba_using_speedangle = 0
        self.slg = 0
        self.obp = 0
        self.iso = 0
        
        self.to_left = 0
        self.to_middle = 0
        self.to_right = 0
        
        self.hard_hit = 0
        self.barrel = 0
        self.totalDistance = 0
        self.launchSpeed = 0
        
        self.pa = 0
        self.ab = 0
        
        
        # Long
        self.b1_long = 0
        self.b2_long = 0
        self.b3_long = 0
        self.hr_long = 0
        self.bb_long = 0
        self.hbp_long = 0
        
        self.so_long = 0       
        self.lo_long = 0
        self.po_long = 0
        self.go_long = 0
        self.fo_long = 0
        
        self.woba_long = 0
        self.estimated_woba_using_speedangle_long = 0
        self.slg_long = 0
        self.obp_long = 0
        self.iso_long = 0
        
        self.to_left_long = 0
        self.to_middle_long = 0
        self.to_right_long = 0
        
        self.hard_hit_long = 0
        self.barrel_long = 0
        self.totalDistance_long = 0
        self.launchSpeed_long = 0
        
        self.pa_long = 0
        self.ab_long = 0
        
        self.imp_l = 0
        self.imp_r = 0
        
        # Fangraphs 
        self.b1_rate = 0
        self.b2_rate = 0
        self.b3_rate = 0
        self.hr_rate = 0
        self.bb_rate = 0
        self.hbp_rate = 0
        self.so_rate = 0
        self.fgobp = 0
        self.fgslg = 0
        self.fgwoba = 0
        
        # Base running
        self.sba_2b = 0
        self.sb_2b = 0
        self.sba_3b = 0
        self.sb_3b = 0
        
        ##########################
        
        ### Proclivities against each hand
        # Short
        # Lefties
        self.b1_l = b1_l
        self.b2_l = b2_l
        self.b3_l = b3_l
        self.hr_l = hr_l
        self.bb_l = bb_l
        self.hbp_l = hbp_l
        
        self.so_l = so_l       
        self.lo_l = lo_l
        self.po_l = po_l
        self.go_l = go_l
        self.fo_l = fo_l
        
        self.woba_l = woba_l
        self.estimated_woba_using_speedangle_l = estimated_woba_using_speedangle_l
        self.slg_l = slg_l
        self.obp_l = obp_l
        self.iso_l = iso_l
        
        self.to_left_l = to_left_l
        self.to_middle_l = to_middle_l
        self.to_right_l = to_right_l
        
        self.hard_hit_l = hard_hit_l
        self.barrel_l = barrel_l
        self.totalDistance_l = totalDistance_l
        self.launchSpeed_l = launchSpeed_l
        
        self.pa_l = pa_l
        self.ab_l = ab_l
        
        
        # Proclivities vs. righties
        self.b1_r = b1_r
        self.b2_r = b2_r
        self.b3_r = b3_r
        self.hr_r = hr_r
        self.bb_r = bb_r
        self.hbp_r = hbp_r
        
        self.so_r = so_r       
        self.lo_r = lo_r
        self.po_r = po_r
        self.go_r = go_r
        self.fo_r = fo_r
        
        self.woba_r = woba_r
        self.estimated_woba_using_speedangle_r = estimated_woba_using_speedangle_r
        self.slg_r = slg_r
        self.obp_r = obp_r
        self.iso_r = iso_r
        
        self.to_left_r = to_left_r
        self.to_middle_r = to_middle_r
        self.to_right_r = to_right_r
        
        self.hard_hit_r = hard_hit_r
        self.barrel_r = barrel_r
        self.totalDistance_r = totalDistance_r
        self.launchSpeed_r = launchSpeed_r
        
        self.pa_r = pa_r
        self.ab_r = ab_r
        
        # Long
        # Proclivities vs. lefties
        self.b1_long_l = b1_long_l
        self.b2_long_l = b2_long_l
        self.b3_long_l = b3_long_l
        self.hr_long_l = hr_long_l
        self.bb_long_l = bb_long_l
        self.hbp_long_l = hbp_long_l
        
        self.so_long_l = so_long_l       
        self.lo_long_l = lo_long_l
        self.po_long_l = po_long_l
        self.go_long_l = go_long_l
        self.fo_long_l = fo_long_l
        
        self.woba_long_l = woba_long_l
        self.estimated_woba_using_speedangle_long_l = estimated_woba_using_speedangle_long_l
        self.slg_long_l = slg_long_l
        self.obp_long_l = obp_long_l
        self.iso_long_l = iso_long_l
        
        self.to_left_long_l = to_left_long_l
        self.to_middle_long_l = to_middle_long_l
        self.to_right_long_l = to_right_long_l
        
        self.hard_hit_long_l = hard_hit_long_l
        self.barrel_long_l = barrel_long_l
        self.totalDistance_long_l = totalDistance_long_l
        self.launchSpeed_long_l = launchSpeed_long_l
        
        self.pa_long_l = pa_long_l
        self.ab_long_l = ab_long_l
        
        
        # Proclivities vs. righties
        self.b1_long_r = b1_long_r
        self.b2_long_r = b2_long_r
        self.b3_long_r = b3_long_r
        self.hr_long_r = hr_long_r
        self.bb_long_r = bb_long_r
        self.hbp_long_r = hbp_long_r
        
        self.so_long_r = so_long_r     
        self.lo_long_r = lo_long_r
        self.po_long_r = po_long_r
        self.go_long_r = go_long_r
        self.fo_long_r = fo_long_r
        
        self.woba_long_r = woba_long_r
        self.estimated_woba_using_speedangle_long_r = estimated_woba_using_speedangle_long_r
        self.slg_long_r = slg_long_r
        self.obp_long_r = obp_long_r
        self.iso_long_r = iso_long_r
        
        self.to_left_long_r = to_left_long_r
        self.to_middle_long_r = to_middle_long_r
        self.to_right_long_r = to_right_long_r
        
        self.hard_hit_long_r = hard_hit_long_r
        self.barrel_long_r = barrel_long_r
        self.totalDistance_long_r = totalDistance_long_r
        self.launchSpeed_long_r = launchSpeed_long_r
        
        self.pa_long_r = pa_long_r
        self.ab_long_r = ab_long_r
        
        self.imp_l = imp_l
        self.imp_r = imp_r
        
        # Fangraphs 
        self.b1_rate = b1_rate
        self.b2_rate = b2_rate
        self.b3_rate = b3_rate
        self.hr_rate = hr_rate
        self.bb_rate = bb_rate
        self.hbp_rate = hbp_rate
        self.so_rate = so_rate
        self.fgobp = fgobp
        self.fgslg = fgslg
        self.fgwoba = fgwoba
        
        # Base running
        self.sba_2b = sba_2b
        self.sb_2b = sb_2b
        self.sba_3b = sba_3b
        self.sb_3b = sb_3b
        
        self.order = order
        
        self.imputed = imputed
                
        # Game stats    
        self.HBP = 0
        self.BB = 0
        self.B1 = 0
        self.B2 = 0
        self.B3 = 0
        self.HR = 0
        self.SB = 0
        self.R = 0
        self.RBI = 0
        self.FP = 0

# %%
class Pitcher:
    def __init__(self, Name, ID, throws,
                 b1_l, b2_l, b3_l, hr_l, bb_l, hbp_l, 
                 so_l, lo_l, po_l, go_l, fo_l, 
                 woba_l, estimated_woba_using_speedangle_l, slg_l, obp_l, iso_l,
                 to_left_l, to_middle_l, to_right_l,
                 hard_hit_l, barrel_l, maxSpeed_l, maxSpin_l,
                 pa_l, ab_l,
                 
                 b1_r, b2_r, b3_r, hr_r, bb_r, hbp_r, 
                 so_r, lo_r, po_r, go_r, fo_r, 
                 woba_r, estimated_woba_using_speedangle_r, slg_r, obp_r, iso_r,
                 to_left_r, to_middle_r, to_right_r,
                 hard_hit_r, barrel_r, maxSpeed_r, maxSpin_r,
                 pa_r, ab_r,
                 
                 b1_long_l, b2_long_l, b3_long_l, hr_long_l, bb_long_l, hbp_long_l, 
                 so_long_l, lo_long_l, po_long_l, go_long_l, fo_long_l, 
                 woba_long_l, estimated_woba_using_speedangle_long_l, slg_long_l, obp_long_l, iso_long_l,
                 to_left_long_l, to_middle_long_l, to_right_long_l,
                 hard_hit_long_l, barrel_long_l, maxSpeed_long_l, maxSpin_long_l,
                 pa_long_l, ab_long_l,
                 
                 b1_long_r, b2_long_r, b3_long_r, hr_long_r, bb_long_r, hbp_long_r, 
                 so_long_r, lo_long_r, po_long_r, go_long_r, fo_long_r, 
                 woba_long_r, estimated_woba_using_speedangle_long_r, slg_long_r, obp_long_r, iso_long_r,
                 to_left_long_r, to_middle_long_r, to_right_long_r,
                 hard_hit_long_r, barrel_long_r, maxSpeed_long_r, maxSpin_long_r,
                 pa_long_r, ab_long_r,
                 imp_l, imp_r,
                 
                 H9, HR9, K9, BB9,
                 avgouts, avgFaced, starts, leverage, imputed
                 ):
        
        
        self.Name = Name
        self.ID = ID
        self.throws = throws
        
        # Proclivities against batter's hand
        # Short
        self.b1 = 0
        self.b2 = 0
        self.b3 = 0
        self.hr = 0
        self.bb = 0
        self.hbp = 0
        
        self.so = 0       
        self.lo = 0
        self.po = 0
        self.go = 0
        self.fo = 0
        
        self.woba = 0
        self.estimated_woba_using_speedangle = 0
        self.slg = 0
        self.obp = 0
        self.iso = 0
        
        self.to_left = 0
        self.to_middle = 0
        self.to_right = 0
        
        self.hard_hit = 0
        self.barrel = 0
        self.maxSpeed = 0
        self.maxSpin = 0
        
        self.pa = 0
        self.ab = 0
        
        
        # Long
        self.b1_long = 0
        self.b2_long = 0
        self.b3_long = 0
        self.hr_long = 0
        self.bb_long = 0
        self.hbp_long = 0
        
        self.so_long = 0       
        self.lo_long = 0
        self.po_long = 0
        self.go_long = 0
        self.fo_long = 0
        
        self.woba_long = 0
        self.estimated_woba_using_speedangle_long = 0
        self.slg_long = 0
        self.obp_long = 0
        self.iso_long = 0
        
        self.to_left_long = 0
        self.to_middle_long = 0
        self.to_right_long = 0
        
        self.hard_hit_long = 0
        self.barrel_long = 0
        self.maxSpeed_long = 0
        self.maxSpin_long = 0
        
        self.pa_long = 0
        self.ab_long = 0
        
        self.imp_l = 0
        self.imp_r = 0
        
        # Fangraphs 
        self.H9 = 0
        self.HR9 = 0
        self.K9 = 0
        self.BB9 = 0
        
        
        
        ##########################
        
        ### Proclivities against each hand
        # Short
        # Lefties
        self.b1_l = b1_l
        self.b2_l = b2_l
        self.b3_l = b3_l
        self.hr_l = hr_l
        self.bb_l = bb_l
        self.hbp_l = hbp_l
        
        self.so_l = so_l       
        self.lo_l = lo_l
        self.po_l = po_l
        self.go_l = go_l
        self.fo_l = fo_l
        
        self.woba_l = woba_l
        self.estimated_woba_using_speedangle_l = estimated_woba_using_speedangle_l 
        self.slg_l = slg_l
        self.obp_l = obp_l
        self.iso_l = iso_l
        
        self.to_left_l = to_left_l
        self.to_middle_l = to_middle_l
        self.to_right_l = to_right_l
        
        self.hard_hit_l = hard_hit_l
        self.barrel_l = barrel_l
        self.maxSpeed_l = maxSpeed_l
        self.maxSpin_l = maxSpin_l
        
        self.pa_l = pa_l
        self.ab_l = ab_l
        
        
        # Proclivities vs. righties
        self.b1_r = b1_r
        self.b2_r = b2_r
        self.b3_r = b3_r
        self.hr_r = hr_r
        self.bb_r = bb_r
        self.hbp_r = hbp_r
        
        self.so_r = so_r       
        self.lo_r = lo_r
        self.po_r = po_r
        self.go_r = go_r
        self.fo_r = fo_r
        
        self.woba_r = woba_r
        self.estimated_woba_using_speedangle_r = estimated_woba_using_speedangle_r
        self.slg_r = slg_r
        self.obp_r = obp_r
        self.iso_r = iso_r
        
        self.to_left_r = to_left_r
        self.to_middle_r = to_middle_r
        self.to_right_r = to_right_r
        
        self.hard_hit_r = hard_hit_r
        self.barrel_r = barrel_r
        self.maxSpeed_r = maxSpeed_r
        self.maxSpin_r = maxSpin_r
        
        self.pa_r = pa_r
        self.ab_r = ab_r
        
        # Long
        # Proclivities vs. lefties
        self.b1_long_l = b1_long_l
        self.b2_long_l = b2_long_l
        self.b3_long_l = b3_long_l
        self.hr_long_l = hr_long_l
        self.bb_long_l = bb_long_l
        self.hbp_long_l = hbp_long_l
        
        self.so_long_l = so_long_l       
        self.lo_long_l = lo_long_l
        self.po_long_l = po_long_l
        self.go_long_l = go_long_l
        self.fo_long_l = fo_long_l
        
        self.woba_long_l = woba_long_l
        self.estimated_woba_using_speedangle_long_l = estimated_woba_using_speedangle_long_l
        self.slg_long_l = slg_long_l
        self.obp_long_l = obp_long_l
        self.iso_long_l = iso_long_l
        
        self.to_left_long_l = to_left_long_l
        self.to_middle_long_l = to_middle_long_l
        self.to_right_long_l = to_right_long_l
        
        self.hard_hit_long_l = hard_hit_long_l
        self.barrel_long_l = barrel_long_l
        self.maxSpeed_long_l = maxSpeed_long_l
        self.maxSpin_long_l = maxSpin_long_l
        
        self.pa_long_l = pa_long_l
        self.ab_long_l = ab_long_l
        
        
        # Proclivities vs. righties
        self.b1_long_r = b1_long_r
        self.b2_long_r = b2_long_r
        self.b3_long_r = b3_long_r
        self.hr_long_r = hr_long_r
        self.bb_long_r = bb_long_r
        self.hbp_long_r = hbp_long_r
        
        self.so_long_r = so_long_r     
        self.lo_long_r = lo_long_r
        self.po_long_r = po_long_r
        self.go_long_r = go_long_r
        self.fo_long_r = fo_long_r
        
        self.woba_long_r = woba_long_r
        self.estimated_woba_using_speedangle_long_r = estimated_woba_using_speedangle_long_r
        self.slg_long_r = slg_long_r
        self.obp_long_r = obp_long_r
        self.iso_long_r = iso_long_r
        
        self.to_left_long_r = to_left_long_r
        self.to_middle_long_r = to_middle_long_r
        self.to_right_long_r = to_right_long_r
        
        self.hard_hit_long_r = hard_hit_long_r
        self.barrel_long_r = barrel_long_r
        self.maxSpeed_long_r = maxSpeed_long_r
        self.maxSpin_long_r = maxSpin_long_r
        
        self.pa_long_r = pa_long_r
        self.ab_long_r = ab_long_r
        
        self.imp_l = imp_l
        self.imp_r = imp_r
        
        # Fangraphs 
        self.H9 = H9
        self.HR9 = HR9
        self.K9 = K9
        self.BB9 = BB9
        
        # Pitcher stats
        self.avgouts = avgouts
        self.avgFaced = avgFaced
        self.starts = starts
        self.leverage = leverage
        
        self.imputed = imputed
        
        
        # Pitcher game stats
        self.winning = False
        self.OUT = 0
        self.SO = 0
        self.HBP = 0
        self.BB = 0
        self.B1 = 0
        self.B2 = 0
        self.B3 = 0
        self.HR = 0
        self.H = 0
        self.CS = 0
        self.ER = 0
        self.W = 0
        self.CG = 0
        self.CGSO = 0
        self.NH = 0
        self.FP = 0
        self.PA = 0
        
        self.faced = 1
        self.starter = 0

# %%
class Scoreboard:
    def __init__(self, home_batters, home_pitchers, away_batters, away_pitchers, park, innings):
        self.park = park
        self.ab = None
        self.pitching = None
        self.on_1b = None
        self.on_2b = None
        self.on_3b = None
        self.home_pitcher = 1
        self.away_pitcher = 1
        self.home_pitcher_up = None
        self.away_pitcher_up = None
        self.winning_pitcher = None
        self.home_score = 0
        self.away_score = 0
        self.winning_team = "Tie"
        self.innings = innings
        self.inning = 1
        self.top_bot = "Top"
        self.outs = 0
        self.home_batter = 1
        self.away_batter = 1
        self.home_starter_pulled = False
        self.away_starter_pulled = False
        self.home_batters = home_batters
        self.home_pitchers = home_pitchers
        self.away_batters = away_batters
        self.away_pitchers = away_pitchers
        self.home_starter = None
        self.away_starter = None
        
        self.onFirst = 0
        self.onSecond = 0
        self.onThird = 0
        
        self.x_vect = 0
        self.y_vect = 0
        self.TEMP_PARK_CT = 70
        
        self.venue_1 = 0
        self.venue_2 = 0
        self.venue_3 = 0
        self.venue_4 = 0
        self.venue_5 = 0
        
        self.venue_7 = 0
        self.venue_10 = 0
        self.venue_12 = 0
        self.venue_13 = 0
        self.venue_14 = 0
        
        self.venue_15 = 0
        self.venue_16 = 0
        self.venue_17 = 0
        self.venue_19 = 0
        self.venue_22 = 0
        
        self.venue_31 = 0
        self.venue_32 = 0
        self.venue_680 = 0
        self.venue_2392 = 0
        self.venue_2394 = 0
        
        self.venue_2395 = 0
        self.venue_2535 = 0
        self.venue_2536 = 0
        self.venue_2602 = 0
        self.venue_2680 = 0
        self.venue_2681 = 0
        
        self.venue_2701 = 0
        self.venue_2735 = 0
        self.venue_2756 = 0
        self.venue_2889 = 0
        self.venue_3289 = 0
        
        self.venue_3309 = 0
        self.venue_3312 = 0
        self.venue_3313 = 0
        self.venue_4169 = 0
        self.venue_4705 = 0
        
        self.venue_5010 = 0
        self.venue_5325 = 0
        self.venue_5365 = 0
        self.venue_5381 = 0
        self.venue_5445 = 0
