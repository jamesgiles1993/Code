# %% [markdown]
# # Models
# Creates 4 models <br>
# Currently a work in progress

# %%
import pandas as pd
import numpy as np
import pickle
import os
import math
import warnings
import re
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

baseball_path = r"C:\Users\james\Documents\MLB\Data"

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import log_loss, classification_report, f1_score, make_scorer
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.inspection import permutation_importance

import joblib

# %% [markdown]
# # Create sample dataset

# %%
# Read in sample dataset (calculated from API)
sample = pd.read_csv(os.path.join(baseball_path, "Inputs", "Sample100.csv"))
sample['date'] = sample['date'].str.replace("-", "")

# %%
# Read in FanGraphs batter projections for each day
batters_fg_sample = pd.read_csv(os.path.join(baseball_path, "Inputs", "Batters FanGraphs.csv"))
# Convert date to string for merge
batters_fg_sample['date'] = batters_fg_sample['date'].astype('str')

# Merge sample data with projections
sample = sample.merge(batters_fg_sample, left_on=['batter', 'date'], right_on=['mlbamid', 'date'], how='inner', suffixes=("_b"))
# Delete to clear up space
del batters_fg_sample

# Read in FanGraphs pitcher projections for each day
pitchers_fg_sample = pd.read_csv(os.path.join(baseball_path, "Inputs", "Pitchers FanGraphs.csv"))
# Convert date to string for merge
pitchers_fg_sample['date'] = pitchers_fg_sample['date'].astype('str')

# Merge sample data with projections
sample = sample.merge(pitchers_fg_sample, left_on=['pitcher', 'date'], right_on=['mlbamid', 'date'], how='inner', suffixes=("_p"))
# Delete to clear up space
del pitchers_fg_sample
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_21776\2574452826.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   batters_fg_sample = pd.read_csv(os.path.join(baseball_path, "Inputs", "Batters FanGraphs.csv"))
# C:\Users\james\AppData\Local\Temp\ipykernel_21776\2574452826.py:7: FutureWarning: Passing 'suffixes' as a <class 'str'>, is not supported and may give unexpected results. Provide 'suffixes' as a tuple instead. In the future a 'TypeError' will be raised.
#   sample = sample.merge(batters_fg_sample, left_on=['batter', 'date'], right_on=['mlbamid', 'date'], how='inner', suffixes=("_b"))
# C:\Users\james\AppData\Local\Temp\ipykernel_21776\2574452826.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   pitchers_fg_sample = pd.read_csv(os.path.join(baseball_path, "Inputs", "Pitchers FanGraphs.csv"))
# C:\Users\james\AppData\Local\Temp\ipykernel_21776\2574452826.py:17: FutureWarning: Passing 'suffixes' as a <class 'str'>, is not supported and may give unexpected results. Provide 'suffixes' as a tuple instead. In the future a 'TypeError' will be raised.
#   sample = sample.merge(pitchers_fg_sample, left_on=['pitcher', 'date'], right_on=['mlbamid', 'date'], how='inner', suffixes=("_p"))

# %% [markdown]
# # Model Inputs

# %%
# Inputs
batter_stats = ['b1_b','b2_b','b3_b','hr_b','bb_b','hbp_b',
                'so_b','fo_b','go_b','lo_b','po_b',
                'iso_b','slg_b','obp_b','woba_b',
                'to_left_b','to_middle_b','to_right_b',
                'hard_hit_b','totalDistance_b','launchSpeed_b','maxSpeed_b','maxSpin_b',
                'ab_b','pa_b',
                'b1_b_long','b2_b_long','b3_b_long','hr_b_long','bb_b_long','hbp_b_long',
                'so_b_long','fo_b_long','go_b_long','lo_b_long','po_b_long',
                'iso_b_long','slg_b_long','obp_b_long','woba_b_long',
                'to_left_b_long','to_middle_b_long','to_right_b_long',
                'hard_hit_b_long','totalDistance_b_long','launchSpeed_b_long','maxSpeed_b_long','maxSpin_b_long',
                'ab_b_long','pa_b_long']

pitcher_stats = ['b1_p','b2_p','b3_p','hr_p','bb_p','hbp_p',
                 'so_p','fo_p','go_p','lo_p','po_p',
                 'iso_p','slg_p','obp_p','woba_p',
                 'to_left_p','to_middle_p','to_right_p',
                 'hard_hit_p','totalDistance_p','launchSpeed_p','maxSpeed_p','maxSpin_p',
                 'ab_p','pa_p',
                 'b1_p_long','b2_p_long','b3_p_long','hr_p_long','bb_p_long','hbp_p_long',
                 'so_p_long','fo_p_long','go_p_long','lo_p_long','po_p_long',
                 'iso_p_long','slg_p_long','obp_p_long','woba_p_long',
                 'to_left_p_long','to_middle_p_long','to_right_p_long',
                 'hard_hit_p_long','totalDistance_p_long','launchSpeed_p_long','maxSpeed_p_long','maxSpin_p_long',
                 'ab_p_long','pa_p_long']

batter_stats_fg = ['b1_rate','b2_rate','b3_rate','hr_rate','bb_rate','hbp_rate','so_rate', 'woba', 'slg', 'obp']

pitcher_stats_fg = ['H/9','HR/9','K/9','BB/9']


venues = ['venue_1', 'venue_2', 'venue_3', 'venue_4', 'venue_5', 'venue_7', 'venue_10', 'venue_12', 
          'venue_13', 'venue_14', 'venue_15', 'venue_16', 'venue_17', 'venue_19', 'venue_22', 'venue_31', 
          'venue_32', 'venue_680', 'venue_2392', 'venue_2394', 'venue_2395', 'venue_2535', 'venue_2536', 
          'venue_2602', 'venue_2680', 'venue_2681', 'venue_2701', 'venue_2735', 'venue_2756', 'venue_2889', 
          'venue_3289', 'venue_3309', 'venue_3312', 'venue_3313', 'venue_4169', 'venue_4705', 'venue_5010', 
          'venue_5325', 'venue_5365', 'venue_5381', 'venue_5445']

years = ['year_2015', 'year_2016', 'year_2017', 'year_2018', 'year_2019', 'year_2020', 'year_2021', 'year_2022', 'year_2023']

other_list = ['p_L','b_L','x_vect','y_vect','temperature','onFirst','onSecond','onThird','inning','top','score_diff']

# %%
# Remove items that do not apply to batters or pitchers
batter_stats.remove("maxSpeed_b")
batter_stats.remove("maxSpin_b")
batter_stats.remove("maxSpeed_b_long")
batter_stats.remove("maxSpin_b_long")

pitcher_stats.remove("totalDistance_p")
pitcher_stats.remove("totalDistance_p_long")
pitcher_stats.remove("launchSpeed_p")
pitcher_stats.remove("launchSpeed_p_long")


# # Not sure why but these are weird
# batter_stats.remove("launchSpeed_b")
# batter_stats.remove("totalDistance_b")
# batter_stats.remove("launchSpeed_b_long")
# batter_stats.remove("totalDistance_b_long")

# pitcher_stats.remove("maxSpeed_p")
# pitcher_stats.remove("maxSpin_p")
# pitcher_stats.remove("maxSpeed_p_long")
# pitcher_stats.remove("maxSpin_p_long")


# Testing removing these
batter_stats.remove('ab_b')
batter_stats.remove('pa_b')
batter_stats.remove('ab_b_long')
batter_stats.remove('pa_b_long')

pitcher_stats.remove('ab_p')
pitcher_stats.remove('pa_p')
pitcher_stats.remove('ab_p_long')
pitcher_stats.remove('pa_p_long')

# %%
# Select variables for each model
# Full batter data, full pitcher data
x_list1 = batter_stats + pitcher_stats + venues + years + other_list 
# Full batter data, short pitcher data
x_list2 = batter_stats + pitcher_stats_fg + venues + years + other_list 
# Short batter data, long pitcher data
x_list3 = batter_stats_fg + pitcher_stats + venues + years + other_list 
# Short batter data, short pitcher data
x_list4 = batter_stats_fg + pitcher_stats_fg + venues + years + other_list 

print(len(x_list1))
# Variables we want to look at for each model (those we're training on plus names and some basic stats as well as the outcome)
x_list1_plus = x_list1 + ['batterName', 'pitcherName', 'batter', 'pitcher', 'batSide', 'pitchHand', 'eventsModel']
x_list2_plus = x_list2 + ['batterName', 'pitcherName', 'batter', 'pitcher', 'batSide', 'pitchHand', 'eventsModel']
x_list3_plus = x_list3 + ['batterName', 'pitcherName', 'batter', 'pitcher', 'batSide', 'pitchHand', 'eventsModel']
x_list4_plus = x_list4 + ['batterName', 'pitcherName', 'batter', 'pitcher', 'batSide', 'pitchHand', 'eventsModel']
# Out:
# 145

# %% [markdown]
# # Clean Data

# %%
# Get rid of small samples when training
sample = sample.query('pa_b_long >= 40').query('pa_p_long >= 40')

# Get rid of PA outcomes that are not valid outputs
sample = sample.query('eventsModel != "Cut"').reset_index(drop=True)

# Note: inner merge of FanGraphs data will remove observations without both batter and pitcher projections

# %%
# Fill missings with reasonable values
# sample['totalDistance_b'].fillna(200, inplace=True)
# sample['totalDistance_b_long'].fillna(200, inplace=True)
# sample['launchSpeed_b'].fillna(100, inplace=True)
# sample['launchSpeed_b_long'].fillna(100, inplace=True)

# sample['maxSpeed_p'].fillna(95, inplace=True)
# sample['maxSpeed_p_long'].fillna(95, inplace=True)
# sample['maxSpin_p'].fillna(95, inplace=True)
# sample['maxSpin_p_long'].fillna(95, inplace=True)

sample.fillna(0, inplace=True)

# %%
# Set directory to models folder 
os.chdir(r"C:\Users\james\Documents\MLB\Code\Models")

# %% [markdown]
# # Model 1
# ##### Complete batter variables
# ##### Complete pitcher variables

# %%
# Split into training and testing groups
X_train = sample.groupby(sample['year']).apply(lambda x: x.head(int(len(x)*2/3)))
X_train = X_train[x_list1]
X_test = sample.groupby(sample['year']).apply(lambda x: x.tail(int(len(x)*1/3)))
X_test = X_test[x_list1]
y_train = sample.groupby(sample['year']).apply(lambda x: x.head(int(len(x)*2/3)))
y_train = y_train['eventsModel']
y_test = sample.groupby(sample['year']).apply(lambda x: x.tail(int(len(x)*1/3)))
y_test = y_test['eventsModel']

# %%
# Scale (hopefully deprecated)
scaler = StandardScaler()
X_train.sort_index(inplace=True)
y_train.sort_index(inplace=True)
X_test.sort_index(inplace=True)
y_test.sort_index(inplace=True)
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Train model
# model1 = MLPClassifier(hidden_layer_sizes=(12), activation='relu', verbose=True, random_state=1, max_iter=20).fit(X_train, y_train)
model1 = MLPClassifier(hidden_layer_sizes=(30,30), activation='relu', verbose=True, random_state=1, max_iter=200).fit(sample[x_list1], sample[['eventsModel']].values.ravel())
filename = "model1_3030l_100.sav"
pickle.dump(model1, open(filename, 'wb'))
# Out:
# Iteration 1, loss = 2.04738010
# Iteration 2, loss = 2.02249948
# Iteration 3, loss = 2.01980535
# Iteration 4, loss = 2.01838512
# Iteration 5, loss = 2.01738843
# Iteration 6, loss = 2.01653599
# Iteration 7, loss = 2.01573524
# Iteration 8, loss = 2.01484017
# Iteration 9, loss = 2.01438192
# Iteration 10, loss = 2.01397163
# Iteration 11, loss = 2.01358133
# Iteration 12, loss = 2.01315564
# Iteration 13, loss = 2.01273765
# Iteration 14, loss = 2.01237082
# Iteration 15, loss = 2.01215345
# Iteration 16, loss = 2.01189241
# Iteration 17, loss = 2.01163415
# Iteration 18, loss = 2.01117473
# Iteration 19, loss = 2.01105371
# Iteration 20, loss = 2.01097164
# Iteration 21, loss = 2.01079173
# Iteration 22, loss = 2.01047177
# Iteration 23, loss = 2.01038281
# Iteration 24, loss = 2.01016426
# Iteration 25, loss = 2.01009141
# Iteration 26, loss = 2.00994792
# Iteration 27, loss = 2.00979341
# Iteration 28, loss = 2.00965915
# Iteration 29, loss = 2.00954153
# Iteration 30, loss = 2.00927387
# Iteration 31, loss = 2.00929928
# Iteration 32, loss = 2.00925583
# Iteration 33, loss = 2.00908270
# Iteration 34, loss = 2.00889864
# Iteration 35, loss = 2.00881417
# Iteration 36, loss = 2.00869461
# Iteration 37, loss = 2.00852087
# Iteration 38, loss = 2.00834724
# Iteration 39, loss = 2.00827420
# Iteration 40, loss = 2.00802673
# Iteration 41, loss = 2.00805514
# Iteration 42, loss = 2.00788417
# Iteration 43, loss = 2.00781668
# Iteration 44, loss = 2.00790220
# Iteration 45, loss = 2.00773940
# Iteration 46, loss = 2.00765985
# Iteration 47, loss = 2.00751976
# Iteration 48, loss = 2.00738164
# Iteration 49, loss = 2.00728958
# Iteration 50, loss = 2.00731824
# Iteration 51, loss = 2.00738942
# Iteration 52, loss = 2.00721089
# Iteration 53, loss = 2.00712241
# Iteration 54, loss = 2.00708996
# Iteration 55, loss = 2.00709754
# Iteration 56, loss = 2.00697416
# Iteration 57, loss = 2.00692982
# Iteration 58, loss = 2.00688084
# Iteration 59, loss = 2.00697285
# Iteration 60, loss = 2.00676887
# Iteration 61, loss = 2.00680418
# Iteration 62, loss = 2.00678258
# Iteration 63, loss = 2.00662737
# Iteration 64, loss = 2.00661581
# Iteration 65, loss = 2.00661272
# Iteration 66, loss = 2.00667156
# Iteration 67, loss = 2.00657049
# Iteration 68, loss = 2.00652191
# Iteration 69, loss = 2.00655303
# Iteration 70, loss = 2.00646591
# Iteration 71, loss = 2.00652173
# Iteration 72, loss = 2.00624956
# Iteration 73, loss = 2.00636400
# Iteration 74, loss = 2.00630790
# Iteration 75, loss = 2.00644300
# Iteration 76, loss = 2.00638701
# Iteration 77, loss = 2.00640444
# Iteration 78, loss = 2.00622553
# Iteration 79, loss = 2.00630796
# Iteration 80, loss = 2.00619954
# Iteration 81, loss = 2.00611270
# Iteration 82, loss = 2.00631534
# Iteration 83, loss = 2.00615448
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
# # Compute feature importances using permutation importance
# result = permutation_importance(model1b, X_test, y_test, n_repeats=10, random_state=42)
# # Print the feature importances
# listt = []
# for i, feature in enumerate(x_list1):
#     importance = result.importances_mean[i]
#     std = result.importances_std[i]
#     print(f"{feature}: {importance:.5f} +/- {std:.5f}")
#     listt.append([feature, importance, std])

# sorted_list = sorted(listt, key=lambda x: x[1])
# sorted_list

# %%
# Keep relevant variables in dataset
sample1 = sample[x_list1_plus].reset_index()
# Rename index to make a merge ID
sample1.rename(columns={'index':'merge'}, inplace=True)

# Predict PA probabilities
try:
    X_test.drop(columns={'b1', 'b2', 'b3', 'bb', 'fo', 'go', 'hbp', 'hr', 'lo', 'po', 'so'}, inplace=True)
except:
    pass

X_test[['b1', 'b2', 'b3', 'bb', 'fo', 'go', 'hbp', 'hr', 'lo', 'po', 'so']] = model1.predict_proba(X_test)

# Keep PA probabilities
X_merge = X_test[['b1', 'b2', 'b3', 'bb', 'fo', 'go', 'hbp', 'hr', 'lo', 'po', 'so']].reset_index()
# Rename index to make a merge ID
X_merge.rename(columns={'level_1':'merge'}, inplace=True)

# Merge PA probabilities in test sample onto full sample, keeping those that merge
X_merge = X_merge.merge(sample1, on='merge', how='inner')
X_merge
# Out:
#         year    merge        b1        b2        b3        bb        fo  \
# 0       2015    85818  0.173138  0.067235  0.009316  0.059860  0.110224
# 1       2015    85819  0.173138  0.067235  0.009316  0.059860  0.110224
# 2       2015    85820  0.173138  0.067235  0.009316  0.059860  0.110224
# 3       2015    85821  0.173138  0.067235  0.009316  0.059860  0.110224
# 4       2015    85822  0.184081  0.066012  0.008468  0.066844  0.113007
# ...      ...      ...       ...       ...       ...       ...       ...
# 421840  2023  1265543  0.149250  0.047764  0.001999  0.090034  0.122397
# 421841  2023  1265544  0.165207  0.033940  0.002698  0.082933  0.087809
# 421842  2023  1265545  0.169469  0.034095  0.002198  0.093954  0.097270
# 421843  2023  1265546  0.114664  0.032945  0.002510  0.111319  0.097153
# 421844  2023  1265547  0.131591  0.050540  0.002184  0.093214  0.158024
#
#               go       hbp        hr  ...  inning  top  score_diff  \
# 0       0.256799  0.003671  0.053678  ...       4    0         2.0
# 1       0.256799  0.003671  0.053678  ...       4    0         2.0
# 2       0.256799  0.003671  0.053678  ...       4    0         2.0
# 3       0.256799  0.003671  0.053678  ...       4    0         2.0
# 4       0.252553  0.004703  0.055741  ...       5    0         4.0
# ...          ...       ...       ...  ...     ...  ...         ...
# 421840  0.230922  0.007872  0.045207  ...       6    0         0.0
# 421841  0.311590  0.009246  0.011341  ...       7    0         0.0
# 421842  0.293728  0.007530  0.012835  ...       7    0         0.0
# 421843  0.201646  0.012388  0.021040  ...       8    0         2.0
# 421844  0.171881  0.008420  0.058417  ...       8    0         2.0
#
#             batterName      pitcherName  batter  pitcher  batSide  pitchHand  \
# 0          Travis Shaw     Johnny Cueto  543768   456501        L          R
# 1          Travis Shaw     Johnny Cueto  543768   456501        L          R
# 2          Travis Shaw     Johnny Cueto  543768   456501        L          R
# 3          Travis Shaw     Johnny Cueto  543768   456501        L          R
# 4          Travis Shaw     Johnny Cueto  543768   456501        L          R
# ...                ...              ...     ...      ...      ...        ...
# 421840      AJ Pollock    Zack Thompson  572041   668868        R          L
# 421841     Kolten Wong    Zack Thompson  543939   668868        L          L
# 421842   J.P. Crawford    Zack Thompson  641487   668868        L          L
# 421843  Jarred Kelenic  Genesis Cabrera  672284   650893        L          L
# 421844      AJ Pollock  Genesis Cabrera  572041   650893        R          L
#
#         eventsModel
# 0                so
# 1                so
# 2                so
# 3                so
# 4                so
# ...             ...
# 421840           lo
# 421841           bb
# 421842           b1
# 421843           go
# 421844           so
#
# [421845 rows x 165 columns]

# %%
X_merge['outs'] = X_merge[['so', 'fo', 'go', 'lo', 'po']].sum(axis=1)
X_merge.loc[X_merge['eventsModel'].isin(['so', 'fo', 'go', 'lo', 'po']), 'outs_act'] = 1
X_merge['outs_act'].fillna(0, inplace=True)

X_merge[['outs', 'outs_act']]

X_merge['decile'] = pd.qcut(X_merge['outs'], 10, labels=False)
test = X_merge.groupby('decile').mean().reset_index()

print(test[['outs', 'outs_act']].plot.line())
test['outs_mse'] = (test['outs'] - test['outs_act']) ** 2
print(test['outs_mse'].mean())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# 2.1907683587075494e-05

# %% [markdown]
# 2020l 5.016818865368933e-05 meh, outs > <br>
# 2222l 8.015858006479433e-05 bad outs >> <br>
# 2424l 2.264872826073692e-05 quite good <br>
# 2626l 1.2353561531608037e-05 very good  <br>
# 2828l 1.4323515100991683e-05 very good, outs >, but barely <br>

# %%
var = "so"
X_merge[f'{var}_act'] = (X_merge['eventsModel'] == var).astype('int')
X_merge['decile'] = pd.qcut(X_merge[var], 10, labels=False)
test = X_merge.groupby('decile').mean().reset_index()

print(test[[var, f'{var}_act']].plot.line())

test['so_mse'] = (test['so'] - test['so_act']) ** 2
print(test['so_mse'].mean())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# 0.00026343649622060576

# %% [markdown]
# 2020l 1.3173149345182704e-05 - perfect <br>
# 2222l 0.00028978928918908396 - bad, so_act > <br>
# 2424l 0.00014665158624185907 - not terrible, but not great. so_act > <br>
# 2626l 7.208820250651846e-05 - very good, so > <br>
# 2828l 5.324577638687756e-05 - very good, so > so_act but barely <br>

# %%
var = "hr"
X_merge[f'{var}_act'] = (X_merge['eventsModel'] == var).astype('int')
X_merge['decile'] = pd.qcut(X_merge[var], 10, labels=False)
test = X_merge.groupby('decile').mean().reset_index()

print(test[[var, f'{var}_act']].plot.line())
test['hr_mse'] = (test['hr'] - test['hr_act']) ** 2
print(test['hr_mse'].mean())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# 1.7960040413697248e-05

# %% [markdown]
# 2020l 1.3187143645074608e-06 - perfect <br>
# 2222l 5.972155308504619e-06 - okay, hr >  <br>
# 2424l 1.9639410733669984e-06 - perfect <br>
# 2626l 5.009839193908185e-06 - disappoint but not awful, hr > <br>
# 2828l 3.1181462100900167e-06 - good. hr > <br>
#
# 2828 is the best!

# %% [markdown]
# # Model 2
# ##### Complete batter variables
# ##### Short pitcher variables

# %%
# Split into training and testing groups
X_train = sample.groupby(sample['year']).apply(lambda x: x.head(int(len(x)*2/3)))
X_train = X_train[x_list2]
X_test = sample.groupby(sample['year']).apply(lambda x: x.tail(int(len(x)*1/3)))
X_test = X_test[x_list2]
y_train = sample.groupby(sample['year']).apply(lambda x: x.head(int(len(x)*2/3)))
y_train = y_train['eventsModel']
y_test = sample.groupby(sample['year']).apply(lambda x: x.tail(int(len(x)*1/3)))
y_test = y_test['eventsModel']

# %%
# Scale
scaler = StandardScaler()
X_train.sort_index(inplace=True)
y_train.sort_index(inplace=True)
X_test.sort_index(inplace=True)
y_test.sort_index(inplace=True)
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Train model
# model2 = MLPClassifier(hidden_layer_sizes=(200,200,200), activation='relu', verbose=True, random_state=1, max_iter=200).fit(X_train, y_train)
model2 = MLPClassifier(hidden_layer_sizes=(24,24), activation='relu', verbose=True, random_state=1, max_iter=200).fit(sample[x_list2], sample[['eventsModel']].values.ravel())
filename = "model2_2424l_100.sav"
pickle.dump(model2, open(filename, 'wb'))
# Out:
# Iteration 1, loss = 2.04444257
# Iteration 2, loss = 2.02397685
# Iteration 3, loss = 2.02177047
# Iteration 4, loss = 2.02077020
# Iteration 5, loss = 2.01982889
# Iteration 6, loss = 2.01907887
# Iteration 7, loss = 2.01847508
# Iteration 8, loss = 2.01797158
# Iteration 9, loss = 2.01752982
# Iteration 10, loss = 2.01705721
# Iteration 11, loss = 2.01679216
# Iteration 12, loss = 2.01658982
# Iteration 13, loss = 2.01636370
# Iteration 14, loss = 2.01612338
# Iteration 15, loss = 2.01600723
# Iteration 16, loss = 2.01588159
# Iteration 17, loss = 2.01570710
# Iteration 18, loss = 2.01563424
# Iteration 19, loss = 2.01554850
# Iteration 20, loss = 2.01546972
# Iteration 21, loss = 2.01543235
# Iteration 22, loss = 2.01525913
# Iteration 23, loss = 2.01528061
# Iteration 24, loss = 2.01519646
# Iteration 25, loss = 2.01509035
# Iteration 26, loss = 2.01515037
# Iteration 27, loss = 2.01498658
# Iteration 28, loss = 2.01499743
# Iteration 29, loss = 2.01491242
# Iteration 30, loss = 2.01482034
# Iteration 31, loss = 2.01499208
# Iteration 32, loss = 2.01487639
# Iteration 33, loss = 2.01478313
# Iteration 34, loss = 2.01467569
# Iteration 35, loss = 2.01474971
# Iteration 36, loss = 2.01455135
# Iteration 37, loss = 2.01457224
# Iteration 38, loss = 2.01452173
# Iteration 39, loss = 2.01444698
# Iteration 40, loss = 2.01443603
# Iteration 41, loss = 2.01445556
# Iteration 42, loss = 2.01441475
# Iteration 43, loss = 2.01422800
# Iteration 44, loss = 2.01430754
# Iteration 45, loss = 2.01422899
# Iteration 46, loss = 2.01427408
# Iteration 47, loss = 2.01420117
# Iteration 48, loss = 2.01411575
# Iteration 49, loss = 2.01407756
# Iteration 50, loss = 2.01415450
# Iteration 51, loss = 2.01410266
# Iteration 52, loss = 2.01403206
# Iteration 53, loss = 2.01404246
# Iteration 54, loss = 2.01391843
# Iteration 55, loss = 2.01392237
# Iteration 56, loss = 2.01396226
# Iteration 57, loss = 2.01394532
# Iteration 58, loss = 2.01391853
# Iteration 59, loss = 2.01383047
# Iteration 60, loss = 2.01381291
# Iteration 61, loss = 2.01373725
# Iteration 62, loss = 2.01380762
# Iteration 63, loss = 2.01381047
# Iteration 64, loss = 2.01381734
# Iteration 65, loss = 2.01373944
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
# Keep relevant variables in dataset
sample2 = sample[x_list2_plus].reset_index()
# Rename index to make a merge ID
sample2.rename(columns={'index':'merge'}, inplace=True)

# Predict PA probabilities
X_test[['b1', 'b2', 'b3', 'bb', 'fo', 'go', 'hbp', 'hr', 'lo', 'po', 'so']] = model2.predict_proba(X_test)

# Keep PA probabilities
X_merge = X_test[['b1', 'b2', 'b3', 'bb', 'fo', 'go', 'hbp', 'hr', 'lo', 'po', 'so']].reset_index()
# Rename index to make a merge ID
X_merge.rename(columns={'level_1':'merge'}, inplace=True)

# Merge PA probabilities in test sample onto full sample, keeping those that merge
X_merge = X_merge.merge(sample2, on='merge', how='inner')
X_merge
# Out:
#         year    merge        b1        b2        b3        bb        fo  \
# 0       2015    85818  0.189875  0.059281  0.008176  0.063862  0.099156
# 1       2015    85819  0.189875  0.059281  0.008176  0.063862  0.099156
# 2       2015    85820  0.189875  0.059281  0.008176  0.063862  0.099156
# 3       2015    85821  0.189875  0.059281  0.008176  0.063862  0.099156
# 4       2015    85822  0.194393  0.057052  0.006591  0.068810  0.097024
# ...      ...      ...       ...       ...       ...       ...       ...
# 421840  2023  1265543  0.142738  0.046073  0.002616  0.099725  0.129326
# 421841  2023  1265544  0.159487  0.036402  0.003635  0.101421  0.106503
# 421842  2023  1265545  0.167036  0.038705  0.004884  0.120642  0.115689
# 421843  2023  1265546  0.122906  0.037215  0.003664  0.129100  0.118080
# 421844  2023  1265547  0.132703  0.049003  0.002944  0.116624  0.146397
#
#               go       hbp        hr  ...  inning  top  score_diff  \
# 0       0.295207  0.005823  0.040829  ...       4    0         2.0
# 1       0.295207  0.005823  0.040829  ...       4    0         2.0
# 2       0.295207  0.005823  0.040829  ...       4    0         2.0
# 3       0.295207  0.005823  0.040829  ...       4    0         2.0
# 4       0.297260  0.007016  0.041855  ...       5    0         4.0
# ...          ...       ...       ...  ...     ...  ...         ...
# 421840  0.243128  0.009496  0.039420  ...       6    0         0.0
# 421841  0.292754  0.013476  0.011940  ...       7    0         0.0
# 421842  0.274739  0.011504  0.011575  ...       7    0         0.0
# 421843  0.196926  0.011925  0.026661  ...       8    0         2.0
# 421844  0.202840  0.010466  0.048077  ...       8    0         2.0
#
#             batterName      pitcherName  batter  pitcher  batSide  pitchHand  \
# 0          Travis Shaw     Johnny Cueto  543768   456501        L          R
# 1          Travis Shaw     Johnny Cueto  543768   456501        L          R
# 2          Travis Shaw     Johnny Cueto  543768   456501        L          R
# 3          Travis Shaw     Johnny Cueto  543768   456501        L          R
# 4          Travis Shaw     Johnny Cueto  543768   456501        L          R
# ...                ...              ...     ...      ...      ...        ...
# 421840      AJ Pollock    Zack Thompson  572041   668868        R          L
# 421841     Kolten Wong    Zack Thompson  543939   668868        L          L
# 421842   J.P. Crawford    Zack Thompson  641487   668868        L          L
# 421843  Jarred Kelenic  Genesis Cabrera  672284   650893        L          L
# 421844      AJ Pollock  Genesis Cabrera  572041   650893        R          L
#
#         eventsModel
# 0                so
# 1                so
# 2                so
# 3                so
# 4                so
# ...             ...
# 421840           lo
# 421841           bb
# 421842           b1
# 421843           go
# 421844           so
#
# [421845 rows x 127 columns]

# %%
X_merge['outs'] = X_merge[['so', 'fo', 'go', 'lo', 'po']].sum(axis=1)
X_merge.loc[X_merge['eventsModel'].isin(['so', 'fo', 'go', 'lo', 'po']), 'outs_act'] = 1
X_merge['outs_act'].fillna(0, inplace=True)

X_merge[['outs', 'outs_act']]

X_merge['decile'] = pd.qcut(X_merge['outs'], 10, labels=False)
test = X_merge.groupby('decile').mean().reset_index()

print(test[['outs', 'outs_act']].plot.line())
test['outs_mse'] = (test['outs'] - test['outs_act']) ** 2
print(test['outs_mse'].mean())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# 4.14255160761689e-05

# %% [markdown]
# 2020l 7.561915367706961e-05 outs > <br>
# 2222l 0.00020822318137444108 outs >> <br>
# 2424l 4.14255160761689e-05 outs_act > <br>

# %%
var = "so"
X_merge[f'{var}_act'] = (X_merge['eventsModel'] == var).astype('int')
X_merge['decile'] = pd.qcut(X_merge[var], 10, labels=False)
test = X_merge.groupby('decile').mean().reset_index()

print(test[[var, f'{var}_act']].plot.line())

test['so_mse'] = (test['so'] - test['so_act']) ** 2
print(test['so_mse'].mean())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# 0.0001726526240688736

# %% [markdown]
# 2020l 2.0166318078224668e-05 - perfect  <br>
# 2222l 0.0005325922527257199 - so >>  <br>
# 2424l 0.0001726526240688736 so_act > <br>

# %%
var = "hr"
X_merge[f'{var}_act'] = (X_merge['eventsModel'] == var).astype('int')
X_merge['decile'] = pd.qcut(X_merge[var], 10, labels=False)
test = X_merge.groupby('decile').mean().reset_index()

print(test[[var, f'{var}_act']].plot.line())
test['hr_mse'] = (test['hr'] - test['hr_act']) ** 2
print(test['hr_mse'].mean())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# 5.234515342856711e-06

# %% [markdown]
# 2020l 2.1635546039730588e-05 hr >> <br>
# 2222l 2.8329508128621513e-06 perfect <br>
# 2424 5.234515342856711e-06 hr_act>  <br>

# %% [markdown]
# # Model 3
# ##### Short batter variables
# ##### Complete pitcher variables

# %%
# Split into training and testing groups
X_train = sample.groupby(sample['year']).apply(lambda x: x.head(int(len(x)*2/3)))
X_train = X_train[x_list3]
X_test = sample.groupby(sample['year']).apply(lambda x: x.tail(int(len(x)*1/3)))
X_test = X_test[x_list3]
y_train = sample.groupby(sample['year']).apply(lambda x: x.head(int(len(x)*2/3)))
y_train = y_train['eventsModel']
y_test = sample.groupby(sample['year']).apply(lambda x: x.tail(int(len(x)*1/3)))
y_test = y_test['eventsModel']

# %%
# Scale
scaler = StandardScaler()
X_train.sort_index(inplace=True)
y_train.sort_index(inplace=True)
X_test.sort_index(inplace=True)
y_test.sort_index(inplace=True)
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Train model
# model3 = MLPClassifier(hidden_layer_sizes=(200,200,200), activation='relu', verbose=True, random_state=1, max_iter=200).fit(X_train, y_train)
model3 = MLPClassifier(hidden_layer_sizes=(20,20), activation='relu', verbose=True, random_state=1, max_iter=200).fit(sample[x_list3], sample[['eventsModel']].values.ravel())
filename = "model3_2020l_100.sav"
pickle.dump(model3, open(filename, 'wb'))
# Out:
# Iteration 1, loss = 2.04638379
# Iteration 2, loss = 2.03054420
# Iteration 3, loss = 2.02718629
# Iteration 4, loss = 2.02538344
# Iteration 5, loss = 2.02401631
# Iteration 6, loss = 2.02296380
# Iteration 7, loss = 2.02224968
# Iteration 8, loss = 2.02148445
# Iteration 9, loss = 2.02101466
# Iteration 10, loss = 2.02044511
# Iteration 11, loss = 2.01996388
# Iteration 12, loss = 2.01942297
# Iteration 13, loss = 2.01912717
# Iteration 14, loss = 2.01867363
# Iteration 15, loss = 2.01829542
# Iteration 16, loss = 2.01813096
# Iteration 17, loss = 2.01797122
# Iteration 18, loss = 2.01761742
# Iteration 19, loss = 2.01754613
# Iteration 20, loss = 2.01743528
# Iteration 21, loss = 2.01723042
# Iteration 22, loss = 2.01714350
# Iteration 23, loss = 2.01687390
# Iteration 24, loss = 2.01693516
# Iteration 25, loss = 2.01666408
# Iteration 26, loss = 2.01672921
# Iteration 27, loss = 2.01658677
# Iteration 28, loss = 2.01644147
# Iteration 29, loss = 2.01636346
# Iteration 30, loss = 2.01638349
# Iteration 31, loss = 2.01628033
# Iteration 32, loss = 2.01613343
# Iteration 33, loss = 2.01612770
# Iteration 34, loss = 2.01612199
# Iteration 35, loss = 2.01596674
# Iteration 36, loss = 2.01592997
# Iteration 37, loss = 2.01595920
# Iteration 38, loss = 2.01581126
# Iteration 39, loss = 2.01587653
# Iteration 40, loss = 2.01570061
# Iteration 41, loss = 2.01567765
# Iteration 42, loss = 2.01561327
# Iteration 43, loss = 2.01553215
# Iteration 44, loss = 2.01552576
# Iteration 45, loss = 2.01538834
# Iteration 46, loss = 2.01533246
# Iteration 47, loss = 2.01531786
# Iteration 48, loss = 2.01524970
# Iteration 49, loss = 2.01526515
# Iteration 50, loss = 2.01521143
# Iteration 51, loss = 2.01518278
# Iteration 52, loss = 2.01505968
# Iteration 53, loss = 2.01518992
# Iteration 54, loss = 2.01509390
# Iteration 55, loss = 2.01516724
# Iteration 56, loss = 2.01495473
# Iteration 57, loss = 2.01487509
# Iteration 58, loss = 2.01500880
# Iteration 59, loss = 2.01498825
# Iteration 60, loss = 2.01501054
# Iteration 61, loss = 2.01496922
# Iteration 62, loss = 2.01476581
# Iteration 63, loss = 2.01490743
# Iteration 64, loss = 2.01486839
# Iteration 65, loss = 2.01470658
# Iteration 66, loss = 2.01469955
# Iteration 67, loss = 2.01473156
# Iteration 68, loss = 2.01469098
# Iteration 69, loss = 2.01463927
# Iteration 70, loss = 2.01463156
# Iteration 71, loss = 2.01474227
# Iteration 72, loss = 2.01465555
# Iteration 73, loss = 2.01473403
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
# Keep relevant variables in dataset
sample3 = sample[x_list3_plus].reset_index()
# Rename index to make a merge ID
sample3.rename(columns={'index':'merge'}, inplace=True)

# Predict PA probabilities
X_test[['b1', 'b2', 'b3', 'bb', 'fo', 'go', 'hbp', 'hr', 'lo', 'po', 'so']] = model3.predict_proba(X_test)

# Keep PA probabilities
X_merge = X_test[['b1', 'b2', 'b3', 'bb', 'fo', 'go', 'hbp', 'hr', 'lo', 'po', 'so']].reset_index()
# Rename index to make a merge ID
X_merge.rename(columns={'level_1':'merge'}, inplace=True)

# Merge PA probabilities in test sample onto full sample, keeping those that merge
X_merge = X_merge.merge(sample3, on='merge', how='inner')
X_merge
# Out:
#         year    merge        b1        b2        b3        bb        fo  \
# 0       2015    85818  0.145216  0.047743  0.004539  0.058215  0.125435
# 1       2015    85819  0.145216  0.047743  0.004539  0.058215  0.125435
# 2       2015    85820  0.145335  0.047830  0.004542  0.058695  0.125654
# 3       2015    85821  0.145335  0.047830  0.004542  0.058695  0.125654
# 4       2015    85822  0.149582  0.049625  0.004728  0.059151  0.133832
# ...      ...      ...       ...       ...       ...       ...       ...
# 421840  2023  1265543  0.136215  0.041829  0.004771  0.104229  0.111843
# 421841  2023  1265544  0.159439  0.038115  0.006306  0.091078  0.087295
# 421842  2023  1265545  0.165422  0.037527  0.007023  0.102176  0.090485
# 421843  2023  1265546  0.106268  0.035533  0.003852  0.121957  0.112774
# 421844  2023  1265547  0.130407  0.047108  0.004337  0.100744  0.152876
#
#               go       hbp        hr  ...  inning  top  score_diff  \
# 0       0.230193  0.008010  0.038307  ...       4    0         2.0
# 1       0.230193  0.008010  0.038307  ...       4    0         2.0
# 2       0.230364  0.007997  0.038282  ...       4    0         2.0
# 3       0.230364  0.007997  0.038282  ...       4    0         2.0
# 4       0.233003  0.009363  0.039705  ...       5    0         4.0
# ...          ...       ...       ...  ...     ...  ...         ...
# 421840  0.231169  0.010136  0.026501  ...       6    0         0.0
# 421841  0.315316  0.011079  0.013312  ...       7    0         0.0
# 421842  0.331791  0.011695  0.010007  ...       7    0         0.0
# 421843  0.168204  0.013576  0.031518  ...       8    0         2.0
# 421844  0.192196  0.009460  0.037447  ...       8    0         2.0
#
#             batterName      pitcherName  batter  pitcher  batSide  pitchHand  \
# 0          Travis Shaw     Johnny Cueto  543768   456501        L          R
# 1          Travis Shaw     Johnny Cueto  543768   456501        L          R
# 2          Travis Shaw     Johnny Cueto  543768   456501        L          R
# 3          Travis Shaw     Johnny Cueto  543768   456501        L          R
# 4          Travis Shaw     Johnny Cueto  543768   456501        L          R
# ...                ...              ...     ...      ...      ...        ...
# 421840      AJ Pollock    Zack Thompson  572041   668868        R          L
# 421841     Kolten Wong    Zack Thompson  543939   668868        L          L
# 421842   J.P. Crawford    Zack Thompson  641487   668868        L          L
# 421843  Jarred Kelenic  Genesis Cabrera  672284   650893        L          L
# 421844      AJ Pollock  Genesis Cabrera  572041   650893        R          L
#
#         eventsModel
# 0                so
# 1                so
# 2                so
# 3                so
# 4                so
# ...             ...
# 421840           lo
# 421841           bb
# 421842           b1
# 421843           go
# 421844           so
#
# [421845 rows x 133 columns]

# %%
X_merge['outs'] = X_merge[['so', 'fo', 'go', 'lo', 'po']].sum(axis=1)
X_merge.loc[X_merge['eventsModel'].isin(['so', 'fo', 'go', 'lo', 'po']), 'outs_act'] = 1
X_merge['outs_act'].fillna(0, inplace=True)

X_merge[['outs', 'outs_act']]

X_merge['decile'] = pd.qcut(X_merge['outs'], 10, labels=False)
test = X_merge.groupby('decile').mean().reset_index()

print(test[['outs', 'outs_act']].plot.line())
test['outs_mse'] = (test['outs'] - test['outs_act']) ** 2
print(test['outs_mse'].mean())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# 9.530395276850536e-06

# %% [markdown]
# 2020l 9.530395276850536e-06 - gorgeous <br>

# %%
var = "so"
X_merge[f'{var}_act'] = (X_merge['eventsModel'] == var).astype('int')
X_merge['decile'] = pd.qcut(X_merge[var], 10, labels=False)
test = X_merge.groupby('decile').mean().reset_index()

print(test[[var, f'{var}_act']].plot.line())

test['so_mse'] = (test['so'] - test['so_act']) ** 2
print(test['so_mse'].mean())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# 5.5378671647455904e-05

# %% [markdown]
# 2020l - 5.5378671647455904e-05 beautiful so_act >

# %%
var = "hr"
X_merge[f'{var}_act'] = (X_merge['eventsModel'] == var).astype('int')
X_merge['decile'] = pd.qcut(X_merge[var], 10, labels=False)
test = X_merge.groupby('decile').mean().reset_index()

print(test[[var, f'{var}_act']].plot.line())
test['hr_mse'] = (test['hr'] - test['hr_act']) ** 2
print(test['hr_mse'].mean())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# 3.4696705678286084e-06

# %% [markdown]
# 2020l 3.4696705678286084e-06 - nice, but hr >

# %% [markdown]
# # Model 4
# ##### Short batter variables
# ##### Short pitcher variables

# %%
# Split into training and testing groups
X_train = sample.groupby(sample['year']).apply(lambda x: x.head(int(len(x)*2/3)))
X_train = X_train[x_list4]
X_test = sample.groupby(sample['year']).apply(lambda x: x.tail(int(len(x)*1/3)))
X_test = X_test[x_list4]
y_train = sample.groupby(sample['year']).apply(lambda x: x.head(int(len(x)*2/3)))
y_train = y_train['eventsModel']
y_test = sample.groupby(sample['year']).apply(lambda x: x.tail(int(len(x)*1/3)))
y_test = y_test['eventsModel']

# %%
# Scale
scaler = StandardScaler()
X_train.sort_index(inplace=True)
y_train.sort_index(inplace=True)
X_test.sort_index(inplace=True)
y_test.sort_index(inplace=True)
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Train model
# model4 = MLPClassifier(hidden_layer_sizes=(200,200,200), activation='relu', verbose=True, random_state=1, max_iter=200).fit(X_train, y_train)
model4 = MLPClassifier(hidden_layer_sizes=(22,22), activation='relu', verbose=True, random_state=1, max_iter=200).fit(sample[x_list4], sample[['eventsModel']].values.ravel())
filename = "model4_2222l_100.sav"
pickle.dump(model4, open(filename, 'wb'))
# Out:
# Iteration 1, loss = 2.05961749
# Iteration 2, loss = 2.03297563
# Iteration 3, loss = 2.02783241
# Iteration 4, loss = 2.02593112
# Iteration 5, loss = 2.02498591
# Iteration 6, loss = 2.02431381
# Iteration 7, loss = 2.02348745
# Iteration 8, loss = 2.02275943
# Iteration 9, loss = 2.02233815
# Iteration 10, loss = 2.02193164
# Iteration 11, loss = 2.02168212
# Iteration 12, loss = 2.02135169
# Iteration 13, loss = 2.02108446
# Iteration 14, loss = 2.02080524
# Iteration 15, loss = 2.02074887
# Iteration 16, loss = 2.02029663
# Iteration 17, loss = 2.02017462
# Iteration 18, loss = 2.02007327
# Iteration 19, loss = 2.01984602
# Iteration 20, loss = 2.01968022
# Iteration 21, loss = 2.01946667
# Iteration 22, loss = 2.01955190
# Iteration 23, loss = 2.01930611
# Iteration 24, loss = 2.01913509
# Iteration 25, loss = 2.01905894
# Iteration 26, loss = 2.01891630
# Iteration 27, loss = 2.01884185
# Iteration 28, loss = 2.01877912
# Iteration 29, loss = 2.01884473
# Iteration 30, loss = 2.01862799
# Iteration 31, loss = 2.01851256
# Iteration 32, loss = 2.01847383
# Iteration 33, loss = 2.01842972
# Iteration 34, loss = 2.01840014
# Iteration 35, loss = 2.01842708
# Iteration 36, loss = 2.01836859
# Iteration 37, loss = 2.01825727
# Iteration 38, loss = 2.01821302
# Iteration 39, loss = 2.01823083
# Iteration 40, loss = 2.01813905
# Iteration 41, loss = 2.01825316
# Iteration 42, loss = 2.01806859
# Iteration 43, loss = 2.01806502
# Iteration 44, loss = 2.01797476
# Iteration 45, loss = 2.01787326
# Iteration 46, loss = 2.01779553
# Iteration 47, loss = 2.01787332
# Iteration 48, loss = 2.01779406
# Iteration 49, loss = 2.01792947
# Iteration 50, loss = 2.01784591
# Iteration 51, loss = 2.01779770
# Iteration 52, loss = 2.01786485
# Iteration 53, loss = 2.01770043
# Iteration 54, loss = 2.01779843
# Iteration 55, loss = 2.01773123
# Iteration 56, loss = 2.01761460
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
# Keep relevant variables in dataset
sample4 = sample[x_list4_plus].reset_index()
# Rename index to make a merge ID
sample4.rename(columns={'index':'merge'}, inplace=True)

# Predict PA probabilities
X_test[['b1', 'b2', 'b3', 'bb', 'fo', 'go', 'hbp', 'hr', 'lo', 'po', 'so']] = model4.predict_proba(X_test)

# Keep PA probabilities
X_merge = X_test[['b1', 'b2', 'b3', 'bb', 'fo', 'go', 'hbp', 'hr', 'lo', 'po', 'so']].reset_index()
# Rename index to make a merge ID
X_merge.rename(columns={'level_1':'merge'}, inplace=True)

# Merge PA probabilities in test sample onto full sample, keeping those that merge
X_merge = X_merge.merge(sample4, on='merge', how='inner')
X_merge
# Out:
#         year    merge        b1        b2        b3        bb        fo  \
# 0       2015    85818  0.158980  0.054652  0.008202  0.062029  0.105311
# 1       2015    85819  0.158980  0.054652  0.008202  0.062029  0.105311
# 2       2015    85820  0.159215  0.054704  0.008155  0.062501  0.105467
# 3       2015    85821  0.159215  0.054704  0.008155  0.062501  0.105467
# 4       2015    85822  0.161357  0.057003  0.008873  0.063904  0.113770
# ...      ...      ...       ...       ...       ...       ...       ...
# 421840  2023  1265543  0.145029  0.040831  0.002321  0.101494  0.117423
# 421841  2023  1265544  0.162816  0.031610  0.002105  0.092109  0.095187
# 421842  2023  1265545  0.178509  0.029821  0.002216  0.104323  0.096347
# 421843  2023  1265546  0.111576  0.034444  0.001923  0.108927  0.124137
# 421844  2023  1265547  0.130766  0.041938  0.002198  0.116531  0.141674
#
#               go       hbp        hr  ...  inning  top  score_diff  \
# 0       0.231891  0.008070  0.040720  ...       4    0         2.0
# 1       0.231891  0.008070  0.040720  ...       4    0         2.0
# 2       0.232171  0.008084  0.040713  ...       4    0         2.0
# 3       0.232171  0.008084  0.040713  ...       4    0         2.0
# 4       0.230437  0.008733  0.044515  ...       5    0         4.0
# ...          ...       ...       ...  ...     ...  ...         ...
# 421840  0.223887  0.011276  0.030550  ...       6    0         0.0
# 421841  0.275679  0.014058  0.014939  ...       7    0         0.0
# 421842  0.302822  0.015830  0.010614  ...       7    0         0.0
# 421843  0.167855  0.012363  0.035409  ...       8    0         2.0
# 421844  0.186375  0.011090  0.038364  ...       8    0         2.0
#
#             batterName      pitcherName  batter  pitcher  batSide  pitchHand  \
# 0          Travis Shaw     Johnny Cueto  543768   456501        L          R
# 1          Travis Shaw     Johnny Cueto  543768   456501        L          R
# 2          Travis Shaw     Johnny Cueto  543768   456501        L          R
# 3          Travis Shaw     Johnny Cueto  543768   456501        L          R
# 4          Travis Shaw     Johnny Cueto  543768   456501        L          R
# ...                ...              ...     ...      ...      ...        ...
# 421840      AJ Pollock    Zack Thompson  572041   668868        R          L
# 421841     Kolten Wong    Zack Thompson  543939   668868        L          L
# 421842   J.P. Crawford    Zack Thompson  641487   668868        L          L
# 421843  Jarred Kelenic  Genesis Cabrera  672284   650893        L          L
# 421844      AJ Pollock  Genesis Cabrera  572041   650893        R          L
#
#         eventsModel
# 0                so
# 1                so
# 2                so
# 3                so
# 4                so
# ...             ...
# 421840           lo
# 421841           bb
# 421842           b1
# 421843           go
# 421844           so
#
# [421845 rows x 95 columns]

# %%
X_merge['outs'] = X_merge[['so', 'fo', 'go', 'lo', 'po']].sum(axis=1)
X_merge.loc[X_merge['eventsModel'].isin(['so', 'fo', 'go', 'lo', 'po']), 'outs_act'] = 1
X_merge['outs_act'].fillna(0, inplace=True)

X_merge[['outs', 'outs_act']]

X_merge['decile'] = pd.qcut(X_merge['outs'], 10, labels=False)
test = X_merge.groupby('decile').mean().reset_index()

print(test[['outs', 'outs_act']].plot.line())
test['outs_mse'] = (test['outs'] - test['outs_act']) ** 2
print(test['outs_mse'].mean())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# 2.1262490527763598e-05

# %% [markdown]
# 2020l 1.5441999816867803e-05 - perfect <br>
# 2525l 0.0001301520793913563 - outs > meh <br>
# 2323l 3.0738464831559375e-05 - outs > but barely. <br>
# 2424l 0.0002734266111179472 - outs >> SUCKS <br>
# 2626l 8.921329293742665e-05 - outs > meh
# 2222l 2.1262490527763598e-05 - outs_act> from 2-8 but barely. Very good <br>

# %%
var = "so"
X_merge[f'{var}_act'] = (X_merge['eventsModel'] == var).astype('int')
X_merge['decile'] = pd.qcut(X_merge[var], 10, labels=False)
test = X_merge.groupby('decile').mean().reset_index()

print(test[[var, f'{var}_act']].plot.line())

test['so_mse'] = (test['so'] - test['so_act']) ** 2
print(test['so_mse'].mean())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# 4.814078470281203e-05

# %% [markdown]
# 2020l 0.00023636926096063299 good so > <br>
# 2525l 0.00013694941594239176 good so_act > <br>
# 2323l 0.0004114926208339209 meh so > <br>
# 2424l 8.211581540327468e-05 perfect <br>
# 2626l 0.00023346188410443158 good so > <br>
# 2222l 4.814078470281203e-05 perfect

# %%
var = "hr"
X_merge[f'{var}_act'] = (X_merge['eventsModel'] == var).astype('int')
X_merge['decile'] = pd.qcut(X_merge[var], 10, labels=False)
test = X_merge.groupby('decile').mean().reset_index()

print(test[[var, f'{var}_act']].plot.line())
test['hr_mse'] = (test['hr'] - test['hr_act']) ** 2
print(test['hr_mse'].mean())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# 1.0804973665838658e-06

# %% [markdown]
# 2020l 0.00011036702089449717 - ass hr >>> <br>
# 2525l 3.76536104000416e-05 - ass hr_act >> <br>
# 2323l 2.2504519671703165e-06 - perfect <br>
# 2424l 6.44486707030848e-07 - perfect <br>
# 2626l 3.855741448284241e-06 - good hr_act > <br>
# 2222l 1.0804973665838658e-06 - perfect <br>

# %%
# # Create a GridSearchCV object
# grid_search = GridSearchCV(cv=5,
#                            estimator=MLPClassifier(max_iter=100),
#                            param_grid={'hidden_layer_sizes': [(50)],
#                            'activation': ['relu'],
#                            'alpha': [0.001]},
#                            scoring=make_scorer(f1_score, average='weighted'), n_jobs=-1, verbose=5)    

# # Fit the GridSearchCV object to the data
# grid_search.fit(X_train_scaled, y_train)

# # Print the best parameter setting
# print(grid_search.best_params_)
# print(grid_search.best_score_)

# # model = MLPClassifier(hidden_layer_sizes=(200,200,200), activation='relu', random_state=1,max_iter=500).fit(X_train_scaled, y_train)
# # preds = model.predict_proba(X_test)

# # print("Train score:", model.score(X_train_scaled, y_train))
# # print("Test score:", model.score(X_test_scaled, y_test))

# %%
# def recall_m(y_true, y_pred):
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     recall = true_positives / (possible_positives + K.epsilon())
#     return recall

# def precision_m(y_true, y_pred):
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
#     precision = true_positives / (predicted_positives + K.epsilon())
#     return precision

# def f1_m(y_true, y_pred):
#     precision = precision_m(y_true, y_pred)
#     recall = recall_m(y_true, y_pred)
#     return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
# from sklearn.model_selection import TimeSeriesSplit

# # Assume X is your time series data and y is your target variable
# tscv = TimeSeriesSplit(n_splits=5)

# # Loop over each fold
# for train_index, test_index in tscv.split(X):
#     # get the training and test data for this fold
#     X_train, X_test = X.loc[train_index], X.loc[test_index]
#     y_train, y_test = y.loc[train_index], y.loc[test_index]
    
#     # train and evaluate your model on this fold
#     model = MLPClassifier(hidden_layer_sizes=(200,200,200), activation='relu', verbose=True, random_state=1, max_iter=10).fit(X_train, y_train)

#     # model.fit(X_train, y_train)
#     score = model.score(X_test, y_test)
    
#     # do whatever you need to with the score for this fold
#     print("Fold score:", score)
