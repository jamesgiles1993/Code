# %%
# %run "C:\Users\james\Documents\MLB\Code\U1. Imports.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U2. Utilities.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U3. Classes.ipynb"

# %%
game_df = read_and_save_games(team_map, generate=True)
game_df = game_df[(game_df['date'] >= todaysdate) & (game_df['date'] <= todaysdate)].reset_index(drop=True)

# %%
# %run "C:\Users\james\Documents\MLB\Code\01. Run DraftKings.ipynb"

# %%
# %run "C:\Users\james\Documents\MLB\Code\02. Run Stats API.ipynb"

# %%
# %run "C:\Users\james\Documents\MLB\Code\03. Run Steamer.ipynb"

# %%
# %run "C:\Users\james\Documents\MLB\Code\04. Run Bullpens.ipynb"

# %%
# %run "C:\Users\james\Documents\MLB\Code\05. Run Rosters.ipynb"

# %%
# %run "C:\Users\james\Documents\MLB\Code\07. Run Projections.ipynb"

# %%
game_df = read_and_save_games(team_map, generate=True)
game_df = game_df[(game_df['date'] >= yesterdaysdate) & (game_df['date'] <= yesterdaysdate)].reset_index(drop=True)

# %%
# %run "C:\Users\james\Documents\MLB\Code\06. Run Weather.ipynb"

# %%
# %run "C:\Users\james\Documents\MLB\Code\08. Run Odds Sportsbook Review.ipynb"

# %%
# %run "C:\Users\james\Documents\MLB\Code\09. Run Contest Guides.ipynb"

# %%
# %run "C:\Users\james\Documents\MLB\Code\10. Run Player Results.ipynb"

# %%
# %run "C:\Users\james\Documents\MLB\Code\11. Run Matchups.ipynb"
