# %% [markdown]
# # A. Morning Dashboard
# - Date: 3/23/2024
# - Description: This runs every morning to gather time-insensitive data:
#     - DraftKings upcoming contests, salaries, and previous results
#     - Stats API and Statcast
#     - Steamer

# %% [markdown]
# ### Imports

# %%
# %run "C:\Users\james\Documents\MLB\Code\U1. Imports-WIP.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U2. Utilities.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U3. Classes.ipynb"

# %% [markdown]
# ### A01. DraftKings

# %%
# %run "C:\Users\james\Documents\MLB\Code\A01. DraftKings.ipynb"

# %% [markdown]
# ##### 1. Contests

# %%
# Scrape contests
contest_df = contests(todaysdate)
# To csv
contest_df.to_csv(os.path.join(baseball_path, 'A01. DraftKings', '1. Contests', f'Contests {todaysdate}.csv'), index=False)

# %% [markdown]
# ##### 7. Subsets

# %%
# Select subset
subset_df = create_subset(contest_df, contests_per_draftGroupId=5, entry_fee_max=100, added_contestKeys=[], date_dash=todaysdate_dash)
subset_df.reset_index(drop=True, inplace=True)

# Save subset
subset_df.to_csv(os.path.join(baseball_path, "A01. DraftKings", "7. Subsets", f'Subset {todaysdate}.csv'), index=False)

# %% [markdown]
# ##### 2. Draftables

# %%
# %%time
# Loop over contests of interest
for draftGroupId in list(subset_df['draftGroupId'].unique()):
    print(draftGroupId)
    try:
        # Scrape draftables (DK Salaries)
        draftable_df = draftables(draftGroupId)
        # To csv
        draftable_df.to_csv(os.path.join(baseball_path, "A01. DraftKings", "2. Draftables", f"Draftables {draftGroupId}.csv"), index=False, encoding='iso-8859-1')
        print(f"Saved {draftGroupId}")
    except:
        print(f"Didn't save {draftGroupId}")
# Out:
# 108414
# Saved 108414
# 108413
# Didn't save 108413
# 108412
# Saved 108412
# 108411
# Didn't save 108411
# 108410
# Saved 108410
# 108409
# Saved 108409
# 108408
# Didn't save 108408
# 108407
# Didn't save 108407
# 108406
# Didn't save 108406
# 108405
# Saved 108405
# 108404
# Saved 108404
# 108403
# Saved 108403
# 108402
# Didn't save 108402
# 108401
# Didn't save 108401
# 108400
# Didn't save 108400
# 108399
# Saved 108399
# 108389
# Saved 108389
# CPU times: total: 4.95 s
# Wall time: 12.3 s

# %% [markdown]
# ##### 3. Payouts

# %%
# %%time
# Loop over contests of interest
for i in range(len(subset_df)):
    # Extract contestKey
    contestKey = subset_df['contestKey'][i]
    try:
        # Scrape payouts
        payout_df = payouts(contestKey)
        # To csv
        payout_df.to_csv(os.path.join(baseball_path, "A01. DraftKings", "3. Payouts", f"Payouts {contestKey}.csv"), index=False, encoding='iso-8859-1')
    except:
        print(f"Didn't save {contestKey}.")
# Out:
# CPU times: total: 21.6 s
# Wall time: 41.4 s

# %% [markdown]
# ##### 4. Results, 5. Entry Results, and 6. Player Results

# %% [markdown]
# Note: This will break if there were no games yesterday.

# %%
# Read in yesterdays subset
yesterdays_subset_df = pd.read_csv(os.path.join(baseball_path, 'A01. DraftKings', '7. Subsets', f'Subset {yesterdaysdate}.csv'))

# %%
# Loop over yesterday's contests
for i in range(len(yesterdays_subset_df)):
    # Extract contestKey
    contestKey = yesterdays_subset_df['contestKey'][i]
    print(contestKey)
    # Scrape results
    results(contestKey, sleep_time=5)

    try:        
        # Read into pandas
        results_df = pd.read_csv(os.path.join(baseball_path, "A01. DraftKings", "4. Results", f"contest-standings-{contestKey}.csv"))
        
        # Entry results
        entry_results_df = entry_results(results_df)
        entry_results_df.to_csv(os.path.join(baseball_path, "A01. DraftKings", "5. Entry Results", f"Entry Results {contestKey}.csv"), index=False, encoding='iso-8859-1')
    
        # Player results
        player_results_df = player_results(results_df)
        player_results_df.to_csv(os.path.join(baseball_path, "A01. DraftKings", "6. Player Results", f"Player Results {contestKey}.csv"), index=False, encoding='iso-8859-1')
    except IndexError as e:
        print(f"Downloaded contest-standings-{contestKey}. Non-traditional format.")
    except pd.errors.EmptyDataError as e:
        print(f"Downloaded contest-standings-{contestKey}. Empty file.")
    except FileNotFoundError as e:
        print(f"Couldn't find {contestKey}.")
# Out:
# 162564050
# contest-standings-162564050
# ['contest-standings-162564050.zip']
# C:\Users\james\Downloads\contest-standings-162564050.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162564050. Non-traditional format.
# 162564049
# contest-standings-162564049
# ['contest-standings-162564049.zip']
# C:\Users\james\Downloads\contest-standings-162564049.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162564049. Non-traditional format.
# 162563936
# contest-standings-162563936
# ['contest-standings-162563936.zip']
# C:\Users\james\Downloads\contest-standings-162563936.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162563936. Non-traditional format.
# 162577090
# contest-standings-162577090
# ['contest-standings-162577090.csv']
# C:\Users\james\Downloads\contest-standings-162577090.csv
# File copied successfully!
# Downloaded contest-standings-162577090. Empty file.
# 162576660
# contest-standings-162576660
# ['contest-standings-162576660.zip']
# C:\Users\james\Downloads\contest-standings-162576660.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162576660. Non-traditional format.
# 162563925
# contest-standings-162563925
# ['contest-standings-162563925.csv']
# C:\Users\james\Downloads\contest-standings-162563925.csv
# File copied successfully!
# Downloaded contest-standings-162563925. Non-traditional format.
# 162563924
# contest-standings-162563924
# ['contest-standings-162563924.csv']
# C:\Users\james\Downloads\contest-standings-162563924.csv
# File copied successfully!
# Downloaded contest-standings-162563924. Non-traditional format.
# 162563923
# contest-standings-162563923
# ['contest-standings-162563923.csv']
# C:\Users\james\Downloads\contest-standings-162563923.csv
# File copied successfully!
# Downloaded contest-standings-162563923. Non-traditional format.
# 162563922
# contest-standings-162563922
# ['contest-standings-162563922.csv']
# C:\Users\james\Downloads\contest-standings-162563922.csv
# File copied successfully!
# Downloaded contest-standings-162563922. Non-traditional format.
# 162563921
# contest-standings-162563921
# ['contest-standings-162563921.csv']
# C:\Users\james\Downloads\contest-standings-162563921.csv
# File copied successfully!
# Downloaded contest-standings-162563921. Empty file.
# 162564096
# contest-standings-162564096
# ['contest-standings-162564096.zip']
# C:\Users\james\Downloads\contest-standings-162564096.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162564096. Non-traditional format.
# 162564094
# contest-standings-162564094
# ['contest-standings-162564094.zip']
# C:\Users\james\Downloads\contest-standings-162564094.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162564094. Non-traditional format.
# 162564098
# contest-standings-162564098
# ['contest-standings-162564098.zip']
# C:\Users\james\Downloads\contest-standings-162564098.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162564098. Non-traditional format.
# 162564089
# contest-standings-162564089
# ['contest-standings-162564089.csv']
# C:\Users\james\Downloads\contest-standings-162564089.csv
# File copied successfully!
# Downloaded contest-standings-162564089. Non-traditional format.
# 162563020
# contest-standings-162563020
# ['contest-standings-162563020.csv']
# C:\Users\james\Downloads\contest-standings-162563020.csv
# File copied successfully!
# Downloaded contest-standings-162563020. Empty file.
# 162563872
# contest-standings-162563872
# ['contest-standings-162563872.csv']
# C:\Users\james\Downloads\contest-standings-162563872.csv
# File copied successfully!
# Downloaded contest-standings-162563872. Empty file.
# 162563871
# contest-standings-162563871
# ['contest-standings-162563871.csv']
# C:\Users\james\Downloads\contest-standings-162563871.csv
# File copied successfully!
# Downloaded contest-standings-162563871. Non-traditional format.
# 162563870
# contest-standings-162563870
# ['contest-standings-162563870.csv']
# C:\Users\james\Downloads\contest-standings-162563870.csv
# File copied successfully!
# Downloaded contest-standings-162563870. Non-traditional format.
# 162563868
# contest-standings-162563868
# ['contest-standings-162563868.csv']
# C:\Users\james\Downloads\contest-standings-162563868.csv
# File copied successfully!
# Downloaded contest-standings-162563868. Empty file.
# 162563867
# contest-standings-162563867
# ['contest-standings-162563867.csv']
# C:\Users\james\Downloads\contest-standings-162563867.csv
# File copied successfully!
# Downloaded contest-standings-162563867. Empty file.
# 162564079
# contest-standings-162564079
# ['contest-standings-162564079.zip']
# C:\Users\james\Downloads\contest-standings-162564079.zip
# Zip file unpacked successfully!
# 162564082
# contest-standings-162564082
# ['contest-standings-162564082.zip']
# C:\Users\james\Downloads\contest-standings-162564082.zip
# Zip file unpacked successfully!
# 162564086
# contest-standings-162564086
# ['contest-standings-162564086.zip']
# C:\Users\james\Downloads\contest-standings-162564086.zip
# Zip file unpacked successfully!
# 162564074
# contest-standings-162564074
# ['contest-standings-162564074.csv']
# C:\Users\james\Downloads\contest-standings-162564074.csv
# File copied successfully!
# 162564078
# contest-standings-162564078
# ['contest-standings-162564078.zip']
# C:\Users\james\Downloads\contest-standings-162564078.zip
# Zip file unpacked successfully!
# 162563908
# contest-standings-162563908
# ['contest-standings-162563908.csv']
# C:\Users\james\Downloads\contest-standings-162563908.csv
# File copied successfully!
# Downloaded contest-standings-162563908. Non-traditional format.
# 162563907
# contest-standings-162563907
# ['contest-standings-162563907.csv']
# C:\Users\james\Downloads\contest-standings-162563907.csv
# File copied successfully!
# Downloaded contest-standings-162563907. Non-traditional format.
# 162563906
# contest-standings-162563906
# ['contest-standings-162563906.csv']
# C:\Users\james\Downloads\contest-standings-162563906.csv
# File copied successfully!
# Downloaded contest-standings-162563906. Non-traditional format.
# 162563905
# contest-standings-162563905
# ['contest-standings-162563905.csv']
# C:\Users\james\Downloads\contest-standings-162563905.csv
# File copied successfully!
# Downloaded contest-standings-162563905. Non-traditional format.
# 162563904
# contest-standings-162563904
# ['contest-standings-162563904.csv']
# C:\Users\james\Downloads\contest-standings-162563904.csv
# File copied successfully!
# Downloaded contest-standings-162563904. Non-traditional format.
# 162564073
# contest-standings-162564073
# ['contest-standings-162564073.zip']
# C:\Users\james\Downloads\contest-standings-162564073.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162564073. Non-traditional format.
# 162564068
# contest-standings-162564068
# ['contest-standings-162564068.zip']
# C:\Users\james\Downloads\contest-standings-162564068.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162564068. Non-traditional format.
# 162562749
# contest-standings-162562749
# ['contest-standings-162562749.csv']
# C:\Users\james\Downloads\contest-standings-162562749.csv
# File copied successfully!
# Downloaded contest-standings-162562749. Non-traditional format.
# 162563636
# contest-standings-162563636
# ['contest-standings-162563636.csv']
# C:\Users\james\Downloads\contest-standings-162563636.csv
# File copied successfully!
# Downloaded contest-standings-162563636. Empty file.
# 162564069
# contest-standings-162564069
# ['contest-standings-162564069.zip']
# C:\Users\james\Downloads\contest-standings-162564069.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162564069. Non-traditional format.
# 162564063
# contest-standings-162564063
# ['contest-standings-162564063.zip']
# C:\Users\james\Downloads\contest-standings-162564063.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162564063. Non-traditional format.
# 162564059
# contest-standings-162564059
# ['contest-standings-162564059.zip']
# C:\Users\james\Downloads\contest-standings-162564059.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162564059. Non-traditional format.
# 162563460
# contest-standings-162563460
# ['contest-standings-162563460.csv']
# C:\Users\james\Downloads\contest-standings-162563460.csv
# File copied successfully!
# Downloaded contest-standings-162563460. Empty file.
# 162562699
# contest-standings-162562699
# ['contest-standings-162562699.csv']
# C:\Users\james\Downloads\contest-standings-162562699.csv
# File copied successfully!
# Downloaded contest-standings-162562699. Non-traditional format.
# 162564061
# contest-standings-162564061
# ['contest-standings-162564061.csv']
# C:\Users\james\Downloads\contest-standings-162564061.csv
# File copied successfully!
# Downloaded contest-standings-162564061. Non-traditional format.
# 162563821
# contest-standings-162563821
# ['contest-standings-162563821.csv']
# C:\Users\james\Downloads\contest-standings-162563821.csv
# File copied successfully!
# Downloaded contest-standings-162563821. Empty file.
# 162563820
# contest-standings-162563820
# ['contest-standings-162563820.csv']
# C:\Users\james\Downloads\contest-standings-162563820.csv
# File copied successfully!
# Downloaded contest-standings-162563820. Non-traditional format.
# 162563817
# contest-standings-162563817
# ['contest-standings-162563817.csv']
# C:\Users\james\Downloads\contest-standings-162563817.csv
# File copied successfully!
# Downloaded contest-standings-162563817. Non-traditional format.
# 162563819
# contest-standings-162563819
# ['contest-standings-162563819.csv']
# C:\Users\james\Downloads\contest-standings-162563819.csv
# File copied successfully!
# Downloaded contest-standings-162563819. Non-traditional format.
# 162563818
# contest-standings-162563818
# ['contest-standings-162563818.csv']
# C:\Users\james\Downloads\contest-standings-162563818.csv
# File copied successfully!
# Downloaded contest-standings-162563818. Non-traditional format.
# 162564053
# contest-standings-162564053
# ['contest-standings-162564053.zip']
# C:\Users\james\Downloads\contest-standings-162564053.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162564053. Non-traditional format.
# 162564055
# contest-standings-162564055
# ['contest-standings-162564055.zip']
# C:\Users\james\Downloads\contest-standings-162564055.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162564055. Non-traditional format.
# 162563548
# contest-standings-162563548
# ['contest-standings-162563548.csv']
# C:\Users\james\Downloads\contest-standings-162563548.csv
# File copied successfully!
# Downloaded contest-standings-162563548. Empty file.
# 162562724
# contest-standings-162562724
# ['contest-standings-162562724.csv']
# C:\Users\james\Downloads\contest-standings-162562724.csv
# File copied successfully!
# Downloaded contest-standings-162562724. Non-traditional format.
# 162564056
# contest-standings-162564056
# ['contest-standings-162564056.zip']
# C:\Users\james\Downloads\contest-standings-162564056.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162564056. Non-traditional format.
# 162564019
# contest-standings-162564019
# ['contest-standings-162564019.zip']
# C:\Users\james\Downloads\contest-standings-162564019.zip
# Zip file unpacked successfully!
# 162564022
# contest-standings-162564022
# ['contest-standings-162564022.zip']
# C:\Users\james\Downloads\contest-standings-162564022.zip
# Zip file unpacked successfully!
# 162564017
# contest-standings-162564017
# ['contest-standings-162564017.zip']
# C:\Users\james\Downloads\contest-standings-162564017.zip
# Zip file unpacked successfully!
# 162564018
# contest-standings-162564018
# ['contest-standings-162564018.zip']
# C:\Users\james\Downloads\contest-standings-162564018.zip
# Zip file unpacked successfully!
# 162564025
# contest-standings-162564025
# ['contest-standings-162564025.zip']
# C:\Users\james\Downloads\contest-standings-162564025.zip
# Zip file unpacked successfully!
# 162563996
# contest-standings-162563996
# ['contest-standings-162563996.zip']
# C:\Users\james\Downloads\contest-standings-162563996.zip
# Zip file unpacked successfully!
# 162564004
# contest-standings-162564004
# ['contest-standings-162564004.zip']
# C:\Users\james\Downloads\contest-standings-162564004.zip
# Zip file unpacked successfully!
# 162564003
# contest-standings-162564003
# ['contest-standings-162564003.zip']
# C:\Users\james\Downloads\contest-standings-162564003.zip
# Zip file unpacked successfully!
# 162563995
# contest-standings-162563995
# ['contest-standings-162563995.csv']
# C:\Users\james\Downloads\contest-standings-162563995.csv
# File copied successfully!
# 162564001
# contest-standings-162564001
# ['contest-standings-162564001.csv']
# C:\Users\james\Downloads\contest-standings-162564001.csv
# File copied successfully!
# 162563989
# contest-standings-162563989
# ['contest-standings-162563989.zip']
# C:\Users\james\Downloads\contest-standings-162563989.zip
# Zip file unpacked successfully!
# 162563992
# contest-standings-162563992
# ['contest-standings-162563992.zip']
# C:\Users\james\Downloads\contest-standings-162563992.zip
# Zip file unpacked successfully!
# 162563986
# contest-standings-162563986
# ['contest-standings-162563986.csv']
# C:\Users\james\Downloads\contest-standings-162563986.csv
# File copied successfully!
# 162563284
# contest-standings-162563284
# ['contest-standings-162563284.csv']
# C:\Users\james\Downloads\contest-standings-162563284.csv
# File copied successfully!
# Downloaded contest-standings-162563284. Empty file.
# 162562649
# contest-standings-162562649
# ['contest-standings-162562649.csv']
# C:\Users\james\Downloads\contest-standings-162562649.csv
# File copied successfully!
# 162563891
# contest-standings-162563891
# ['contest-standings-162563891.csv']
# C:\Users\james\Downloads\contest-standings-162563891.csv
# File copied successfully!
# Downloaded contest-standings-162563891. Empty file.
# 162563890
# contest-standings-162563890
# ['contest-standings-162563890.csv']
# C:\Users\james\Downloads\contest-standings-162563890.csv
# File copied successfully!
# Downloaded contest-standings-162563890. Non-traditional format.
# 162563889
# contest-standings-162563889
# ['contest-standings-162563889.csv']
# C:\Users\james\Downloads\contest-standings-162563889.csv
# File copied successfully!
# Downloaded contest-standings-162563889. Non-traditional format.
# 162563888
# contest-standings-162563888
# ['contest-standings-162563888.csv']
# C:\Users\james\Downloads\contest-standings-162563888.csv
# File copied successfully!
# Downloaded contest-standings-162563888. Non-traditional format.
# 162563887
# contest-standings-162563887
# ['contest-standings-162563887.csv']
# C:\Users\james\Downloads\contest-standings-162563887.csv
# File copied successfully!
# Downloaded contest-standings-162563887. Non-traditional format.
# 162563982
# contest-standings-162563982
# ['contest-standings-162563982.zip']
# C:\Users\james\Downloads\contest-standings-162563982.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162563982. Non-traditional format.
# 162563977
# contest-standings-162563977
# ['contest-standings-162563977.zip']
# C:\Users\james\Downloads\contest-standings-162563977.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162563977. Non-traditional format.
# 162563196
# contest-standings-162563196
# ['contest-standings-162563196.csv']
# C:\Users\james\Downloads\contest-standings-162563196.csv
# File copied successfully!
# Downloaded contest-standings-162563196. Empty file.
# 162562624
# contest-standings-162562624
# ['contest-standings-162562624.csv']
# C:\Users\james\Downloads\contest-standings-162562624.csv
# File copied successfully!
# Downloaded contest-standings-162562624. Non-traditional format.
# 162563980
# contest-standings-162563980
# ['contest-standings-162563980.csv']
# C:\Users\james\Downloads\contest-standings-162563980.csv
# File copied successfully!
# Downloaded contest-standings-162563980. Non-traditional format.
# 162563789
# contest-standings-162563789
# ['contest-standings-162563789.csv']
# C:\Users\james\Downloads\contest-standings-162563789.csv
# File copied successfully!
# Downloaded contest-standings-162563789. Empty file.
# 162563788
# contest-standings-162563788
# ['contest-standings-162563788.csv']
# C:\Users\james\Downloads\contest-standings-162563788.csv
# File copied successfully!
# Downloaded contest-standings-162563788. Empty file.
# 162563785
# contest-standings-162563785
# ['contest-standings-162563785.csv']
# C:\Users\james\Downloads\contest-standings-162563785.csv
# File copied successfully!
# Downloaded contest-standings-162563785. Empty file.
# 162563786
# contest-standings-162563786
# ['contest-standings-162563786.csv']
# C:\Users\james\Downloads\contest-standings-162563786.csv
# File copied successfully!
# Downloaded contest-standings-162563786. Empty file.
# 162563787
# contest-standings-162563787
# ['contest-standings-162563787.csv']
# C:\Users\james\Downloads\contest-standings-162563787.csv
# File copied successfully!
# Downloaded contest-standings-162563787. Empty file.
# 162563848
# contest-standings-162563848
# ['contest-standings-162563848.csv']
# C:\Users\james\Downloads\contest-standings-162563848.csv
# File copied successfully!
# Downloaded contest-standings-162563848. Non-traditional format.
# 162563847
# contest-standings-162563847
# ['contest-standings-162563847.csv']
# C:\Users\james\Downloads\contest-standings-162563847.csv
# File copied successfully!
# Downloaded contest-standings-162563847. Non-traditional format.
# 162563846
# contest-standings-162563846
# ['contest-standings-162563846.csv']
# C:\Users\james\Downloads\contest-standings-162563846.csv
# File copied successfully!
# Downloaded contest-standings-162563846. Non-traditional format.
# 162563843
# contest-standings-162563843
# ['contest-standings-162563843.csv']
# C:\Users\james\Downloads\contest-standings-162563843.csv
# File copied successfully!
# Downloaded contest-standings-162563843. Non-traditional format.
# 162563844
# contest-standings-162563844
# ['contest-standings-162563844.csv']
# C:\Users\james\Downloads\contest-standings-162563844.csv
# File copied successfully!
# Downloaded contest-standings-162563844. Non-traditional format.
# 162563973
# contest-standings-162563973
# ['contest-standings-162563973.zip']
# C:\Users\james\Downloads\contest-standings-162563973.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162563973. Non-traditional format.
# 162563974
# contest-standings-162563974
# ['contest-standings-162563974.zip']
# C:\Users\james\Downloads\contest-standings-162563974.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162563974. Non-traditional format.
# 162562599
# contest-standings-162562599
# ['contest-standings-162562599.csv']
# C:\Users\james\Downloads\contest-standings-162562599.csv
# File copied successfully!
# Downloaded contest-standings-162562599. Non-traditional format.
# 162563108
# contest-standings-162563108
# ['contest-standings-162563108.csv']
# C:\Users\james\Downloads\contest-standings-162563108.csv
# File copied successfully!
# Downloaded contest-standings-162563108. Empty file.
# 162563970
# contest-standings-162563970
# ['contest-standings-162563970.csv']
# C:\Users\james\Downloads\contest-standings-162563970.csv
# File copied successfully!
# Downloaded contest-standings-162563970. Non-traditional format.
# 162563944
# contest-standings-162563944
# ['contest-standings-162563944.zip']
# C:\Users\james\Downloads\contest-standings-162563944.zip
# Zip file unpacked successfully!
# 162563947
# contest-standings-162563947
# ['contest-standings-162563947.zip']
# C:\Users\james\Downloads\contest-standings-162563947.zip
# Zip file unpacked successfully!
# 162563945
# contest-standings-162563945
# ['contest-standings-162563945.zip']
# C:\Users\james\Downloads\contest-standings-162563945.zip
# Zip file unpacked successfully!
# 162563941
# contest-standings-162563941
# ['contest-standings-162563941.zip']
# C:\Users\james\Downloads\contest-standings-162563941.zip
# Zip file unpacked successfully!
# 162563943
# contest-standings-162563943
# ['contest-standings-162563943.zip']
# C:\Users\james\Downloads\contest-standings-162563943.zip
# Zip file unpacked successfully!
# 162563983
# contest-standings-162563983
# ['contest-standings-162563983.zip']
# C:\Users\james\Downloads\contest-standings-162563983.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162563983. Non-traditional format.
# 162563990
# contest-standings-162563990
# ['contest-standings-162563990.zip']
# C:\Users\james\Downloads\contest-standings-162563990.zip
# Zip file unpacked successfully!
# 162564021
# contest-standings-162564021
# ['contest-standings-162564021.zip']
# C:\Users\james\Downloads\contest-standings-162564021.zip
# Zip file unpacked successfully!
# 162564065
# contest-standings-162564065
# ['contest-standings-162564065.zip']
# C:\Users\james\Downloads\contest-standings-162564065.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162564065. Non-traditional format.
# 162564070
# contest-standings-162564070
# ['contest-standings-162564070.zip']
# C:\Users\james\Downloads\contest-standings-162564070.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162564070. Non-traditional format.
# 162564080
# contest-standings-162564080
# ['contest-standings-162564080.zip']
# C:\Users\james\Downloads\contest-standings-162564080.zip
# Zip file unpacked successfully!
# 162564097
# contest-standings-162564097
# ['contest-standings-162564097.zip']
# C:\Users\james\Downloads\contest-standings-162564097.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-162564097. Non-traditional format.

# %% [markdown]
# ### A02. MLB API

# %%
# %run "C:\Users\james\Documents\MLB\Code\A02. MLB API.ipynb"

# %% [markdown]
# ##### 1. Stats API

# %%
statsapi_df = plays_statsapi("03/20/2024", "11/15/2024")
statsapi_df.to_csv(os.path.join(baseball_path, "A02. MLB API", "1. Stats API", "Stats API 2024.csv"), index=False, encoding='iso-8859-1')

del statsapi_df

# %% [markdown]
# ##### 2. Statcast

# %%
statcast_df = plays_statcast("2024-03-20", "2024-11-15")
statcast_df.to_csv(os.path.join(baseball_path, "A02. MLB API", "2. Statcast", "Statcast 2024.csv"), index=False, encoding='iso-8859-1')

del statcast_df
# Out:
# This is a large query, it may take a moment to complete
# 100%|██████████| 241/241 [13:01<00:00,  3.24s/it]

# %% [markdown]
# ### A03. Steamer

# %%
# %run "C:\Users\james\Documents\MLB\Code\A03. Steamer.ipynb"

# %%
download_steamer()

# %%
move_steamer()
# Out:
# Moved 'C:\Users\james\Downloads\steamer_pitchers_weekly_log.csv' to 'C:\Users\james\Documents\MLB\Database\A03. Steamer'.
# Moved 'C:\Users\james\Downloads\steamer_hitters_weekly_log.csv' to 'C:\Users\james\Documents\MLB\Database\A03. Steamer'.
# Moved 'C:\Users\james\Downloads\steamer_pitchers.csv' to 'C:\Users\james\Documents\MLB\Database\A03. Steamer'.
# Moved 'C:\Users\james\Downloads\steamer_hitters.csv' to 'C:\Users\james\Documents\MLB\Database\A03. Steamer'.

# %% [markdown]
# ### A07. Projections

# %%
# %run "C:\Users\james\Documents\MLB\Code\A07. Projections.ipynb"

# %%
# Scrape slates
dff_slates_df = dff_slates(todaysdate)
# To csv
dff_slates_df.to_csv(os.path.join(baseball_path, "A07. Projections", "1. DFF", "1. Slates", f"DFF Slates {todaysdate}.csv"), index=False)

# %%
# Scrape slates
roto_slates_df = roto_slates(todaysdate)
# To csv
roto_slates_df.to_csv(os.path.join(baseball_path, "A07. Projections", "2. RotoWire", "1. Slates", f"RotoWire Slates {todaysdate}.csv"), index=False)
