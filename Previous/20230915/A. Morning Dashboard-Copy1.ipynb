# %% [markdown]
# # A. Morning Dashboard
# - Date: 3/23/2024
# - Description: This runs every morning to gather time-insensitive data:
#     - DraftKings upcoming contests, salaries, and previous results
#     - Stats API and Statcast
#     - Steamer

# %% [markdown]
# ### Imports

# %%
# %run "C:\Users\james\Documents\MLB\Code\U1. Imports.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U2. Utilities.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\U3. Classes.ipynb"

# %% [markdown]
# ### Games

# %% [markdown]
# Select start and end date (should be yesterdaysdate for both if running day-of) <br>
# Note: Past information may not be available for all scrapes.

# %%
start_date = yesterdaysdate
end_date = yesterdaysdate

# %% [markdown]
# Read in games

# %%
game_df = read_and_save_games(team_map, generate=True)

# %%
game_df = game_df[(game_df['date'] >= start_date) & (game_df['date'] <= end_date)].reset_index(drop=True)

# %% [markdown]
# ### A01. DraftKings

# %%
# %run "C:\Users\james\Documents\MLB\Code\A01. DraftKings.ipynb"

# %% [markdown]
# ##### 1. Contests

# %%
# Scrape contests
contest_df = contests(todaysdate)
# To csv
contest_df.to_csv(os.path.join(baseball_path, 'A01. DraftKings', '1. Contests', f'Contests {todaysdate}.csv'), index=False)

# %% [markdown]
# ##### 7. Subsets

# %%
# Select subset
subset_df = create_subset(contest_df, contests_per_draftGroupId=5, entry_fee_max=100, added_contestKeys=[], date_dash=todaysdate_dash)
subset_df.reset_index(drop=True, inplace=True)

# Save subset
subset_df.to_csv(os.path.join(baseball_path, "A01. DraftKings", "7. Subsets", f'Subset {todaysdate}.csv'), index=False)

# %% [markdown]
# ##### 2. Draftables

# %%
# %%time
# Loop over contests of interest
for draftGroupId in list(subset_df['draftGroupId'].unique()):
    print(draftGroupId)
    try:
        # Scrape draftables (DK Salaries)
        draftable_df = draftables(draftGroupId)
        # To csv
        draftable_df.to_csv(os.path.join(baseball_path, "A01. DraftKings", "2. Draftables", f"Draftables {draftGroupId}.csv"), index=False, encoding='iso-8859-1')
        print(f"Saved {draftGroupId}")
    except:
        print(f"Didn't save {draftGroupId}")
# Out:
# 105038
# Saved 105038
# 105035
# Didn't save 105035
# 105034
# Didn't save 105034
# 105033
# Saved 105033
# 105032
# Didn't save 105032
# 105031
# Saved 105031
# 105043
# Saved 105043
# 105045
# Saved 105045
# 105052
# Saved 105052
# CPU times: total: 2.23 s
# Wall time: 4.86 s

# %% [markdown]
# ##### 3. Payouts

# %%
# %%time
# Loop over contests of interest
for i in range(len(subset_df)):
    # Extract contestKey
    contestKey = subset_df['contestKey'][i]
    try:
        # Scrape payouts
        payout_df = payouts(contestKey)
        # To csv
        payout_df.to_csv(os.path.join(baseball_path, "A01. DraftKings", "3. Payouts", f"Payouts {contestKey}.csv"), index=False, encoding='iso-8859-1')
    except:
        print(f"Didn't save {contestKey}.")
# Out:
# CPU times: total: 6.67 s
# Wall time: 15.2 s

# %% [markdown]
# ##### 4. Results, 5. Entry Results, and 6. Player Results

# %% [markdown]
# Note: This will break if there were no games yesterday.

# %%
# Read in yesterdays subset
yesterdays_subset_df = pd.read_csv(os.path.join(baseball_path, 'A01. DraftKings', '7. Subsets', f'Subset {yesterdaysdate}.csv'))

# %%
# Loop over yesterday's contests
for i in range(len(yesterdays_subset_df)):
    # Extract contestKey
    contestKey = yesterdays_subset_df['contestKey'][i]
    print(contestKey)
    # Scrape results
    results(contestKey, sleep_time=5)

    try:        
        # Read into pandas
        results_df = pd.read_csv(os.path.join(baseball_path, "A01. DraftKings", "4. Results", f"contest-standings-{contestKey}.csv"))
        
        # Entry results
        entry_results_df = entry_results(results_df)
        entry_results_df.to_csv(os.path.join(baseball_path, "A01. DraftKings", "5. Entry Results", f"Entry Results {contestKey}.csv"), index=False, encoding='iso-8859-1')
    
        # Player results
        player_results_df = player_results(results_df)
        player_results_df.to_csv(os.path.join(baseball_path, "A01. DraftKings", "6. Player Results", f"Player Results {contestKey}.csv"), index=False, encoding='iso-8859-1')
    except IndexError as e:
        print(f"Downloaded contest-standings-{contestKey}. Non-traditional format.")
    except pd.errors.EmptyDataError as e:
        print(f"Downloaded contest-standings-{contestKey}. Empty file.")
# Out:
# 160773720
# contest-standings-160773720
# ['contest-standings-160773720.zip']
# C:\Users\james\Downloads\contest-standings-160773720.zip
# Zip file unpacked successfully!
# 160773723
# contest-standings-160773723
# ['contest-standings-160773723.zip']
# C:\Users\james\Downloads\contest-standings-160773723.zip
# Zip file unpacked successfully!
# 160773721
# contest-standings-160773721
# ['contest-standings-160773721.zip']
# C:\Users\james\Downloads\contest-standings-160773721.zip
# Zip file unpacked successfully!
# 160773719
# contest-standings-160773719
# ['contest-standings-160773719.csv']
# C:\Users\james\Downloads\contest-standings-160773719.csv
# File copied successfully!
# 160773718
# contest-standings-160773718
# ['contest-standings-160773718.csv']
# C:\Users\james\Downloads\contest-standings-160773718.csv
# File copied successfully!
# 160764296
# contest-standings-160764296
# ['contest-standings-160764296.csv']
# C:\Users\james\Downloads\contest-standings-160764296.csv
# File copied successfully!
# Downloaded contest-standings-160764296. Empty file.
# 160764295
# contest-standings-160764295
# ['contest-standings-160764295.csv']
# C:\Users\james\Downloads\contest-standings-160764295.csv
# File copied successfully!
# Downloaded contest-standings-160764295. Non-traditional format.
# 160764294
# contest-standings-160764294
# ['contest-standings-160764294.csv']
# C:\Users\james\Downloads\contest-standings-160764294.csv
# File copied successfully!
# Downloaded contest-standings-160764294. Non-traditional format.
# 160764291
# contest-standings-160764291
# ['contest-standings-160764291.csv']
# C:\Users\james\Downloads\contest-standings-160764291.csv
# File copied successfully!
# Downloaded contest-standings-160764291. Non-traditional format.
# 160764292
# contest-standings-160764292
# ['contest-standings-160764292.csv']
# C:\Users\james\Downloads\contest-standings-160764292.csv
# File copied successfully!
# Downloaded contest-standings-160764292. Non-traditional format.
# 160771976
# contest-standings-160771976
# ['contest-standings-160771976.zip']
# C:\Users\james\Downloads\contest-standings-160771976.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-160771976. Non-traditional format.
# 160771978
# contest-standings-160771978
# ['contest-standings-160771978.zip']
# C:\Users\james\Downloads\contest-standings-160771978.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-160771978. Non-traditional format.
# 160764199
# contest-standings-160764199
# ['contest-standings-160764199.csv']
# C:\Users\james\Downloads\contest-standings-160764199.csv
# File copied successfully!
# Downloaded contest-standings-160764199. Empty file.
# 160763593
# contest-standings-160763593
# ['contest-standings-160763593.csv']
# C:\Users\james\Downloads\contest-standings-160763593.csv
# File copied successfully!
# Downloaded contest-standings-160763593. Non-traditional format.
# 160763599
# contest-standings-160763599
# ['contest-standings-160763599.csv']
# C:\Users\james\Downloads\contest-standings-160763599.csv
# File copied successfully!
# Downloaded contest-standings-160763599. Non-traditional format.
# 160771960
# contest-standings-160771960
# ['contest-standings-160771960.zip']
# C:\Users\james\Downloads\contest-standings-160771960.zip
# Zip file unpacked successfully!
# 160771954
# contest-standings-160771954
# ['contest-standings-160771954.zip']
# C:\Users\james\Downloads\contest-standings-160771954.zip
# Zip file unpacked successfully!
# 160771955
# contest-standings-160771955
# ['contest-standings-160771955.zip']
# C:\Users\james\Downloads\contest-standings-160771955.zip
# Zip file unpacked successfully!
# 160771961
# contest-standings-160771961
# ['contest-standings-160771961.zip']
# C:\Users\james\Downloads\contest-standings-160771961.zip
# Zip file unpacked successfully!
# 160771965
# contest-standings-160771965
# ['contest-standings-160771965.zip']
# C:\Users\james\Downloads\contest-standings-160771965.zip
# Zip file unpacked successfully!
# 160771943
# contest-standings-160771943
# ['contest-standings-160771943.zip']
# C:\Users\james\Downloads\contest-standings-160771943.zip
# Zip file unpacked successfully!
# 160771945
# contest-standings-160771945
# ['contest-standings-160771945.zip']
# C:\Users\james\Downloads\contest-standings-160771945.zip
# Zip file unpacked successfully!
# 160771940
# contest-standings-160771940
# ['contest-standings-160771940.csv']
# C:\Users\james\Downloads\contest-standings-160771940.csv
# File copied successfully!
# 160763939
# contest-standings-160763939
# ['contest-standings-160763939.csv']
# C:\Users\james\Downloads\contest-standings-160763939.csv
# File copied successfully!
# Downloaded contest-standings-160763939. Empty file.
# 160771941
# contest-standings-160771941
# ['contest-standings-160771941.csv']
# C:\Users\james\Downloads\contest-standings-160771941.csv
# File copied successfully!
# 160764249
# contest-standings-160764249
# ['contest-standings-160764249.csv']
# C:\Users\james\Downloads\contest-standings-160764249.csv
# File copied successfully!
# Downloaded contest-standings-160764249. Empty file.
# 160764248
# contest-standings-160764248
# ['contest-standings-160764248.csv']
# C:\Users\james\Downloads\contest-standings-160764248.csv
# File copied successfully!
# Downloaded contest-standings-160764248. Non-traditional format.
# 160764245
# contest-standings-160764245
# ['contest-standings-160764245.csv']
# C:\Users\james\Downloads\contest-standings-160764245.csv
# File copied successfully!
# Downloaded contest-standings-160764245. Non-traditional format.
# 160764247
# contest-standings-160764247
# ['contest-standings-160764247.csv']
# C:\Users\james\Downloads\contest-standings-160764247.csv
# File copied successfully!
# Downloaded contest-standings-160764247. Non-traditional format.
# 160764246
# contest-standings-160764246
# ['contest-standings-160764246.csv']
# C:\Users\james\Downloads\contest-standings-160764246.csv
# File copied successfully!
# Downloaded contest-standings-160764246. Non-traditional format.
# 160771925
# contest-standings-160771925
# ['contest-standings-160771925.zip']
# C:\Users\james\Downloads\contest-standings-160771925.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-160771925. Non-traditional format.
# 160771927
# contest-standings-160771927
# ['contest-standings-160771927.zip']
# C:\Users\james\Downloads\contest-standings-160771927.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-160771927. Non-traditional format.
# 160771922
# contest-standings-160771922
# ['contest-standings-160771922.csv']
# C:\Users\james\Downloads\contest-standings-160771922.csv
# File copied successfully!
# Downloaded contest-standings-160771922. Non-traditional format.
# 160771928
# contest-standings-160771928
# ['contest-standings-160771928.zip']
# C:\Users\james\Downloads\contest-standings-160771928.zip
# Zip file unpacked successfully!
# Downloaded contest-standings-160771928. Non-traditional format.
# 160763853
# contest-standings-160763853
# ['contest-standings-160763853.csv']
# C:\Users\james\Downloads\contest-standings-160763853.csv
# File copied successfully!
# Downloaded contest-standings-160763853. Empty file.
# 160773880
# contest-standings-160773880
# ['contest-standings-160773880.zip']
# C:\Users\james\Downloads\contest-standings-160773880.zip
# Zip file unpacked successfully!
# 160773882
# contest-standings-160773882
# ['contest-standings-160773882.zip']
# C:\Users\james\Downloads\contest-standings-160773882.zip
# Zip file unpacked successfully!
# 160771882
# contest-standings-160771882
# ['contest-standings-160771882.zip']
# C:\Users\james\Downloads\contest-standings-160771882.zip
# Zip file unpacked successfully!
# 160771899
# contest-standings-160771899
# ['contest-standings-160771899.zip']
# C:\Users\james\Downloads\contest-standings-160771899.zip
# Zip file unpacked successfully!
# 160771885
# contest-standings-160771885
# ['contest-standings-160771885.zip']
# C:\Users\james\Downloads\contest-standings-160771885.zip
# Zip file unpacked successfully!
# 160771939
# contest-standings-160771939
# ['contest-standings-160771939.zip']
# C:\Users\james\Downloads\contest-standings-160771939.zip
# Zip file unpacked successfully!

# %% [markdown]
# ### A02. MLB API

# %%
# %run "C:\Users\james\Documents\MLB\Code\A02. MLB API.ipynb"

# %% [markdown]
# ##### 1. Stats API

# %%
statsapi_df = plays_statsapi("03/20/2024", "11/15/2024")
statsapi_df.to_csv(os.path.join(baseball_path, "A02. MLB API", "1. Stats API", "Stats API 2024.csv"), index=False, encoding='iso-8859-1')

del statsapi_df

# %% [markdown]
# ##### 2. Statcast

# %%
statcast_df = plays_statcast("2024-03-20", "2024-11-15")
statcast_df.to_csv(os.path.join(baseball_path, "A02. MLB API", "2. Statcast", "Statcast 2024.csv"), index=False, encoding='iso-8859-1')

del statcast_df
# Out:
# This is a large query, it may take a moment to complete
# 100%|██████████| 241/241 [07:33<00:00,  1.88s/it]

# %% [markdown]
# ### A03. Steamer

# %% [markdown]
# Note: Ensure code is on same screen as web browser for pyautogui controls to work as intended.

# %%
# %run "C:\Users\james\Documents\MLB\Code\A03. Steamer.ipynb"

# %%
time.sleep(5)

# %%
copy_page_source('http://www.steamerprojections.com/index.php/projections/2024-projections')

url_text = find_url_after_text("Pitchers, 2024", pyperclip.paste())
print(url_text)
print(pyperclip.paste())
webbrowser.open("http:www.steamerprojections.com" + url_text)

url_text = find_url_after_text("Hitters, 2024", pyperclip.paste())
print(url_text)
webbrowser.open("http:www.steamerprojections.com" + url_text)
# Out:
# /index.php/projections/2024-projections?task=callelement&amp;format=raw&amp;item_id=1168&amp;element=2331b84b-d95c-470d-89ef-f458ce60ad9a&amp;method=download&amp;args[0]=0.0&amp;args[1]=8dcfb20d925a756767fc73d2e62fa403
#
# <!DOCTYPE html>
# <html lang="en-gb" dir="ltr" vocab="http://schema.org/">
#     <head>
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#         <meta name="viewport" content="width=device-width, initial-scale=1">
#         <link rel="shortcut icon" href="/images/ornament-bg5.png">
#         <link rel="apple-touch-icon-precomposed" href="/images/ornament-bg5.png">
#         <meta charset="utf-8" />
# 	<base href="http://www.steamerprojections.com/index.php/projections/2024-projections" />
# 	<meta name="rights" content="Copyright 2018" />
# 	<title>Steamer Projections - 2024 Projections</title>
# 	<link href="/index.php/projections/2024-projections/feed/rss/projections/2024?format=feed" rel="alternate" type="application/rss+xml" title="RSS 2.0" />
# 	<link href="/index.php/projections/2024-projections/feed/atom/projections/2024?format=feed" rel="alternate" type="application/atom+xml" title="Atom 1.0" />
# 	<link href="/media/zoo/assets/css/uikit3-zoo.css?ver=20190311" rel="stylesheet" />
# 	<link href="http://www.steamerprojections.com/media/com_akeebasubs/css/frontend.css?58957365f04242892b0df85f76d52c10" rel="stylesheet" />
# 	<link href="/templates/yootheme/cache/styles-181f6ebf.css?v=1.19.2" rel="stylesheet" id="styles-css" />
# 	<script type="application/json" class="joomla-script-options new">{"csrf.token":"4ed6438f4c7f3cd6c40ea2f172e5e422","system.paths":{"root":"","base":""}}</script>
# 	<script src="/media/jui/js/jquery.min.js?0bbb6deb53c24d536611a66c56457a2d"></script>
# 	<script src="/media/jui/js/jquery-noconflict.js?0bbb6deb53c24d536611a66c56457a2d"></script>
# 	<script src="/media/jui/js/jquery-migrate.min.js?0bbb6deb53c24d536611a66c56457a2d"></script>
# 	<script src="/media/zoo/assets/js/responsive.js?ver=20190311"></script>
# 	<script src="/components/com_zoo/assets/js/default.js?ver=20190311"></script>
# 	<script src="/media/system/js/core.js?0bbb6deb53c24d536611a66c56457a2d"></script>
# 	<script src="/templates/yootheme/cache/scripts-bfa206f5.js?v=1.19.2"></script>
# 	<script src="/templates/yootheme/vendor/yootheme/theme-cookie/app/cookie.min.js?v=1.19.2" defer></script>
# 	<script>
# document.addEventListener('DOMContentLoaded', function() {
#     Array.prototype.slice.call(document.querySelectorAll('a span[id^="cloak"]')).forEach(function(span) {
#         span.innerText = span.textContent;
#     });
# });
# 	</script>
#
#     </head>
#     <body class="">
#
#
#
#         <div class="tm-page">
#
#
# <div class="tm-header-mobile uk-hidden@m">
#
# <div uk-sticky cls-active="uk-navbar-sticky" sel-target=".uk-navbar-container">
#
#     <nav class="uk-navbar-container" uk-navbar>
#
#                 <div class="uk-navbar-left">
#
#
#                         <a class="uk-navbar-toggle" href="#tm-mobile" uk-toggle>
#                 <div uk-navbar-toggle-icon></div>
#                             </a>
#
#
#         </div>
#
#                 <div class="uk-navbar-center">
#             <a class="uk-navbar-item uk-logo" href="http://www.steamerprojections.com">
#                 <img alt src="/templates/yootheme/cache/ornament-bg5-13911bef.png" srcset="/templates/yootheme/cache/ornament-bg5-13911bef.png 100w, /templates/yootheme/cache/ornament-bg5-350d1a1a.png 200w" sizes="(min-width: 100px) 100px" data-width="100" data-height="80">            </a>
#         </div>
#
#
#     </nav>
#
#
# </div>
#
#
# <div id="tm-mobile" class="uk-modal-full" uk-modal>
#     <div class="uk-modal-dialog uk-modal-body uk-flex uk-height-viewport">
#
#         <button class="uk-modal-close-full" type="button" uk-close></button>
#
#                 <div class="uk-margin-auto-vertical uk-width-1-1">
#
#
# <div class="uk-child-width-1-1" uk-grid>    <div>
# <div class="uk-panel" id="module-0">
#
#
#
# <ul class="uk-nav uk-nav-primary">
#
# 	<li><a href="/index.php">Home</a></li>
# 	<li class="uk-active uk-parent"><a href="/index.php/projections">Projections</a>
# 	<ul class="uk-nav-sub">
#
# 		<li class="uk-active"><a href="/index.php/projections/2024-projections">2024 Projections</a></li>
# 		<li><a href="/index.php/projections/pre-season-projections">Pre-Season Projections</a></li>
# 		<li><a href="/index.php/projections/historical-weekly-logs">Historical Weekly Logs</a></li></ul></li>
# 	<li class="uk-parent"><a href="/index.php/about">About</a>
# 	<ul class="uk-nav-sub">
#
# 		<li><a href="/index.php/about/memberships">Memberships</a></li>
# 		<li><a href="/index.php/about/glossary">Glossary</a></li></ul></li>
# 	<li class="uk-parent"><a href="/index.php/account/userinfo">Account</a>
# 	<ul class="uk-nav-sub">
#
# 		<li><a href="/index.php/account/userinfo">My Account</a></li>
# 		<li><a href="/index.php/account/my-membership/subscriptions">My Membership</a></li>
# 		<li><a href="/index.php/account/logout">Logout</a></li>
# 		<li><a href="/index.php/account/subscriptions/levels">Subscriptions</a></li></ul></li>
# 	<li><a href="/index.php/blog">Blog</a></li></ul>
#
# </div>
# </div></div>
#
#                     </div>
#
#     </div>
# </div>
# </div>
#
#
# <div class="tm-header uk-visible@m" uk-header>
#
#
#
#         <div uk-sticky media="@m" cls-active="uk-navbar-sticky" sel-target=".uk-navbar-container">
#
#         <div class="uk-navbar-container">
#
#             <div class="uk-container">
#                 <nav class="uk-navbar" uk-navbar="{&quot;align&quot;:&quot;left&quot;,&quot;boundary&quot;:&quot;!.uk-navbar-container&quot;,&quot;dropbar&quot;:true,&quot;dropbar-anchor&quot;:&quot;!.uk-navbar-container&quot;,&quot;dropbar-mode&quot;:&quot;slide&quot;}">
#
#                                         <div class="uk-navbar-left">
#
#
# <a href="http://www.steamerprojections.com" class="uk-navbar-item uk-logo">
#     <img alt src="/templates/yootheme/cache/logo_reverse-c1fa698d.png" srcset="/templates/yootheme/cache/logo_reverse-c1fa698d.png 280w, /templates/yootheme/cache/logo_reverse-ffa314df.png 559w, /templates/yootheme/cache/logo_reverse-04573bec.png 560w" sizes="(min-width: 280px) 280px" data-width="280" data-height="80"><img class="uk-logo-inverse" alt src="/templates/yootheme/cache/logo-b17b486d.png" srcset="/templates/yootheme/cache/logo-b17b486d.png 280w, /templates/yootheme/cache/logo-b8d77562.png 559w, /templates/yootheme/cache/logo-43235a51.png 560w" sizes="(min-width: 280px) 280px" data-width="280" data-height="80"></a>
#
#
#                     </div>
#
#
#                                         <div class="uk-navbar-right">
#
#
# <ul class="uk-navbar-nav">
#
# 	<li><a href="/index.php">Home</a></li>
# 	<li class="uk-active uk-parent"><a href="/index.php/projections">Projections</a>
# 	<div class="uk-navbar-dropdown"><div class="uk-navbar-dropdown-grid uk-child-width-1-1" uk-grid><div><ul class="uk-nav uk-navbar-dropdown-nav">
#
# 		<li class="uk-active"><a href="/index.php/projections/2024-projections">2024 Projections</a></li>
# 		<li><a href="/index.php/projections/pre-season-projections">Pre-Season Projections</a></li>
# 		<li><a href="/index.php/projections/historical-weekly-logs">Historical Weekly Logs</a></li></ul></div></div></div></li>
# 	<li class="uk-parent"><a href="/index.php/about">About</a>
# 	<div class="uk-navbar-dropdown"><div class="uk-navbar-dropdown-grid uk-child-width-1-1" uk-grid><div><ul class="uk-nav uk-navbar-dropdown-nav">
#
# 		<li><a href="/index.php/about/memberships">Memberships</a></li>
# 		<li><a href="/index.php/about/glossary">Glossary</a></li></ul></div></div></div></li>
# 	<li class="uk-parent"><a href="/index.php/account/userinfo">Account</a>
# 	<div class="uk-navbar-dropdown"><div class="uk-navbar-dropdown-grid uk-child-width-1-1" uk-grid><div><ul class="uk-nav uk-navbar-dropdown-nav">
#
# 		<li><a href="/index.php/account/userinfo">My Account</a></li>
# 		<li><a href="/index.php/account/my-membership/subscriptions">My Membership</a></li>
# 		<li><a href="/index.php/account/logout">Logout</a></li>
# 		<li><a href="/index.php/account/subscriptions/levels">Subscriptions</a></li></ul></div></div></div></li>
# 	<li><a href="/index.php/blog">Blog</a></li></ul>
#
#
#
#
#                     </div>
#
#                 </nav>
#             </div>
#
#         </div>
#
#         </div>
#
#
#
#
#
# </div>
#
#
#
#
#             <div id="tm-main"  class="tm-main uk-section uk-section-default" uk-height-viewport="expand: true">
#                 <div class="uk-container">
#
#
#                     <div class="uk-grid" uk-grid>
#                         <div class="uk-width-expand@m">
#
#
#
#
#             <div id="system-message-container">
# </div>
#
#
# <div class="yoo-zoo product-uikit3 product-uikit3-2024">
#
#
#
# 				<h1>2024</h1>
#
#
#
#
#
#
# <div class="uk-grid" uk-grid uk-height-match><div class="uk-width-1-2@m">
# <div class="uk-card uk-card-default uk-card-body">
#
#
# <div class="uk-overflow-hidden">
#
#
# 	 Fielding, 2024 rest-of-season
# <ul class="uk-list">
#
# <li class="element element-download element-downloadpro">
# 	<a class="yoo-zoo element-download-button uk-button uk-button-primary" href="/index.php/projections/2024-projections?task=callelement&amp;format=raw&amp;item_id=1165&amp;element=2331b84b-d95c-470d-89ef-f458ce60ad9a&amp;method=download&amp;args[0]=0.0&amp;args[1]=a35926b7aea470933d5211d0805a1929" title="Download"><span><span>Download</span></span><span uk-icon="icon: download" class="uk-margin-left"></span></a></li>
#
# <li class="element element-download element-downloadpro">
# 	125.65 KB</li></ul>
#
#
# </div></div></div><div class="uk-width-1-2@m">
# <div class="uk-card uk-card-default uk-card-body">
#
#
# <div class="uk-overflow-hidden">
#
#
# 	 Pitcher Opp Batter Splits, 2024 rest-of-season
# <ul class="uk-list">
#
# <li class="element element-download element-downloadpro">
# 	<a class="yoo-zoo element-download-button uk-button uk-button-primary" href="/index.php/projections/2024-projections?task=callelement&amp;format=raw&amp;item_id=1164&amp;element=2331b84b-d95c-470d-89ef-f458ce60ad9a&amp;method=download&amp;args[0]=0.0&amp;args[1]=9012a5bd439a6e453dd759029bd7ed7c" title="Download"><span><span>Download</span></span><span uk-icon="icon: download" class="uk-margin-left"></span></a></li>
#
# <li class="element element-download element-downloadpro">
# 	45805.34 KB</li></ul>
#
#
# </div></div></div></div><div class="uk-grid" uk-grid uk-height-match><div class="uk-width-1-2@m">
# <div class="uk-card uk-card-default uk-card-body">
#
#
# <div class="uk-overflow-hidden">
#
#
# 	 Pitcher Splits, 2024 rest-of-season
# <ul class="uk-list">
#
# <li class="element element-download element-downloadpro">
# 	<a class="yoo-zoo element-download-button uk-button uk-button-primary" href="/index.php/projections/2024-projections?task=callelement&amp;format=raw&amp;item_id=1166&amp;element=2331b84b-d95c-470d-89ef-f458ce60ad9a&amp;method=download&amp;args[0]=0.0&amp;args[1]=14f98615c8ccc3f76cf318d92d94ee9c" title="Download"><span><span>Download</span></span><span uk-icon="icon: download" class="uk-margin-left"></span></a></li>
#
# <li class="element element-download element-downloadpro">
# 	15330.93 KB</li></ul>
#
#
# </div></div></div><div class="uk-width-1-2@m">
# <div class="uk-card uk-card-default uk-card-body">
#
#
# <div class="uk-overflow-hidden">
#
#
# 	 Hitter Splits, 2024 rest-of-season
# <ul class="uk-list">
#
# <li class="element element-download element-downloadpro">
# 	<a class="yoo-zoo element-download-button uk-button uk-button-primary" href="/index.php/projections/2024-projections?task=callelement&amp;format=raw&amp;item_id=1169&amp;element=2331b84b-d95c-470d-89ef-f458ce60ad9a&amp;method=download&amp;args[0]=0.0&amp;args[1]=419a4498d2044aa0fbb3e133ee38e631" title="Download"><span><span>Download</span></span><span uk-icon="icon: download" class="uk-margin-left"></span></a></li>
#
# <li class="element element-download element-downloadpro">
# 	10755.9 KB</li></ul>
#
#
# </div></div></div></div><div class="uk-grid" uk-grid uk-height-match><div class="uk-width-1-2@m">
# <div class="uk-card uk-card-default uk-card-body">
#
#
# <div class="uk-overflow-hidden">
#
#
# 	 Pitchers, 2024 rest-of-season
# <ul class="uk-list">
#
# <li class="element element-download element-downloadpro">
# 	<a class="yoo-zoo element-download-button uk-button uk-button-primary" href="/index.php/projections/2024-projections?task=callelement&amp;format=raw&amp;item_id=1168&amp;element=2331b84b-d95c-470d-89ef-f458ce60ad9a&amp;method=download&amp;args[0]=0.0&amp;args[1]=8dcfb20d925a756767fc73d2e62fa403" title="Download"><span><span>Download</span></span><span uk-icon="icon: download" class="uk-margin-left"></span></a></li>
#
# <li class="element element-download element-downloadpro">
# 	2819.61 KB</li></ul>
#
#
# </div></div></div><div class="uk-width-1-2@m">
# <div class="uk-card uk-card-default uk-card-body">
#
#
# <div class="uk-overflow-hidden">
#
#
# 	 Hitters, 2024 rest-of-season
# <ul class="uk-list">
#
# <li class="element element-download element-downloadpro">
# 	<a class="yoo-zoo element-download-button uk-button uk-button-primary" href="/index.php/projections/2024-projections?task=callelement&amp;format=raw&amp;item_id=1167&amp;element=2331b84b-d95c-470d-89ef-f458ce60ad9a&amp;method=download&amp;args[0]=0.0&amp;args[1]=13825866a924a340bd19ef435d98bbd6" title="Download"><span><span>Download</span></span><span uk-icon="icon: download" class="uk-margin-left"></span></a></li>
#
# <li class="element element-download element-downloadpro">
# 	1718.57 KB</li></ul>
#
#
# </div></div></div></div><div class="uk-grid" uk-grid uk-height-match><div class="uk-width-1-2@m">
# <div class="uk-card uk-card-default uk-card-body">
#
#
# <div class="uk-overflow-hidden">
#
#
# 	 Pitchers, Percentile Projections
# <ul class="uk-list">
#
# <li class="element element-download element-downloadpro">
# 	<a class="yoo-zoo element-download-button uk-button uk-button-primary" href="/index.php/projections/2024-projections?task=callelement&amp;format=raw&amp;item_id=1170&amp;element=2331b84b-d95c-470d-89ef-f458ce60ad9a&amp;method=download&amp;args[0]=0.0&amp;args[1]=9156a60f5d1ce67279bd0bc53c75e6cb" title="Download"><span><span>Download</span></span><span uk-icon="icon: download" class="uk-margin-left"></span></a></li>
#
# <li class="element element-download element-downloadpro">
# 	668.31 KB</li></ul>
#
#
# </div></div></div><div class="uk-width-1-2@m">
# <div class="uk-card uk-card-default uk-card-body">
#
#
# <div class="uk-overflow-hidden">
#
#
# 	 Hitters, Percentile Projections
# <ul class="uk-list">
#
# <li class="element element-download element-downloadpro">
# 	<a class="yoo-zoo element-download-button uk-button uk-button-primary" href="/index.php/projections/2024-projections?task=callelement&amp;format=raw&amp;item_id=1171&amp;element=2331b84b-d95c-470d-89ef-f458ce60ad9a&amp;method=download&amp;args[0]=0.0&amp;args[1]=d88379509a6c5beab1a8f29a567c773a" title="Download"><span><span>Download</span></span><span uk-icon="icon: download" class="uk-margin-left"></span></a></li>
#
# <li class="element element-download element-downloadpro">
# 	405.47 KB</li></ul>
#
#
# </div></div></div></div>
#
#
# </div>
#
#
#
#
#                                                 </div>
#
#
# <aside id="tm-sidebar" class="tm-sidebar uk-width-1-5@m">
#
# <div class="uk-child-width-1-1" uk-grid>    <div>
# <div class="uk-panel" id="module-99">
#
#         <h3>
#
#                     My Membership
#     </h3>
#
#     <div id="mod-akmysubs-99" class="mod-akmysubs">
# 	<div id="akeeba-renderer-fef" class="akeeba-renderer-fef ">
#
#
# <div id="akeebasubs" class="subscriptions">
# 	<h2 class="pageTitle">My Subscriptions</h2>
#
#         <div class="alert alert-warning">
#         <h3>
#             WARNING: Dates and times below are not displayed in your time zone.        </h3>
#         <p>
# 	        The subscription activation and expiration dates and times below are displayed in the UTC time zone, i.e. the default timezone of our site. Please go to your <a href=/index.php/component/users/?task=profile.edit&amp;user_id=893&amp;Itemid=101&returnurl=L2luZGV4LnBocC9jb21wb25lbnQvYWtlZWJhc3Vicy9zdWJzY3JpcHRpb25z>user profile edit page</a>, select your time zone, scroll all the way down and click on Submit for this message to go away.        </p>
#     </div>
#
# 	<form action="http://www.steamerprojections.com/index.php/projections/2024-projections" method="post" class="adminform" name="adminForm" id="adminForm">
# 	<input type="hidden" name="4ed6438f4c7f3cd6c40ea2f172e5e422" value="1" />
#
# 	<table class="akeeba-table--striped" width="100%">
# 		<thead>
# 			<tr>
# 				<th width="40px">
# 					ID				</th>
# 							<th width="100px">
# 					Level				</th>
# 				<th width="60px">
# 					Payment				</th>
# 				<th width="80px">
# 					Valid From				</th>
# 				<th width="80px">
# 					Valid To				</th>
# 				<th width="40px">
# 					Active				</th>
# 				<th>
# 					Actions				</th>
# 			</tr>
# 		</thead>
#
# 		<tfoot>
# 			<tr>
# 				<td colspan="20">
#
# <div class="pagination pagination-toolbar clearfix" style="text-align: center;">
#
# 			<div class="limit pull-right">
# 			Display #<select id="limit" name="limit" class="inputbox input-mini" size="1" onchange="this.form.submit()">
# 	<option value="5">5</option>
# 	<option value="10">10</option>
# 	<option value="15">15</option>
# 	<option value="20">20</option>
# 	<option value="25">25</option>
# 	<option value="30">30</option>
# 	<option value="50">50</option>
# 	<option value="100">100</option>
# 	<option value="0" selected="selected">All</option>
# </select>
# 		</div>
#
#
# 			<input type="hidden" name="limitstart" value="0" />
#
# </div>
# 				</td>
# 			</tr>
# 		</tfoot>
#
# 		<tbody>
#
# 									<tr>
# 				<td colspan="8">
# 					<h4>Active</h4>
# 				</td>
# 			</tr>
# 												<tr class="row0 ">
# 				<td align="left">
# 					00704				</td>
# 							<td>
# 										Member									</td>
# 				<td>
# 					Completed				</td>
# 				<td>
# 										12-22-2023 11:32									</td>
# 				<td>
# 										12-21-2024 11:32									</td>
# 				<td align="center">
# 										<span class="akion-checkmark" title="Active"></span>
#
# 						            </td>
# 	            <td>
# 					<a class="akeeba-btn--small--info" href="/index.php/component/akeebasubs/subscription/704?returnurl=aHR0cDovL3d3dy5zdGVhbWVycHJvamVjdGlvbnMuY29tL2luZGV4LnBocC9wcm9qZWN0aW9ucy8yMDI0LXByb2plY3Rpb25z">
# 						View details					</a>
#
#
# 						            		            	<a class="akeeba-btn--small--green" href="/index.php/component/akeebasubs/new/member">
# 	            		Renew	            	</a>
#
# 		            		            <a class="akeeba-btn--small--red" href="/index.php/component/akeebasubs/callback?task=cancel&amp;paymentmethod=paypal&amp;sid=704">
# 			            Cancel recurring		            </a>
# 		            	            </td>
# 			</tr>
# 																		<tr>
# 				<td colspan="8">
# 					<h4>Expired</h4>
# 				</td>
# 			</tr>
# 									<tr class="row1 expired">
# 				<td align="left">
# 					00916				</td>
# 							<td>
# 										Member									</td>
# 				<td>
# 					Completed				</td>
# 				<td>
# 										12-22-2022 22:24									</td>
# 				<td>
# 										12-22-2023 11:32									</td>
# 				<td align="center">
# 											<span class="akion-close" title="Inactive"></span>
# 						            </td>
# 	            <td>
# 					<a class="akeeba-btn--small--info" href="/index.php/component/akeebasubs/subscription/916?returnurl=aHR0cDovL3d3dy5zdGVhbWVycHJvamVjdGlvbnMuY29tL2luZGV4LnBocC9wcm9qZWN0aW9ucy8yMDI0LXByb2plY3Rpb25z">
# 						View details					</a>
#
#
# 						            		            	<a class="akeeba-btn--small--green" href="/index.php/component/akeebasubs/new/member">
# 	            		Renew	            	</a>
#
# 		            		            <a class="akeeba-btn--small--red" href="/index.php/component/akeebasubs/callback?task=cancel&amp;paymentmethod=paypal&amp;sid=916">
# 			            Cancel recurring		            </a>
# 		            	            </td>
# 			</tr>
# 														</tbody>
#
# 	</table>
# 	</form>
# </div>
# </div>
# </div>
#
# </div>
# </div></div>
# </aside>
#
#
#                     </div>
#
#                 </div>
#             </div>
#
#
#
#
# <div class="uk-section-default uk-section" uk-scrollspy="target: [uk-scrollspy-class]; cls: uk-animation-fade; delay: false;">
#
#
#
#
#
#             <div class="uk-container"><div class="uk-grid-margin" uk-grid>
# <div class="uk-width-expand@m">
#
#
#
#
#
# <div class="uk-panel uk-text-left" uk-scrollspy-class>
#
#
# <ul class="uk-subnav">
#     <li><a href="/index.php/login">Login</a></li><li><a href="/index.php/privacy-policy">Privacy Policy</a></li><li><a href="/index.php/new-member/new">Sign Up</a></li><li><a href="/index.php/free/new">Free Access</a></li></ul>
#
# </div>
#
#
#
#
# </div>
#
# <div class="uk-width-expand@m">
#
#
#
#
#
#
#
#
# </div>
# </div><div class="uk-grid-margin" uk-grid>
# <div class="uk-width-1-1@m">
#
#
#
#
#                 <div class="uk-text-small uk-margin-small uk-text-left@m uk-text-center" uk-scrollspy-class>Copyright © 2019 All Rights Reserved</div><div class="uk-text-small uk-text-muted uk-margin-small uk-margin-remove-top uk-text-left@m uk-text-center" uk-scrollspy-class="uk-animation-slide-bottom-medium">Designed & Developed by <a href="https://www.themicrotechs.org">The Microtechs</a></div>
#
#
#
# </div>
# </div></div>
#
#
#
# </div>
#
#         </div>
#
#
#
#
#     </body>
# </html>
#
# /index.php/projections/2024-projections?task=callelement&amp;format=raw&amp;item_id=1167&amp;element=2331b84b-d95c-470d-89ef-f458ce60ad9a&amp;method=download&amp;args[0]=0.0&amp;args[1]=13825866a924a340bd19ef435d98bbd6
# True

# %%
time.sleep(5)

# %%
copy_page_source('http://www.steamerprojections.com/index.php/projections/historical-weekly-logs')
webbrowser.open("http:www.steamerprojections.com" + find_url_after_text("Pitchers, 2014-present, weekly in-season log", pyperclip.paste()))
webbrowser.open("http:www.steamerprojections.com" + find_url_after_text("Hitters, 2014-present, weekly in-season log", pyperclip.paste()))
# Out:
# True

# %% [markdown]
# ### A07. Projections

# %%
# %run "C:\Users\james\Documents\MLB\Code\A07. Projections.ipynb"

# %%
# Scrape slates
dff_slates_df = dff_slates(todaysdate)
# To csv
dff_slates_df.to_csv(os.path.join(baseball_path, "A07. Projections", "1. DFF", "1. Slates", f"DFF Slates {todaysdate}.csv"), index=False)

# %%
# Scrape slates
roto_slates_df = roto_slates(todaysdate)
# To csv
roto_slates_df.to_csv(os.path.join(baseball_path, "A07. Projections", "2. RotoWire", "1. Slates", f"RotoWire Slates {todaysdate}.csv"), index=False)

# %% [markdown]
# ### A10. Player Results

# %%
# %run "C:\Users\james\Documents\MLB\Code\A10. Player Results.ipynb"

# %% [markdown]
# Note: This will break if there were no games yesterday.

# %%
# %%time
for i in range(len(game_df)):
    run_result_dfs(i)
# Out:
# 746477
# 746481
# 747047
# 746073
# 744942
# 745831
# 746968
# 746806
# 745997
# 745018
# 746398
# 746239
# 747210
# 745673
# 745426
# 745260
# CPU times: total: 9.78 s
# Wall time: 15.4 s

# %% [markdown]
# ### A05. Rosters

# %% [markdown]
# Note: This should fix incorrect or missing information from yesterday.

# %%
# %run "C:\Users\james\Documents\MLB\Code\A05. Rosters.ipynb"

# %% [markdown]
# ##### 1. Batting Orders

# %%
# Run in parallel
empty_list = Parallel(n_jobs=-1, verbose=0)(delayed(orders)(team_map, game_df, row) for row in range(len(game_df)))

# %% [markdown]
# ##### 2. Rosters

# %%
# Run in parallel
empty_list = Parallel(n_jobs=-1, verbose=0)(delayed(rosters)(team_map, game_df, row) for row in range(len(game_df)))

# %% [markdown]
# ### A06. Weather

# %%
# %run "C:\Users\james\Documents\MLB\Code\A06. Weather.ipynb"

# %%
daily_weather_df = park_and_weather_factors(game_df, date=yesterdaysdate, overwrite_year=2023)

# To csv
daily_weather_df.to_csv(os.path.join(baseball_path, "A06. Weather", "4. Park and Weather Factors", f'Park and Weather Factors {yesterdaysdate}.csv'), index=False)
# Out:
# 20240430

# %% [markdown]
# ### A09. Contest Guides

# %%
# %run "C:\Users\james\Documents\MLB\Code\A09. Contest Guides.ipynb"

# %%
# Loop over contestKeys
yesterdays_subset_df = yesterdays_subset_df.reset_index(drop=True)

for contestKey in yesterdays_subset_df['contestKey'].reset_index(drop=True):
    print(contestKey)
    try:
        guide = contest_guide(game_df, subset_df=yesterdays_subset_df, contestKey=contestKey)
        if not guide.empty:
            guide.to_csv(os.path.join(baseball_path, "A09. Contest Guides", f"Contest Guide {contestKey}.csv"), index=False)
        else:
            print(f"Contest Guide {contestKey} is empty.")
    except FileNotFoundError as e:
        print(f"Draftables {contestKey}.csv not found.")
# Out:
# 161050365
# Draftables 161050365.csv not found.
# 161050364
# Draftables 161050364.csv not found.
# 161050363
# Draftables 161050363.csv not found.
# 161050360
# Draftables 161050360.csv not found.
# 161050361
# Draftables 161050361.csv not found.
# 161050073
# Draftables 161050073.csv not found.
# 161050069
# Draftables 161050069.csv not found.
# 161051762
# Draftables 161051762.csv not found.
# 161051189
# Draftables 161051189.csv not found.
# 161050070
# Draftables 161050070.csv not found.
# 161050092
# 161050095
# 161050093
# 161050098
# 161050090
# 161050062
# 161050063
# 161050066
# 161051166
# 161051673
# 161050439
# Draftables 161050439.csv not found.
# 161050438
# Draftables 161050438.csv not found.
# 161050435
# Draftables 161050435.csv not found.
# 161050437
# Draftables 161050437.csv not found.
# 161050436
# Draftables 161050436.csv not found.
# 161050039
# Draftables 161050039.csv not found.
# 161050040
# Draftables 161050040.csv not found.
# 161050041
# Draftables 161050041.csv not found.
# 161050038
# Draftables 161050038.csv not found.
# 161051495
# Draftables 161051495.csv not found.
# 161050342
# Draftables 161050342.csv not found.
# 161050341
# Draftables 161050341.csv not found.
# 161050340
# Draftables 161050340.csv not found.
# 161050337
# Draftables 161050337.csv not found.
# 161050338
# Draftables 161050338.csv not found.
# 161050027
# 161050024
# 161050033
# 161050032
# 161050028
# 161058284
# 161058285
# 161050117
# 161050118
# 161050129
# 161050119

# %% [markdown]
# ### B01. Matchups

# %% [markdown]
# Note: This should fix incorrect or missing information from yesterday.

# %%
# %run "C:\Users\james\Documents\MLB\Code\A02. MLB API.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\A03. Steamer.ipynb"
# %run "C:\Users\james\Documents\MLB\Code\B01. Matchups.ipynb"

# %%
# %%time
# Read in dataset 
complete_dataset = create_pa_inputs(park_factors, team_map, 2015, 2024, 50, 300)
# Subset
complete_dataset = complete_dataset.query('date > 20220301')

# Read in Steamer hitters
steamer_hitters_df = pd.read_csv(os.path.join(baseball_path, "A03. Steamer", "steamer_hitters_weekly_log.csv"), encoding='iso-8859-1')
steamer_hitters_df_current = pd.read_csv(os.path.join(baseball_path, "A03. Steamer", "steamer_hitters.csv"), encoding='iso-8859-1')
steamer_hitters_df = pd.concat([steamer_hitters_df, steamer_hitters_df_current], axis=0)
steamer_hitters_df['proj_year'].fillna(2024, inplace=True)
steamer_hitters_df['proj_date'].fillna(todaysdate_dash, inplace=True)
steamer_hitters_df = clean_steamer_hitters(steamer_hitters_df)

# Read in Steamer pitchers
steamer_pitchers_df = pd.read_csv(os.path.join(baseball_path, "A03. Steamer", "steamer_pitchers_weekly_log.csv"), encoding='iso-8859-1')
steamer_pitchers_df_current = pd.read_csv(os.path.join(baseball_path, "A03. Steamer", "steamer_pitchers.csv"), encoding='iso-8859-1')
steamer_pitchers_df = pd.concat([steamer_pitchers_df, steamer_pitchers_df_current], axis=0)
steamer_pitchers_df['proj_year'].fillna(2024, inplace=True)
steamer_pitchers_df['proj_date'].fillna(todaysdate_dash, inplace=True)
steamer_pitchers_df = clean_steamer_pitchers(steamer_pitchers_df)
# Out:
# CPU times: total: 2min 41s
# Wall time: 2min 46s

# %%
# Write to CSV (we'll read these later in B.)
complete_dataset.to_csv(os.path.join(baseball_path, "Stat Dataset.csv"), index=False)
steamer_hitters_df.to_csv(os.path.join(baseball_path, "Steamer Hitters.csv"), index=False)
steamer_pitchers_df.to_csv(os.path.join(baseball_path, "Steamer Pitchers.csv"), index=False)

# %%
# %%time
print(len(game_df))
empty_list = Parallel(n_jobs=-1, verbose=True)(delayed(create_matchup_files)(game_df, row, complete_dataset, steamer_hitters_df, steamer_pitchers_df, team_map) for row in range(len(game_df)))
# Out:
# 16
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  16 | elapsed:   18.1s remaining:  2.1min
# [Parallel(n_jobs=-1)]: Done  16 out of  16 | elapsed:   59.8s finished
# CPU times: total: 46.8 s
# Wall time: 1min

# %% [markdown]
# ### A08. Odds Sportsbook Review

# %%
# %run "C:\Users\james\Documents\MLB\Code\A08. Odds Sportsbook Review.ipynb"

# %%
# Scrape odds from Sportsbook Review
odds_df = create_odds_df(yesterdaysdate_dash)

# Save 
odds_df.to_csv(os.path.join(baseball_path, "A08. Odds Sportsbook Review", f"Odds {yesterdaysdate}.csv"), index=False)

# %% [markdown]
# ### A03. Steamer

# %% [markdown]
# Files were downloaded above. This should give them enough time to finish downloading.

# %%
move_steamer()
# Out:
# Moved 'C:\Users\james\Downloads\steamer_pitchers_weekly_log.csv' to 'C:\Users\james\Documents\MLB\Database\A03. Steamer'.
# Moved 'C:\Users\james\Downloads\steamer_hitters_weekly_log.csv' to 'C:\Users\james\Documents\MLB\Database\A03. Steamer'.
# Moved 'C:\Users\james\Downloads\steamer_pitchers.csv' to 'C:\Users\james\Documents\MLB\Database\A03. Steamer'.
# Moved 'C:\Users\james\Downloads\steamer_hitters.csv' to 'C:\Users\james\Documents\MLB\Database\A03. Steamer'.
